# %% [markdown]
# # Showing possible IDs in PathwayCommons
#
# From a list of entities, we go through their `bp:xref` references. Then we search for their `bp:id` and `bp:db` to show wich database the ID refers to. Then we sort database on the number of ID they have for a list of sample genes.

# %%
from typing import List, Any

from IPython.display import display, Markdown, Latex
from rdflib import Graph, RDF, RDFS, Namespace
from SPARQLWrapper import SPARQLWrapper, JSON
from string import Template

import operator

import networkx as nx
import matplotlib.pyplot as plt
#from nxpd import draw

import requests
import json
import io
import time
import csv

INPUT_GENES = ['JUN/FOS', 'SCN5A']

SPARQL_ENDPOINT = "http://rdf.pathwaycommons.org/sparql"  # type: str

def read_input_genes(filename):
    res = []
    with open(filename, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=' ', quotechar='|')
        for row in reader:
            res.append(''.join(row))
    return res

# %%
input_genes = read_input_genes('/Users/gaignard-a/Documents/Dev/BRAvo/nathalie-TF.csv')

dbs = {}

cache_ids = {}

cpt = 1

for gene in input_genes:
#    if ((cpt % 50) == 0):
#        break 
        
    print('processing '+gene)
    cpt += 1
    
    query = """
PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 

SELECT DISTINCT ?name ?id ?db WHERE {
    
    # ?participant bp:displayName ?name ;
        bp:xref ?xref .
    # ?xref bp:id ?id ; 
        bp:db ?db .

    FILTER ( ?name = \"""" + gene + """\"^^xsd:string )
} 
"""
    #print(query)
    
    sparql = SPARQLWrapper(SPARQL_ENDPOINT)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
          
    for result in results["results"]["bindings"]:
        name, ident, db = result["name"]["value"], result["id"]["value"], result["db"]["value"]
        
        if name not in cache_ids.keys():
            cache_ids[name] = [(ident, db)]
        else: 
            cache_ids[name].append((ident, db))
        
        if db not in dbs.keys():
            dbs[db] = 1
        else: 
            dbs[db] +=1 

print()
cpt = 1
for key in cache_ids.keys():
    if ((cpt % 10) == 0):
        break
    print(key + " : "+str(cache_ids[key]))
    print()
    cpt += 1
            

sorted_dbs = reversed(sorted(dbs.items(), key=lambda x: x[1]))            
md = """
| Database | number of identifiers |
|----------|-----------------------|
"""
for i in sorted_dbs:
    md += "|"+i[0]+"|"+str(i[1])+"|\n"

display(Markdown(md))
# Out:
# processing IRX5
# processing SCN3A
# processing SCN5A
# processing SCN9A
# processing KCNA2
# processing HCN3
# processing IRX4
# processing SBSPON
# processing ALB
# processing NMU
# processing ST7L
# processing MYCN
# processing RBP7
# processing MEG3
# processing RDH10
# processing TDRD1
# processing TM2D2
# processing BMP3
# processing DPAGT1
# processing PAGE4
# processing PRKCB
# processing ENTPD5
# processing GSS
# processing HSPA8
# processing NCCRP1
# processing TMEM178A
# processing COX7A1
# processing DUSP14
# processing PYM1
# processing TUBB
# processing NPR3
# processing APOM
# processing SLC35A4
# processing CES1
# processing KDM1B
# processing KIF13A
# processing FAM47E
# processing MAGOHB
# processing NECAB1
# processing SCAMP2
# processing FRMD4B
# processing BTBD1
# processing PSMC5
# processing SPOCK1
# processing POP4
# processing RASSF3
# processing CCT5
# processing COL2A1
# processing TMBIM6
# processing CPXM1
# processing CTPS1
# processing PLA2G12A
# processing APLP1
# processing PMP22
# processing ANO5
# processing DAXX
# processing HEY2
# processing NAGK
# processing TYW1B
# processing SMTNL2
# processing REC8
# processing CTSA
# processing MAPRE1
# processing C3orf14
# processing NQO1
# processing TPM3
# processing GAB1
# processing TMEM230
# processing TUB
# processing TMX2
# processing C22orf39
# processing FGL1
# processing GLIS2
# processing PSMD11
# processing SH3KBP1
# processing STIP1
# processing VEGFB
# processing ICAM4
# processing UGT2B4
# processing AMBP
# processing SST
# processing TCP1
# processing RPN2
# processing TMEM151A
# processing PIN4
# processing TMEM179B
# processing METTL1
# processing TNFRSF21
# processing B4GALT3
# processing RNF216P1
# processing CDCA7L
# processing SNF8
# processing UFD1L
# processing LGALS1
# processing GBAS
# processing PWWP2A
# processing RPAP1
# processing ATP1A2
# processing EXTL3
# processing RAB37
# processing LEPR
# processing ARL4A
# processing PPP1R11
# processing PTGS1
# processing FBXO32
# processing SCAMP3
# processing APOC1P1
# processing GC
# processing ABCF3
# processing CD52
# processing ARPC4
# processing DDX39A
# processing SERPINA6
# processing TUSC3
# processing ZNF507
# processing YWHAZ
# processing FOS
# processing PBX3
# processing COL9A3
# processing ALDH1A1
# processing BICDL1
# processing MMP11
# processing RPL13
# processing CLDN11
# processing PTCHD4
# processing AES
# processing ARL5A
# processing HLA-DRB5
# processing KLK10
# processing MCRS1
# processing BHMT
# processing ID4
# processing OGFOD1
# processing SORD
# processing CD68
# processing CPSF6
# processing CRYBB1
# processing FKBP5
# processing GAL3ST3
# processing NCKAP5L
# processing PPP1R1C
# processing QKI
# processing RHOA
# processing SPOCK2
# processing UMPS
# processing UNC5B
# processing USF1
# processing XRCC6
# processing ACTA2
# processing PTPRU
# processing EDF1
# processing IDH1
# processing SLC39A10
# processing APOC1
# processing GGCX
# processing GSTO2
# processing HCN4
# processing LGMN
# processing MAPK1IP1L
# processing NME6
# processing TMX4
# processing UFC1
# processing TNMD
# processing PDGFD
# processing MTX1
# processing NDUFS2
# processing EFNB3
# processing POLR2G
# processing SNX7
# processing STX11
# processing CDCP1
# processing LMAN2L
# processing TET1
# processing WNT2B
# processing MPHOSPH6
# processing DNAAF2
# processing PIGT
# processing PPM1K
# processing MSH6
# processing CERK
# processing HMGB3
# processing TYW3
# processing AKR1C3
# processing ZNF483
# processing GLMP
# processing BMS1P20
# processing HOPX
# processing METTL7B
# processing MOXD1
# processing PIGC
# processing TERF1
# processing WARS
# processing COL13A1
# processing ACAP1
# processing CDC25B
# processing INAFM2
# processing VIL1
# processing PSMC3
# processing EIF3F
# processing ATF6B
# processing EPB41L4A-AS1
# processing SDHC
# processing AP2S1
# processing C14orf37
# processing HVCN1
# processing JMY
# processing MPHOSPH10
# processing NOC3L
# processing OXR1
# processing RFXANK
# processing PSMC4
# processing ARHGEF26
# processing EIF5B
# processing PPA1
# processing ZCCHC24
# processing ACTR1B
# processing IKBKAP
# processing SLC31A1
# processing TMEM108
# processing TRIM36
# processing GJA5
# processing UNC5B-AS1
# processing RRAD
# processing ELOVL1
# processing RAB24
# processing BCAP31
# processing COA3
# processing COL15A1
# processing RNF4
# processing DPP3
# processing CAP1
# processing ACSS3
# processing CHCHD10
# processing PDCL3
# processing PEX6
# processing SPTSSB
# processing TMEM126A
# processing RBM8A
# processing LCP1
# processing LOC105370333
# processing THAP11
# processing GPATCH4
# processing MYO5B
# processing CHMP4A
# processing KCNQ1
# processing TUBA1C
# processing KRTCAP2
# processing TP53I3
# processing RPS2
# processing SPAG9
# processing FAM69B
# processing GRPEL1
# processing PSEN1
# processing SH3BGRL3
# processing ZDHHC6
# processing ZDHHC9
# processing DOK4
# processing ASTN1
# processing CMTR2
# processing SULT1E1
# processing THOC1
# processing WT1
# processing ZSCAN18
# processing ADD2
# processing DLG1
# processing UBB
# processing NUTM2B-AS1
# processing PPIL1
# processing ZBTB4
# processing AEBP1
# processing MRPL54
# processing NECAP1
# processing NSA2
# processing TBL1XR1
# processing ZNF410
# processing ZNF254
# processing VASH1
# processing MRPS10
# processing SEC11C
# processing POLR2L
# processing IGFBP5
# processing ETV1
# processing PPP2R1A
# processing LOC403323
# processing LRRC20
# processing MOB1B
# processing POLR3C
# processing AHSG
# processing PINLYP
# processing SLC25A36
# processing WBSCR22
# processing ATP6V0D1
# processing MED6
# processing NCSTN
# processing UGT8
# processing UNC50
# processing NEO1
# processing HEBP1
# processing NEK7
# processing TGIF2
# processing TECR
# processing BCAS2
# processing C1S
# processing CXCL3
# processing DAAM1
# processing DDRGK1
# processing EMC3
# processing HARS
# processing LAMTOR2
# processing MAP4K3
# processing SMDT1
# processing SOCS2
# processing SPRY1
# processing TMTC1
# processing CFAP20
# processing ORAI1
# processing PPP2R1B
# processing STK26
# processing KLHL24
# processing ABCF2
# processing ADAMTS12
# processing C2orf40
# processing DHRS7B
# processing STT3A
# processing TBX18
# processing UBE2L3
# processing FAM110C
# processing VRK3
# processing ACAA2
# processing CSTB
# processing TUBA1A
# processing TMEM87A
# processing GGPS1
# processing KLHL42
# processing TRPV2
# processing METTL17
# processing RSRP1
# processing COMMD4
# processing DNM1
# processing SLC5A6
# processing RARRES2
# processing RFX7
# processing SUGT1
# processing WASF1
# processing ATP6V0B
# processing DEPDC1
# processing NEDD9
# processing MARS
# processing CUL4B
# processing GALE
# processing SDF2
# processing ZNF558
# processing STEAP1
# processing TBX5
# processing KCNN3
# processing POLR2J
# processing TALDO1
# processing GRK5
# processing MAN1A2
# processing LRPPRC
# processing TECRL
# processing UBE2E2
# processing ALDH1A2
# processing COL26A1
# processing EIF4A3
# processing NAP1L1
# processing CIDECP
# processing TPT1
# processing EXOSC10
# processing HN1
# processing HERC6
# processing MKRN1
# processing CHD1L
# processing FAM150B
# processing PPARGC1B
# processing SHMT2
# processing DZIP1
# processing RGL2
# processing KIAA1161
# processing SLC35A5
# processing PSMD9
# processing CALB2
# processing RAPGEFL1
# processing FDPSP2
# processing EIF4E2
# processing PAX6
# processing CD63
# processing RAMP2
# processing GLTSCR2
# processing HUS1
# processing MRTO4
# processing ZNF746
# processing KLHDC3
# processing PTGIS
# processing LRAT
# processing THNSL2
# processing MTHFD1
#
# MCRS1 : [('10445', 'ncbi gene'), ('MCRS1', 'hgnc symbol'), ('HGNC:6960', 'hgnc'), ('Q96EZ8', 'uniprot'), ('R-HSA-3321849', 'reactome')]
#
# APOC1 : [('HGNC:607', 'hgnc'), ('P02654', 'uniprot'), ('R-HSA-8855541', 'reactome'), ('341', 'ncbi gene'), ('APOC1', 'hgnc symbol')]
#
# AMBP : [('187937114', 'genbank indentifier'), ('31541901', 'genbank indentifier'), ('259', 'ncbi gene'), ('176870', 'omim'), ('NM_001633', 'refseq'), ('AMBP', 'hgnc symbol'), ('P02760', 'uniprot'), ('HGNC:453', 'hgnc'), ('R-HSA-2203514', 'reactome'), ('R-HSA-2168853', 'reactome'), ('R-HSA-2168855', 'reactome'), ('P02760', 'uniprot knowledgebase')]
#
# GGCX : [('ENSP00000233838', 'ensembl'), ('4247', 'hgnc'), ('137167', 'omim'), ('NM_001311312', 'refseq'), ('XM_005264259', 'refseq'), ('XM_011532764', 'refseq'), ('XM_011532765', 'refseq'), ('B4DMC5', 'uniprot knowledgebase'), ('Q14415', 'uniprot knowledgebase'), ('P38435', 'uniprot knowledgebase'), ('XP_011531066', 'refseq'), ('2677', 'ncbi gene'), ('GGCX', 'hgnc symbol'), ('P38435', 'uniprot'), ('00665', 'hprd'), ('E9PEE1', 'uniprot knowledgebase'), ('NM_001142269', 'refseq'), ('HGNC:4247', 'hgnc'), ('214010147', 'genbank indentifier'), ('R-HSA-159860', 'reactome'), ('NM_000821', 'refseq'), ('52851441', 'genbank indentifier'), ('Q6GU45', 'uniprot knowledgebase'), ('108945', 'biogrid'), ('XM_017003803', 'refseq')]
#
# LRRC20 : [('Q8TCA0', 'uniprot'), ('55222', 'ncbi gene'), ('HGNC:23421', 'hgnc'), ('LRRC20', 'hgnc symbol')]
#
# RRAD : [('6236', 'ncbi gene'), ('HGNC:10446', 'hgnc'), ('RRAD', 'hgnc symbol'), ('P55042', 'uniprot')]
#
# ACSS3 : [('Q9H6R3', 'uniprot'), ('79611', 'ncbi gene'), ('HGNC:24723', 'hgnc'), ('ACSS3', 'hgnc symbol'), ('R-HSA-5696385', 'reactome')]
#
# PBX3 : [('P40426', 'uniprot knowledgebase'), ('111123', 'biogrid'), ('ENSP00000341990', 'ensembl'), ('ENSP00000387456', 'ensembl'), ('5090', 'ncbi gene'), ('8634', 'hgnc'), ('15938', 'hprd'), ('176312', 'omim'), ('NM_001134778', 'refseq'), ('NM_006195', 'refseq'), ('XM_006717130', 'refseq'), ('XM_006717131', 'refseq'), ('XM_006717132', 'refseq'), ('XM_006717133', 'refseq'), ('E9PB27', 'uniprot knowledgebase'), ('Q5JSA0', 'uniprot knowledgebase'), ('Q5JSA1', 'uniprot knowledgebase'), ('Q5VXL3', 'uniprot knowledgebase'), ('Q96PF9', 'uniprot knowledgebase'), ('Q96PG0', 'uniprot knowledgebase'), ('Q5JS98', 'uniprot knowledgebase'), ('Q96AL5', 'uniprot knowledgebase'), ('XP_006717196', 'refseq'), ('P40426', 'uniprot'), ('ENSP00000362586', 'ensembl'), ('ENSP00000362588', 'ensembl'), ('HGNC:8634', 'hgnc'), ('PBX3', 'hgnc symbol')]
#
# TUBB : [('203068', 'ncbi gene'), ('B4DMJ5', 'uniprot knowledgebase'), ('B4DQN9', 'uniprot knowledgebase'), ('B4DY90', 'uniprot knowledgebase'), ('191130', 'omim'), ('ENSBTAP00000043991', 'ensembl'), ('533307', 'ncbi gene'), ('XM_002698780', 'refseq'), ('XM_612678', 'refseq'), ('E1B953', 'uniprot knowledgebase'), ('XP_002698826', 'refseq'), ('P99024', 'uniprot knowledgebase'), ('542712', 'biogrid'), ('NP_001040014', 'refseq'), ('P07437', 'uniprot knowledgebase'), ('NP_001280145', 'refseq'), ('R-HSA-6799370', 'reactome'), ('189906', 'biogrid'), ('A5D9A3', 'uniprot knowledgebase'), ('Q2KJD0', 'uniprot knowledgebase'), ('NP_821133', 'refseq'), ('NM_001046549', 'refseq'), ('P07437', 'uniprot'), ('NP_001280141', 'refseq'), ('ENSBTAP00000009158', 'ensembl'), ('128444', 'biogrid'), ('ENSP00000339001', 'ensembl'), ('20778', 'hgnc'), ('NM_001293212', 'refseq'), ('NM_001293213', 'refseq'), ('NM_001293214', 'refseq'), ('NM_001293215', 'refseq'), ('NM_001293216', 'refseq'), ('NM_178014', 'refseq'), ('NP_001280142', 'refseq'), ('NP_001280143', 'refseq'), ('NP_001280144', 'refseq'), ('P05218', 'uniprot knowledgebase'), ('Q8WUC1', 'uniprot knowledgebase'), ('Q9CY33', 'uniprot knowledgebase'), ('Q5ST81', 'uniprot knowledgebase'), ('Q5SU16', 'uniprot knowledgebase'), ('R-HSA-380317', 'reactome'), ('P69897', 'uniprot knowledgebase'), ('XM_005223680', 'refseq'), ('615087', 'ncbi gene'), ('HGNC:20778', 'hgnc'), ('TUBB', 'hgnc symbol')]
# | Database | number of identifiers |
# |----------|-----------------------|
# |refseq|1156|
# |uniprot knowledgebase|989|
# |hgnc|438|
# |reactome|396|
# |ncbi gene|347|
# |hgnc symbol|303|
# |uniprot|302|
# |ensembl|260|
# |biogrid|162|
# |omim|160|
# |hprd|141|
# |genbank indentifier|99|
# |inoh|26|
# |http://www.inoh.org (moleculeroleontology)|24|
# |molecular interactions ontology|9|
# |kegg genes|5|
# |panther pathway component|4|
# |sgd|4|
# |protein data bank|2|
# |database of interacting proteins|2|
# |tair|1|
# |uniprot isoform|1|
# |nucleotide sequence database|1|
