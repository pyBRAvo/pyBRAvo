# %% [markdown]
# # Upstream regulation network reconstruction, with synonym expansion, and network summarization (based on standard names)
#
# The following code defines the main parameter and data considered as input:
# - SPARQL_ENDPOINT : the main PathwayCommons (PC) SPARQL endpoint
# - CHUNKS_SIZE : the number of genes to be processed within each PC query
# - MAX_DEPTH : the maximum depth of exploration, can be null to explore the full regulation graph
# - DATA_SOURCES : used to limit the data source to be explored. Must be a list of values from : bind, biogrid, corum, ctd, dip, drugbank, hprd, humancyc, inoh, intact, kegg, mirtarbase, netpath, panther, pid, psp, reactome, reconx, smpdb, wp, intact_complex, msigdb.

# %%
from typing import List, Any

from IPython.display import display, Markdown, Latex
from rdflib import Graph, RDF, RDFS, Namespace
from SPARQLWrapper import SPARQLWrapper, JSON
from string import Template

import networkx as nx
import matplotlib.pyplot as plt
#from nxpd import draw

import requests
import json
import io
import time
import csv

INPUT_GENES = ['JUN/FOS', 'SCN5A']

SPARQL_ENDPOINT = "http://rdf.pathwaycommons.org/sparql"  # type: str
CHUNKS_SIZE = 20  # type: int
MAX_DEPTH = 2 # type: int
SKIP_SMALL_MOLECULES = True # type: Boolean
DATA_SOURCES = ['pid', 'humancyc', 'panther', 'msigdb']
#DATA_SOURCES = []  # type: List[str]

HAS_MAX_DEPTH = False
try:
  MAX_DEPTH
except NameError:
  HAS_MAX_DEPTH = False
else:
  HAS_MAX_DEPTH = True

HAS_DATA_SOURCES = False
try:
  DATA_SOURCES
except NameError:
  HAS_DATA_SOURCES = False
else:
  HAS_DATA_SOURCES = True

# %%
def init_gene_synonyms_cache():
    cache = []
    with open('Homo_sapiens.gene_info', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter='\t', quotechar='|')
        for row in reader:
            entry = {'key':row[2], 'synonym':row[4].split('|')}
            cache.append(entry)
    return cache

def init_gene_synonyms_cache_v2():
    index_syn = {}
    index_std = {}
    with open('Homo_sapiens.gene_info', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter='\t', quotechar='|')
        for row in reader:
            index_std[row[2]] = row[4].split('|')
            
            index_syn[row[2]] = row[2]
            for syn in row[4].split('|'):
                index_syn[syn] = row[2]
    return index_std, index_syn

cache = init_gene_synonyms_cache()

print('--- Memory foot print cache v1 ---')
s = 0
for e in cache:
    s += 1 + len(e['synonym'])
print('Cache size : '+str(s))

print('--- Memory foot print cache v2 ---')
index_std, index_syn = init_gene_synonyms_cache_v2()
print('index_syn size : ' + str(len(index_syn.keys()) * 2))
s = 0
for key, value in index_std.items():
    s += 1 + len(value)
print('index_std size : ' + str(s))
# Out:
# --- Memory foot print cache v1 ---
# Cache size : 161857
# --- Memory foot print cache v2 ---
# index_syn size : 244398
# index_std size : 161611

# %%
def are_synonyms(n, m, syn_cache):
    for entry in syn_cache:
        all_possible_names = entry['synonym'] + [entry['key']]
        if (n in all_possible_names) and (m in all_possible_names):
            return True
    return False

def get_synonyms(n, syn_cache):
    all_possible_names = []
    for entry in syn_cache:
        all_possible_names = entry['synonym'] + [entry['key']]
        if (n in all_possible_names):
            all_possible_names.remove(n)
            return all_possible_names
    return all_possible_names

def get_std_name(n, syn_cache):
    for entry in syn_cache:
        all_possible_names = entry['synonym'] + [entry['key']]
        if (n in all_possible_names):
            return entry['key']
        
start = time.time()
print('ABG has for synonyms: ' + str(get_synonyms('ABG', cache)))
print('ABG has for standard name: ' + str(get_std_name('ABG', cache)))
elapsed = time.time() - start
print('Time = ' + str(elapsed))
# Out:
# ABG has for synonyms: ['A1B', 'GAB', 'HYST2477', 'A1BG']
# ABG has for standard name: A1BG
# Time = 0.0005500316619873047

# %%
def fast_get_std_name(n, index_syn):
    return index_syn[n]

def fast_get_synonyms(n, index_std, index_syn):
    std = index_syn[n]
    synonyms = index_std[std]
    all_names = []
    all_names = [std] + synonyms
    all_names.remove(n) 
    return all_names

def fast_are_synonyms(n, m, index_syn):
    try:
        index_syn[n]
    except:
        return False
    try:
        index_syn[m]
    except:
        return False
    return (index_syn[n] == index_syn[m])

start = time.time()
print('ABG has for synonyms: ' + str(fast_get_synonyms('ABG', index_std=index_std, index_syn=index_syn)))
print('ABG has for standard name: ' + str(fast_get_std_name('ABG', index_syn=index_syn)))
elapsed = time.time() - start
print('Time = ' + str(elapsed))
# Out:
# ABG has for synonyms: ['A1BG', 'A1B', 'GAB', 'HYST2477']
# ABG has for standard name: A1BG
# Time = 0.0003669261932373047

# %% [markdown]
# # 1. Pathway Commons template SPARQL query
# The query will be post-processed to integrate filters on gene names `$filter_Chunks`, for skipping small molecules `$filter_SkipSmallMollecules`, and considering only a subset of data sources `$filter_DataSources`.

# %%
tpl_select_reg_query = """
PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 

SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
    $filter_Chunks
    $filter_SkipSmallMollecules
    $filter_DataSources
    
    # ?participant bp:displayName ?controlledName ;
        rdf:type ?controlledType .
    # ?controller bp:displayName ?controllerName ;
        rdf:type ?controllerType . 
    
    # ?controlled bp:participant ?participant .

    # ?tempReac a bp:TemplateReactionRegulation ; 
        bp:controlled ?controlled ; 
        bp:controller ?controller ; 
        bp:controlType ?controlType ; 
        bp:dataSource ?source . 
} 
"""

# %% [markdown]
# The query is based on the BioPax ontology. It aims at matching a graph pattern on the full Pathway Commons knowledge base. The following diagram shows variable graph nodes (dashed circles), fixed nodes (rectangle), and what we search for in red.

# %%
from nxpd import draw
bgp = nx.DiGraph()
bgp.graph['dpi'] = 120

bgp.add_node("?controllerName", color="red")
bgp.add_node("?controlType", color="red")
bgp.add_node("?controlledName", color="red")

bgp.add_edge("?participant", "?controlledName", label="displayName")
bgp.add_edge("?participant", "?controlledType", label="is-a")
bgp.add_edge("?controller", "?controllerName", label="displayName")
bgp.add_edge("?controller", "?controllerType", label="is-a")
bgp.add_edge("?controlled", "?participant", label="participant")
bgp.add_edge("?tempReac", "TemplateReactionRegulation", label="is-a")
bgp.add_edge("?tempReac", "?controlled", label="controlled")
bgp.add_edge("?tempReac", "?controller", label="controller")
bgp.add_edge("?tempReac", "?controlType", label="controlType")
bgp.add_edge("?tempReac", "?source", label="dataSource")
for e in bgp.edges():
    for i in range(0,2):
        if "?" in e[i]:
            bgp.add_node(e[i], style='dashed')
        else: 
            bgp.add_node(e[i], shape='rectangle')
    
draw(bgp, show='ipynb')

# %% [markdown]
# ### Splitting a list of genes based on `CHUNKS_SIZE`

# %%
def gen_chunks(list_of_genes):
    """
    """
    chunks_list = []
    chunk = []
    cpt = 0
    for gene in list_of_genes:
        chunk.append(gene)
        cpt += 1
        if ((cpt % CHUNKS_SIZE) == 0):
            chunks_list.append(chunk)
            chunk = []
    if (len(chunk) > 0):
        chunks_list.append(chunk)
    return chunks_list

# %% [markdown]
# ### Generation of a SPARQL Filter clause to restrict data sources
# Produces something like
# ```
# FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>))
# ```

# %%
def gen_data_source_filter(data_sources):
    """
    generates a SPARQL Filter clause aimed at 
    limiting the possible values of a ?source vairable
    """
    filter_clause = ''
    if len(data_sources) > 0 : 
        filter_clause = 'FILTER (?source IN ('
        for ds in data_sources :
            dsUri = '<http://pathwaycommons.org/pc2/' + ds.lower() + '>'
            filter_clause = filter_clause + dsUri + ', '
        k = filter_clause.rfind(", ")
        filter_clause = filter_clause[:k]
        filter_clause = filter_clause + ')) .'
    return filter_clause

# %% [markdown]
# ### Generation of a SPARQL Filter clause to restrict gene/protein/etc. names
# Produces something like
# ```
# FILTER (
#     ((?controlledName = "JUN"^^xsd:string) && (?controllerName != "JUN"^^xsd:string))
#     || ((?controlledName = "FOS"^^xsd:string) && (?controllerName != "FOS"^^xsd:string))
# ```

# %%
def gen_chunks_filter(chunks):
    """
    """
    filter_clause = ''
    if len(chunks) > 0 : 
        filter_clause = 'FILTER ( \n'
        for g in chunks :
            filter_clause += '((?controlledName = "' + g + '"^^xsd:string) && (?controllerName != "' + g + '"^^xsd:string)) \n'
            filter_clause +=' || '
        k = filter_clause.rfind(" || ")
        filter_clause = filter_clause[:k]
        filter_clause += ' ) .'
    return filter_clause

# %% [markdown]
# ### Generation of a SPARQL Filter clause to exclude small molecules
# Produces something like
# ```
# FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")
# ```

# %%
def gen_small_mol_filter(skip_small_molecules = True):
    if skip_small_molecules:
        return 'FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .'
    else:
        return ''

# %% [markdown]
# # 2. Upstream regulation algorithm
# Recursive exploration with two stopping criteria:
# - nothing new to explore
# - the maximum exploration depth is reached

# %%
def upstream_regulation(to_be_explored, already_explored, sif_network, depth, explored_reg):
    """
    """
    
    """ 1st stopping criteria """
    if len(to_be_explored) == 0:
        print("Exploring done")
        return sif_network
    
    """ 2nd stopping criteria """
    if (HAS_MAX_DEPTH and (depth >= MAX_DEPTH)):
        print("Exploring alted due to maximum depth")
        return sif_network
    
    print()
    print('exploration depth ' + str(depth))
    print('to be explored ' + str(to_be_explored))
    
    """ Decomposing protein complexes """
    new_to_be_explored = []
    for name in to_be_explored:
        splits = name.split('/')
        if len(splits) > 1 : 
            print(name + ' decomposed into ' + str(splits))
            new_to_be_explored.extend(splits)
            for s in splits:
                sif_network.append({"source":s, "relation":"PART_OF", "target":name})
    
    for new in new_to_be_explored:
        if new not in to_be_explored:
                to_be_explored.append(new)
    print('to be explored after complex decomposition ' + str(to_be_explored))
    
    """ Expanding the list with synonyms """
    new_to_be_explored = []
    for name in to_be_explored:
        synonyms = get_synonyms(name, cache)
        for s in synonyms:
            if s not in "-":
                new_to_be_explored.append(s)
    if len(new_to_be_explored) > 0:
        print('new synonmys to be explored:' + str(new_to_be_explored))
    
    for new in new_to_be_explored:
        if new not in to_be_explored:
                to_be_explored.append(new)
    
    """ Grouping genes into chunks to be processed remotely by block """
    chunks = gen_chunks(to_be_explored)
    to_be_explored = []
    
    for regulators in chunks :
        print('exploring ' + str(regulators))
        query = Template(tpl_select_reg_query)
        
        fds = gen_data_source_filter(DATA_SOURCES)
        fchunks = gen_chunks_filter(regulators)
        ssm = gen_small_mol_filter(SKIP_SMALL_MOLECULES)
        
        q = query.substitute(filter_DataSources = fds,
                    filter_SkipSmallMollecules = ssm, 
                    filter_Chunks = fchunks)
        
        print("=====================")
        print(q)
        print("=====================")
        
        sparql = SPARQLWrapper(SPARQL_ENDPOINT)
        sparql.setQuery(q)
        sparql.setReturnFormat(JSON)
        results = sparql.query().convert()
        
        already_explored.extend(regulators)
        #print('already explored ' + str(already_explored))
        
        for result in results["results"]["bindings"]:
            source, reg_type, target = result["controllerName"]["value"], result["controlType"]["value"], result["controlledName"]["value"]
            sif_network.append({"source":source, "relation":reg_type, "target":target})
            #print(source + ' --- ' + reg_type + ' --> ' + target)
            
            if source not in already_explored:
                if source not in to_be_explored:
                    to_be_explored.append(source)
                    explored_reg += 1
                    #print('Adding ' + source + ', in to_be_explored')
            #else:
                #print('skipping ' + source + ', already_explored')
        
        print()
        print('Explored ' + str(explored_reg)+ ' regulators')
        
    depth += 1
    upstream_regulation(to_be_explored, already_explored, sif_network, depth, explored_reg)
    
    return sif_network

# %% [markdown]
# # 3. RUNNING the algorithm
# based on the `INPUT_GENES` list.

# %%
start_time = time.time()

reconstructed_network = upstream_regulation(["JUN/FOS", "SCN5A"], [], [], depth=0, explored_reg=0)

elapsed_time = round((time.time() - start_time), 2)
print("--- Upstream regulation network in %s seconds ---" % elapsed_time)

G = nx.DiGraph()
for e in reconstructed_network:
#    print(e['source'] + ' --- ' + e['regulation'] + ' --> ' + e['target'])
    G.add_edge(e['source'], e['target'], 
               color = 'g' if (e['relation'] in 'ACTIVATION') else 'r',
               label=e['relation'])

print('Number of nodes = ' + str(len(G.nodes())))
print('Number of edges = ' + str(len(G.edges())))
# Out:
# exploration depth 0
# to be explored ['JUN/FOS', 'SCN5A']
# JUN/FOS decomposed into ['JUN', 'FOS']
# to be explored after complex decomposition ['JUN/FOS', 'SCN5A', 'JUN', 'FOS']
# new synonmys to be explored:['16S rRNA', 'CDCD2', 'CMD1E', 'CMPD2', 'HB1', 'HB2', 'HBBD', 'HH1', 'ICCD', 'IVF', 'LQT3', 'Nav1.5', 'PFHB1', 'SSS1', 'VF1', 'AP-1', 'AP1', 'c-Jun', 'p39', 'AP-1', 'C-FOS', 'p55']
# exploring ['JUN/FOS', 'SCN5A', 'JUN', 'FOS', '16S rRNA', 'CDCD2', 'CMD1E', 'CMPD2', 'HB1', 'HB2', 'HBBD', 'HH1', 'ICCD', 'IVF', 'LQT3', 'Nav1.5', 'PFHB1', 'SSS1', 'VF1', 'AP-1']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "JUN/FOS"^^xsd:string) && (?controllerName != "JUN/FOS"^^xsd:string))
#  || ((?controlledName = "SCN5A"^^xsd:string) && (?controllerName != "SCN5A"^^xsd:string))
#  || ((?controlledName = "JUN"^^xsd:string) && (?controllerName != "JUN"^^xsd:string))
#  || ((?controlledName = "FOS"^^xsd:string) && (?controllerName != "FOS"^^xsd:string))
#  || ((?controlledName = "16S rRNA"^^xsd:string) && (?controllerName != "16S rRNA"^^xsd:string))
#  || ((?controlledName = "CDCD2"^^xsd:string) && (?controllerName != "CDCD2"^^xsd:string))
#  || ((?controlledName = "CMD1E"^^xsd:string) && (?controllerName != "CMD1E"^^xsd:string))
#  || ((?controlledName = "CMPD2"^^xsd:string) && (?controllerName != "CMPD2"^^xsd:string))
#  || ((?controlledName = "HB1"^^xsd:string) && (?controllerName != "HB1"^^xsd:string))
#  || ((?controlledName = "HB2"^^xsd:string) && (?controllerName != "HB2"^^xsd:string))
#  || ((?controlledName = "HBBD"^^xsd:string) && (?controllerName != "HBBD"^^xsd:string))
#  || ((?controlledName = "HH1"^^xsd:string) && (?controllerName != "HH1"^^xsd:string))
#  || ((?controlledName = "ICCD"^^xsd:string) && (?controllerName != "ICCD"^^xsd:string))
#  || ((?controlledName = "IVF"^^xsd:string) && (?controllerName != "IVF"^^xsd:string))
#  || ((?controlledName = "LQT3"^^xsd:string) && (?controllerName != "LQT3"^^xsd:string))
#  || ((?controlledName = "Nav1.5"^^xsd:string) && (?controllerName != "Nav1.5"^^xsd:string))
#  || ((?controlledName = "PFHB1"^^xsd:string) && (?controllerName != "PFHB1"^^xsd:string))
#  || ((?controlledName = "SSS1"^^xsd:string) && (?controllerName != "SSS1"^^xsd:string))
#  || ((?controlledName = "VF1"^^xsd:string) && (?controllerName != "VF1"^^xsd:string))
#  || ((?controlledName = "AP-1"^^xsd:string) && (?controllerName != "AP-1"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 63 regulators
# exploring ['AP1', 'c-Jun', 'p39', 'C-FOS', 'p55']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "AP1"^^xsd:string) && (?controllerName != "AP1"^^xsd:string))
#  || ((?controlledName = "c-Jun"^^xsd:string) && (?controllerName != "c-Jun"^^xsd:string))
#  || ((?controlledName = "p39"^^xsd:string) && (?controllerName != "p39"^^xsd:string))
#  || ((?controlledName = "C-FOS"^^xsd:string) && (?controllerName != "C-FOS"^^xsd:string))
#  || ((?controlledName = "p55"^^xsd:string) && (?controllerName != "p55"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 63 regulators
#
# exploration depth 1
# to be explored ['MAZ', 'POU3F2', 'CREB1', 'CEBPA', 'SPZ1', 'ICER', 'TCF3', 'ATF3', 'ERK1-2/ELK1', 'FOXM1C', 'ESRRA', 'SRF', 'MYOD1', 'SRF(dimer)/MAL(dimer)', 'JUN/ATF2', 'MEIS1', 'EGR3', 'ERK1-2-active', 'STAT5 (dimer)-active', 'p300', 'ATF2', 'REPIN1', 'ZEB1', 'GATA1', 'LEF1', 'ELK1/SRF', 'Calcineurin A alpha-beta B1', 'AP1', 'SMAD3/SMAD4/JUN/FOS', 'RHOA/GTP', 'TCR/CD3/MHC II/CD4', 'IL12/IL12R/TYK2/JAK2', 'JDP2', 'Jnk1', 'ATF2/c-Jun', 'ELK1', 'JNK1-2-active', 'ATF1', 'NRF1', 'PAX2', 'TBP', 'ATF4', 'YY1', 'FOXF2', 'HSF2', 'STAT5B', 'PAX4', 'SP1', 'STAT5A', 'EGR2', 'MTF1', 'SP3', 'HSF1', 'FOXN1', 'MYB', 'ALX4', 'SF1', 'TFAP2C', 'TFAP2A', 'POU2F1', 'HNF1A', 'CEBPD', 'IRF7']
# ERK1-2/ELK1 decomposed into ['ERK1-2', 'ELK1']
# SRF(dimer)/MAL(dimer) decomposed into ['SRF(dimer)', 'MAL(dimer)']
# JUN/ATF2 decomposed into ['JUN', 'ATF2']
# ELK1/SRF decomposed into ['ELK1', 'SRF']
# SMAD3/SMAD4/JUN/FOS decomposed into ['SMAD3', 'SMAD4', 'JUN', 'FOS']
# RHOA/GTP decomposed into ['RHOA', 'GTP']
# TCR/CD3/MHC II/CD4 decomposed into ['TCR', 'CD3', 'MHC II', 'CD4']
# IL12/IL12R/TYK2/JAK2 decomposed into ['IL12', 'IL12R', 'TYK2', 'JAK2']
# ATF2/c-Jun decomposed into ['ATF2', 'c-Jun']
# to be explored after complex decomposition ['MAZ', 'POU3F2', 'CREB1', 'CEBPA', 'SPZ1', 'ICER', 'TCF3', 'ATF3', 'ERK1-2/ELK1', 'FOXM1C', 'ESRRA', 'SRF', 'MYOD1', 'SRF(dimer)/MAL(dimer)', 'JUN/ATF2', 'MEIS1', 'EGR3', 'ERK1-2-active', 'STAT5 (dimer)-active', 'p300', 'ATF2', 'REPIN1', 'ZEB1', 'GATA1', 'LEF1', 'ELK1/SRF', 'Calcineurin A alpha-beta B1', 'AP1', 'SMAD3/SMAD4/JUN/FOS', 'RHOA/GTP', 'TCR/CD3/MHC II/CD4', 'IL12/IL12R/TYK2/JAK2', 'JDP2', 'Jnk1', 'ATF2/c-Jun', 'ELK1', 'JNK1-2-active', 'ATF1', 'NRF1', 'PAX2', 'TBP', 'ATF4', 'YY1', 'FOXF2', 'HSF2', 'STAT5B', 'PAX4', 'SP1', 'STAT5A', 'EGR2', 'MTF1', 'SP3', 'HSF1', 'FOXN1', 'MYB', 'ALX4', 'SF1', 'TFAP2C', 'TFAP2A', 'POU2F1', 'HNF1A', 'CEBPD', 'IRF7', 'ERK1-2', 'SRF(dimer)', 'MAL(dimer)', 'JUN', 'SMAD3', 'SMAD4', 'FOS', 'RHOA', 'GTP', 'TCR', 'CD3', 'MHC II', 'CD4', 'IL12', 'IL12R', 'TYK2', 'JAK2', 'c-Jun']
# new synonmys to be explored:['PUR1', 'Pur-1', 'SAF-1', 'SAF-2', 'SAF-3', 'ZF87', 'ZNF801', 'Zif87', 'BRN2', 'N-Oct3', 'OCT7', 'OTF-7', 'OTF7', 'POUF3', 'brn-2', 'oct-7', 'CREB', 'CREB-1', 'C/EBP-alpha', 'CEBP', 'NYD-TSP1', 'PPP1R148', 'CREM-2', 'hCREM-2', 'CREM', 'AGM8', 'E2A', 'E47', 'ITF1', 'TCF-3', 'VDIR', 'bHLHb21', 'p75', '16S rRNA', 'FKHL16', 'FOXM1A', 'FOXM1B', 'HFH-11', 'HFH11', 'HNF-3', 'INS-1', 'MPHOSPH2', 'MPP-2', 'MPP2', 'PIG29', 'TRIDENT', 'FOXM1', 'ERR1', 'ERRa', 'ERRalpha', 'ESRL1', 'NR3B1', 'MCM1', 'MYF3', 'MYOD', 'PUM', 'bHLHc1', '16S rRNA', '16S rRNA', 'EGR-3', 'PILOT', '16S rRNA', '16S rRNA', 'KAT3B', 'RSTS2', 'EP300', 'CRE-BP1', 'CREB-2', 'CREB2', 'HB16', 'TREB7', 'AP4', 'RIP60', 'ZNF464', 'Zfp464', 'AREB6', 'BZP', 'DELTAEF1', 'FECD6', 'NIL2A', 'PPCD3', 'TCF8', 'ZFHEP', 'ZFHX1A', 'ERYF1', 'GATA-1', 'GF-1', 'GF1', 'NF-E1', 'NFE1', 'XLANP', 'XLTDA', 'XLTT', 'LEF-1', 'TCF10', 'TCF1ALPHA', 'TCF7L3', '16S rRNA', '16S rRNA', 'AP-1', 'c-Jun', 'p39', 'JUN', '16S rRNA', '16S rRNA', '16S rRNA', '16S rRNA', 'JUNDM2', '16S rRNA', '16S rRNA', '16S rRNA', 'EWS-ATF1', 'FUS/ATF-1', 'TREB36', 'LCR-F1', 'TCF11', 'NFE2L1', 'FSGS7', 'PAPRS', 'GTF2D', 'GTF2D1', 'HDL4', 'SCA17', 'TFIID', 'CREB-2', 'CREB2', 'TAXREB67', 'TXREB', 'DELTA', 'GADEVS', 'INO80S', 'NF-E1', 'UCRBP', 'YIN-YANG-1', 'FKHL6', 'FREAC-2', 'FREAC2', 'HSF 2', 'HSTF 2', 'STAT5', 'KPD', 'MODY9', 'B1G1', 'CD66f', 'DHFRP2', 'FL-NCA-1/2', 'PBG1', 'PS-beta-C/D', 'PS-beta-G-1', 'PSBG-1', 'PSBG1', 'PSG95', 'PSGGA', 'PSGIIA', 'PSG1', 'MGF', 'STAT5', 'AT591', 'CMT1D', 'CMT4E', 'KROX20', 'CD228', 'MAP97', 'MFI2', 'MTf', 'MELTF', 'AZF', 'AZFA', 'AZF1', 'HSTF1', 'FKHL20', 'RONU', 'WHN', 'Cmyb', 'c-myb', 'c-myb_CDS', 'efg', 'CRS5', 'FND2', 'AD4BP', 'ELP', 'FTZ1', 'FTZF1', 'POF7', 'SF-1', 'SPGF8', 'SRXX4', 'SRXY3', 'hSF-1', 'NR5A1', 'AP2-GAMMA', 'ERF1', 'TFAP2G', 'hAP-2g', 'AP-2', 'AP-2alpha', 'AP2TF', 'BOFS', 'TFAP2', 'OCT1', 'OTF1', 'oct-1B', 'HNF-1A', 'HNF1', 'HNF4A', 'IDDM20', 'LFB1', 'MODY3', 'TCF-1', 'TCF1', 'C/EBP-delta', 'CELF', 'CRP3', 'NF-IL6-beta', 'IMD39', 'IRF-7', 'IRF-7H', 'IRF7A', 'IRF7B', 'IRF7C', 'IRF7H', '16S rRNA', '16S rRNA', '16S rRNA', 'AP-1', 'AP1', 'c-Jun', 'p39', 'HSPC193', 'HsT17436', 'JV15-2', 'LDS1C', 'LDS3', 'MADH3', 'DPC4', 'JIP', 'MADH4', 'MYHRS', 'AP-1', 'C-FOS', 'p55', 'ARH12', 'ARHA', 'RHO12', 'RHOH12', 'GTPBP7', 'MTG1', 'CDR3', 'TCRB', 'TCRBV20S2', 'TCRBV2O', 'TCRBV2S2O', 'TRB', 'TRBV20OR9-2', '16S rRNA', '16S rRNA', 'CD4mut', '16S rRNA', '16S rRNA', 'IMD35', 'JTK1', 'JTK10', 'THCYT3', 'AP-1', 'AP1', 'p39', 'JUN']
# exploring ['MAZ', 'POU3F2', 'CREB1', 'CEBPA', 'SPZ1', 'ICER', 'TCF3', 'ATF3', 'ERK1-2/ELK1', 'FOXM1C', 'ESRRA', 'SRF', 'MYOD1', 'SRF(dimer)/MAL(dimer)', 'JUN/ATF2', 'MEIS1', 'EGR3', 'ERK1-2-active', 'STAT5 (dimer)-active', 'p300']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "MAZ"^^xsd:string) && (?controllerName != "MAZ"^^xsd:string))
#  || ((?controlledName = "POU3F2"^^xsd:string) && (?controllerName != "POU3F2"^^xsd:string))
#  || ((?controlledName = "CREB1"^^xsd:string) && (?controllerName != "CREB1"^^xsd:string))
#  || ((?controlledName = "CEBPA"^^xsd:string) && (?controllerName != "CEBPA"^^xsd:string))
#  || ((?controlledName = "SPZ1"^^xsd:string) && (?controllerName != "SPZ1"^^xsd:string))
#  || ((?controlledName = "ICER"^^xsd:string) && (?controllerName != "ICER"^^xsd:string))
#  || ((?controlledName = "TCF3"^^xsd:string) && (?controllerName != "TCF3"^^xsd:string))
#  || ((?controlledName = "ATF3"^^xsd:string) && (?controllerName != "ATF3"^^xsd:string))
#  || ((?controlledName = "ERK1-2/ELK1"^^xsd:string) && (?controllerName != "ERK1-2/ELK1"^^xsd:string))
#  || ((?controlledName = "FOXM1C"^^xsd:string) && (?controllerName != "FOXM1C"^^xsd:string))
#  || ((?controlledName = "ESRRA"^^xsd:string) && (?controllerName != "ESRRA"^^xsd:string))
#  || ((?controlledName = "SRF"^^xsd:string) && (?controllerName != "SRF"^^xsd:string))
#  || ((?controlledName = "MYOD1"^^xsd:string) && (?controllerName != "MYOD1"^^xsd:string))
#  || ((?controlledName = "SRF(dimer)/MAL(dimer)"^^xsd:string) && (?controllerName != "SRF(dimer)/MAL(dimer)"^^xsd:string))
#  || ((?controlledName = "JUN/ATF2"^^xsd:string) && (?controllerName != "JUN/ATF2"^^xsd:string))
#  || ((?controlledName = "MEIS1"^^xsd:string) && (?controllerName != "MEIS1"^^xsd:string))
#  || ((?controlledName = "EGR3"^^xsd:string) && (?controllerName != "EGR3"^^xsd:string))
#  || ((?controlledName = "ERK1-2-active"^^xsd:string) && (?controllerName != "ERK1-2-active"^^xsd:string))
#  || ((?controlledName = "STAT5 (dimer)-active"^^xsd:string) && (?controllerName != "STAT5 (dimer)-active"^^xsd:string))
#  || ((?controlledName = "p300"^^xsd:string) && (?controllerName != "p300"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
# Explored 165 regulators
# exploring ['ATF2', 'REPIN1', 'ZEB1', 'GATA1', 'LEF1', 'ELK1/SRF', 'Calcineurin A alpha-beta B1', 'AP1', 'SMAD3/SMAD4/JUN/FOS', 'RHOA/GTP', 'TCR/CD3/MHC II/CD4', 'IL12/IL12R/TYK2/JAK2', 'JDP2', 'Jnk1', 'ATF2/c-Jun', 'ELK1', 'JNK1-2-active', 'ATF1', 'NRF1', 'PAX2']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "ATF2"^^xsd:string) && (?controllerName != "ATF2"^^xsd:string))
#  || ((?controlledName = "REPIN1"^^xsd:string) && (?controllerName != "REPIN1"^^xsd:string))
#  || ((?controlledName = "ZEB1"^^xsd:string) && (?controllerName != "ZEB1"^^xsd:string))
#  || ((?controlledName = "GATA1"^^xsd:string) && (?controllerName != "GATA1"^^xsd:string))
#  || ((?controlledName = "LEF1"^^xsd:string) && (?controllerName != "LEF1"^^xsd:string))
#  || ((?controlledName = "ELK1/SRF"^^xsd:string) && (?controllerName != "ELK1/SRF"^^xsd:string))
#  || ((?controlledName = "Calcineurin A alpha-beta B1"^^xsd:string) && (?controllerName != "Calcineurin A alpha-beta B1"^^xsd:string))
#  || ((?controlledName = "AP1"^^xsd:string) && (?controllerName != "AP1"^^xsd:string))
#  || ((?controlledName = "SMAD3/SMAD4/JUN/FOS"^^xsd:string) && (?controllerName != "SMAD3/SMAD4/JUN/FOS"^^xsd:string))
#  || ((?controlledName = "RHOA/GTP"^^xsd:string) && (?controllerName != "RHOA/GTP"^^xsd:string))
#  || ((?controlledName = "TCR/CD3/MHC II/CD4"^^xsd:string) && (?controllerName != "TCR/CD3/MHC II/CD4"^^xsd:string))
#  || ((?controlledName = "IL12/IL12R/TYK2/JAK2"^^xsd:string) && (?controllerName != "IL12/IL12R/TYK2/JAK2"^^xsd:string))
#  || ((?controlledName = "JDP2"^^xsd:string) && (?controllerName != "JDP2"^^xsd:string))
#  || ((?controlledName = "Jnk1"^^xsd:string) && (?controllerName != "Jnk1"^^xsd:string))
#  || ((?controlledName = "ATF2/c-Jun"^^xsd:string) && (?controllerName != "ATF2/c-Jun"^^xsd:string))
#  || ((?controlledName = "ELK1"^^xsd:string) && (?controllerName != "ELK1"^^xsd:string))
#  || ((?controlledName = "JNK1-2-active"^^xsd:string) && (?controllerName != "JNK1-2-active"^^xsd:string))
#  || ((?controlledName = "ATF1"^^xsd:string) && (?controllerName != "ATF1"^^xsd:string))
#  || ((?controlledName = "NRF1"^^xsd:string) && (?controllerName != "NRF1"^^xsd:string))
#  || ((?controlledName = "PAX2"^^xsd:string) && (?controllerName != "PAX2"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 197 regulators
# exploring ['TBP', 'ATF4', 'YY1', 'FOXF2', 'HSF2', 'STAT5B', 'PAX4', 'SP1', 'STAT5A', 'EGR2', 'MTF1', 'SP3', 'HSF1', 'FOXN1', 'MYB', 'ALX4', 'SF1', 'TFAP2C', 'TFAP2A', 'POU2F1']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "TBP"^^xsd:string) && (?controllerName != "TBP"^^xsd:string))
#  || ((?controlledName = "ATF4"^^xsd:string) && (?controllerName != "ATF4"^^xsd:string))
#  || ((?controlledName = "YY1"^^xsd:string) && (?controllerName != "YY1"^^xsd:string))
#  || ((?controlledName = "FOXF2"^^xsd:string) && (?controllerName != "FOXF2"^^xsd:string))
#  || ((?controlledName = "HSF2"^^xsd:string) && (?controllerName != "HSF2"^^xsd:string))
#  || ((?controlledName = "STAT5B"^^xsd:string) && (?controllerName != "STAT5B"^^xsd:string))
#  || ((?controlledName = "PAX4"^^xsd:string) && (?controllerName != "PAX4"^^xsd:string))
#  || ((?controlledName = "SP1"^^xsd:string) && (?controllerName != "SP1"^^xsd:string))
#  || ((?controlledName = "STAT5A"^^xsd:string) && (?controllerName != "STAT5A"^^xsd:string))
#  || ((?controlledName = "EGR2"^^xsd:string) && (?controllerName != "EGR2"^^xsd:string))
#  || ((?controlledName = "MTF1"^^xsd:string) && (?controllerName != "MTF1"^^xsd:string))
#  || ((?controlledName = "SP3"^^xsd:string) && (?controllerName != "SP3"^^xsd:string))
#  || ((?controlledName = "HSF1"^^xsd:string) && (?controllerName != "HSF1"^^xsd:string))
#  || ((?controlledName = "FOXN1"^^xsd:string) && (?controllerName != "FOXN1"^^xsd:string))
#  || ((?controlledName = "MYB"^^xsd:string) && (?controllerName != "MYB"^^xsd:string))
#  || ((?controlledName = "ALX4"^^xsd:string) && (?controllerName != "ALX4"^^xsd:string))
#  || ((?controlledName = "SF1"^^xsd:string) && (?controllerName != "SF1"^^xsd:string))
#  || ((?controlledName = "TFAP2C"^^xsd:string) && (?controllerName != "TFAP2C"^^xsd:string))
#  || ((?controlledName = "TFAP2A"^^xsd:string) && (?controllerName != "TFAP2A"^^xsd:string))
#  || ((?controlledName = "POU2F1"^^xsd:string) && (?controllerName != "POU2F1"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 235 regulators
# exploring ['HNF1A', 'CEBPD', 'IRF7', 'ERK1-2', 'SRF(dimer)', 'MAL(dimer)', 'JUN', 'SMAD3', 'SMAD4', 'FOS', 'RHOA', 'GTP', 'TCR', 'CD3', 'MHC II', 'CD4', 'IL12', 'IL12R', 'TYK2', 'JAK2']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "HNF1A"^^xsd:string) && (?controllerName != "HNF1A"^^xsd:string))
#  || ((?controlledName = "CEBPD"^^xsd:string) && (?controllerName != "CEBPD"^^xsd:string))
#  || ((?controlledName = "IRF7"^^xsd:string) && (?controllerName != "IRF7"^^xsd:string))
#  || ((?controlledName = "ERK1-2"^^xsd:string) && (?controllerName != "ERK1-2"^^xsd:string))
#  || ((?controlledName = "SRF(dimer)"^^xsd:string) && (?controllerName != "SRF(dimer)"^^xsd:string))
#  || ((?controlledName = "MAL(dimer)"^^xsd:string) && (?controllerName != "MAL(dimer)"^^xsd:string))
#  || ((?controlledName = "JUN"^^xsd:string) && (?controllerName != "JUN"^^xsd:string))
#  || ((?controlledName = "SMAD3"^^xsd:string) && (?controllerName != "SMAD3"^^xsd:string))
#  || ((?controlledName = "SMAD4"^^xsd:string) && (?controllerName != "SMAD4"^^xsd:string))
#  || ((?controlledName = "FOS"^^xsd:string) && (?controllerName != "FOS"^^xsd:string))
#  || ((?controlledName = "RHOA"^^xsd:string) && (?controllerName != "RHOA"^^xsd:string))
#  || ((?controlledName = "GTP"^^xsd:string) && (?controllerName != "GTP"^^xsd:string))
#  || ((?controlledName = "TCR"^^xsd:string) && (?controllerName != "TCR"^^xsd:string))
#  || ((?controlledName = "CD3"^^xsd:string) && (?controllerName != "CD3"^^xsd:string))
#  || ((?controlledName = "MHC II"^^xsd:string) && (?controllerName != "MHC II"^^xsd:string))
#  || ((?controlledName = "CD4"^^xsd:string) && (?controllerName != "CD4"^^xsd:string))
#  || ((?controlledName = "IL12"^^xsd:string) && (?controllerName != "IL12"^^xsd:string))
#  || ((?controlledName = "IL12R"^^xsd:string) && (?controllerName != "IL12R"^^xsd:string))
#  || ((?controlledName = "TYK2"^^xsd:string) && (?controllerName != "TYK2"^^xsd:string))
#  || ((?controlledName = "JAK2"^^xsd:string) && (?controllerName != "JAK2"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
# Explored 245 regulators
# exploring ['c-Jun', 'PUR1', 'Pur-1', 'SAF-1', 'SAF-2', 'SAF-3', 'ZF87', 'ZNF801', 'Zif87', 'BRN2', 'N-Oct3', 'OCT7', 'OTF-7', 'OTF7', 'POUF3', 'brn-2', 'oct-7', 'CREB', 'CREB-1', 'C/EBP-alpha']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "c-Jun"^^xsd:string) && (?controllerName != "c-Jun"^^xsd:string))
#  || ((?controlledName = "PUR1"^^xsd:string) && (?controllerName != "PUR1"^^xsd:string))
#  || ((?controlledName = "Pur-1"^^xsd:string) && (?controllerName != "Pur-1"^^xsd:string))
#  || ((?controlledName = "SAF-1"^^xsd:string) && (?controllerName != "SAF-1"^^xsd:string))
#  || ((?controlledName = "SAF-2"^^xsd:string) && (?controllerName != "SAF-2"^^xsd:string))
#  || ((?controlledName = "SAF-3"^^xsd:string) && (?controllerName != "SAF-3"^^xsd:string))
#  || ((?controlledName = "ZF87"^^xsd:string) && (?controllerName != "ZF87"^^xsd:string))
#  || ((?controlledName = "ZNF801"^^xsd:string) && (?controllerName != "ZNF801"^^xsd:string))
#  || ((?controlledName = "Zif87"^^xsd:string) && (?controllerName != "Zif87"^^xsd:string))
#  || ((?controlledName = "BRN2"^^xsd:string) && (?controllerName != "BRN2"^^xsd:string))
#  || ((?controlledName = "N-Oct3"^^xsd:string) && (?controllerName != "N-Oct3"^^xsd:string))
#  || ((?controlledName = "OCT7"^^xsd:string) && (?controllerName != "OCT7"^^xsd:string))
#  || ((?controlledName = "OTF-7"^^xsd:string) && (?controllerName != "OTF-7"^^xsd:string))
#  || ((?controlledName = "OTF7"^^xsd:string) && (?controllerName != "OTF7"^^xsd:string))
#  || ((?controlledName = "POUF3"^^xsd:string) && (?controllerName != "POUF3"^^xsd:string))
#  || ((?controlledName = "brn-2"^^xsd:string) && (?controllerName != "brn-2"^^xsd:string))
#  || ((?controlledName = "oct-7"^^xsd:string) && (?controllerName != "oct-7"^^xsd:string))
#  || ((?controlledName = "CREB"^^xsd:string) && (?controllerName != "CREB"^^xsd:string))
#  || ((?controlledName = "CREB-1"^^xsd:string) && (?controllerName != "CREB-1"^^xsd:string))
#  || ((?controlledName = "C/EBP-alpha"^^xsd:string) && (?controllerName != "C/EBP-alpha"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 245 regulators
# exploring ['CEBP', 'NYD-TSP1', 'PPP1R148', 'CREM-2', 'hCREM-2', 'CREM', 'AGM8', 'E2A', 'E47', 'ITF1', 'TCF-3', 'VDIR', 'bHLHb21', 'p75', '16S rRNA', 'FKHL16', 'FOXM1A', 'FOXM1B', 'HFH-11', 'HFH11']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "CEBP"^^xsd:string) && (?controllerName != "CEBP"^^xsd:string))
#  || ((?controlledName = "NYD-TSP1"^^xsd:string) && (?controllerName != "NYD-TSP1"^^xsd:string))
#  || ((?controlledName = "PPP1R148"^^xsd:string) && (?controllerName != "PPP1R148"^^xsd:string))
#  || ((?controlledName = "CREM-2"^^xsd:string) && (?controllerName != "CREM-2"^^xsd:string))
#  || ((?controlledName = "hCREM-2"^^xsd:string) && (?controllerName != "hCREM-2"^^xsd:string))
#  || ((?controlledName = "CREM"^^xsd:string) && (?controllerName != "CREM"^^xsd:string))
#  || ((?controlledName = "AGM8"^^xsd:string) && (?controllerName != "AGM8"^^xsd:string))
#  || ((?controlledName = "E2A"^^xsd:string) && (?controllerName != "E2A"^^xsd:string))
#  || ((?controlledName = "E47"^^xsd:string) && (?controllerName != "E47"^^xsd:string))
#  || ((?controlledName = "ITF1"^^xsd:string) && (?controllerName != "ITF1"^^xsd:string))
#  || ((?controlledName = "TCF-3"^^xsd:string) && (?controllerName != "TCF-3"^^xsd:string))
#  || ((?controlledName = "VDIR"^^xsd:string) && (?controllerName != "VDIR"^^xsd:string))
#  || ((?controlledName = "bHLHb21"^^xsd:string) && (?controllerName != "bHLHb21"^^xsd:string))
#  || ((?controlledName = "p75"^^xsd:string) && (?controllerName != "p75"^^xsd:string))
#  || ((?controlledName = "16S rRNA"^^xsd:string) && (?controllerName != "16S rRNA"^^xsd:string))
#  || ((?controlledName = "FKHL16"^^xsd:string) && (?controllerName != "FKHL16"^^xsd:string))
#  || ((?controlledName = "FOXM1A"^^xsd:string) && (?controllerName != "FOXM1A"^^xsd:string))
#  || ((?controlledName = "FOXM1B"^^xsd:string) && (?controllerName != "FOXM1B"^^xsd:string))
#  || ((?controlledName = "HFH-11"^^xsd:string) && (?controllerName != "HFH-11"^^xsd:string))
#  || ((?controlledName = "HFH11"^^xsd:string) && (?controllerName != "HFH11"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 246 regulators
# exploring ['HNF-3', 'INS-1', 'MPHOSPH2', 'MPP-2', 'MPP2', 'PIG29', 'TRIDENT', 'FOXM1', 'ERR1', 'ERRa', 'ERRalpha', 'ESRL1', 'NR3B1', 'MCM1', 'MYF3', 'MYOD', 'PUM', 'bHLHc1', 'EGR-3', 'PILOT']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "HNF-3"^^xsd:string) && (?controllerName != "HNF-3"^^xsd:string))
#  || ((?controlledName = "INS-1"^^xsd:string) && (?controllerName != "INS-1"^^xsd:string))
#  || ((?controlledName = "MPHOSPH2"^^xsd:string) && (?controllerName != "MPHOSPH2"^^xsd:string))
#  || ((?controlledName = "MPP-2"^^xsd:string) && (?controllerName != "MPP-2"^^xsd:string))
#  || ((?controlledName = "MPP2"^^xsd:string) && (?controllerName != "MPP2"^^xsd:string))
#  || ((?controlledName = "PIG29"^^xsd:string) && (?controllerName != "PIG29"^^xsd:string))
#  || ((?controlledName = "TRIDENT"^^xsd:string) && (?controllerName != "TRIDENT"^^xsd:string))
#  || ((?controlledName = "FOXM1"^^xsd:string) && (?controllerName != "FOXM1"^^xsd:string))
#  || ((?controlledName = "ERR1"^^xsd:string) && (?controllerName != "ERR1"^^xsd:string))
#  || ((?controlledName = "ERRa"^^xsd:string) && (?controllerName != "ERRa"^^xsd:string))
#  || ((?controlledName = "ERRalpha"^^xsd:string) && (?controllerName != "ERRalpha"^^xsd:string))
#  || ((?controlledName = "ESRL1"^^xsd:string) && (?controllerName != "ESRL1"^^xsd:string))
#  || ((?controlledName = "NR3B1"^^xsd:string) && (?controllerName != "NR3B1"^^xsd:string))
#  || ((?controlledName = "MCM1"^^xsd:string) && (?controllerName != "MCM1"^^xsd:string))
#  || ((?controlledName = "MYF3"^^xsd:string) && (?controllerName != "MYF3"^^xsd:string))
#  || ((?controlledName = "MYOD"^^xsd:string) && (?controllerName != "MYOD"^^xsd:string))
#  || ((?controlledName = "PUM"^^xsd:string) && (?controllerName != "PUM"^^xsd:string))
#  || ((?controlledName = "bHLHc1"^^xsd:string) && (?controllerName != "bHLHc1"^^xsd:string))
#  || ((?controlledName = "EGR-3"^^xsd:string) && (?controllerName != "EGR-3"^^xsd:string))
#  || ((?controlledName = "PILOT"^^xsd:string) && (?controllerName != "PILOT"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
# Explored 247 regulators
# exploring ['KAT3B', 'RSTS2', 'EP300', 'CRE-BP1', 'CREB-2', 'CREB2', 'HB16', 'TREB7', 'AP4', 'RIP60', 'ZNF464', 'Zfp464', 'AREB6', 'BZP', 'DELTAEF1', 'FECD6', 'NIL2A', 'PPCD3', 'TCF8', 'ZFHEP']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "KAT3B"^^xsd:string) && (?controllerName != "KAT3B"^^xsd:string))
#  || ((?controlledName = "RSTS2"^^xsd:string) && (?controllerName != "RSTS2"^^xsd:string))
#  || ((?controlledName = "EP300"^^xsd:string) && (?controllerName != "EP300"^^xsd:string))
#  || ((?controlledName = "CRE-BP1"^^xsd:string) && (?controllerName != "CRE-BP1"^^xsd:string))
#  || ((?controlledName = "CREB-2"^^xsd:string) && (?controllerName != "CREB-2"^^xsd:string))
#  || ((?controlledName = "CREB2"^^xsd:string) && (?controllerName != "CREB2"^^xsd:string))
#  || ((?controlledName = "HB16"^^xsd:string) && (?controllerName != "HB16"^^xsd:string))
#  || ((?controlledName = "TREB7"^^xsd:string) && (?controllerName != "TREB7"^^xsd:string))
#  || ((?controlledName = "AP4"^^xsd:string) && (?controllerName != "AP4"^^xsd:string))
#  || ((?controlledName = "RIP60"^^xsd:string) && (?controllerName != "RIP60"^^xsd:string))
#  || ((?controlledName = "ZNF464"^^xsd:string) && (?controllerName != "ZNF464"^^xsd:string))
#  || ((?controlledName = "Zfp464"^^xsd:string) && (?controllerName != "Zfp464"^^xsd:string))
#  || ((?controlledName = "AREB6"^^xsd:string) && (?controllerName != "AREB6"^^xsd:string))
#  || ((?controlledName = "BZP"^^xsd:string) && (?controllerName != "BZP"^^xsd:string))
#  || ((?controlledName = "DELTAEF1"^^xsd:string) && (?controllerName != "DELTAEF1"^^xsd:string))
#  || ((?controlledName = "FECD6"^^xsd:string) && (?controllerName != "FECD6"^^xsd:string))
#  || ((?controlledName = "NIL2A"^^xsd:string) && (?controllerName != "NIL2A"^^xsd:string))
#  || ((?controlledName = "PPCD3"^^xsd:string) && (?controllerName != "PPCD3"^^xsd:string))
#  || ((?controlledName = "TCF8"^^xsd:string) && (?controllerName != "TCF8"^^xsd:string))
#  || ((?controlledName = "ZFHEP"^^xsd:string) && (?controllerName != "ZFHEP"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 247 regulators
# exploring ['ZFHX1A', 'ERYF1', 'GATA-1', 'GF-1', 'GF1', 'NF-E1', 'NFE1', 'XLANP', 'XLTDA', 'XLTT', 'LEF-1', 'TCF10', 'TCF1ALPHA', 'TCF7L3', 'AP-1', 'p39', 'JUNDM2', 'EWS-ATF1', 'FUS/ATF-1', 'TREB36']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "ZFHX1A"^^xsd:string) && (?controllerName != "ZFHX1A"^^xsd:string))
#  || ((?controlledName = "ERYF1"^^xsd:string) && (?controllerName != "ERYF1"^^xsd:string))
#  || ((?controlledName = "GATA-1"^^xsd:string) && (?controllerName != "GATA-1"^^xsd:string))
#  || ((?controlledName = "GF-1"^^xsd:string) && (?controllerName != "GF-1"^^xsd:string))
#  || ((?controlledName = "GF1"^^xsd:string) && (?controllerName != "GF1"^^xsd:string))
#  || ((?controlledName = "NF-E1"^^xsd:string) && (?controllerName != "NF-E1"^^xsd:string))
#  || ((?controlledName = "NFE1"^^xsd:string) && (?controllerName != "NFE1"^^xsd:string))
#  || ((?controlledName = "XLANP"^^xsd:string) && (?controllerName != "XLANP"^^xsd:string))
#  || ((?controlledName = "XLTDA"^^xsd:string) && (?controllerName != "XLTDA"^^xsd:string))
#  || ((?controlledName = "XLTT"^^xsd:string) && (?controllerName != "XLTT"^^xsd:string))
#  || ((?controlledName = "LEF-1"^^xsd:string) && (?controllerName != "LEF-1"^^xsd:string))
#  || ((?controlledName = "TCF10"^^xsd:string) && (?controllerName != "TCF10"^^xsd:string))
#  || ((?controlledName = "TCF1ALPHA"^^xsd:string) && (?controllerName != "TCF1ALPHA"^^xsd:string))
#  || ((?controlledName = "TCF7L3"^^xsd:string) && (?controllerName != "TCF7L3"^^xsd:string))
#  || ((?controlledName = "AP-1"^^xsd:string) && (?controllerName != "AP-1"^^xsd:string))
#  || ((?controlledName = "p39"^^xsd:string) && (?controllerName != "p39"^^xsd:string))
#  || ((?controlledName = "JUNDM2"^^xsd:string) && (?controllerName != "JUNDM2"^^xsd:string))
#  || ((?controlledName = "EWS-ATF1"^^xsd:string) && (?controllerName != "EWS-ATF1"^^xsd:string))
#  || ((?controlledName = "FUS/ATF-1"^^xsd:string) && (?controllerName != "FUS/ATF-1"^^xsd:string))
#  || ((?controlledName = "TREB36"^^xsd:string) && (?controllerName != "TREB36"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 247 regulators
# exploring ['LCR-F1', 'TCF11', 'NFE2L1', 'FSGS7', 'PAPRS', 'GTF2D', 'GTF2D1', 'HDL4', 'SCA17', 'TFIID', 'TAXREB67', 'TXREB', 'DELTA', 'GADEVS', 'INO80S', 'UCRBP', 'YIN-YANG-1', 'FKHL6', 'FREAC-2', 'FREAC2']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "LCR-F1"^^xsd:string) && (?controllerName != "LCR-F1"^^xsd:string))
#  || ((?controlledName = "TCF11"^^xsd:string) && (?controllerName != "TCF11"^^xsd:string))
#  || ((?controlledName = "NFE2L1"^^xsd:string) && (?controllerName != "NFE2L1"^^xsd:string))
#  || ((?controlledName = "FSGS7"^^xsd:string) && (?controllerName != "FSGS7"^^xsd:string))
#  || ((?controlledName = "PAPRS"^^xsd:string) && (?controllerName != "PAPRS"^^xsd:string))
#  || ((?controlledName = "GTF2D"^^xsd:string) && (?controllerName != "GTF2D"^^xsd:string))
#  || ((?controlledName = "GTF2D1"^^xsd:string) && (?controllerName != "GTF2D1"^^xsd:string))
#  || ((?controlledName = "HDL4"^^xsd:string) && (?controllerName != "HDL4"^^xsd:string))
#  || ((?controlledName = "SCA17"^^xsd:string) && (?controllerName != "SCA17"^^xsd:string))
#  || ((?controlledName = "TFIID"^^xsd:string) && (?controllerName != "TFIID"^^xsd:string))
#  || ((?controlledName = "TAXREB67"^^xsd:string) && (?controllerName != "TAXREB67"^^xsd:string))
#  || ((?controlledName = "TXREB"^^xsd:string) && (?controllerName != "TXREB"^^xsd:string))
#  || ((?controlledName = "DELTA"^^xsd:string) && (?controllerName != "DELTA"^^xsd:string))
#  || ((?controlledName = "GADEVS"^^xsd:string) && (?controllerName != "GADEVS"^^xsd:string))
#  || ((?controlledName = "INO80S"^^xsd:string) && (?controllerName != "INO80S"^^xsd:string))
#  || ((?controlledName = "UCRBP"^^xsd:string) && (?controllerName != "UCRBP"^^xsd:string))
#  || ((?controlledName = "YIN-YANG-1"^^xsd:string) && (?controllerName != "YIN-YANG-1"^^xsd:string))
#  || ((?controlledName = "FKHL6"^^xsd:string) && (?controllerName != "FKHL6"^^xsd:string))
#  || ((?controlledName = "FREAC-2"^^xsd:string) && (?controllerName != "FREAC-2"^^xsd:string))
#  || ((?controlledName = "FREAC2"^^xsd:string) && (?controllerName != "FREAC2"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
# Explored 248 regulators
# exploring ['HSF 2', 'HSTF 2', 'STAT5', 'KPD', 'MODY9', 'B1G1', 'CD66f', 'DHFRP2', 'FL-NCA-1/2', 'PBG1', 'PS-beta-C/D', 'PS-beta-G-1', 'PSBG-1', 'PSBG1', 'PSG95', 'PSGGA', 'PSGIIA', 'PSG1', 'MGF', 'AT591']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "HSF 2"^^xsd:string) && (?controllerName != "HSF 2"^^xsd:string))
#  || ((?controlledName = "HSTF 2"^^xsd:string) && (?controllerName != "HSTF 2"^^xsd:string))
#  || ((?controlledName = "STAT5"^^xsd:string) && (?controllerName != "STAT5"^^xsd:string))
#  || ((?controlledName = "KPD"^^xsd:string) && (?controllerName != "KPD"^^xsd:string))
#  || ((?controlledName = "MODY9"^^xsd:string) && (?controllerName != "MODY9"^^xsd:string))
#  || ((?controlledName = "B1G1"^^xsd:string) && (?controllerName != "B1G1"^^xsd:string))
#  || ((?controlledName = "CD66f"^^xsd:string) && (?controllerName != "CD66f"^^xsd:string))
#  || ((?controlledName = "DHFRP2"^^xsd:string) && (?controllerName != "DHFRP2"^^xsd:string))
#  || ((?controlledName = "FL-NCA-1/2"^^xsd:string) && (?controllerName != "FL-NCA-1/2"^^xsd:string))
#  || ((?controlledName = "PBG1"^^xsd:string) && (?controllerName != "PBG1"^^xsd:string))
#  || ((?controlledName = "PS-beta-C/D"^^xsd:string) && (?controllerName != "PS-beta-C/D"^^xsd:string))
#  || ((?controlledName = "PS-beta-G-1"^^xsd:string) && (?controllerName != "PS-beta-G-1"^^xsd:string))
#  || ((?controlledName = "PSBG-1"^^xsd:string) && (?controllerName != "PSBG-1"^^xsd:string))
#  || ((?controlledName = "PSBG1"^^xsd:string) && (?controllerName != "PSBG1"^^xsd:string))
#  || ((?controlledName = "PSG95"^^xsd:string) && (?controllerName != "PSG95"^^xsd:string))
#  || ((?controlledName = "PSGGA"^^xsd:string) && (?controllerName != "PSGGA"^^xsd:string))
#  || ((?controlledName = "PSGIIA"^^xsd:string) && (?controllerName != "PSGIIA"^^xsd:string))
#  || ((?controlledName = "PSG1"^^xsd:string) && (?controllerName != "PSG1"^^xsd:string))
#  || ((?controlledName = "MGF"^^xsd:string) && (?controllerName != "MGF"^^xsd:string))
#  || ((?controlledName = "AT591"^^xsd:string) && (?controllerName != "AT591"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 248 regulators
# exploring ['CMT1D', 'CMT4E', 'KROX20', 'CD228', 'MAP97', 'MFI2', 'MTf', 'MELTF', 'AZF', 'AZFA', 'AZF1', 'HSTF1', 'FKHL20', 'RONU', 'WHN', 'Cmyb', 'c-myb', 'c-myb_CDS', 'efg', 'CRS5']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "CMT1D"^^xsd:string) && (?controllerName != "CMT1D"^^xsd:string))
#  || ((?controlledName = "CMT4E"^^xsd:string) && (?controllerName != "CMT4E"^^xsd:string))
#  || ((?controlledName = "KROX20"^^xsd:string) && (?controllerName != "KROX20"^^xsd:string))
#  || ((?controlledName = "CD228"^^xsd:string) && (?controllerName != "CD228"^^xsd:string))
#  || ((?controlledName = "MAP97"^^xsd:string) && (?controllerName != "MAP97"^^xsd:string))
#  || ((?controlledName = "MFI2"^^xsd:string) && (?controllerName != "MFI2"^^xsd:string))
#  || ((?controlledName = "MTf"^^xsd:string) && (?controllerName != "MTf"^^xsd:string))
#  || ((?controlledName = "MELTF"^^xsd:string) && (?controllerName != "MELTF"^^xsd:string))
#  || ((?controlledName = "AZF"^^xsd:string) && (?controllerName != "AZF"^^xsd:string))
#  || ((?controlledName = "AZFA"^^xsd:string) && (?controllerName != "AZFA"^^xsd:string))
#  || ((?controlledName = "AZF1"^^xsd:string) && (?controllerName != "AZF1"^^xsd:string))
#  || ((?controlledName = "HSTF1"^^xsd:string) && (?controllerName != "HSTF1"^^xsd:string))
#  || ((?controlledName = "FKHL20"^^xsd:string) && (?controllerName != "FKHL20"^^xsd:string))
#  || ((?controlledName = "RONU"^^xsd:string) && (?controllerName != "RONU"^^xsd:string))
#  || ((?controlledName = "WHN"^^xsd:string) && (?controllerName != "WHN"^^xsd:string))
#  || ((?controlledName = "Cmyb"^^xsd:string) && (?controllerName != "Cmyb"^^xsd:string))
#  || ((?controlledName = "c-myb"^^xsd:string) && (?controllerName != "c-myb"^^xsd:string))
#  || ((?controlledName = "c-myb_CDS"^^xsd:string) && (?controllerName != "c-myb_CDS"^^xsd:string))
#  || ((?controlledName = "efg"^^xsd:string) && (?controllerName != "efg"^^xsd:string))
#  || ((?controlledName = "CRS5"^^xsd:string) && (?controllerName != "CRS5"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 248 regulators
# exploring ['FND2', 'AD4BP', 'ELP', 'FTZ1', 'FTZF1', 'POF7', 'SF-1', 'SPGF8', 'SRXX4', 'SRXY3', 'hSF-1', 'NR5A1', 'AP2-GAMMA', 'ERF1', 'TFAP2G', 'hAP-2g', 'AP-2', 'AP-2alpha', 'AP2TF', 'BOFS']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "FND2"^^xsd:string) && (?controllerName != "FND2"^^xsd:string))
#  || ((?controlledName = "AD4BP"^^xsd:string) && (?controllerName != "AD4BP"^^xsd:string))
#  || ((?controlledName = "ELP"^^xsd:string) && (?controllerName != "ELP"^^xsd:string))
#  || ((?controlledName = "FTZ1"^^xsd:string) && (?controllerName != "FTZ1"^^xsd:string))
#  || ((?controlledName = "FTZF1"^^xsd:string) && (?controllerName != "FTZF1"^^xsd:string))
#  || ((?controlledName = "POF7"^^xsd:string) && (?controllerName != "POF7"^^xsd:string))
#  || ((?controlledName = "SF-1"^^xsd:string) && (?controllerName != "SF-1"^^xsd:string))
#  || ((?controlledName = "SPGF8"^^xsd:string) && (?controllerName != "SPGF8"^^xsd:string))
#  || ((?controlledName = "SRXX4"^^xsd:string) && (?controllerName != "SRXX4"^^xsd:string))
#  || ((?controlledName = "SRXY3"^^xsd:string) && (?controllerName != "SRXY3"^^xsd:string))
#  || ((?controlledName = "hSF-1"^^xsd:string) && (?controllerName != "hSF-1"^^xsd:string))
#  || ((?controlledName = "NR5A1"^^xsd:string) && (?controllerName != "NR5A1"^^xsd:string))
#  || ((?controlledName = "AP2-GAMMA"^^xsd:string) && (?controllerName != "AP2-GAMMA"^^xsd:string))
#  || ((?controlledName = "ERF1"^^xsd:string) && (?controllerName != "ERF1"^^xsd:string))
#  || ((?controlledName = "TFAP2G"^^xsd:string) && (?controllerName != "TFAP2G"^^xsd:string))
#  || ((?controlledName = "hAP-2g"^^xsd:string) && (?controllerName != "hAP-2g"^^xsd:string))
#  || ((?controlledName = "AP-2"^^xsd:string) && (?controllerName != "AP-2"^^xsd:string))
#  || ((?controlledName = "AP-2alpha"^^xsd:string) && (?controllerName != "AP-2alpha"^^xsd:string))
#  || ((?controlledName = "AP2TF"^^xsd:string) && (?controllerName != "AP2TF"^^xsd:string))
#  || ((?controlledName = "BOFS"^^xsd:string) && (?controllerName != "BOFS"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
# Explored 249 regulators
# exploring ['TFAP2', 'OCT1', 'OTF1', 'oct-1B', 'HNF-1A', 'HNF1', 'HNF4A', 'IDDM20', 'LFB1', 'MODY3', 'TCF-1', 'TCF1', 'C/EBP-delta', 'CELF', 'CRP3', 'NF-IL6-beta', 'IMD39', 'IRF-7', 'IRF-7H', 'IRF7A']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "TFAP2"^^xsd:string) && (?controllerName != "TFAP2"^^xsd:string))
#  || ((?controlledName = "OCT1"^^xsd:string) && (?controllerName != "OCT1"^^xsd:string))
#  || ((?controlledName = "OTF1"^^xsd:string) && (?controllerName != "OTF1"^^xsd:string))
#  || ((?controlledName = "oct-1B"^^xsd:string) && (?controllerName != "oct-1B"^^xsd:string))
#  || ((?controlledName = "HNF-1A"^^xsd:string) && (?controllerName != "HNF-1A"^^xsd:string))
#  || ((?controlledName = "HNF1"^^xsd:string) && (?controllerName != "HNF1"^^xsd:string))
#  || ((?controlledName = "HNF4A"^^xsd:string) && (?controllerName != "HNF4A"^^xsd:string))
#  || ((?controlledName = "IDDM20"^^xsd:string) && (?controllerName != "IDDM20"^^xsd:string))
#  || ((?controlledName = "LFB1"^^xsd:string) && (?controllerName != "LFB1"^^xsd:string))
#  || ((?controlledName = "MODY3"^^xsd:string) && (?controllerName != "MODY3"^^xsd:string))
#  || ((?controlledName = "TCF-1"^^xsd:string) && (?controllerName != "TCF-1"^^xsd:string))
#  || ((?controlledName = "TCF1"^^xsd:string) && (?controllerName != "TCF1"^^xsd:string))
#  || ((?controlledName = "C/EBP-delta"^^xsd:string) && (?controllerName != "C/EBP-delta"^^xsd:string))
#  || ((?controlledName = "CELF"^^xsd:string) && (?controllerName != "CELF"^^xsd:string))
#  || ((?controlledName = "CRP3"^^xsd:string) && (?controllerName != "CRP3"^^xsd:string))
#  || ((?controlledName = "NF-IL6-beta"^^xsd:string) && (?controllerName != "NF-IL6-beta"^^xsd:string))
#  || ((?controlledName = "IMD39"^^xsd:string) && (?controllerName != "IMD39"^^xsd:string))
#  || ((?controlledName = "IRF-7"^^xsd:string) && (?controllerName != "IRF-7"^^xsd:string))
#  || ((?controlledName = "IRF-7H"^^xsd:string) && (?controllerName != "IRF-7H"^^xsd:string))
#  || ((?controlledName = "IRF7A"^^xsd:string) && (?controllerName != "IRF7A"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 250 regulators
# exploring ['IRF7B', 'IRF7C', 'IRF7H', 'HSPC193', 'HsT17436', 'JV15-2', 'LDS1C', 'LDS3', 'MADH3', 'DPC4', 'JIP', 'MADH4', 'MYHRS', 'C-FOS', 'p55', 'ARH12', 'ARHA', 'RHO12', 'RHOH12', 'GTPBP7']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "IRF7B"^^xsd:string) && (?controllerName != "IRF7B"^^xsd:string))
#  || ((?controlledName = "IRF7C"^^xsd:string) && (?controllerName != "IRF7C"^^xsd:string))
#  || ((?controlledName = "IRF7H"^^xsd:string) && (?controllerName != "IRF7H"^^xsd:string))
#  || ((?controlledName = "HSPC193"^^xsd:string) && (?controllerName != "HSPC193"^^xsd:string))
#  || ((?controlledName = "HsT17436"^^xsd:string) && (?controllerName != "HsT17436"^^xsd:string))
#  || ((?controlledName = "JV15-2"^^xsd:string) && (?controllerName != "JV15-2"^^xsd:string))
#  || ((?controlledName = "LDS1C"^^xsd:string) && (?controllerName != "LDS1C"^^xsd:string))
#  || ((?controlledName = "LDS3"^^xsd:string) && (?controllerName != "LDS3"^^xsd:string))
#  || ((?controlledName = "MADH3"^^xsd:string) && (?controllerName != "MADH3"^^xsd:string))
#  || ((?controlledName = "DPC4"^^xsd:string) && (?controllerName != "DPC4"^^xsd:string))
#  || ((?controlledName = "JIP"^^xsd:string) && (?controllerName != "JIP"^^xsd:string))
#  || ((?controlledName = "MADH4"^^xsd:string) && (?controllerName != "MADH4"^^xsd:string))
#  || ((?controlledName = "MYHRS"^^xsd:string) && (?controllerName != "MYHRS"^^xsd:string))
#  || ((?controlledName = "C-FOS"^^xsd:string) && (?controllerName != "C-FOS"^^xsd:string))
#  || ((?controlledName = "p55"^^xsd:string) && (?controllerName != "p55"^^xsd:string))
#  || ((?controlledName = "ARH12"^^xsd:string) && (?controllerName != "ARH12"^^xsd:string))
#  || ((?controlledName = "ARHA"^^xsd:string) && (?controllerName != "ARHA"^^xsd:string))
#  || ((?controlledName = "RHO12"^^xsd:string) && (?controllerName != "RHO12"^^xsd:string))
#  || ((?controlledName = "RHOH12"^^xsd:string) && (?controllerName != "RHOH12"^^xsd:string))
#  || ((?controlledName = "GTPBP7"^^xsd:string) && (?controllerName != "GTPBP7"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
#
# Explored 250 regulators
# exploring ['MTG1', 'CDR3', 'TCRB', 'TCRBV20S2', 'TCRBV2O', 'TCRBV2S2O', 'TRB', 'TRBV20OR9-2', 'CD4mut', 'IMD35', 'JTK1', 'JTK10', 'THCYT3']
# =====================
#
# PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT DISTINCT ?controllerName ?controlType ?controlledName ?ds WHERE {
#     FILTER (
# ((?controlledName = "MTG1"^^xsd:string) && (?controllerName != "MTG1"^^xsd:string))
#  || ((?controlledName = "CDR3"^^xsd:string) && (?controllerName != "CDR3"^^xsd:string))
#  || ((?controlledName = "TCRB"^^xsd:string) && (?controllerName != "TCRB"^^xsd:string))
#  || ((?controlledName = "TCRBV20S2"^^xsd:string) && (?controllerName != "TCRBV20S2"^^xsd:string))
#  || ((?controlledName = "TCRBV2O"^^xsd:string) && (?controllerName != "TCRBV2O"^^xsd:string))
#  || ((?controlledName = "TCRBV2S2O"^^xsd:string) && (?controllerName != "TCRBV2S2O"^^xsd:string))
#  || ((?controlledName = "TRB"^^xsd:string) && (?controllerName != "TRB"^^xsd:string))
#  || ((?controlledName = "TRBV20OR9-2"^^xsd:string) && (?controllerName != "TRBV20OR9-2"^^xsd:string))
#  || ((?controlledName = "CD4mut"^^xsd:string) && (?controllerName != "CD4mut"^^xsd:string))
#  || ((?controlledName = "IMD35"^^xsd:string) && (?controllerName != "IMD35"^^xsd:string))
#  || ((?controlledName = "JTK1"^^xsd:string) && (?controllerName != "JTK1"^^xsd:string))
#  || ((?controlledName = "JTK10"^^xsd:string) && (?controllerName != "JTK10"^^xsd:string))
#  || ((?controlledName = "THCYT3"^^xsd:string) && (?controllerName != "THCYT3"^^xsd:string))
#  ) .
#     FILTER( str(?controllerType) != "http://www.biopax.org/release/biopax-level3.owl#SmallMolecule")  .
#     FILTER (?source IN (<http://pathwaycommons.org/pc2/pid>, <http://pathwaycommons.org/pc2/humancyc>, <http://pathwaycommons.org/pc2/panther>, <http://pathwaycommons.org/pc2/msigdb>)) .
#
#     ?participant bp:displayName ?controlledName ;
#         rdf:type ?controlledType .
#     ?controller bp:displayName ?controllerName ;
#         rdf:type ?controllerType .
#
#     ?controlled bp:participant ?participant .
#
#     ?tempReac a bp:TemplateReactionRegulation ;
#         bp:controlled ?controlled ;
#         bp:controller ?controller ;
#         bp:controlType ?controlType ;
#         bp:dataSource ?source .
# }
#
# =====================
# Explored 250 regulators
# Exploring alted due to maximum depth
# --- Upstream regulation network in 44.49 seconds ---
# Number of nodes = 246
# Number of edges = 897

# %%
def read_input_genes(filename):
    res = []
    with open(filename, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=' ', quotechar='|')
        for row in reader:
            res.append(''.join(row))
    return res

input_genes = read_input_genes('/Users/gaignard-a/Documents/Dev/BRAvo/nathalie-TF.csv')

# %%
def write_to_SIF(graph, filename):
    with open(filename, 'w', newline='') as csvfile:
        sif_writer = csv.writer(csvfile, delimiter='\t')
        for e in G.edges(data='label'):
            sif_writer.writerow([e[0], e[2], e[1]])
    print('SIF network written to ' + filename)

write_to_SIF(G, 'out.sif')
# Out:
# SIF network written to out.sif

# %%
import operator
centrality = nx.degree_centrality(G)
#centrality = nx.closeness_centrality(G)
#centrality = nx.betweenness_centrality(G)
sorted_centrality = reversed(sorted(centrality.items(), key=operator.itemgetter(1)))
sorted_centrality = list(sorted_centrality)
cpt = 0
md = """
| Gene | Degree Centrality |
|------|------|
"""
for g in sorted_centrality:
    md += "| " + g[0] + " | " + str(g[1]) + " | \n"
    cpt += 1
    if cpt > 9:
        break
#print(md)
display(Markdown(md))
# Out:
# | Gene | Degree Centrality |
# |------|------|
# | POU2F1 | 0.22448979591836737 |
# | EGR2 | 0.2 |
# | MAZ | 0.1836734693877551 |
# | FOS | 0.1836734693877551 |
# | PAX2 | 0.17551020408163268 |
# | EGR3 | 0.163265306122449 |
# | HNF1A | 0.15918367346938778 |
# | LEF1 | 0.1510204081632653 |
# | ESRRA | 0.1510204081632653 |
# | SP1 | 0.1469387755102041 |

# %%
edges = G.edges()
colors = [G[u][v]['color'] for u,v in edges]

nx.draw_spring(G, 
               with_labels=True, 
               edge_color = colors,
               node_color = 'bisque',
               font_weight='light', 
               node_size = 2000, 
               width = 2)
plt.show()

# %% [markdown]
# # 4. Synonym-based network simplification

# %%
def fast_reg_network_syn_simp(graph, index_syn):
    H = graph.copy()
    cpt = 0
    nodes_size = len(H.nodes())
    for n in H.nodes():    
        #print('for each ' + str(n))
        for m in H.nodes():
            if n not in m:
                #print('\tfor each ' + str(m))
                if (fast_are_synonyms(n,m, index_syn=index_syn)):
                    key = index_syn[n]
                    if n not in key:
                        #print('\t\t' + str(n) + ' is synonym with ' + str(m))
                        print('\t\t' + 'merging node ' + str(n) + ' into node ' + str(key))
                        try:
                            H = nx.contracted_nodes(H, key, n)
                        except:
                            continue
                    if m not in key:
                        print('\t\t' + 'merging node ' + str(m) + ' into node ' + str(key))
                        try:
                            H = nx.contracted_nodes(H, key, m)
                        except:
                            continue
    return H

# %%
start_time = time.time()
G_prime = fast_reg_network_syn_simp(G, index_syn)
elapsed_time = round((time.time() - start_time), 2)
print("--- Network simplification in %s seconds ---" % elapsed_time)

write_to_SIF(G_prime, 'out_second.sif')
print('Nodes after simplification = ' + str(len(G_prime.nodes())))
print('Edges after simplification = ' + str(len(G_prime.edges())))
# Out:
# 		merging node AP1 into node JUN
# 		merging node AP1 into node JUN
# 		merging node TCF1 into node HNF1A
# 		merging node HNF4A into node HNF1A
# 		merging node TCF1 into node HNF1A
# 		merging node HNF4A into node HNF1A
# 		merging node p300 into node EP300
# 		merging node c-Jun into node JUN
# 		merging node p300 into node EP300
# 		merging node ATF2 into node GDNF
# 		merging node ATF1 into node GDNF
# 		merging node ATF1 into node GDNF
# 		merging node ICER into node CREM
# 		merging node c-Jun into node JUN
# 		merging node ICER into node CREM
# 		merging node FOXM1C into node FOXM1
# --- Network simplification in 0.11 seconds ---
# SIF network written to out_second.sif
# Nodes after simplification = 238
# Edges after simplification = 889

# %%
edges = G_prime.edges()
colors = [G_prime[u][v]['color'] for u,v in edges]

nx.draw_spring(G_prime, 
               with_labels=True, 
               edge_color = colors,
               node_color = 'bisque',
               font_weight='light', 
               node_size = 2000, 
               width = 2)
plt.show()

# %% [markdown]
# ---
# ---
# # Validating the network summarization on a simple example
# In the graph, edges represent either `alias` or `regulation` links.

# %%
G2 = nx.DiGraph()
G2.add_edges_from([("B", "B'"), ("B", "B''"), ("A", "A'")], label='blue')
G2.add_edges_from([("B''", "A'")], label='red')

nx.draw_spring(G2, 
               with_labels=True, 
               node_color = 'bisque',
               font_weight='light', 
               node_size = 2000, 
               width = 2)
plt.show()

# %%
""" The two indexes """
i_syn = {"B'":"B", "B''":"B", 'B':'B', "A'":"A", 'A':'A'}
i_std = {"A":["A'"], "B":["B'","B''"]}

G2_prime = fast_reg_network_syn_simp(G2, i_syn)

nx.draw_spring(G2_prime, 
               with_labels=True, 
               node_color = 'bisque',
               font_weight='light', 
               node_size = 2000, 
               width = 2)
plt.show()
# Out:
# 		merging node A' into node A
# 		merging node B' into node B
# 		merging node B'' into node B
