# %% [markdown]
# # Demonstration for the upstream regulation network reconstruction
#
# This notebook demonstrates how to use BRAvo to reconstruct a regulation network with specific options and use it as a model, here to infer new knownledge from partial knowledge on nodes evolution.

# %%
# Imports
import time
import csv
from IPython.display import display, Markdown, Latex
import networkx as nx
import bravo.regulation as regulation
import bravo.signaling as signaling
import bravo.config as config
import bravo.util as util
import pyBravo as bravo_main

# %% [markdown]
# ## Network reconstruction

# %% [markdown]
# ### Global options
#
# We define below the global options regarding the execution:
#
# - Max depth of 10 levels
# - Fast reconstruction (look only at standard names)
# - Decompose complexes
# - Extend search by considering synonyms and removing suffixes
# - Include unsinged interactions
# - Use Pathway Commons' SPARQL endpoint
# - Consider all data sources except MiRTarBase and MSigDB

# %%
# Global options

config.MAX_DEPTH = 10
config.HAS_MAX_DEPTH = True
config.FAST = True
config.DECOMPOSE_COMPLEXES = True
config.EXTEND_WITH_SYNONYMS = True
config.EXTEND_WITH_SUFFIXES = True
config.UNKNOWN = True
config.SPARQL_ENDPOINT = "http://rdf.pathwaycommons.org/sparql/"
config.VERBOSE = False

""" all possible data sources """
ds = ['bind', 'biogrid', 'corum',
      'ctd', 'dip', 'drugbank', 'hprd', 'humancyc', 'inoh',
      'intact', 'kegg', 'mirtarbase', 'netpath', 'panther',
      'pid', 'psp', 'reactome', 'reconx', 'smpdb', 'wp',
      'intact_complex', 'msigdb', 'reach', 'wikipathways']

config.DATA_SOURCES = set(ds) - set(['mirtarbase', 'msigdb'])

pybravo_stdout = [''] * 3

# %% [markdown]
# ### Gene names input list
#
# Here we read the list of input gene names from a file called `input-910.csv`. This file should contain one gene name per line.

# %%
# Read input genes list from a file
def read_input_genes(filename):
    res = []
    with open(filename, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=' ', quotechar='|')
        for row in reader:
            res.append(''.join(row))
    return res

# Genes input list
gene_list = read_input_genes('reg-demo/data/input-910.csv')
print('{} genes in input list'.format(len(gene_list)))
# Out:
# 910 genes in input list

# %% [markdown]
# ### Initial reconstruction
#
# We now call the reconstruction on the previous list of gene names.
# This iterative step is performed by querying the Pathway Commons endpoint and using the results to complete the graph and prepare the next query.
# It may take some time, typically between 20 and 30 minutes.

# %%
# %%capture --no-display pybravo_stdout_0

start_time = time.time()

# Call reconstruction
reconstructed_network = regulation.upstream_regulation(gene_list)

elapsed_time = round((time.time() - start_time), 2)

# %%
print("--- Upstream regulation network reconstructed in {} seconds ---".format(elapsed_time))
# Out:
# --- Upstream regulation network reconstructed in 1783.73 seconds ---

# %%
# %%capture --no-display pybravo_stdout_1

# Build digraph representation in memory
G = bravo_main.build_nx_digraph(reconstructed_network)

bravo_main.write_to_SIF(G, 'reg-demo/out.sif')
bravo_main.write_provenance(G, 'reg-demo/out-provenance.csv')

# %% [markdown]
# ### Synonym-based unification
#
# We now perform a synonym-unification, which consists in fusing nodes together if they are synonyms.
# This process is useful because of the high heterogeneity of the data sources that compose Pathway Commons.
# It typically takes a few seconds.

# %%
# %%capture --no-display pybravo_stdout_2

start_time = time.time()
# Perform unification
G_prime = util.fast_reg_network_unification(G, util.index_syn)
elapsed_time = round((time.time() - start_time), 2)
print("--- Network simplification in %s seconds ---" % elapsed_time)

# Write to files
bravo_main.write_to_SIF(G_prime, 'reg-demo/out-unified.sif')
bravo_main.write_provenance(G_prime, 'reg-demo/out-unified-provenance.csv')

# Count nodes/edges
print('Nodes after simplification = ' + str(len(G_prime.nodes())))
print('Edges after simplification = ' + str(len(G_prime.edges())))

# Compute centrality
print(bravo_main.get_centrality_as_md(G_prime))

# %% [markdown]
# ### Saving output
#
# Here we simply save all output provided by pyBRAvo during the reconstruction into a texte file.

# %%
all_stdout = '\n'.join([s.stdout for s in [pybravo_stdout_0, pybravo_stdout_1, pybravo_stdout_2]])
print(all_stdout)
# Out:
# to be explored after complex decomposition ['LUM', 'CPZ', 'DCN', 'ISLR', 'FNDC1', 'THBS2', 'COL16A1', 'COL1A1', 'COL3A1', 'COL5A1', 'SSC5D', 'MMP28', 'GEM', 'DACT3', 'MRC2', 'GPR124', 'LOXL1', 'ST6GAL2', 'COL1A2', 'PRICKLE1', 'LTBP2', 'COL6A3', 'CDR2L', 'PMP22', 'EMILIN1', 'COL14A1', 'CDH11', 'C1QTNF2', 'CCDC80', 'EFEMP1', 'GLT8D2', 'GGT5', 'ANTXR1', 'SNAI1', 'TSHZ3', 'PPAPDC1A', 'ALDH1A3', 'HEPH', 'FBN1', 'ECM1', 'DPYSL3', 'SRPX', 'PODN', 'GFPT2', 'FOXL1', 'COL10A1', 'GAS1', 'ITGA11', 'GLI2', 'HAND2', 'VCAN', 'GPX8', 'POSTN', 'CRISPLD2', 'PTGIR', 'CALHM2', 'FOXF1', 'MOXD1', 'MGP', 'ASPN', 'COL12A1', 'ZNF469', 'CHST3', 'NHS', 'LAMA2', 'AEBP1', 'PCDH7', 'HTRA3', 'HDGFRP3', 'MXRA5', 'HEYL', 'SVEP1', 'MAP1A', 'SPEG', 'GLI3', 'COL6A2', 'F2R', 'FAP', 'C13orf33', 'SEMA3C', 'ALDH1L2', 'LXN', 'PHLDB1', 'PRELP', 'ADAMTS2', 'PMEPA1', 'EPHA3', 'FLNA', 'RSPO3', 'TGFB3', 'TMEM132E', 'SGCA', 'C1QTNF7', 'COL8A2', 'ADAMTS12', 'MFAP4', 'LAMA1', 'PLAT', 'CTBP2', 'COL4A2', 'NBLA00301', 'BGN', 'LOC100130776', 'SHISA2', 'SCD5', 'PDPN', 'PDE1A', 'MMP2', 'LRRC4C', 'EDNRA', 'LZTS1', 'GEFT', 'WFDC1', 'COL8A1', 'AMPH', 'LHFP', 'MXRA8', 'ABR', 'MYOF', 'HOXB4', 'PXDN', 'MAP1B', 'STMN2', 'LRRC32', 'JAG1', 'SPON1', 'PDZD4', 'COMP', 'WISP1', 'ITGA3', 'SFRP1', 'KAL1', 'LTBP4', 'SULF1', 'HS3ST1', 'FMOD', 'HSPB2', 'XYLT1', 'ARHGAP6', 'FBLN2', 'CACNA1C', 'LEPREL1', 'TCF21', 'ZNF521', 'MRVI1', 'LBH', 'EFNB3', 'ARHGEF10', 'UNC5B', 'THBD', 'SLIT2', 'FLRT2', 'ZFPM2', 'TSPYL5', 'DCLK1', 'CPXM1', 'GABBR1', 'PCBP3', 'TSPAN2', 'PKNOX2', 'MARVELD1', 'TMEM119', 'FOXF2', 'PELI2', 'NOTCH3', 'TMEM173', 'CCL21', 'WBSCR17', 'TNC', 'SSPN', 'ID4', 'RGS4', 'PTPN13', 'CCDC3', 'HOXB3', 'TAGLN', 'SFRP4', 'FGFR1', 'LEPREL2', 'CLEC11A', 'PRR16', 'MYH11', 'RCAN2', 'PLA2R1', 'NEXN', 'COL13A1', 'PDE10A', 'ARHGEF17', 'GUCY1A3', 'GAL3ST4', 'NTM', 'CPXM2', 'PTGIS', 'CERCAM', 'LGI2', 'PCDH18', 'WNT2', 'ITGA9', 'AFAP1', 'AXL', 'FAM171B', 'INMT', 'ENDOD1', 'DKK2', 'MEIS3', 'IGFBP5', 'SLC24A3', 'COL6A1', 'SCARF2', 'CCDC8', 'KIF26A', 'TNFAIP6', 'PCDHGA12', 'ROR2', 'MN1', 'HSPB7', 'PNMA2', 'PODNL1', 'KCTD12', 'JPH2', 'P4HA3', 'CTSK', 'FIBIN', 'TM6SF1', 'NTRK2', 'CCL2', 'FOXS1', 'PDZRN3', 'FOXC2', 'MYL9', 'KAZ', 'ELN', 'SCG2', 'CLIP3', 'C11orf63', 'C1QTNF1', 'RAB31', 'ODZ4', 'OLFML2A', 'GUCY1B3', 'RGS11', 'HAS1', 'FZD2', 'MYO10', 'PNMAL2', 'LAMC2', 'ARMCX2', 'SUSD5', 'NGFR', 'TEK', 'FSTL1', 'LRRC15', 'SNCA', 'LOC728264', 'CLIC6', 'SAMD14', 'VGLL3', 'MSRB3', 'NALCN', 'MEOX1', 'PRSS23', 'BHLHE22', 'RASL11B', 'PTH1R', 'KCNE4', 'LRFN4', 'LPAR1', 'ZNF423', 'ISLR2', 'FAM43B', 'EGR2', 'PTGS2', 'DACT1', 'TWIST1', 'MMP23B', 'SOD3', 'TMEM159', 'TSPAN11', 'C7', 'GPBAR1', 'MEGF6', 'KIAA1211', 'IGF1R', 'SLIT3', 'NRP2', 'CCL11', 'PROCR', 'CHST4', 'ALOX5', 'EFEMP2', 'RNF150', 'KIF3C', 'MYOZ1', 'VTCN1', 'AQP1', 'CXCL14', 'CREB3L1', 'MMP7', 'TCEAL7', 'STON1', 'LAMC3', 'PAPPA', 'NOV', 'ADAM12', 'APLNR', 'HAS2', 'TPPP3', 'IL17RD', 'TIMP2', 'KIAA1644', 'MDFI', 'RAI2', 'LRRK1', 'NXN', 'PDGFRA', 'SOX8', 'SULF2', 'OSBPL5', 'LRRC55', 'ADRA2A', 'CRLF1', 'BEND6', 'PRAM1', 'OLFM1', 'ADAMTSL1', 'MAGEL2', 'FAM180A', 'F3', 'SLC6A6', 'DNAH2', 'KIRREL', 'TMEM130', 'WISP2', 'ABI3BP', 'ADCY5', 'EPHB3', 'SYNPO2', 'TPBG', 'PLN', 'FAM101A', 'AG2', 'IGFBP6', 'CNN1', 'PRKG1', 'NPTXR', 'BHLHE41', 'FHL2', 'FSTL3', 'LOC100270710', 'HGF', 'DHH', 'BMPR1B', 'ADAM28', 'GPR173', 'METRNL', 'OGN', 'EFS', 'MBOAT2', 'ITGBL1', 'DZIP1', 'CCDC74A', 'C20orf103', 'ATP10A', 'PDLIM3', 'OMD', 'MAPK10', 'ITGB8', 'BNC2', 'STRA6', 'RBMS3', 'CYS1', 'CXCL6', 'SAMD11', 'MAP9', 'PLXDC2', 'CTXN1', 'FZD10', 'CDH3', 'PLCB4', 'TIMP1', 'STMN3', 'PAMR1', 'PDLIM4', 'NACAD', 'BDKRB2', 'HHIP', 'RRAD', 'COL15A1', 'MFAP2', 'CILP2', 'ADAMTS15', 'FLJ23867', 'CXCL12', 'LOC644538', 'SFRP5', 'SHISA3', 'CRISPLD1', 'ADAMTS3', 'WTIP', 'PDE5A', 'PAPLN', 'NUDT11', 'TMEM200C', 'CRIP1', 'FRZB', 'CILP', 'PLA2G4A', 'WNT2B', 'CLDN10', 'FGF1', 'REM1', 'TMEM200A', 'CCL22', 'ITIH5', 'PLCXD3', 'PTN', 'LIMCH1', 'ASAM', 'PFKFB3', 'SRPX2', 'ANO4', 'LTC4S', 'PRSS22', 'JAM2', 'CST2', 'MSC', 'CRT ...
# new synonmys to be explored:['LDC', 'SLRR2D', 'CSCD', 'DSPG2', 'PG40', 'PGII', 'PGS2', 'SLRR1B', 'HsT17563', 'Meflin', 'AGS8', 'FNDC2', 'MEL4B3', 'bA243O10.1', 'dJ322A24.1', 'TSP2', '447AA', 'FP1572', 'EDSARTH1', 'EDSC', 'OI1', 'OI2', 'OI3', 'OI4', 'EDS4A', 'EDSVASC', 'EDSC', 'EDSCL1', 'S5D-SRCRB', 'EPILYSIN', 'MM28', 'MMP-25', 'MMP-28', 'MMP25', 'KIR', 'DAPPER3', 'RRR1', 'CD280', 'CLEC13E', 'ENDO180', 'UPARAP', 'ADGRA2', 'TEM5', 'LOL', 'LOXL', 'SIAT2', 'ST6GalII', 'EDSARTH2', 'EDSCV', 'OI4', 'EPM1B', 'RILP', 'LTBP3', 'DASS', 'GPHYSD3', 'LTBP-3', 'STHAG6', 'pp6425', 'BTHLM1', 'DYT27', 'UCMD1', 'HUMPPA', 'PXMP2', 'EMI', 'EMILIN', 'gp115', 'UND', 'CAD11', 'CDHOB', 'ESWS', 'OB', 'OSF-4', 'CTRP2', 'zacrp2', 'DRO1', 'SSG1', 'URB', 'okuribin', 'DHRD', 'DRAD', 'FBLN3', 'FBNL', 'FIBL-3', 'MLVT', 'MTLV', 'S1-5', 'GGL', 'GGT 5', 'GGT-REL', 'GGTLA1', 'ATR', 'GAPO', 'TEM8', 'SLUGH2', 'SNA', 'SNAH', 'SNAIL', 'SNAIL1', 'dJ710H13.1', 'TSH3', 'ZNF537', 'PLPP4', 'DPPL2', 'PPAPDC1', 'ALDH1A6', 'ALDH6', 'MCOP8', 'RALDH3', 'CPL', 'ACMICD', 'ECTOL1', 'FBN', 'GPHYSD2', 'MASS', 'MFLS', 'MFS1', 'OCTD', 'SGS', 'SSKS', 'WMS', 'WMS2', 'URBWD', 'CRMP-4', 'CRMP4', 'DRP-3', 'DRP3', 'LCRMP', 'ULIP', 'ULIP-1', 'DRS', 'ETX1', 'HEL-S-83p', 'SRPX1', 'PCAN', 'SLRR5A', 'GFAT', 'GFAT 2', 'GFAT2', 'FKH6', 'FKHL11', 'FREAC7', 'HsT18964', 'CJS', 'HPE9', 'PHS2', 'THP1', 'THP2', 'DHAND2', 'Hed', 'Thing2', 'bHLHa26', 'dHand', 'CSPG2', 'ERVR', 'GHAP', 'PG-M', 'WGN', 'WGN1', 'EPLA847', 'GPx-8', 'GSHPx-8', 'UNQ847', 'OSF-2', 'OSF2', 'PDLPOSTN', 'PN', 'CRISP11', 'LCRISP2', 'LGL1', 'IP', 'PRIPR', 'FAM26B', 'ACDMPV', 'FKHL5', 'FREAC1', 'MOX', 'PRO5780', 'dJ248E1.1', 'GIG36', 'MGLAP', 'NTI', 'OS3', 'PLAP-1', 'PLAP1', 'SLRR1C', 'BA209D8.1', 'BTHLM2', 'COL12A1L', 'DJ234P15.1', 'EDSMYP', 'UCMD2', 'BCS', 'BCS1', 'C6ST', 'C6ST1', 'HSD', 'CTRCT40', 'CXN', 'SCML1', 'LAMM', 'ACLP', 'BH-Pcdh', 'BHPCDH', 'PPP1R120', 'Prsp', 'Tasp', 'HDGFL3', 'CGI-142', 'HDGF-2', 'HDGF2', 'HRP-3', 'HESR3', 'HEY3', 'HRT3', 'bHLHb33', 'C9orf13', 'CCP22', 'POLYDOM', 'SEL-OB', 'SELOB', 'METAP1', 'MetAP1A', 'APEG-1', 'APEG1', 'BPEG', 'CNM5', 'SPEGalpha', 'SPEGbeta', 'ACLS', 'GCPS', 'GLI3-190', 'GLI3FL', 'PAP-A', 'PAPA', 'PAPA1', 'PAPB', 'PHS', 'PPDIV', 'BTHLM1', 'PP3610', 'UCMD1', 'CF2R', 'HTR', 'PAR-1', 'PAR1', 'TR', 'GLMN', 'FAP48', 'FAP68', 'FKBPAP', 'GLML', 'GVM', 'VMGLOM', 'MEDAG', 'AWMS3', 'MEDA-4', 'MEDA4', 'hAWMS3', 'SEMAE', 'SemE', 'mtFDH', 'ECI', 'TCI', 'LL5A', 'MST161', 'MSTP161', 'SLRR2A', 'ADAM-TS2', 'ADAMTS-2', 'ADAMTS-3', 'EDSDERMS', 'NPI', 'PC I-NP', 'PCI-NP', 'PCINP', 'PCPNI', 'PNPI', 'STAG1', 'TMEPAI', 'EK4', 'ETK', 'ETK1', 'HEK', 'HEK4', 'TYRO4', 'ABP-280', 'ABPX', 'CSBS', 'CVD1', 'FGS2', 'FLN', 'FLN-A', 'FLN1', 'FMD', 'MNS', 'NHBP', 'OPD', 'OPD1', 'OPD2', 'XLVD', 'XMVD', 'CRISTIN1', 'PWTSR', 'THSD2', 'ARVD', 'ARVD1', 'LDS5', 'RNHF', 'TGF-beta3', 'DFNB99', '50DAG', 'ADL', 'DAG2', 'DMDA2', 'LGMD2D', 'SCARMD1', 'adhalin', 'CTRP7', 'ZACRP7', 'FECD', 'FECD1', 'PPCD', 'PPCD2', 'PRO4389', 'LAMA', 'PTBHS', 'S-LAM-alpha', 'T-PA', 'TPA', 'ICH', 'POREN2', 'HAND2-AS1', 'DEIN', 'UPH', 'DSPG1', 'MRLS', 'PG-S1', 'PGI', 'SEMDX', 'SLRR1A', 'C13orf13', 'PRO28631', 'TMEM46', 'WGAR9166', 'bA398O19.2', 'hShisa', 'ACOD4', 'FADS4', 'HSCD5', 'SCD2', 'SCD4', 'AGGRUS', 'GP36', 'GP40', 'Gp38', 'HT1A-1', 'OTS8', 'PA2.26', 'T1A', 'T1A-2', 'T1A2', 'TI1A', 'CAM-PDE 1A', 'CAM-PDE-1A', 'HCAM-1', 'HCAM1', 'HSPDE1A', 'CLG4', 'CLG4A', 'MMP-2', 'MMP-II', 'MONA', 'TBE-1', 'NGL-1', 'NGL1', 'ET-A', 'ETA', 'ETA-R', 'ETAR', 'ETRA', 'MFDA', 'hET-AR', 'F37', 'FEZ1', 'ARHGEF25', 'p63RhoGEF', 'PS20', 'C3orf7', 'AMPH1', 'LHFPL6', 'ASP3', 'MDB', 'FER1L3', 'HOX-2.6', 'HOX2', 'HOX2F', 'ASGD7', 'COPOA', 'D2S448', 'D2S448E', 'MG50', 'PRG2', 'PXN', 'VPO', 'FUTSCH', 'MAP5', 'PPP1R102', 'SCG10', 'SCGN10', 'D11S833E', 'GARP', 'AGS', 'AGS1', 'AHD', 'AWS', 'CD339', 'DCHE', 'HJ1', 'JAGL1', 'VSGP/F-spondin', 'f-spondin', 'LNX5', 'LU1', 'PDZK4', 'PDZRN4L', 'EDM1', 'EPD1', 'MED', 'PSACH', 'THBS5', 'TSP5', 'CCN4', 'WISP1-OT1', 'WISP1-UT1', 'WISP1c', ' ...
#
# Explored 16 regulators
#
# Explored 16 regulators
#
# Explored 25 regulators
#
# Explored 25 regulators
#
# Explored 28 regulators
# 		removing suffix  protein for PPARA protein
# 				 --> PPARA
# 		removing suffix  protein for TNF protein
# 				 --> TNF
# 		removing suffix  protein for ESR2 protein
# 				 --> ESR2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  protein for MPO protein
# 				 --> MPO
# 		removing suffix  protein for ESR1 protein
# 				 --> ESR1
# 		removing suffix  complex for tungsten carbide/Cobalt complex
# 				 --> tungsten carbide/Cobalt
# 		removing suffix  protein for CXCL8 protein
# 				 --> CXCL8
# 		removing suffix  protein for VEGFA protein
# 				 --> VEGFA
# 		removing suffix  protein for S100B protein
# 				 --> S100B
# 		removing suffix  protein for TLR2 protein
# 				 --> TLR2
# 		removing suffix  protein for TNFSF11 protein
# 				 --> TNFSF11
# 		removing suffix  protein for VEGFC protein
# 				 --> VEGFC
# 		removing suffix  protein for IFNG protein
# 				 --> IFNG
# 		removing suffix  protein for AGT protein modified form
# 				 --> AGT modified form
# 		removing suffix  modified form for AGT modified form
# 				 --> AGT
# 		removing suffix  protein for PPARG protein
# 				 --> PPARG
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  protein for IL1A protein
# 				 --> IL1A
# 		removing suffix  protein for IL1B protein
# 				 --> IL1B
# 		removing suffix  protein for HGF protein
# 				 --> HGF
# 		removing suffix  protein for HRAS protein
# 				 --> HRAS
# 		removing suffix  protein for PRKCA protein
# 				 --> PRKCA
# 		removing suffix  protein for TGFA protein
# 				 --> TGFA
# 		removing suffix  protein for RB1 protein
# 				 --> RB1
# 		removing suffix  protein for F2 protein
# 				 --> F2
# 		removing suffix  complex for Vitallium analog/titanium dioxide complex
# 				 --> Vitallium analog/titanium dioxide
# 		removing suffix  protein for PRODH protein
# 				 --> PRODH
# 		removing suffix  complex for Polyethyleneimine/Gold complex
# 				 --> Polyethyleneimine/Gold
# 		removing suffix  protein for E2F1 protein
# 				 --> E2F1
# 		removing suffix  protein for IL1B protein
# 				 --> IL1B
# 		removing suffix  protein for TNF protein
# 				 --> TNF
# 		removing suffix  protein for JUN protein
# 				 --> JUN
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  protein for TP53 protein
# 				 --> TP53
# 		removing suffix  protein for APP protein modified form
# 				 --> APP modified form
# 		removing suffix  modified form for APP modified form
# 				 --> APP
# 		removing suffix  mRNA for GSN mRNA
# 				 --> GSN
# 		removing suffix  protein for PSEN2 protein mutant form
# 				 --> PSEN2 mutant form
# 		removing suffix  mutant form for PSEN2 mutant form
# 				 --> PSEN2
# 		removing suffix  protein for EDN1 protein
# 				 --> EDN1
# 		removing suffix  complex for Vitallium analog/titanium dioxide complex
# 				 --> Vitallium analog/titanium dioxide
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  complex for Thiosemicarbazones/Copper complex
# 				 --> Thiosemicarbazones/Copper
# 		removing suffix  protein for IGF2 protein
# 				 --> IGF2
# 		removing suffix  protein for IGF1 protein
# 				 --> IGF1
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
#
# Explored 74 regulators
#
# Explored 76 regulators
#
# Explored 79 regulators
#
# Explored 82 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
#
# Explored 83 regulators
#
# Explored 83 regulators
#
# Explored 88 regulators
#
# Explored 93 regulators
#
# Explored 93 regulators
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  protein for INS protein
# 				 --> INS
#
# Explored 93 regulators
#
# Explored 93 regulators
#
# Explored 94 regulators
#
# Explored 95 regulators
# 		removing suffix  complex for NFX1/SIN3/HDAC complex
# 				 --> NFX1/SIN3/HDAC
#
# Explored 112 regulators
#
# Explored 112 regulators
#
# Explored 114 regulators
#
# Explored 115 regulators
#
# Explored 115 regulators
#
# Explored 115 regulators
#
# Explored 115 regulators
#
# Explored 115 regulators
#
# Explored 115 regulators
#
# Explored 116 regulators
#
# Explored 116 regulators
#
# Explored 116 regulators
#
# Explored 118 regulators
#
# Explored 118 regulators
#
# Explored 118 regulators
#
# Explored 118 regulators
#
# Explored 118 regulators
#
# Explored 120 regulators
#
# Explored 120 regulators
#
# Explored 120 regulators
#
# Explored 120 regulators
#
# Explored 120 regulators
#
# Explored 120 regulators
#
# Explored 124 regulators
#
# Explored 124 regulators
#
# Explored 124 regulators
#
# Explored 124 regulators
#
# Explored 124 regulators
#
# Explored 124 regulators
#
# Explored 124 regulators
#
# Explored 124 regulators
#
# Explored 124 regulators
#
# Explored 124 regulators
#
# Explored 126 regulators
#
# Explored 126 regulators
#
# Explored 128 regulators
#
# Explored 128 regulators
#
# Explored 128 regulators
#
# Explored 128 regulators
#
# Explored 128 regulators
#
# Explored 128 regulators
#
# Explored 128 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 132 regulators
#
# Explored 133 regulators
#
# Explored 133 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for DCN mRNA
# 				 --> DCN
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for LUM mRNA
# 				 --> LUM
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for LUM mRNA
# 				 --> LUM
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for DCN mRNA
# 				 --> DCN
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for CPZ mRNA
# 				 --> CPZ
# 		removing suffix  complex for tungsten carbide/Cobalt complex
# 				 --> tungsten carbide/Cobalt
# 		removing suffix  mRNA for DCN mRNA
# 				 --> DCN
#
# Explored 133 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for THBS2 mRNA
# 				 --> THBS2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for FNDC1 mRNA
# 				 --> FNDC1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for ISLR mRNA
# 				 --> ISLR
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for THBS2 mRNA
# 				 --> THBS2
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  mRNA for COL16A1 mRNA
# 				 --> COL16A1
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  mRNA for THBS2 mRNA
# 				 --> THBS2
#
# Explored 133 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL5A1 mRNA
# 				 --> COL5A1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL3A1 mRNA
# 				 --> COL3A1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for COL3A1 mRNA
# 				 --> COL3A1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for COL3A1 mRNA
# 				 --> COL3A1
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for COL5A1 mRNA
# 				 --> COL5A1
# 		removing suffix  protein for IL6 protein
# 				 --> IL6
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  mRNA for SULF1 mRNA
# 				 --> SULF1
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for COL3A1 mRNA
# 				 --> COL3A1
# 		removing suffix  protein for ACTA2 protein
# 				 --> ACTA2
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for DEFA1 protein
# 				 --> DEFA1
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for NR1I2 protein
# 				 --> NR1I2
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for AGT protein modified form
# 				 --> AGT modified form
# 		removing suffix  modified form for AGT modified form
# 				 --> AGT
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for AGT protein modified form
# 				 --> AGT modified form
# 		removing suffix  modified form for AGT modified form
# 				 --> AGT
# 		removing suffix  mRNA for COL3A1 mRNA
# 				 --> COL3A1
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for COL5A1 mRNA
# 				 --> COL5A1
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for COL3A1 mRNA
# 				 --> COL3A1
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for COL3A1 mRNA
# 				 --> COL3A1
# 		removing suffix  protein for IL1B protein
# 				 --> IL1B
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for IL1B protein
# 				 --> IL1B
# 		removing suffix  mRNA for COL3A1 mRNA
# 				 --> COL3A1
# 		removing suffix  protein for IL1B protein
# 				 --> IL1B
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for ABL1 protein
# 				 --> ABL1
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for LEP protein
# 				 --> LEP
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
# 		removing suffix  protein for DEFA2 protein
# 				 --> DEFA2
# 		removing suffix  mRNA for COL1A1 mRNA
# 				 --> COL1A1
#
# Explored 140 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for MRC2 mRNA
# 				 --> MRC2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for GEM mRNA
# 				 --> GEM
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for GEM mRNA
# 				 --> GEM
# 		removing suffix  complex for ormosil/Polyethylene Glycols complex
# 				 --> ormosil/Polyethylene Glycols
# 		removing suffix  mRNA for GEM mRNA
# 				 --> GEM
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for DACT3 mRNA
# 				 --> DACT3
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for GEM mRNA
# 				 --> GEM
# 		removing suffix  mRNA for GEM mRNA
# 				 --> GEM
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for GEM mRNA
# 				 --> GEM
#
# Explored 143 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL1A2 mRNA
# 				 --> COL1A2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PRICKLE1 mRNA
# 				 --> PRICKLE1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PRICKLE1 mRNA
# 				 --> PRICKLE1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for ST6GAL2 mRNA
# 				 --> ST6GAL2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for COL1A2 mRNA
# 				 --> COL1A2
# 		removing suffix  protein for CYP2E1 protein
# 				 --> CYP2E1
# 		removing suffix  mRNA for COL1A2 mRNA
# 				 --> COL1A2
# 		removing suffix  protein for BMP2 protein
# 				 --> BMP2
# 		removing suffix  mRNA for COL1A2 mRNA
# 				 --> COL1A2
# 		removing suffix  mRNA for COL1A2 mRNA
# 				 --> COL1A2
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for PRICKLE1 mRNA
# 				 --> PRICKLE1
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for COL1A2 mRNA
# 				 --> COL1A2
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for COL1A2 mRNA
# 				 --> COL1A2
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for LOXL1 mRNA
# 				 --> LOXL1
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for COL1A2 mRNA
# 				 --> COL1A2
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for LTBP2 mRNA
# 				 --> LTBP2
#
# Explored 145 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL6A3 mRNA
# 				 --> COL6A3
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PMP22 mRNA
# 				 --> PMP22
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PMP22 mRNA
# 				 --> PMP22
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for EMILIN1 mRNA
# 				 --> EMILIN1
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  mRNA for PMP22 mRNA
# 				 --> PMP22
#
# Explored 145 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for CCDC80 mRNA
# 				 --> CCDC80
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for CDH11 mRNA
# 				 --> CDH11
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL14A1 mRNA
# 				 --> COL14A1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for EFEMP1 mRNA
# 				 --> EFEMP1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for C1QTNF2 mRNA
# 				 --> C1QTNF2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for CCDC80 mRNA
# 				 --> CCDC80
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for EFEMP1 mRNA
# 				 --> EFEMP1
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for CDH11 mRNA
# 				 --> CDH11
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for EFEMP1 mRNA
# 				 --> EFEMP1
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for CCDC80 mRNA
# 				 --> CCDC80
# 		removing suffix  mRNA for HSPA1A mRNA
# 				 --> HSPA1A
# 		removing suffix  mRNA for CDH11 mRNA
# 				 --> CDH11
# 		removing suffix  protein for IFNG protein
# 				 --> IFNG
# 		removing suffix  mRNA for EFEMP1 mRNA
# 				 --> EFEMP1
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for EFEMP1 mRNA
# 				 --> EFEMP1
#
# Explored 146 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for ANTXR1 mRNA
# 				 --> ANTXR1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for GLT8D2 mRNA
# 				 --> GLT8D2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for TSHZ3 mRNA
# 				 --> TSHZ3
# 		removing suffix  protein for BID protein
# 				 --> BID
# 		removing suffix  protein for SNAI1 protein
# 				 --> SNAI1
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for TSHZ3 mRNA
# 				 --> TSHZ3
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  protein for SNAI1 protein
# 				 --> SNAI1
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for ANTXR1 mRNA
# 				 --> ANTXR1
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for TSHZ3 mRNA
# 				 --> TSHZ3
# 		removing suffix  protein for AGT protein modified form
# 				 --> AGT modified form
# 		removing suffix  modified form for AGT modified form
# 				 --> AGT
# 		removing suffix  protein for SNAI1 protein
# 				 --> SNAI1
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  protein for SNAI1 protein
# 				 --> SNAI1
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  protein for SNAI1 protein
# 				 --> SNAI1
# 		removing suffix  protein for SNAI1 protein
# 				 --> SNAI1
# 		removing suffix  protein for AKT1 protein
# 				 --> AKT1
# 		removing suffix  protein for SNAI1 protein
# 				 --> SNAI1
# 		removing suffix  protein for FGF16 protein
# 				 --> FGF16
# 		removing suffix  protein for SNAI1 protein
# 				 --> SNAI1
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  mRNA for GGT5 mRNA
# 				 --> GGT5
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  protein for SNAI1 protein
# 				 --> SNAI1
#
# Explored 149 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for ALDH1A3 mRNA
# 				 --> ALDH1A3
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for FBN1 mRNA
# 				 --> FBN1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for FBN1 mRNA
# 				 --> FBN1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for HEPH mRNA
# 				 --> HEPH
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for ALDH1A3 mRNA
# 				 --> ALDH1A3
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for FBN1 mRNA
# 				 --> FBN1
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for FBN1 mRNA
# 				 --> FBN1
#
# Explored 149 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for GFPT2 mRNA
# 				 --> GFPT2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for DPYSL3 mRNA
# 				 --> DPYSL3
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for SRPX mRNA
# 				 --> SRPX
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for DPYSL3 mRNA
# 				 --> DPYSL3
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for SRPX mRNA
# 				 --> SRPX
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for GFPT2 mRNA
# 				 --> GFPT2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PODN mRNA
# 				 --> PODN
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  mRNA for ECM1 mRNA
# 				 --> ECM1
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  mRNA for SRPX mRNA
# 				 --> SRPX
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for DPYSL3 mRNA
# 				 --> DPYSL3
#
# Explored 149 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for GAS1 mRNA
# 				 --> GAS1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for ITGA11 mRNA
# 				 --> ITGA11
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for ITGA11 mRNA
# 				 --> ITGA11
# 		removing suffix  mutant form for TRIM33 mutant form
# 				 --> TRIM33
# 		removing suffix  mRNA for FOXL1 mRNA
# 				 --> FOXL1
# 		removing suffix  protein for IFNA1 protein
# 				 --> IFNA1
# 		removing suffix  mRNA for GAS1 mRNA
# 				 --> GAS1
#
# Explored 151 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for POSTN mRNA
# 				 --> POSTN
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for GLI2 mRNA
# 				 --> GLI2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for GLI2 mRNA
# 				 --> GLI2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for VCAN mRNA
# 				 --> VCAN
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for HAND2 mRNA
# 				 --> HAND2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for VCAN mRNA
# 				 --> VCAN
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for POSTN mRNA
# 				 --> POSTN
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  mRNA for VCAN mRNA
# 				 --> VCAN
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for VCAN mRNA
# 				 --> VCAN
#
# Explored 151 regulators
# 		removing suffix  protein for ESR2 protein
# 				 --> ESR2
# 		removing suffix  mRNA for CRISPLD2 mRNA
# 				 --> CRISPLD2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for CRISPLD2 mRNA
# 				 --> CRISPLD2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for CRISPLD2 mRNA
# 				 --> CRISPLD2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PTGIR mRNA
# 				 --> PTGIR
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PTGIR mRNA
# 				 --> PTGIR
# 		removing suffix  protein for ESR1 protein
# 				 --> ESR1
# 		removing suffix  mRNA for CRISPLD2 mRNA
# 				 --> CRISPLD2
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for CRISPLD2 mRNA
# 				 --> CRISPLD2
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for CRISPLD2 mRNA
# 				 --> CRISPLD2
#
# Explored 151 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL12A1 mRNA
# 				 --> COL12A1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for MOXD1 mRNA
# 				 --> MOXD1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for COL12A1 mRNA
# 				 --> COL12A1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for MGP mRNA
# 				 --> MGP
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for COL12A1 mRNA
# 				 --> COL12A1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for ASPN mRNA
# 				 --> ASPN
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for ASPN mRNA
# 				 --> ASPN
# 		removing suffix  mutant form for PIK3CA gene mutant form
# 				 --> PIK3CA gene
# 		removing suffix  gene for PIK3CA gene
# 				 --> PIK3CA
# 		removing suffix  mRNA for MGP mRNA
# 				 --> MGP
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  mRNA for MOXD1 mRNA
# 				 --> MOXD1
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for COL12A1 mRNA
# 				 --> COL12A1
# 		removing suffix  complex for Vitallium analog/titanium dioxide complex
# 				 --> Vitallium analog/titanium dioxide
# 		removing suffix  mRNA for COL12A1 mRNA
# 				 --> COL12A1
#
# Explored 152 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for LAMA2 mRNA
# 				 --> LAMA2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for NHS mRNA
# 				 --> NHS
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for AEBP1 mRNA
# 				 --> AEBP1
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for LAMA2 mRNA
# 				 --> LAMA2
#
# Explored 152 regulators
# 		removing suffix  protein for ESR2 protein
# 				 --> ESR2
# 		removing suffix  mRNA for PCDH7 mRNA
# 				 --> PCDH7
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PCDH7 mRNA
# 				 --> PCDH7
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for HTRA3 mRNA
# 				 --> HTRA3
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for MXRA5 mRNA
# 				 --> MXRA5
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for HEYL mRNA
# 				 --> HEYL
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for MXRA5 mRNA
# 				 --> MXRA5
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for PCDH7 mRNA
# 				 --> PCDH7
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for HEYL mRNA
# 				 --> HEYL
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for HTRA3 mRNA
# 				 --> HTRA3
#
# Explored 152 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for MAP1A mRNA
# 				 --> MAP1A
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for SVEP1 mRNA
# 				 --> SVEP1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for GLI3 mRNA
# 				 --> GLI3
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for SVEP1 mRNA
# 				 --> SVEP1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for MAP1A mRNA
# 				 --> MAP1A
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for GLI3 mRNA
# 				 --> GLI3
#
# Explored 152 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for SEMA3C mRNA
# 				 --> SEMA3C
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL6A2 mRNA
# 				 --> COL6A2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for FAP mRNA
# 				 --> FAP
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for FAP mRNA
# 				 --> FAP
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for F2R mRNA
# 				 --> F2R
# 		removing suffix  protein for TP73 protein
# 				 --> TP73
# 		removing suffix  mRNA for SEMA3C mRNA
# 				 --> SEMA3C
#
# Explored 153 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for ALDH1L2 mRNA
# 				 --> ALDH1L2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PRELP mRNA
# 				 --> PRELP
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for ADAMTS2 mRNA
# 				 --> ADAMTS2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PHLDB1 mRNA
# 				 --> PHLDB1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for LXN mRNA
# 				 --> LXN
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for ALDH1L2 mRNA
# 				 --> ALDH1L2
#
# Explored 153 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PMEPA1 mRNA
# 				 --> PMEPA1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for RSPO3 mRNA
# 				 --> RSPO3
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for EPHA3 mRNA
# 				 --> EPHA3
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PMEPA1 mRNA
# 				 --> PMEPA1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for RSPO3 mRNA
# 				 --> RSPO3
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for EPHA3 mRNA
# 				 --> EPHA3
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for FLNA mRNA
# 				 --> FLNA
# 		removing suffix  mutant form for PIK3CA gene mutant form
# 				 --> PIK3CA gene
# 		removing suffix  gene for PIK3CA gene
# 				 --> PIK3CA
# 		removing suffix  mRNA for PMEPA1 mRNA
# 				 --> PMEPA1
#
# Explored 153 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for TMEM132E mRNA
# 				 --> TMEM132E
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL8A2 mRNA
# 				 --> COL8A2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for TGFB3 mRNA
# 				 --> TGFB3
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for COL8A2 mRNA
# 				 --> COL8A2
# 		removing suffix  mRNA for TGFB3 mRNA
# 				 --> TGFB3
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for C1QTNF7 mRNA
# 				 --> C1QTNF7
#
# Explored 153 regulators
# 		removing suffix  protein for TNF protein
# 				 --> TNF
# 		removing suffix  mRNA for PLAT mRNA
# 				 --> PLAT
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PLAT mRNA
# 				 --> PLAT
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for ADAMTS12 mRNA
# 				 --> ADAMTS12
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for LAMA1 mRNA
# 				 --> LAMA1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PLAT mRNA
# 				 --> PLAT
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for MFAP4 mRNA
# 				 --> MFAP4
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for PLAT mRNA
# 				 --> PLAT
# 		removing suffix  protein for LPA protein modified form
# 				 --> LPA modified form
# 		removing suffix  modified form for LPA modified form
# 				 --> LPA
# 		removing suffix  mRNA for PLAT mRNA
# 				 --> PLAT
# 		removing suffix  protein for LPA protein modified form
# 				 --> LPA modified form
# 		removing suffix  modified form for LPA modified form
# 				 --> LPA
# 		removing suffix  mRNA for PLAT mRNA
# 				 --> PLAT
#
# Explored 154 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for BGN mRNA
# 				 --> BGN
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for CTBP2 mRNA
# 				 --> CTBP2
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for CTBP2 mRNA
# 				 --> CTBP2
# 		removing suffix  protein for AGT protein modified form
# 				 --> AGT modified form
# 		removing suffix  modified form for AGT modified form
# 				 --> AGT
# 		removing suffix  mRNA for COL4A2 mRNA
# 				 --> COL4A2
#
# Explored 154 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PDPN mRNA
# 				 --> PDPN
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for SCD5 mRNA
# 				 --> SCD5
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for SHISA2 mRNA
# 				 --> SHISA2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PDE1A mRNA
# 				 --> PDE1A
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PDE1A mRNA
# 				 --> PDE1A
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PDPN mRNA
# 				 --> PDPN
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for SCD5 mRNA
# 				 --> SCD5
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for SHISA2 mRNA
# 				 --> SHISA2
# 		removing suffix  complex for Disulfiram/Copper complex
# 				 --> Disulfiram/Copper
# 		removing suffix  mRNA for PDPN mRNA
# 				 --> PDPN
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for PDE1A mRNA
# 				 --> PDE1A
#
# Explored 154 regulators
# 		removing suffix  protein for TNF protein
# 				 --> TNF
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for LZTS1 mRNA
# 				 --> LZTS1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for LRRC4C mRNA
# 				 --> LRRC4C
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for EDNRA mRNA
# 				 --> EDNRA
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for LRRC4C mRNA
# 				 --> LRRC4C
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for ESR1 protein
# 				 --> ESR1
# 		removing suffix  mRNA for EDNRA mRNA
# 				 --> EDNRA
# 		removing suffix  protein for HMOX1 protein
# 				 --> HMOX1
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  mRNA for RHOA mRNA
# 				 --> RHOA
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for VEGFA protein
# 				 --> VEGFA
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for FGF2 protein
# 				 --> FGF2
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for AKR1B10 protein
# 				 --> AKR1B10
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for MIF protein
# 				 --> MIF
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for AGT protein modified form
# 				 --> AGT modified form
# 		removing suffix  modified form for AGT modified form
# 				 --> AGT
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for IL1B protein
# 				 --> IL1B
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for FGF16 protein
# 				 --> FGF16
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  mRNA for MMP2 mRNA
# 				 --> MMP2
# 		removing suffix  protein for ESR2 protein
# 				 --> ESR2
# 		removing suffix  mRNA for EDNRA mRNA
# 				 --> EDNRA
#
# Explored 160 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for COL8A1 mRNA
# 				 --> COL8A1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for AMPH mRNA
# 				 --> AMPH
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for AMPH mRNA
# 				 --> AMPH
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for LHFP mRNA
# 				 --> LHFP
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for COL8A1 mRNA
# 				 --> COL8A1
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for COL8A1 mRNA
# 				 --> COL8A1
#
# Explored 160 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for MYOF mRNA
# 				 --> MYOF
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PXDN mRNA
# 				 --> PXDN
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for MYOF mRNA
# 				 --> MYOF
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for MXRA8 mRNA
# 				 --> MXRA8
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for ABR mRNA
# 				 --> ABR
# 		removing suffix  protein for TP73 protein
# 				 --> TP73
# 		removing suffix  mRNA for MYOF mRNA
# 				 --> MYOF
#
# Explored 160 regulators
# 		removing suffix  protein for ESR2 protein
# 				 --> ESR2
# 		removing suffix  mRNA for JAG1 mRNA
# 				 --> JAG1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for STMN2 mRNA
# 				 --> STMN2
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for JAG1 mRNA
# 				 --> JAG1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  protein for MAP1B protein
# 				 --> MAP1B
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for STMN2 mRNA
# 				 --> STMN2
# ...
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for S100B mRNA
# 				 --> S100B
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for S100B mRNA
# 				 --> S100B
#
# Explored 686 regulators
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for NFATC2 mRNA
# 				 --> NFATC2
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
# 		removing suffix  complex for NSC 689534/Copper complex
# 				 --> NSC 689534/Copper
# 		removing suffix  mRNA for RNASEH2A mRNA
# 				 --> RNASEH2A
#
# Explored 686 regulators
#
# Explored 686 regulators
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for TXLNG mRNA
# 				 --> TXLNG
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
# 		removing suffix  protein for TNF protein
# 				 --> TNF
# 		removing suffix  mRNA for PPARGC1A mRNA
# 				 --> PPARGC1A
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PPARGC1A mRNA
# 				 --> PPARGC1A
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PPARGC1A mRNA
# 				 --> PPARGC1A
#
# Explored 686 regulators
#
# Explored 686 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for SMARCA4 mRNA
# 				 --> SMARCA4
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PVT1 mRNA
# 				 --> PVT1
# 		removing suffix  protein for Hyaluronic Acid/CD44 protein complex
# 				 --> Hyaluronic Acid/CD44 complex
# 		removing suffix  complex for Hyaluronic Acid/CD44 complex
# 				 --> Hyaluronic Acid/CD44
# 		removing suffix  mRNA for EP300 mRNA
# 				 --> EP300
# 		removing suffix  mRNA for EP300 mRNA
# 				 --> EP300
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for EP300 mRNA
# 				 --> EP300
# 		removing suffix  mRNA for EP300 mRNA
# 				 --> EP300
# 		removing suffix  mRNA for PKM mRNA
# 				 --> PKM
# 		removing suffix  mRNA for EP300 mRNA
# 				 --> EP300
# 		removing suffix  complex for Polyethyleneimine/Gold complex
# 				 --> Polyethyleneimine/Gold
# 		removing suffix  mRNA for EP300 mRNA
# 				 --> EP300
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for NOC2L mRNA
# 				 --> NOC2L
#
# Explored 686 regulators
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  mRNA for ZBTB17 mRNA
# 				 --> ZBTB17
#
# Explored 686 regulators
#
# Explored 686 regulators
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for MLXIPL mRNA
# 				 --> MLXIPL
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for MLXIPL mRNA
# 				 --> MLXIPL
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for MLXIPL mRNA
# 				 --> MLXIPL
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for TP53BP1 mRNA
# 				 --> TP53BP1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for ZNF225 mRNA
# 				 --> ZNF225
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for ZNF225 mRNA
# 				 --> ZNF225
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
#
# Explored 686 regulators
# Angiotensin II/AGTR1 decomposed into ['Angiotensin II', 'AGTR1']
# Angiotensin II/AGTR1 decomposed into ['AGTR1'] when removing small molecules
# Gold/Dimethyldithiocarbamate decomposed into ['Gold', 'Dimethyldithiocarbamate']
# Gold/Dimethyldithiocarbamate decomposed into [] when removing small molecules
# Gold/Dimethyldithiocarbamate is only composed by small molecules. It should be removed from the graph...
# Troglitazone/PPARG decomposed into ['Troglitazone', 'PPARG']
# Troglitazone/PPARG decomposed into ['PPARG'] when removing small molecules
# TP73/IL4R intron decomposed into ['TP73', 'IL4R intron']
# TP73/IL4R intron decomposed into ['TP73', 'IL4R intron'] when removing small molecules
# to be explored after complex decomposition ['Angiotensin II/AGTR1', 'Thrombin', 'Ang1-4', 'NERF2', 'p38 alpha', 'Gold/Dimethyldithiocarbamate', 'MIR21', 'Troglitazone/PPARG', 'TP73/IL4R intron', 'TSHB', 'AGTR1', 'PPARG', 'TP73', 'IL4R intron']
# new synonmys to be explored:['MIRN21', 'hsa-mir-21', 'miR-21', 'miRNA21', 'TSH-B', 'TSH-BETA', 'AG2S', 'AGTR1B', 'AT1', 'AT1AR', 'AT1B', 'AT1BR', 'AT1R', 'AT2R1', 'HAT1R', 'CIMT1', 'GLM1', 'NR1C3', 'PPARG1', 'PPARG2', 'PPARgamma', 'P73']
#
# Explored 687 regulators
#
# Explored 687 regulators
# 		removing suffix  protein for TNF protein
# 				 --> TNF
# 		removing suffix  mRNA for AGTR1 mRNA
# 				 --> AGTR1
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for MIR21 mRNA
# 				 --> MIR21
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for AGTR1 mRNA
# 				 --> AGTR1
# 		removing suffix  protein for TRH protein
# 				 --> TRH
# 		removing suffix  protein for TSHB protein
# 				 --> TSHB
# 		removing suffix  protein for APP protein modified form/Aluminum complex
# 				 --> APP modified form/Aluminum complex
# 		removing suffix  complex for APP modified form/Aluminum complex
# 				 --> APP modified form/Aluminum
# 		removing suffix  modified form for APP modified form/Aluminum
# 				 --> APP/Aluminum
# 		removing suffix  mRNA for AGTR1 mRNA
# 				 --> AGTR1
# 		removing suffix  protein for pirinixic acid/PPARA protein complex
# 				 --> pirinixic acid/PPARA complex
# 		removing suffix  complex for pirinixic acid/PPARA complex
# 				 --> pirinixic acid/PPARA
# 		removing suffix  protein for TSHB protein
# 				 --> TSHB
# 		removing suffix  protein for AGT protein modified form
# 				 --> AGT modified form
# 		removing suffix  modified form for AGT modified form
# 				 --> AGT
# 		removing suffix  mRNA for AGTR1 mRNA
# 				 --> AGTR1
# 		removing suffix  mRNA for PKM mRNA
# 				 --> PKM
# 		removing suffix  mRNA for AGTR1 mRNA
# 				 --> AGTR1
#
# Explored 687 regulators
# 		removing suffix  protein for TNF protein
# 				 --> TNF
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for TNF protein
# 				 --> TNF
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for RXRA protein
# 				 --> RXRA
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for IFNG protein
# 				 --> IFNG
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for IFNG protein
# 				 --> IFNG
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for NR1I2 protein
# 				 --> NR1I2
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for AGT protein modified form
# 				 --> AGT modified form
# 		removing suffix  modified form for AGT modified form
# 				 --> AGT
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for TGFB1 protein
# 				 --> TGFB1
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for IL1A protein
# 				 --> IL1A
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
# 		removing suffix  protein for IL1B protein
# 				 --> IL1B
# 		removing suffix  mRNA for PPARG mRNA
# 				 --> PPARG
#
# Explored 687 regulators
#
# Explored 687 regulators
#
# Explored 687 regulators
#
# Explored 687 regulators
#
# Explored 687 regulators
#
# Explored 687 regulators
# Tie2/Ang1 decomposed into ['Tie2', 'Ang1']
# Tie2/Ang1 decomposed into ['Tie2', 'Ang1'] when removing small molecules
# to be explored after complex decomposition ['Tie2/Ang1', 'Tie2', 'Ang1']
#
# Explored 687 regulators
# Exploring done
#
# Number of nodes = 1728
# Number of edges = 4226
# SIF network written to reg-demo/out.sif
# Basic regulation reaction provenance written to reg-demo/out-provenance.csv
#
# 		merging node SNAIL into node SNAI1
# 		merging node AP1 into node JUN
# 		merging node AP1 into node JUN
# 		merging node ATF2 into node GDNF
# 		merging node ATF1 into node GDNF
# 		merging node ATF2 into node GDNF
# 		merging node FOXM1B into node FOXM1
# 		merging node FOXM1B into node FOXM1
# 		merging node COX-2 into node PTGS2
# 		merging node IL8 into node CXCL8
# 		merging node NEF into node S100B
# 		merging node RANKL into node TNFSF11
# 		merging node AGT into node AGXT
# 		merging node PRKACA into node PRKCA
# 		merging node c-Jun into node JUN
# 		merging node ET1 into node EDN1
# 		merging node RAD1 into node RRAD
# 		merging node JUNB into node RNASEH2A
# 		merging node IL8 into node CXCL8
# 		merging node MYC into node PVT1
# 		merging node SNAIL into node SNAI1
# 		merging node CSPG2 into node VCAN
# 		merging node SM22 into node TAGLN
# 		merging node COX-2 into node PTGS2
# 		merging node DEC2 into node BHLHE41
# 		merging node MCAD into node CDH15
# 		merging node CDH3 into node CDH15
# 		merging node TIF2 into node NCOA2
# 		merging node BK2 into node BDKRB2
# 		merging node SDF1 into node CXCL12
# 		merging node TGF-beta2 into node TGFB2
# 		merging node ATFA into node ATF7
# 		merging node NOXA into node PMAIP1
# 		merging node APC into node PROC
# 		merging node HST into node SULT2A1
# 		merging node LTBP2 into node LTBP3
# 		merging node PMP22 into node PXMP2
# 		merging node HSP70-1A into node HSPA1A
# 		merging node MAP1A into node METAP1
# 		merging node FAP into node GLMN
# 		merging node STAG1 into node PMEPA1
# 		merging node SCD4 into node SCD5
# 		merging node FEZ1 into node LZTS1
# 		merging node FGF2 into node FGF13
# 		merging node ARL1 into node AKR1B10
# 		merging node MIF into node S100A9
# 		merging node PXN into node PXDN
# 		merging node RCN2 into node RCAN2
# 		merging node CAIX into node CA9
# 		merging node ROR2 into node RORA
# 		merging node ROR1 into node RORA
# 		merging node ROR2 into node RORA
# 		merging node ZFP423 into node ZNF423
# 		merging node LPA1 into node LPAR1
# 		merging node SLIT1 into node SLIT3
# 		merging node CDH3 into node CDH15
# 		merging node CRIP1 into node CNRIP1
# 		merging node CST6 into node CSTB
# 		merging node CFD into node PIKFYVE
# 		merging node IL1RA into node IL1RN
# 		merging node ROR1 into node RORA
# 		merging node HIF2A into node EPAS1
# 		merging node SELP into node SELENOP
# 		merging node CLK1 into node COLEC11
# 		merging node CD1A into node CD1E
# 		merging node SULT1C2 into node SULT1C4
# 		merging node SPP2 into node SGPP2
# 		merging node REN into node KCTD11
# 		merging node POR into node VDAC2
# 		merging node STAG1 into node PMEPA1
# 		merging node SCD4 into node SCD5
# 		merging node FEZ1 into node LZTS1
# 		merging node PXN into node PXDN
# 		merging node RCN2 into node RCAN2
# 		merging node ZFP423 into node ZNF423
# 		merging node SLIT1 into node SLIT3
# 		merging node RAD1 into node RRAD
# 		merging node BCLX into node BCL2L1
# 		merging node CD14 into node NDUFA2
# 		merging node CLK1 into node COLEC11
# 		merging node CD1A into node CD1E
# 		merging node SULT1C2 into node SULT1C4
# 		merging node SPP2 into node SGPP2
# 		merging node MIZ-1 into node ZBTB17
# 		merging node LPA1 into node LPAR1
# 		merging node HIF2A into node EPAS1
# 		merging node TCF4 into node TCF7L2
# 		merging node GCN5 into node KAT2A
# 		merging node SPT3 into node SPTLC3
# 		merging node p300 into node EP300
# 		merging node DP into node SRPRA
# 		merging node ELK1 into node KCNH8
# 		merging node JAB1 into node COPS5
# 		merging node ATF1 into node GDNF
# 		merging node PCAF into node KAT2B
# 		merging node MCG10 into node PCBP4
# 		merging node p107 into node RBL1
# 		merging node JNK2 into node MAPK9
# 		merging node PLCgamma1 into node PLCG1
# 		merging node GRAIL into node RNF128
# 		merging node NFAT1 into node NFATC2
# 		merging node NFATc into node NFATC1
# 		merging node HNF4A into node HNF1A
# 		merging node TCF1 into node HNF1A
# 		merging node HNF4A into node HNF1A
# 		merging node PGC1A into node PPARGC1A
# 		merging node FOXM1C into node FOXM1
# 		merging node ICER into node CREM
# 		merging node KAP1 into node TRIM28
# 		merging node TIF1B into node TRIM28
# 		merging node TNF-alpha into node TNF
# 		merging node c-Jun into node JUN
# 		merging node RANKL into node TNFSF11
# 		merging node ET1 into node EDN1
# 		merging node HSP70-1A into node HSPA1A
# 		merging node CBF into node CEBPZ
# 		merging node CAIX into node CA9
# 		merging node IL1RA into node IL1RN
# 		merging node BCLX into node BCL2L1
# 		merging node CCN1 into node PPP3CA
# 		merging node MNSOD into node SOD2
# 		merging node maspin into node SERPINB5
# 		merging node p21CIP1 into node CDKN1A
# 		merging node LKB1 into node STK11
# 		merging node BACH1 into node BRIP1
# 		merging node RANTES into node CCL5
# 		merging node RASSF5 into node RASSF3
# 		merging node ZAK into node MAP3K20
# 		merging node PRKACA into node PRKCA
# 		merging node CGA into node CHGA
# 		merging node REDD1 into node DDIT4
# 		merging node DAT into node SLC6A3
# 		merging node ARL1 into node AKR1B10
# 		merging node MIM into node MTSS1
# 		merging node LKB1 into node STK11
# 		merging node BRM into node SMARCA2
# 		merging node TCF1 into node HNF1A
# 		merging node TCF3 into node TCF7L1
# 		merging node BRG1 into node SMARCA4
# 		merging node TIF1B into node TRIM28
# 		merging node CD3G into node TARP
# 		merging node FOXO3A into node FOXO3
# 		merging node MCG10 into node PCBP4
# 		merging node MCG10 into node PCBP4
# 		merging node PGC1A into node PPARGC1A
# 		merging node MNSOD into node SOD2
# 		merging node maspin into node SERPINB5
# 		merging node p21CIP1 into node CDKN1A
# 		merging node HZF into node RNF39
# 		merging node RANTES into node CCL5
# 		merging node REDD1 into node DDIT4
# 		merging node DAT into node SLC6A3
# 		merging node SCF into node KITLG
# 		merging node VIP into node CPAMD8
# 		merging node TRP53 into node TP53
# 		merging node ZAK into node MAP3K20
# 		merging node CaM into node CALM3
# 		merging node NEF into node S100B
# 		merging node FIAT into node TXLNG
# 		merging node NIR into node NOC2L
# 		merging node SCF into node KITLG
# --- Network simplification in 4.53 seconds ---
# SIF network written to reg-demo/out-unified.sif
# Basic regulation reaction provenance written to reg-demo/out-unified-provenance.csv
# Nodes after simplification = 1619
# Edges after simplification = 4196
#
# | Node | Degree Centrality |
# |------|------|
# | NOG | 0.401 |
# | INS | 0.188 |
# | APP/Aluminum | 0.108 |
# | TNF | 0.091 |
# | NSC 689534/Copper | 0.085 |
# | pirinixic acid/PPARA | 0.075 |
# | IL1B | 0.051 |
# | CDKN1A | 0.048 |
# | Disulfiram/Copper | 0.047 |
# | TGFB1 | 0.046 |

# %%
with open('std.out', 'w') as outfile:
    print(all_stdout, file = outfile)

# %% [markdown]
# ### Statistics extraction
#
# Here we call several Bash and Python scripts on the results to extracts statistics on the provenance and coverage, and we sum up these into a CSV table that can be loaded in Cytoscape and applied to the edges of the network.

# %%
# %%bash
# cd reg-demo
#
# # Extract genes of the unified and non-unified results
# sh scripts/get-genes-from-sif.sh out-unified.sif > out-unified.sif.genes
# # Provenance of all edges in unified result
# bash scripts/pybravo-provenances.sh out-unified-provenance.csv > provenance-unified.txt
# # Provenance of signed edges only in unified result
# bash scripts/pybravo-provenances.sh <(grep -v 'UNKNOWN' out-unified-provenance.csv) > provenance-unified-signed.txt
#
# # Coverage
# python3 scripts/compute_coverage.py out-unified.sif data/input-910.csv ../Homo_sapiens.gene_info > coverage.txt
#
# # Provenance CSV for Cytoscape
# mkdir cytoscape
# echo "edge name,provenance" > cytoscape/edges-provenance.csv
# sed 's/\t\(.*\)\t/ (\1) /;' out-unified-provenance.csv >> cytoscape/edges-provenance.csv

# %% [markdown]
# ## Using Iggy to make predictions

# %% [markdown]
# In this part we use the previously extracted network as a model in order to make predictions on it, using the tool [Iggy](https://github.com/bioasp/iggy).
#
# Using some preliminary observations on some nodes, consisting in signs “$+$” (observed up-regulation) and “$-$” (observed down-regulation), Iggy tries to infer new information on the other nodes which can thus also be predicted as “$+$” or “$-$”. This call relies on Bash and Ptyhon scripts.
#
# For this step, you need Iggy 1.4.1 installed, for instance using pip:
#
# > ```pip install iggy==1.4.1```
#
# Once Iggy is installed, please provide the path to it (default with pip is `~/.local/bin/iggy.py`):

# %%
iggy_command = "${HOME}/.local/bin/iggy.py"

# %%
# Interpret Iggy command line
iggy_command = !echo "$iggy_command"
iggy_command = iggy_command[0]
print(iggy_command)
# Out:
# /home/max/.local/bin/iggy.py

# %% [markdown]
# The scripts below call Iggy, with some data preparation beforehand and a comparison of the result with the original ICGC experimental data afterwards.
#
# The printed output sums up the results of the prediction, and the consistency of these results with the initial ICGC expression data (matching or not matching predictions).
#
# The full result can be found in file `reg-demo/cytoscape/nodes-iggy.csv` in a format that can be fed to Cytoscape in order to label nodes with their observation/prediction sign.

# %%
# %%bash -s "$iggy_command"
# # Make folders for execution results
# cd reg-demo
# mkdir iggy
# cd iggy
# mkdir result
#
# # Create graph (SIF) file (removes unsigned edges)
# bash ../scripts/format-iggy.sh ../out-unified.sif | grep -v 'UNKNOWN' > out-unified-iggy.sif
#
# # Create observations (OBS) file
# bash ../scripts/construct-inputs.sh out-unified-iggy.sif ../data/updownreg-v4.3-noinputs.obs > updownreg.obs
#
# # Extract true observations (actually in network)
# bash ../scripts/get-genes-from-sif.sh out-unified-iggy.sif > out-unified-iggy.sif.genes
# grep -w -f out-unified-iggy.sif.genes updownreg.obs > updownreg_true.obs
#
# # Run Iggy workflow
# bash ../scripts/workflow-iggy.sh --iggy-command $1 updownreg_true.obs out-unified-iggy.sif ../data/icgc.syn.csv 0 0 result/iggy.out > result/out-unified.tsv
# cp result/out-unified.tsv ../cytoscape/nodes-iggy.csv
#
# # Output stats
# bash ../scripts/stats-result.sh --en --skip0 result/out-unified.tsv out-unified-iggy.sif > result/stats.txt
# cat result/stats.txt
# Out:
# Total number of nodes: 1619
# Total number of edges: 4196
# Number of observations: 643
# Number of predictions: 79
#   positive (+): 42
#   negative (−): 34
#   no-change (0): 0
#   may-up (NOT−): 0
#   may-down (NOT+): 0
#   change (CHANGE/NOT0): 3
#
# Predictions found in ICGC data: 61
#     +: 31
#     -: 29
#     0: 0
#   coherent: 29
#     +: 20
#     -: 9
#   weakly coherent: 1
#     NOT-: 0
#     NOT+: 0
#     CHANGE: 1
#   not coherent: 31
#     predicted +: 11
#       (should be -)
#      predicted -: 20
#       (should be +)
#      predicted NOT-/NOT+/CHANGE: 0

# %%
# %%bash
# cd reg-demo
# cd iggy
# bash ../scripts/stats-2.sh "../out-unified.sif" "../../std.out"
# Out:
# Nodes: 1619 ../out-unified.sif.genes
# Edges: 4196 ../out-unified.sif
#  - signed: 3625
#  - unsigned: 0
#  - PART_OF: 571
#
# Coverage: 689 genes are present over 910
#
# Complexes: 304
# Complexes involving small molecules: 113
