# %%
import time
import csv
from IPython.display import display, Markdown, Latex
import networkx as nx
import bravo.regulation as regulation
import bravo.signaling as signaling
import bravo.config as config
import bravo.util as util
import pyBravo as bravo_main

# %% [markdown]
# # Upstream regulation network reconstruction
#
# The following lines of code specify that regulation will be expored at depth 2 (`config.MAX_DEPTH = 2`), on all datasources except *mirtarbase* (`config.DATA_SOURCES = set(ds) - set(['mirtarbase'])`), on a set of genes `['PLPP4', 'DPPL2', ... , 'PECI', 'ACAD8']`.
#
# The regulation graph reconstruction is called with
# ```
# reconstructed_network = regulation.upstream_regulation(gene_list,
#                                                        already_explored = [],
#                                                        sif_network = [],
#                                                        current_depth = 0,
#                                                        explored_reg = 0)
# ```
#
# Parameters are set to default values to allow re-execution of this cell without side-effect of previous executions.

# %%
start_time = time.time()

# global options
config.MAX_DEPTH = 2
config.FAST = True
config.DECOMPOSE_COMPLEXES = True
config.EXTEND_WITH_SYNONYMS = True
config.EXTEND_WITH_SUFFIXES = True
config.VERBOSE = False

""" all possible data sources """
ds = ['bind', 'biogrid', 'corum',
                'ctd', 'dip', 'drugbank', 'hprd', 'humancyc', 'inoh',
                'intact', 'kegg', 'mirtarbase', 'netpath', 'panther',
                'pid', 'psp', 'reactome', 'reconx', 'smpdb', 'wp',
                'intact_complex', 'msigdb']

""" removing mirtarbase """
config.DATA_SOURCES = set(ds) 
#config.DATA_SOURCES = set(ds) - set(['mirtarbase'])

""" specifiyng inputs """
gene_list = ['PLPP4', 'DPPL2', 'PPAPDC1', 'PPAPDC1A', 'SLC7A1', 'ATRC1', 'CAT-1', 'ERR', 'HCAT1', 'REC1L', 
             'PNLIPRP3', 'PNPLA3', 'ADPN', 'C22orf20', 'FLJ22012', 'adiponutrin', 'dJ796I17.1', 'iPLA2epsilon', 
             'ECI2', 'DRS1', 'ACBD2', 'HCA88', 'PECI', 'ACAD8']

""" reconstruction call """
reconstructed_network = regulation.upstream_regulation(gene_list, 
                                                       already_explored = [], 
                                                       sif_network = [], 
                                                       current_depth = 0, 
                                                       explored_reg = 0)

elapsed_time = round((time.time() - start_time), 2)

print("--- Upstream regulation network in %s seconds ---" % elapsed_time)
# Out:
# exploration depth 0
# to be explored ['PLPP4', 'DPPL2', 'PPAPDC1', 'PPAPDC1A', 'SLC7A1', 'ATRC1', 'CAT-1', 'ERR', 'HCAT1', 'REC1L', 'PNLIPRP3', 'PNPLA3', 'ADPN', 'C22orf20', 'FLJ22012', 'adiponutrin', 'dJ796I17.1', 'iPLA2epsilon', 'ECI2', 'DRS1', 'ACBD2', 'HCA88', 'PECI', 'ACAD8']
#
# to be explored after complex decomposition ['PLPP4', 'DPPL2', 'PPAPDC1', 'PPAPDC1A', 'SLC7A1', 'ATRC1', 'CAT-1', 'ERR', 'HCAT1', 'REC1L', 'PNLIPRP3', 'PNPLA3', 'ADPN', 'C22orf20', 'FLJ22012', 'adiponutrin', 'dJ796I17.1', 'iPLA2epsilon', 'ECI2', 'DRS1', 'ACBD2', 'HCA88', 'PECI', 'ACAD8']
# new synonmys to be explored:['DPPL2', 'PPAPDC1', 'PPAPDC1A', 'PLPP4', 'PPAPDC1', 'PPAPDC1A', 'PLPP4', 'DPPL2', 'PPAPDC1A', 'PLPP4', 'DPPL2', 'PPAPDC1', 'ATRC1', 'CAT-1', 'ERR', 'HCAT1', 'REC1L', 'SLC7A1', 'CAT-1', 'ERR', 'HCAT1', 'REC1L', 'SLC7A1', 'ATRC1', 'ERR', 'HCAT1', 'REC1L', 'SLC7A1', 'ATRC1', 'CAT-1', 'HCAT1', 'REC1L', 'SLC7A1', 'ATRC1', 'CAT-1', 'ERR', 'REC1L', 'SLC7A1', 'ATRC1', 'CAT-1', 'ERR', 'HCAT1', 'ADPN', 'C22orf20', 'iPLA(2)epsilon', 'PNPLA3', 'C22orf20', 'iPLA(2)epsilon', 'PNPLA3', 'ADPN', 'iPLA(2)epsilon', 'ACBD2', 'DRS-1', 'DRS1', 'HCA88', 'PECI', 'dJ1013A10.3', 'DDX27', 'Drs1p', 'HSPC259', 'PP3241', 'RHLP', 'dJ686N3.1', 'ECI2', 'DRS-1', 'DRS1', 'HCA88', 'PECI', 'dJ1013A10.3', 'ECI2', 'ACBD2', 'DRS-1', 'DRS1', 'PECI', 'dJ1013A10.3', 'ECI2', 'ACBD2', 'DRS-1', 'DRS1', 'HCA88', 'dJ1013A10.3', 'ACAD-8', 'ARC42']
# exploring ['PLPP4', 'DPPL2', 'PPAPDC1', 'PPAPDC1A', 'SLC7A1', 'ATRC1', 'CAT-1', 'ERR', 'HCAT1', 'REC1L', 'PNLIPRP3', 'PNPLA3', 'ADPN', 'C22orf20', 'FLJ22012', 'adiponutrin', 'dJ796I17.1', 'iPLA2epsilon', 'ECI2', 'DRS1', 'ACBD2', 'HCA88', 'PECI', 'ACAD8', 'iPLA(2)epsilon', 'DRS-1', 'dJ1013A10.3', 'DDX27', 'Drs1p', 'HSPC259', 'PP3241', 'RHLP', 'dJ686N3.1', 'ACAD-8', 'ARC42', 'PLPP4 mRna', 'PLPP4 protein', 'DPPL2 mRna', 'DPPL2 protein', 'PPAPDC1 mRna', 'PPAPDC1 protein', 'PPAPDC1A mRna', 'PPAPDC1A protein', 'SLC7A1 mRna', 'SLC7A1 protein', 'ATRC1 mRna', 'ATRC1 protein', 'CAT-1 mRna', 'CAT-1 protein', 'ERR mRna']
#
# Explored 208 regulators
# exploring ['ERR protein', 'HCAT1 mRna', 'HCAT1 protein', 'REC1L mRna', 'REC1L protein', 'PNLIPRP3 mRna', 'PNLIPRP3 protein', 'PNPLA3 mRna', 'PNPLA3 protein', 'ADPN mRna', 'ADPN protein', 'C22orf20 mRna', 'C22orf20 protein', 'FLJ22012 mRna', 'FLJ22012 protein', 'adiponutrin mRna', 'adiponutrin protein', 'dJ796I17.1 mRna', 'dJ796I17.1 protein', 'iPLA2epsilon mRna', 'iPLA2epsilon protein', 'ECI2 mRna', 'ECI2 protein', 'DRS1 mRna', 'DRS1 protein', 'ACBD2 mRna
hsa-miR-4417', 'hsa-miR-4701-5p', 'hsa-miR-3194-5p', 'hsa-miR-4769-3p', 'hsa-miR-671-5p', 'hsa-miR-1228-3p', 'hsa-miR-4283', 'hsa-miR-4689', 'hsa-miR-3925-3p', 'hsa-miR-4687-5p', 'CREB1', 'ATF2', 'SRF', 'CRX', 'ATF4', 'SPI1', 'SRY', 'RFX1']
#
# Explored 501 regulators
# exploring ['STAT6', 'FOXO4', 'ETS1', 'TP53', 'HMGA1', 'PITX2', 'MEF2A', 'SP1', 'CREB', 'CREB-1', 'GDNF', 'ATF', 'ATF1', 'HFB1-GDNF', 'HSCR3', 'MCM1', 'CORD2', 'CRD', 'LCA7', 'OTX3', 'CREB-2', 'CREB2', 'TAXREB67', 'TXREB', 'OF', 'PU.1', 'SFPI1', 'SPI-1', 'SPI-A', 'SRXX1', 'SRXY1', 'TDF', 'TDY', 'EFC', 'RFX', 'D12S1644', 'IL-4-STAT', 'STAT6B', 'STAT6C', 'AFX', 'AFX1', 'MLLT7', 'ETS-1', 'EWSR2', 'c-ets-1', 'p54', 'TP53BP1', '53BP1', 'TDRD30', 'p202']
#
# Explored 927 regulators
# exploring ['p53BP1', 'HMG-R', 'HMGA1A', 'HMGIY', 'ARP1', 'ASGD4', 'Brx1', 'IDG2', 'IGDS', 'IGDS2', 'IHG2', 'IRID2', 'Otlx2', 'PTX2', 'RGS', 'RIEG', 'RIEG1', 'RS', 'ADCAD1', 'RSRFC4', 'RSRFC9', 'mef2', 'DAND5', 'CER2', 'CERL2', 'CKTSF1B3', 'COCO', 'CRL2', 'DANTE', 'GREM3', 'hsa-miR-92a-3p mRna', 'hsa-miR-92a-3p protein', 'hsa-miR-1976 mRna', 'hsa-miR-1976 protein', 'hsa-miR-3116 mRna', 'hsa-miR-3116 protein', 'hsa-miR-1587 mRna', 'hsa-miR-1587 protein', 'hsa-miR-5010-3p mRna', 'hsa-miR-5010-3p protein', 'hsa-miR-3198 mRna', 'hsa-miR-3198 protein', 'hsa-miR-6079 mRna', 'hsa-miR-6079 protein', 'hsa-miR-1825 mRna', 'hsa-miR-1825 protein', 'hsa-miR-181a-5p mRna', 'hsa-miR-181a-5p protein', 'hsa-miR-92b-3p mRna', 'hsa-miR-92b-3p protein']
#
# Explored 939 regulators
# exploring ['hsa-miR-186-5p mRna', 'hsa-miR-186-5p protein', 'hsa-miR-181d-5p mRna', 'hsa-miR-181d-5p protein', 'hsa-miR-5589-5p mRna', 'hsa-miR-5589-5p protein', 'hsa-miR-10b-5p mRna', 'hsa-miR-10b-5p protein', 'hsa-miR-21-5p mRna', 'hsa-miR-21-5p protein', 'hsa-miR-5589-3p mRna', 'hsa-miR-5589-3p protein', 'hsa-miR-4757-5p mRna', 'hsa-miR-4757-5p protein', 'hsa-miR-124-3p mRna', 'hsa-miR-124-3p protein', 'hsa-miR-375 mRna', 'hsa-miR-375 protein', 'hsa-miR-328-3p mRna', 'hsa-miR-328-3p protein', 'hsa-miR-125b-5p mRna', 'hs
4675 mRna', 'hsa-miR-4675 protein', 'hsa-miR-4786-3p mRna', 'hsa-miR-4786-3p protein', 'hsa-miR-32-5p mRna', 'hsa-miR-32-5p protein', 'hsa-miR-16-5p mRna', 'hsa-miR-16-5p protein', 'hsa-miR-520g-3p mRna', 'hsa-miR-520g-3p protein', 'hsa-miR-6747-3p mRna', 'hsa-miR-6747-3p protein']
#
# Explored 939 regulators
# exploring ['hsa-miR-520h mRna', 'hsa-miR-520h protein', 'hsa-miR-483-3p mRna', 'hsa-miR-483-3p protein', 'hsa-miR-6783-3p mRna', 'hsa-miR-6783-3p protein', 'hsa-miR-6513-3p mRna', 'hsa-miR-6513-3p protein', 'hsa-miR-6778-3p mRna', 'hsa-miR-6778-3p protein', 'hsa-miR-6829-5p mRna', 'hsa-miR-6829-5p protein', 'hsa-miR-4524a-3p mRna', 'hsa-miR-4524a-3p protein', 'hsa-miR-6823-5p mRna', 'hsa-miR-6823-5p protein', 'hsa-miR-541-3p mRna', 'hsa-miR-541-3p protein', 'hsa-miR-4421 mRna', 'hsa-miR-4421 protein', 'hsa-miR-4308 mRna', 'hsa-miR-4308 protein', 'hsa-miR-23b-5p mRna', 'hsa-miR-23b-5p protein', 'hsa-miR-2113 mRna', 'hsa-miR-2113 protein', 'hsa-miR-4793-3p mRna', 'hsa-miR-4793-3p protein', 'hsa-miR-122-5p mRna', 'hsa-miR-122-5p protein', 'hsa-miR-651-3p mRna', 'hsa-miR-651-3p protein', 'hsa-miR-6813-3p mRna', 'hsa-miR-6813-3p protein', 'hsa-miR-593-3p mRna', 'hsa-miR-593-3p protein', 'hsa-miR-3653-5p mRna', 'hsa-miR-3653-5p protein', 'hsa-miR-148a-3p mRna', 'hsa-miR-148a-3p protein', 'hsa-miR-4727-5p mRna', 'hsa-miR-4727-5p protein', 'hsa-miR-3148 mRna', 'hsa-miR-3148 protein', 'hsa-miR-4417 mRna', 'hsa-miR-4417 protein', 'hsa-miR-4701-5p mRna', 'hsa-miR-4701-5p protein', 'hsa-miR-3194-5p mRna', 'hsa-miR-3194-5p protein']
#
# Explored 939 regulators
# exploring ['hsa-miR-4769-3p mRna', 'hsa-miR-4769-3p protein', 'hsa-miR-671-5p mRna', 'hsa-miR-671-5p protein', 'hsa-miR-1228-3p mRna', 'hsa-miR-1228-3p protein', 'hsa-miR-4283 mRna', 'hsa-miR-4283 protein', 'hsa-miR-4689 mRna', 'hsa-miR-4689 protein', 'hsa-miR-3925-3p mRna', 'hsa-miR-3925-3p protein', 'hsa-miR-4687-5p mRna', 'hsa-miR-4687-5p protein', 'CREB1 mRna', 'CREB1 protein', 'ATF2 mRna', 'ATF2 protein', 'SRF mRna', 'SRF protein', 'CRX mRna', 'CRX protein', 'ATF4 mRna', 'ATF4 protein', 'SPI1 mRna', 'SPI1 protein', 'SRY mRna', 'SRY protein', 'RFX1 mRna', 'RFX1 protein', 'STAT6 mRna', 'STAT6 protein', 'FOXO4 mRna', 'FOXO4 protein', 'ETS1 mRna', 'ETS1 protein', 'TP53 mRna', 'TP53 protein', 'HMGA1 mRna', 'HMGA1 protein', 'PITX2 mRna', 'PITX2 protein', 'MEF2A mRna', 'MEF2A protein', 'SP1 mRna', 'SP1 protein', 'CREB mRna', 'CREB protein', 'CREB-1 mRna', 'CREB-1 protein']
# 		removing suffix  mRNA for MIR27A mRNA
# 				 --> MIR27A
# 		removing suffix  protein for SP1 protein
# 				 --> SP1
# 		removing suffix  mutant form for SLC39A8 mutant form
# 				 --> SLC39A8
# 		removing suffix  protein for SP1 protein
# 				 --> SP1
# 		removing suffix  protein for INS protein
# 				 --> INS
# 		removing suffix  protein for SP1 protein
# 				 --> SP1
#
# Explored 942 regulators
# exploring ['GDNF mRna', 'GDNF protein', 'ATF mRna', 'ATF protein', 'ATF1 mRna', 'ATF1 protein', 'HFB1-GDNF mRna', 'HFB1-GDNF protein', 'HSCR3 mRna', 'HSCR3 protein', 'MCM1 mRna', 'MCM1 protein', 'CORD2 mRna', 'CORD2 protein', 'CRD mRna', 'CRD protein', 'LCA7 mRna', 'LCA7 protein', 'OTX3 mRna', 'OTX3 protein', 'CREB-2 mRna', 'CREB-2 protein', 'CREB2 mRna', 'CREB2 protein', 'TAXREB67 mRna', 'TAXREB67 protein', 'TXREB mRna', 'TXREB protein', 'OF mRna', 'OF protein', 'PU.1 mRna', 'PU.1 protein', 'SFPI1 mRna', 'SFPI1 protein', 'SPI-1 mRna', 'SPI-1 protein', 'SPI-A mRna', 'SPI-A protein', 'SRXX1 mRna', 'SRXX1 protein', 'SRXY1 mRna', 'SRXY1 protein', 'TDF mRna', 'TDF protein', 'TDY mRna', 'TDY protein', 'EFC mRna', 'EFC protein', 'RFX mRna', 'RFX protein']
# 		removing suffix  protein for NOG protein
# 				 --> NOG
# 		removing suffix  protein for GDNF protein
# 				 --> GDNF
#
# Explored 943 regulators
# exploring ['D12S1644 mRna', 'D12S1644 protein', 'IL-4-STAT mRna', 'IL-4-STAT protein', 'STAT6B mRna', 'STAT6B protein', 'STAT6C mRna', 'STAT6C protein', 'AFX mRna', 'AFX protein', 'AFX1 mRna', 'AFX1 protein', 'MLLT7 mRna', 'MLLT7 protein', 'ETS-1 mRna', 'ETS-1 protein', 'EWSR2 mRna', 'EWSR2 protein', 'c-ets-1 mRna', 'c-ets-1 protein', 'p54 mRna', 'p54 protein', 'TP53BP1 mRna', 'TP53BP1 protein', '53BP1 mRna', '53BP1 protein', 'TDRD30 mRna', 'TDRD30 protein', 'p202 mRna', 'p202 protein', 'p53BP1 mRna', 'p53BP1 protein', 'HMG-R mRna', 'HMG-R protein', 'HMGA1A mRna', 'HMGA1A protein', 'HMGIY mRna', 'HMGIY protein', 'ARP1 mRna', 'ARP1 protein', 'ASGD4 mRna', 'ASGD4 protein', 'Brx1 mRna', 'Brx1 protein', 'IDG2 mRna', 'IDG2 protein', 'IGDS mRna', 'IGDS protein', 'IGDS2 mRna', 'IGDS2 protein']
#
# Explored 943 regulators
# exploring ['IHG2 mRna', 'IHG2 protein', 'IRID2 mRna', 'IRID2 protein', 'Otlx2 mRna', 'Otlx2 protein', 'PTX2 mRna', 'PTX2 protein', 'RGS mRna', 'RGS protein', 'RIEG mRna', 'RIEG protein', 'RIEG1 mRna', 'RIEG1 protein', 'RS mRna', 'RS protein', 'ADCAD1 mRna', 'ADCAD1 protein', 'RSRFC4 mRna', 'RSRFC4 protein', 'RSRFC9 mRna', 'RSRFC9 protein', 'mef2 mRna', 'mef2 protein', 'DAND5 mRna', 'DAND5 protein', 'CER2 mRna', 'CER2 protein', 'CERL2 mRna', 'CERL2 protein', 'CKTSF1B3 mRna', 'CKTSF1B3 protein', 'COCO mRna', 'COCO protein', 'CRL2 mRna', 'CRL2 protein', 'DANTE mRna', 'DANTE protein', 'GREM3 mRna', 'GREM3 protein']
#
# Explored 943 regulators
# Exploring halted due to maximum depth
# --- Upstream regulation network in 8.21 seconds ---

# %% [markdown]
# ## Metrics and SIF export of the regulation network

# %%
G = bravo_main.build_nx_digraph(reconstructed_network)

G_unified = util.fast_reg_network_unification(G, util.index_syn)
print('Nodes after synonym-based unification = ' + str(len(G_unified.nodes())))
print('Edges after synonym-based unification = ' + str(len(G_unified.edges())))

md = bravo_main.get_centrality_as_md(G_unified)
display(Markdown(md))

bravo_main.write_to_SIF(G_unified, 'no-mirtarbase-regulation.sif')
bravo_main.write_provenance(G_unified, 'no-mirtarbase-regulation-prov.csv')
# Out:
# Number of nodes = 950
# Number of edges = 1456
# 		merging node ATF2 into node GDNF
# 		merging node ATF1 into node GDNF
# 		merging node ATF2 into node GDNF
# 		merging node HMGIY into node HMGA1
# 		merging node SP1 into node DAND5
# 		merging node HNF4A into node HNF1A
# 		merging node ATF1 into node GDNF
# 		merging node HMGIY into node HMGA1
# Nodes after synonym-based unification = 945
# Edges after synonym-based unification = 1446
# | Node | Degree Centrality |
# |------|------|
# | HMGA1 | 0.21 |
# | DAND5 | 0.209 |
# | TP53 | 0.158 |
# | CREB1 | 0.13 |
# | SRF | 0.12 |
# | GDNF | 0.115 |
# | SLC7A1 | 0.094 |
# | PITX2 | 0.092 |
# | PNPLA3 | 0.09 |
# | ETS1 | 0.086 |
# SIF network written to no-mirtarbase-regulation.sif
# Basic regulation reaction provenance written to no-mirtarbase-regulation-prov.csv

# %%
with open('no-mirtarbase-regulation-prov.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in reader:
        print(', '.join(row))
# Out:
# hsa-miR-92a-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-92a-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-92a-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-1976	INHIBITION	ACAD8, mirtarbase
# hsa-miR-1976	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-1976	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3116	INHIBITION	ACAD8, mirtarbase
# hsa-miR-1587	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-5010-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-3198	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6079	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-1825	INHIBITION	PLPP4, mirtarbase
# hsa-miR-1825	INHIBITION	ETS1, mirtarbase
# hsa-miR-181a-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-181a-5p	INHIBITION	DDX27, mirtarbase
# hsa-miR-181a-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-92b-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-92b-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-186-5p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-186-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-181d-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-181d-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-5589-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-5589-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-10b-5p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-10b-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-10b-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-10b-5p	INHIBITION	STAT6, mirtarbase
# hsa-miR-21-5p	INHIBITION	ECI2, mirtarbase
# hsa-miR-21-5p	INHIBITION	MEF2A, mirtarbase
# hsa-miR-21-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-21-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-5589-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4757-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-124-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-124-3p	INHIBITION	ECI2, mirtarbase
# hsa-miR-124-3p	INHIBITION	RFX1, mirtarbase
# hsa-miR-124-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-124-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-375	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-375	INHIBITION	TP53, mirtarbase
# hsa-miR-375	INHIBITION	DAND5, mirtarbase
# hsa-miR-328-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-125b-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-125b-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-125b-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-125b-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-6807-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6807-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-8055	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-155-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-155-5p	INHIBITION	SPI1, mirtarbase
# hsa-miR-155-5p	INHIBITION	MEF2A, mirtarbase
# hsa-miR-155-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-155-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4309	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4252	INHIBITION	PLPP4, mirtarbase
# hsa-miR-4252	INHIBITION	ACAD8, mirtarbase
# hsa-miR-4252	INHIBITION	CREB1, mirtarbase
# hsa-miR-939-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-939-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6852-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6852-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4537	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-212-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6134	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-181b-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-181b-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-181b-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-1304-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6765-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-652-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-1205	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-7113-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-7113-3p	INHIBITION	SPI1, mirtarbase
# hsa-miR-7703	INHIBITION	ACAD8, mirtarbase
# hsa-miR-7703	INHIBITION	DAND5, mirtarbase
# hsa-miR-6744-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4489	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-3919	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4756-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-5096	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6742-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6742-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6732-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-6878-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-339-5p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-339-5p	INHIBITION	SPI1, mirtarbase
# hsa-miR-3158-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-1343-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6818-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-3978	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-3978	INHIBITION	RFX1, mirtarbase
# hsa-miR-1289	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4802-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-6766-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-6766-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-1254	INHIBITION	ACAD8, mirtarbase
# hsa-miR-6895-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-6804-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-6727-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-6727-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6727-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-6727-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-654-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4717-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-23a-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-23a-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-4684-5p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-6739-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-3620-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-8062	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4656	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4498	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-5001-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4741	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4741	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4294	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6876-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-26a-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-26a-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-26a-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-191-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-152-3p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-150-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-150-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-150-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-150-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4465	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-5693	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-5693	INHIBITION	TP53, mirtarbase
# hsa-miR-4722-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-4722-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4722-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-4722-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-197-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-197-3p	INHIBITION	RFX1, mirtarbase
# hsa-miR-6756-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-6756-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-4279	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-7854-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-3150b-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-7852-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-7852-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-508-5p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-508-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4784	INHIBITION	SLC7A1, mirtarbase
# hsa-let-7a-5p	INHIBITION	ACAD8, mirtarbase
# hsa-let-7a-5p	INHIBITION	CRX, mirtarbase
# hsa-let-7a-5p	INHIBITION	HMGA1, mirtarbase
# hsa-let-7a-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4731-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4731-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4731-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-3916	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-3916	INHIBITION	HMGA1, mirtarbase
# hsa-miR-2467-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-2467-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4438	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4438	INHIBITION	CREB1, mirtarbase
# hsa-miR-30e-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-5699-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-1273g-3p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-1273g-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-7151-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-7151-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-5095	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-5095	INHIBITION	CREB1, mirtarbase
# hsa-miR-4775	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-562	INHIBITION	ACAD8, mirtarbase
# hsa-miR-26b-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-26b-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-26b-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-26b-5p	INHIBITION	STAT6, mirtarbase
# hsa-miR-130b-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-551b-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-3678-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-877-3p	INHIBITION	ECI2, mirtarbase
# hsa-miR-877-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6832-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6504-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6504-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6880-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6880-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-6880-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6817-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4524b-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-23b-3p	INHIBITION	DDX27, mirtarbase
# hsa-miR-23b-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-199b-5p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-181c-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-181c-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-199a-5p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-199a-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-762	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-10a-5p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-10a-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-335-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-335-5p	INHIBITION	PNLIPRP3, mirtarbase
# hsa-miR-335-5p	INHIBITION	FOXO4, mirtarbase
# hsa-miR-335-5p	INHIBITION	MEF2A, mirtarbase
# hsa-miR-335-5p	INHIBITION	STAT6, mirtarbase
# hsa-miR-335-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-335-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-335-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-5189-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4292	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4292	INHIBITION	DAND5, mirtarbase
# hsa-miR-3688-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-656-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-185-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-185-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-548c-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-129-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-129-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-129-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-664a-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-186-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-186-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-590-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4735-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4735-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6828-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-24-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-24-3p	INHIBITION	CRX, mirtarbase
# hsa-miR-24-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-24-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-661	INHIBITION	ACAD8, mirtarbase
# hsa-miR-661	INHIBITION	DAND5, mirtarbase
# hsa-miR-411-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6858-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4435	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-550b-2-5p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-5680	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-1297	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-1297	INHIBITION	HMGA1, mirtarbase
# hsa-miR-30d-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-455-3p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-455-3p	INHIBITION	CRX, mirtarbase
# hsa-miR-30a-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-30a-3p	INHIBITION	MEF2A, mirtarbase
# hsa-miR-1227-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-148b-3p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-148b-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-3665	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-657	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-548n	INHIBITION	ACAD8, mirtarbase
# hsa-miR-4694-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4694-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3668	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-6791-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6791-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4763-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4476	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-1260b	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4486	INHIBITION	ACAD8, mirtarbase
# hsa-miR-3677-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4794	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-1251-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4492	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4675	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4675	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4786-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-32-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-32-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-16-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-16-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-16-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-16-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-520g-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-520g-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6747-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-6747-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6747-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-6747-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6747-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-520h	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-520h	INHIBITION	CREB1, mirtarbase
# hsa-miR-483-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-483-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-6783-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6513-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6778-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6829-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4524a-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-6823-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-541-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4421	INHIBITION	ACAD8, mirtarbase
# hsa-miR-4308	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4308	INHIBITION	DAND5, mirtarbase
# hsa-miR-23b-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-2113	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4793-3p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-4793-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-122-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-122-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-122-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-651-3p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-6813-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-593-3p	INHIBITION	ACAD8, mirtarbase
# hsa-miR-3653-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-148a-3p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-4727-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-3148	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-3148	INHIBITION	RFX1, mirtarbase
# hsa-miR-3148	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4417	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4701-5p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-4701-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3194-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4769-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-671-5p	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-671-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-1228-3p	INHIBITION	PNPLA3, mirtarbase
# hsa-miR-1228-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-1228-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-4283	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-4689	INHIBITION	SLC7A1, mirtarbase
# hsa-miR-3925-3p	INHIBITION	PLPP4, mirtarbase
# hsa-miR-4687-5p	INHIBITION	PNPLA3, mirtarbase
# CREB1	UNKNOWN	PNPLA3, msigdb
# CREB1	UNKNOWN	SPI1, msigdb
# CREB1	UNKNOWN	PITX2, msigdb
# CREB1	UNKNOWN	GDNF, msigdb
# SRF	UNKNOWN	SLC7A1, msigdb
# SRF	UNKNOWN	SRF, msigdb
# SRF	UNKNOWN	ATF4, msigdb
# SRF	UNKNOWN	FOXO4, msigdb
# CRX	UNKNOWN	PNPLA3, msigdb
# CRX	UNKNOWN	PITX2, msigdb
# ATF4	UNKNOWN	PNPLA3, msigdb
# ATF4	UNKNOWN	PITX2, msigdb
# ATF4	UNKNOWN	GDNF, msigdb
# SPI1	UNKNOWN	SLC7A1, msigdb
# SPI1	UNKNOWN	SPI1, msigdb
# SPI1	UNKNOWN	FOXO4, msigdb
# SPI1	UNKNOWN	STAT6, msigdb
# SPI1	UNKNOWN	PITX2, msigdb
# SRY	UNKNOWN	SLC7A1, msigdb
# SRY	UNKNOWN	FOXO4, msigdb
# SRY	UNKNOWN	DAND5, msigdb
# RFX1	UNKNOWN	SLC7A1, msigdb
# RFX1	UNKNOWN	TP53BP1, msigdb
# RFX1	UNKNOWN	PITX2, msigdb
# STAT6	UNKNOWN	SLC7A1, msigdb
# STAT6	UNKNOWN	SPI1, msigdb
# STAT6	UNKNOWN	HMGA1, msigdb
# FOXO4	UNKNOWN	SLC7A1, msigdb
# FOXO4	UNKNOWN	TP53, msigdb
# FOXO4	UNKNOWN	FOXO4, msigdb
# FOXO4	UNKNOWN	STAT6, msigdb
# FOXO4	UNKNOWN	PITX2, msigdb
# FOXO4	UNKNOWN	ETS1, msigdb
# FOXO4	UNKNOWN	DAND5, msigdb
# ETS1	UNKNOWN	SLC7A1, msigdb
# ETS1	UNKNOWN	SPI1, msigdb
# ETS1	UNKNOWN	FOXO4, msigdb
# ETS1	ACTIVATION	ETS1, pid
# ETS1	UNKNOWN	HMGA1, msigdb
# TP53	UNKNOWN	SLC7A1, msigdb
# HMGA1	UNKNOWN	SLC7A1, msigdb
# HMGA1	UNKNOWN	PITX2, msigdb
# PITX2	UNKNOWN	PNPLA3, msigdb
# PITX2	UNKNOWN	RFX1, msigdb
# PITX2	UNKNOWN	CRX, msigdb
# PITX2	UNKNOWN	TP53, msigdb
# PITX2	UNKNOWN	FOXO4, msigdb
# PITX2	UNKNOWN	PITX2, msigdb
# PITX2	UNKNOWN	TP53BP1, msigdb
# PITX2	UNKNOWN	GDNF, msigdb
# MEF2A	UNKNOWN	SLC7A1, msigdb
# MEF2A	UNKNOWN	CREB1, msigdb
# MEF2A	UNKNOWN	PITX2, msigdb
# MEF2A	UNKNOWN	ETS1, msigdb
# hsa-miR-619-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1827	INHIBITION	SRF, mirtarbase
# hsa-miR-6893-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-363-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-664a-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-567	INHIBITION	CREB1, mirtarbase
# hsa-miR-520b	INHIBITION	CREB1, mirtarbase
# hsa-miR-520e	INHIBITION	CREB1, mirtarbase
# hsa-miR-3664-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-3612	INHIBITION	SRF, mirtarbase
# hsa-miR-520d-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-205-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-106b-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-106b-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-20a-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-20a-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-485-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-485-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6875-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-484	INHIBITION	SRF, mirtarbase
# hsa-miR-204-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-204-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6499-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-6499-3p	INHIBITION	CRX, mirtarbase
# hsa-miR-18a-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-18a-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-101-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-3606-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-297	INHIBITION	CREB1, mirtarbase
# hsa-miR-6731-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-6731-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-363-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-363-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4316	INHIBITION	SRF, mirtarbase
# hsa-miR-4514	INHIBITION	SRF, mirtarbase
# hsa-miR-664b-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-2682-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-4768-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-6834-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6834-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-4789-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-7160-5p	INHIBITION	SRF, mirtarbase
# hsa-let-7b-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4760-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4643	INHIBITION	CREB1, mirtarbase
# hsa-miR-4643	INHIBITION	ETS1, mirtarbase
# hsa-miR-3929	INHIBITION	SRF, mirtarbase
# hsa-miR-3175	INHIBITION	SRF, mirtarbase
# hsa-miR-650	INHIBITION	SRF, mirtarbase
# hsa-miR-3185	INHIBITION	SRF, mirtarbase
# hsa-miR-6804-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-512-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-302e	INHIBITION	CREB1, mirtarbase
# hsa-miR-4263	INHIBITION	CREB1, mirtarbase
# hsa-miR-4459	INHIBITION	SRF, mirtarbase
# hsa-miR-4459	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4640-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-3160-3p	INHIBITION	SRF, mirtarbase
# hsa-let-7a-3p	INHIBITION	CREB1, mirtarbase
# hsa-let-7f-1-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-8085	INHIBITION	SRF, mirtarbase
# hsa-miR-8085	INHIBITION	TP53, mirtarbase
# hsa-miR-4723-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-6794-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-6794-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6734-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6734-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-423-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-423-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-3126-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-1224-5p	INHIBITION	CREB1, mirtarbase
# SRF(dimer)/MAL(dimer)	ACTIVATION	SRF, pid
# hsa-miR-520c-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4756-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-4756-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6506-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-7847-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-182-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-182-5p	INHIBITION	TP53BP1, mirtarbase
# hsa-miR-182-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-1294	INHIBITION	SRF, mirtarbase
# hsa-miR-4478	INHIBITION	SRF, mirtarbase
# hsa-miR-15a-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-15a-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-15a-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-940	INHIBITION	SRF, mirtarbase
# hsa-miR-513a-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-520a-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-513c-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-466	INHIBITION	CREB1, mirtarbase
# hsa-miR-466	INHIBITION	GDNF, mirtarbase
# hsa-miR-466	INHIBITION	DAND5, mirtarbase
# hsa-miR-4433a-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-1277-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1277-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-5089-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-7515	INHIBITION	SRF, mirtarbase
# hsa-miR-7111-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-302c-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-376a-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-433-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-324-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-324-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-302a-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-331-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-331-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6870-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-510-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-6129	INHIBITION	SRF, mirtarbase
# hsa-miR-6129	INHIBITION	TP53, mirtarbase
# hsa-miR-6129	INHIBITION	HMGA1, mirtarbase
# hsa-miR-200b-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-200b-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-200b-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-483-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-373-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1185-1-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-34b-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-519d-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-372-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-320a	INHIBITION	SRF, mirtarbase
# hsa-miR-1229-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-28-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-28-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-302d-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1185-2-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4789-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4789-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-512-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1226-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4692	INHIBITION	SRF, mirtarbase
# hsa-miR-3145-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-98-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6864-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-3179	INHIBITION	SRF, mirtarbase
# hsa-miR-6738-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6738-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-708-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-19b-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-19b-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-19b-3p	INHIBITION	MEF2A, mirtarbase
# hsa-miR-19b-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-200a-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-200a-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-190a-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-190a-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-190a-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-34b-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-106a-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-106a-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6808-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-6868-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4716-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-4716-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-33b-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-103a-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-1-3p	INHIBITION	MEF2A, mirtarbase
# hsa-miR-1-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-1-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-7154-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-4443	INHIBITION	SRF, mirtarbase
# hsa-miR-665	INHIBITION	SRF, mirtarbase
# hsa-miR-6130	INHIBITION	SRF, mirtarbase
# hsa-miR-6130	INHIBITION	TP53, mirtarbase
# hsa-miR-6130	INHIBITION	HMGA1, mirtarbase
# hsa-miR-204-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-3928-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-4666a-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-579-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1914-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1914-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-576-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6745	INHIBITION	SRF, mirtarbase
# hsa-miR-6781-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-6862-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-6862-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6784-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-6784-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6802-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-6802-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-5194	INHIBITION	CREB1, mirtarbase
# hsa-miR-5194	INHIBITION	DAND5, mirtarbase
# hsa-miR-374b-5p	INHIBITION	PITX2, mirtarbase
# hsa-miR-374b-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-374b-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-20b-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-27b-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-27b-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-17-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-17-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6835-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6835-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-1183	INHIBITION	CREB1, mirtarbase
# hsa-miR-1224-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1224-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6511a-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-3924	INHIBITION	CREB1, mirtarbase
# hsa-miR-203a-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-381-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-526b-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4519	INHIBITION	SRF, mirtarbase
# hsa-miR-93-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4510	INHIBITION	SRF, mirtarbase
# hsa-miR-4510	INHIBITION	TP53, mirtarbase
# hsa-miR-4510	INHIBITION	HMGA1, mirtarbase
# hsa-miR-656-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-5011-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-5011-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-5011-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-3139	INHIBITION	SRF, mirtarbase
# hsa-miR-3184-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-3184-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-548e-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-548e-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-4760-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-3074-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-578	INHIBITION	CREB1, mirtarbase
# hsa-miR-578	INHIBITION	RFX1, mirtarbase
# hsa-miR-9-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-9-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-9-5p	INHIBITION	SPI1, mirtarbase
# hsa-miR-9-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-9-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-5698	INHIBITION	SRF, mirtarbase
# hsa-miR-4419a	INHIBITION	SRF, mirtarbase
# hsa-miR-4419a	INHIBITION	TP53, mirtarbase
# hsa-miR-4419a	INHIBITION	HMGA1, mirtarbase
# hsa-miR-302b-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-582-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4302	INHIBITION	SRF, mirtarbase
# hsa-miR-300	INHIBITION	CREB1, mirtarbase
# hsa-miR-300	INHIBITION	TP53, mirtarbase
# hsa-miR-519d-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-6884-5p	INHIBITION	SRF, mirtarbase
# hsa-miR-4419b	INHIBITION	SRF, mirtarbase
# hsa-let-7f-2-3p	INHIBITION	CREB1, mirtarbase
# hsa-miR-1321	INHIBITION	SRF, mirtarbase
# hsa-miR-1321	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3943	INHIBITION	SRF, mirtarbase
# hsa-miR-5696	INHIBITION	CREB1, mirtarbase
# hsa-miR-6511b-3p	INHIBITION	SRF, mirtarbase
# hsa-miR-526b-5p	INHIBITION	CREB1, mirtarbase
# hsa-miR-4739	INHIBITION	SRF, mirtarbase
# hsa-miR-4739	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6127	INHIBITION	SRF, mirtarbase
# hsa-miR-6127	INHIBITION	TP53, mirtarbase
# hsa-miR-6127	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6133	INHIBITION	SRF, mirtarbase
# hsa-miR-6133	INHIBITION	TP53, mirtarbase
# hsa-miR-6133	INHIBITION	HMGA1, mirtarbase
# hsa-miR-8061	INHIBITION	CREB1, mirtarbase
# hsa-miR-3915	INHIBITION	SRF, mirtarbase
# MAZ	UNKNOWN	SRF, msigdb
# MAZ	UNKNOWN	RFX1, msigdb
# MAZ	UNKNOWN	SPI1, msigdb
# MAZ	UNKNOWN	TP53, msigdb
# MAZ	UNKNOWN	FOXO4, msigdb
# MAZ	UNKNOWN	PITX2, msigdb
# MAZ	UNKNOWN	STAT6, msigdb
# MAZ	UNKNOWN	HMGA1, msigdb
# MAZ	UNKNOWN	GDNF, msigdb
# MAZ	UNKNOWN	DAND5, msigdb
# POU2F1	UNKNOWN	SRF, msigdb
# POU2F1	UNKNOWN	PITX2, msigdb
# POU2F1	UNKNOWN	TP53BP1, msigdb
# IRF1	UNKNOWN	CREB1, msigdb
# IRF1	UNKNOWN	PITX2, msigdb
# IRF1	UNKNOWN	STAT6, msigdb
# E4F1	UNKNOWN	CREB1, msigdb
# E4F1	UNKNOWN	RFX1, msigdb
# E4F1	UNKNOWN	PITX2, msigdb
# E4F1	UNKNOWN	GDNF, msigdb
# GFI1	UNKNOWN	ETS1, msigdb
# GFI1	UNKNOWN	HMGA1, msigdb
# GFI1	UNKNOWN	PITX2, msigdb
# GFI1	UNKNOWN	GDNF, msigdb
# MTF1	UNKNOWN	CREB1, msigdb
# MTF1	UNKNOWN	FOXO4, msigdb
# MTF1	UNKNOWN	HMGA1, msigdb
# MTF1	UNKNOWN	GDNF, msigdb
# PAX4	UNKNOWN	SRF, msigdb
# PAX4	UNKNOWN	RFX1, msigdb
# PAX4	UNKNOWN	TP53, msigdb
# PAX4	UNKNOWN	FOXO4, msigdb
# PAX4	UNKNOWN	HMGA1, msigdb
# PAX4	UNKNOWN	PITX2, msigdb
# PAX4	UNKNOWN	STAT6, msigdb
# PAX4	UNKNOWN	TP53BP1, msigdb
# PAX4	UNKNOWN	GDNF, msigdb
# MYC	UNKNOWN	SRF, msigdb
# MYC	UNKNOWN	ATF4, msigdb
# MYC	UNKNOWN	TP53, msigdb
# MYC	UNKNOWN	HMGA1, msigdb
# MYC	UNKNOWN	GDNF, msigdb
# YY1	UNKNOWN	SRF, msigdb
# YY1	UNKNOWN	ATF4, msigdb
# YY1	UNKNOWN	RFX1, msigdb
# YY1	UNKNOWN	TP53BP1, msigdb
# YY1	UNKNOWN	GDNF, msigdb
# YY1	UNKNOWN	DAND5, msigdb
# SMAD4	UNKNOWN	CREB1, msigdb
# NKX2-1	UNKNOWN	CREB1, msigdb
# NKX2-1	UNKNOWN	DAND5, msigdb
# VDR	UNKNOWN	SRF, msigdb
# VDR	UNKNOWN	PITX2, msigdb
# REPIN1	UNKNOWN	SRF, msigdb
# REPIN1	UNKNOWN	FOXO4, msigdb
# REPIN1	UNKNOWN	ETS1, msigdb
# REPIN1	UNKNOWN	TP53BP1, msigdb
# REPIN1	UNKNOWN	GDNF, msigdb
# ZEB1	UNKNOWN	PITX2, msigdb
# ZEB1	UNKNOWN	STAT6, msigdb
# ZEB1	UNKNOWN	GDNF, msigdb
# REL	UNKNOWN	CREB1, msigdb
# REL	UNKNOWN	TP53, msigdb
# REL	UNKNOWN	STAT6, msigdb
# FOXF2	UNKNOWN	FOXO4, msigdb
# FOXF2	UNKNOWN	PITX2, msigdb
# FOXF2	UNKNOWN	ETS1, msigdb
# FOXF2	UNKNOWN	STAT6, msigdb
# FOXF2	UNKNOWN	GDNF, msigdb
# GATA1	UNKNOWN	SRF, msigdb
# GATA1	UNKNOWN	FOXO4, msigdb
# GATA1	UNKNOWN	PITX2, msigdb
# GTF2A2	UNKNOWN	SRF, msigdb
# AHR	UNKNOWN	TP53, msigdb
# AHR	UNKNOWN	GDNF, msigdb
# NF1	UNKNOWN	SRF, msigdb
# NF1	UNKNOWN	CRX, msigdb
# NF1	UNKNOWN	ATF4, msigdb
# NF1	UNKNOWN	MEF2A, msigdb
# NF1	UNKNOWN	PITX2, msigdb
# NF1	UNKNOWN	DAND5, msigdb
# EGR2	UNKNOWN	SRF, msigdb
# EGR2	UNKNOWN	HMGA1, msigdb
# EGR2	UNKNOWN	DAND5, msigdb
# HIF1A	UNKNOWN	SRF, msigdb
# HIF1A	UNKNOWN	FOXO4, msigdb
# HIF1A	UNKNOWN	HMGA1, msigdb
# HIF1A	UNKNOWN	PITX2, msigdb
# PAX5	UNKNOWN	SRF, msigdb
# MAX	UNKNOWN	SRF, msigdb
# MAX	UNKNOWN	ATF4, msigdb
# MAX	UNKNOWN	TP53, msigdb
# MAX	UNKNOWN	HMGA1, msigdb
# TFCP2	UNKNOWN	CREB1, msigdb
# TFCP2	UNKNOWN	PITX2, msigdb
# TCF3	UNKNOWN	SPI1, msigdb
# TCF3	UNKNOWN	FOXO4, msigdb
# TCF3	UNKNOWN	HMGA1, msigdb
# TCF3	UNKNOWN	TP53BP1, msigdb
# TCF3	UNKNOWN	GDNF, msigdb
# FOXO3	UNKNOWN	PITX2, msigdb
# FOXO3	UNKNOWN	GDNF, msigdb
# RELA	UNKNOWN	CREB1, msigdb
# RELA	UNKNOWN	TP53, msigdb
# RELA	UNKNOWN	STAT6, msigdb
# RORA	UNKNOWN	CREB1, msigdb
# RORA	UNKNOWN	PITX2, msigdb
# SREBF1	UNKNOWN	SPI1, msigdb
# SREBF1	UNKNOWN	ATF4, msigdb
# SREBF1	UNKNOWN	TP53BP1, msigdb
# SREBF1	UNKNOWN	STAT6, msigdb
# SREBF1	UNKNOWN	GDNF, msigdb
# GTF2A1	UNKNOWN	SRF, msigdb
# hsa-let-7g-5p	INHIBITION	CRX, mirtarbase
# hsa-let-7g-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4753-5p	INHIBITION	RFX1, mirtarbase
# hsa-let-7f-5p	INHIBITION	CRX, mirtarbase
# hsa-let-7f-5p	INHIBITION	HMGA1, mirtarbase
# hsa-let-7f-5p	INHIBITION	DAND5, mirtarbase
# hsa-let-7c-5p	INHIBITION	CRX, mirtarbase
# hsa-let-7c-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-5590-5p	INHIBITION	RFX1, mirtarbase
# hsa-miR-5590-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-548z	INHIBITION	RFX1, mirtarbase
# hsa-miR-548d-3p	INHIBITION	RFX1, mirtarbase
# hsa-miR-4327	INHIBITION	CRX, mirtarbase
# hsa-miR-370-5p	INHIBITION	RFX1, mirtarbase
# hsa-miR-6826-5p	INHIBITION	RFX1, mirtarbase
# hsa-miR-8069	INHIBITION	RFX1, mirtarbase
# hsa-miR-1283	INHIBITION	ATF4, mirtarbase
# hsa-miR-196b-5p	INHIBITION	ATF4, mirtarbase
# hsa-miR-196b-5p	INHIBITION	HMGA1, mirtarbase
# hsa-let-7i-5p	INHIBITION	CRX, mirtarbase
# hsa-let-7i-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-758-5p	INHIBITION	RFX1, mirtarbase
# hsa-miR-569	INHIBITION	SPI1, mirtarbase
# hsa-let-7e-5p	INHIBITION	CRX, mirtarbase
# hsa-let-7e-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-346	INHIBITION	RFX1, mirtarbase
# hsa-miR-346	INHIBITION	ETS1, mirtarbase
# hsa-let-7b-5p	INHIBITION	CRX, mirtarbase
# hsa-let-7b-5p	INHIBITION	HMGA1, mirtarbase
# hsa-let-7b-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-500a-5p	INHIBITION	CRX, mirtarbase
# hsa-let-7d-5p	INHIBITION	CRX, mirtarbase
# hsa-let-7d-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4451	INHIBITION	CRX, mirtarbase
# hsa-miR-548h-3p	INHIBITION	RFX1, mirtarbase
# hsa-miR-98-5p	INHIBITION	CRX, mirtarbase
# hsa-miR-98-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-342-3p	INHIBITION	ATF4, mirtarbase
# hsa-miR-296-3p	INHIBITION	SPI1, mirtarbase
# hsa-miR-296-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6749-3p	INHIBITION	SPI1, mirtarbase
# hsa-miR-6749-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-6749-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4458	INHIBITION	CRX, mirtarbase
# hsa-miR-4458	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3657	INHIBITION	SPI1, mirtarbase
# hsa-miR-5587-3p	INHIBITION	SPI1, mirtarbase
# hsa-miR-5587-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-6831-5p	INHIBITION	CRX, mirtarbase
# hsa-miR-548as-3p	INHIBITION	RFX1, mirtarbase
# hsa-miR-6781-5p	INHIBITION	CRX, mirtarbase
# hsa-miR-214-3p	INHIBITION	ATF4, mirtarbase
# hsa-miR-214-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-4659a-5p	INHIBITION	RFX1, mirtarbase
# hsa-miR-4659a-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6845-3p	INHIBITION	SPI1, mirtarbase
# hsa-miR-6124	INHIBITION	RFX1, mirtarbase
# hsa-miR-6124	INHIBITION	DAND5, mirtarbase
# hsa-miR-4669	INHIBITION	SPI1, mirtarbase
# hsa-miR-3178	INHIBITION	CRX, mirtarbase
# hsa-miR-4659b-5p	INHIBITION	RFX1, mirtarbase
# hsa-miR-4659b-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4776-3p	INHIBITION	RFX1, mirtarbase
# hsa-miR-4776-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-4732-5p	INHIBITION	CRX, mirtarbase
# hsa-miR-1247-3p	INHIBITION	CRX, mirtarbase
# hsa-miR-1247-3p	INHIBITION	SPI1, mirtarbase
# hsa-miR-1247-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-3927-3p	INHIBITION	CRX, mirtarbase
# hsa-miR-6499-5p	INHIBITION	CRX, mirtarbase
# hsa-miR-424-5p	INHIBITION	SPI1, mirtarbase
# hsa-miR-153-5p	INHIBITION	RFX1, mirtarbase
# hsa-miR-153-5p	INHIBITION	PITX2, mirtarbase
# hsa-miR-6516-5p	INHIBITION	CRX, mirtarbase
# hsa-miR-92a-1-5p	INHIBITION	RFX1, mirtarbase
# hsa-miR-92a-1-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-92a-1-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4500	INHIBITION	CRX, mirtarbase
# hsa-miR-4500	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6799-5p	INHIBITION	CRX, mirtarbase
# hsa-miR-34a-5p	INHIBITION	SPI1, mirtarbase
# hsa-miR-34a-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-10b-3p	INHIBITION	RFX1, mirtarbase
# hsa-miR-6090	INHIBITION	SPI1, mirtarbase
# hsa-miR-6090	INHIBITION	HMGA1, mirtarbase
# hsa-miR-548ac	INHIBITION	RFX1, mirtarbase
# hsa-miR-15a-3p	INHIBITION	RFX1, mirtarbase
# hsa-miR-548bb-3p	INHIBITION	RFX1, mirtarbase
# hsa-miR-6801-5p	INHIBITION	RFX1, mirtarbase
# hsa-miR-587	INHIBITION	RFX1, mirtarbase
# PPARA	UNKNOWN	RFX1, msigdb
# PPARA	UNKNOWN	TP53, msigdb
# MYOG	UNKNOWN	SPI1, msigdb
# STAT5A	UNKNOWN	ATF4, msigdb
# STAT5A	UNKNOWN	ETS1, msigdb
# STAT5A	UNKNOWN	PITX2, msigdb
# ESRRA	UNKNOWN	RFX1, msigdb
# ESRRA	UNKNOWN	TP53BP1, msigdb
# ESRRA	UNKNOWN	PITX2, msigdb
# MYOD1	UNKNOWN	RFX1, msigdb
# MYOD1	UNKNOWN	SPI1, msigdb
# MYOD1	UNKNOWN	HMGA1, msigdb
# MSX1	UNKNOWN	CRX, msigdb
# MSX1	UNKNOWN	TP53, msigdb
# MEIS1	UNKNOWN	CRX, msigdb
# MEIS1	UNKNOWN	PITX2, msigdb
# MEIS1	UNKNOWN	ETS1, msigdb
# ETV4	UNKNOWN	SPI1, msigdb
# BACH2	UNKNOWN	ATF4, msigdb
# BACH2	UNKNOWN	GDNF, msigdb
# LEF1	UNKNOWN	ATF4, msigdb
# LEF1	UNKNOWN	TP53, msigdb
# LEF1	UNKNOWN	HMGA1, msigdb
# LEF1	UNKNOWN	ETS1, msigdb
# LEF1	UNKNOWN	PITX2, msigdb
# LEF1	UNKNOWN	TP53BP1, msigdb
# LEF1	UNKNOWN	GDNF, msigdb
# BPTF	UNKNOWN	RFX1, msigdb
# BPTF	UNKNOWN	FOXO4, msigdb
# BPTF	UNKNOWN	PITX2, msigdb
# BPTF	UNKNOWN	GDNF, msigdb
# ESR1	UNKNOWN	RFX1, msigdb
# GTF3A	UNKNOWN	RFX1, msigdb
# FOXO1	UNKNOWN	RFX1, msigdb
# FOXO1	UNKNOWN	PITX2, msigdb
# HOXA9	UNKNOWN	CRX, msigdb
# ETS2	UNKNOWN	SPI1, msigdb
# ETS2	UNKNOWN	FOXO4, msigdb
# ETS2	UNKNOWN	ETS1, msigdb
# ETS2	UNKNOWN	HMGA1, msigdb
# ETS2	UNKNOWN	PITX2, msigdb
# ETS2	UNKNOWN	GDNF, msigdb
# JUN	UNKNOWN	ATF4, msigdb
# JUN	UNKNOWN	HMGA1, msigdb
# JUN	UNKNOWN	STAT6, msigdb
# JUN	UNKNOWN	PITX2, msigdb
# JUN	UNKNOWN	GDNF, msigdb
# JUN	UNKNOWN	DAND5, msigdb
# TEAD1	UNKNOWN	ATF4, msigdb
# TEAD1	UNKNOWN	HMGA1, msigdb
# ATF3	UNKNOWN	SPI1, msigdb
# ATF3	UNKNOWN	CRX, msigdb
# ATF3	UNKNOWN	RFX1, msigdb
# ATF3	UNKNOWN	PITX2, msigdb
# ATF3	UNKNOWN	GDNF, msigdb
# ARNT	UNKNOWN	ATF4, msigdb
# ARNT	UNKNOWN	HMGA1, msigdb
# hsa-miR-125a-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-125a-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-513b-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-6883-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-30d-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-324-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-324-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-324-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-638	INHIBITION	TP53, mirtarbase
# hsa-miR-125b-1-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-4306	INHIBITION	TP53, mirtarbase
# hsa-miR-5197-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-1285-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-4650-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6778-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-622	INHIBITION	TP53, mirtarbase
# hsa-miR-4736	INHIBITION	TP53, mirtarbase
# hsa-miR-4516	INHIBITION	TP53, mirtarbase
# hsa-miR-28-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-491-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-5196-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-505-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-4276	INHIBITION	TP53, mirtarbase
# hsa-miR-4276	INHIBITION	DAND5, mirtarbase
# hsa-miR-8071	INHIBITION	TP53, mirtarbase
# hsa-miR-1249-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-5003-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-5003-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-223-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-223-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-155-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-330-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-330-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-222-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-222-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-222-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4728-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-660-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-660-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3529-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-3165	INHIBITION	TP53, mirtarbase
# hsa-miR-6825-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-3065-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-3065-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4644	INHIBITION	TP53, mirtarbase
# hsa-miR-30a-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-30a-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-4725-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-4725-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-18a-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-5702	INHIBITION	TP53, mirtarbase
# hsa-miR-30c-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-30c-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-30c-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4682	INHIBITION	TP53, mirtarbase
# hsa-miR-1972	INHIBITION	TP53, mirtarbase
# hsa-miR-194-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-27a-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-27a-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-214-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-1909-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-377-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-377-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-377-3p	INHIBITION	PITX2, mirtarbase
# hsa-miR-663a	INHIBITION	TP53, mirtarbase
# hsa-miR-30b-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-937-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6803-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6751-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-4697-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-518c-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-504-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-4795-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-149-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-6785-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-605-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-151a-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-5703	INHIBITION	TP53, mirtarbase
# hsa-miR-4531	INHIBITION	TP53, mirtarbase
# hsa-miR-4651	INHIBITION	TP53, mirtarbase
# hsa-miR-608	INHIBITION	TP53, mirtarbase
# hsa-miR-6722-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-1207-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-1207-5p	INHIBITION	STAT6, mirtarbase
# hsa-miR-1207-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4763-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-4763-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-2110	INHIBITION	TP53, mirtarbase
# hsa-miR-2110	INHIBITION	DAND5, mirtarbase
# hsa-miR-6752-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6842-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6835-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-25-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-25-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6882-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-19a-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-19a-3p	INHIBITION	MEF2A, mirtarbase
# hsa-miR-19a-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-221-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-221-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-30e-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6760-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-185-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-185-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-5193	INHIBITION	TP53, mirtarbase
# hsa-miR-1233-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-4271	INHIBITION	TP53, mirtarbase
# hsa-miR-4271	INHIBITION	DAND5, mirtarbase
# hsa-miR-26a-1-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-1264	INHIBITION	TP53, mirtarbase
# hsa-miR-6797-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-4434	INHIBITION	TP53, mirtarbase
# hsa-miR-4286	INHIBITION	TP53, mirtarbase
# hsa-miR-4286	INHIBITION	HMGA1, mirtarbase
# hsa-miR-1273f	INHIBITION	TP53, mirtarbase
# hsa-miR-612	INHIBITION	TP53, mirtarbase
# hsa-miR-612	INHIBITION	DAND5, mirtarbase
# hsa-miR-454-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-150-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-6780b-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-6780b-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-1225-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-92a-2-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-7110-5p	INHIBITION	TP53, mirtarbase
# hsa-miR-1296-3p	INHIBITION	TP53, mirtarbase
# hsa-miR-7150	INHIBITION	TP53, mirtarbase
# SOX5	UNKNOWN	TP53, msigdb
# NR2F2	UNKNOWN	TP53, msigdb
# NR2F2	UNKNOWN	GDNF, msigdb
# ZIC2	UNKNOWN	TP53, msigdb
# ZIC2	UNKNOWN	TP53BP1, msigdb
# ELK1	UNKNOWN	TP53, msigdb
# ELK1	UNKNOWN	PITX2, msigdb
# ELK1	UNKNOWN	HMGA1, msigdb
# hsa-miR-362-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-362-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-362-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-33a-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-216a-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-216a-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-3681-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3681-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4493	INHIBITION	DAND5, mirtarbase
# hsa-miR-145-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-145-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-326	INHIBITION	DAND5, mirtarbase
# hsa-miR-133a-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-605-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-31-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-3153	INHIBITION	DAND5, mirtarbase
# hsa-miR-670-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4312	INHIBITION	DAND5, mirtarbase
# hsa-miR-8089	INHIBITION	DAND5, mirtarbase
# hsa-miR-4700-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4685-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-3692-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-711	INHIBITION	DAND5, mirtarbase
# hsa-miR-4257	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4257	INHIBITION	DAND5, mirtarbase
# hsa-miR-29b-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-329-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-329-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-329-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-8485	INHIBITION	ETS1, mirtarbase
# hsa-miR-8485	INHIBITION	GDNF, mirtarbase
# hsa-miR-8485	INHIBITION	DAND5, mirtarbase
# hsa-miR-6796-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-5582-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-149-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6083	INHIBITION	DAND5, mirtarbase
# hsa-miR-499a-5p	INHIBITION	FOXO4, mirtarbase
# hsa-miR-499a-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-4667-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-5692c	INHIBITION	PITX2, mirtarbase
# hsa-miR-5692c	INHIBITION	DAND5, mirtarbase
# hsa-miR-128-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-128-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-128-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-31-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-31-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-378a-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4287	INHIBITION	DAND5, mirtarbase
# hsa-miR-2355-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-2355-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-520f-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-527	INHIBITION	DAND5, mirtarbase
# hsa-miR-133b	INHIBITION	DAND5, mirtarbase
# hsa-miR-627-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-7977	INHIBITION	DAND5, mirtarbase
# hsa-miR-99b-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6756-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-429	INHIBITION	DAND5, mirtarbase
# hsa-miR-296-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-296-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-5190	INHIBITION	DAND5, mirtarbase
# hsa-miR-4668-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4428	INHIBITION	DAND5, mirtarbase
# hsa-miR-7159-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4530	INHIBITION	DAND5, mirtarbase
# hsa-miR-518a-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-218-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-218-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6792-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-421	INHIBITION	FOXO4, mirtarbase
# hsa-miR-202-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-1274a	INHIBITION	FOXO4, mirtarbase
# hsa-miR-4747-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-29c-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-200c-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-200c-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-22-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-137	INHIBITION	DAND5, mirtarbase
# hsa-miR-216b-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-211-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6126	INHIBITION	DAND5, mirtarbase
# hsa-miR-4755-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-615-3p	INHIBITION	FOXO4, mirtarbase
# hsa-miR-4533	INHIBITION	DAND5, mirtarbase
# hsa-miR-7160-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-670-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6859-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6752-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-1248	INHIBITION	DAND5, mirtarbase
# hsa-miR-141-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4749-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4749-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6793-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6739-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-5006-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6733-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-1200	INHIBITION	DAND5, mirtarbase
# hsa-miR-410-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-410-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-3941	INHIBITION	GDNF, mirtarbase
# hsa-miR-3941	INHIBITION	DAND5, mirtarbase
# hsa-miR-922	INHIBITION	DAND5, mirtarbase
# hsa-miR-5692b	INHIBITION	PITX2, mirtarbase
# hsa-miR-5692b	INHIBITION	DAND5, mirtarbase
# hsa-miR-3127-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-5196-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4691-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6832-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4672	INHIBITION	GDNF, mirtarbase
# hsa-miR-4672	INHIBITION	DAND5, mirtarbase
# hsa-miR-625-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-625-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-603	INHIBITION	GDNF, mirtarbase
# hsa-miR-603	INHIBITION	DAND5, mirtarbase
# hsa-miR-369-3p	INHIBITION	PITX2, mirtarbase
# hsa-miR-369-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-374a-5p	INHIBITION	PITX2, mirtarbase
# hsa-miR-374a-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6871-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6871-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-3140-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-892b	INHIBITION	DAND5, mirtarbase
# TCF4	UNKNOWN	FOXO4, msigdb
# POU1F1	UNKNOWN	FOXO4, msigdb
# POU1F1	UNKNOWN	PITX2, msigdb
# SPZ1	UNKNOWN	FOXO4, msigdb
# SPZ1	UNKNOWN	HMGA1, msigdb
# SPZ1	UNKNOWN	DAND5, msigdb
# TFAP4	UNKNOWN	FOXO4, msigdb
# TFAP4	UNKNOWN	TP53BP1, msigdb
# TFAP4	UNKNOWN	PITX2, msigdb
# LMO2	UNKNOWN	FOXO4, msigdb
# LMO2	UNKNOWN	PITX2, msigdb
# PCBP1	UNKNOWN	DAND5, msigdb
# EGR3	UNKNOWN	HMGA1, msigdb
# EGR3	UNKNOWN	DAND5, msigdb
# NRF1	UNKNOWN	FOXO4, msigdb
# MYB	UNKNOWN	PITX2, msigdb
# MYB	UNKNOWN	DAND5, msigdb
# FOXM1	UNKNOWN	PITX2, msigdb
# FOXM1	UNKNOWN	DAND5, msigdb
# E2F1	UNKNOWN	HMGA1, msigdb
# E2F1	UNKNOWN	DAND5, msigdb
# HNF1A	UNKNOWN	MEF2A, msigdb
# HNF1A	UNKNOWN	PITX2, msigdb
# HNF1A	UNKNOWN	DAND5, msigdb
# HNF1A	UNKNOWN	CREB1, msigdb
# HNF1A	UNKNOWN	ATF4, msigdb
# HNF1A	UNKNOWN	TP53, msigdb
# HNF1A	UNKNOWN	TP53BP1, msigdb
# HNF1A	UNKNOWN	GDNF, msigdb
# XBP1	UNKNOWN	DAND5, msigdb
# ATF6	UNKNOWN	PITX2, msigdb
# ATF6	UNKNOWN	GDNF, msigdb
# ATF6	UNKNOWN	DAND5, msigdb
# FOXN1	UNKNOWN	FOXO4, msigdb
# RREB1	UNKNOWN	DAND5, msigdb
# STAT3	UNKNOWN	FOXO4, msigdb
# EGR1	UNKNOWN	HMGA1, msigdb
# EGR1	UNKNOWN	DAND5, msigdb
# ELF1	UNKNOWN	FOXO4, msigdb
# ELF1	UNKNOWN	STAT6, msigdb
# TAL1	UNKNOWN	FOXO4, msigdb
# hsa-miR-3611	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4722-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-450b-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-450b-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-4262	INHIBITION	ETS1, mirtarbase
# hsa-miR-208a-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-6779-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-584-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-135a-5p	INHIBITION	STAT6, mirtarbase
# hsa-miR-195-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-138-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-939-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-663b	INHIBITION	HMGA1, mirtarbase
# hsa-miR-1343-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-5006-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-507	INHIBITION	ETS1, mirtarbase
# hsa-miR-507	INHIBITION	GDNF, mirtarbase
# hsa-miR-570-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-3972	INHIBITION	ETS1, mirtarbase
# hsa-miR-4270	INHIBITION	HMGA1, mirtarbase
# hsa-miR-1233-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-520a-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-1184	INHIBITION	HMGA1, mirtarbase
# hsa-miR-5011-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-4300	INHIBITION	HMGA1, mirtarbase
# hsa-miR-525-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6789-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4666b	INHIBITION	ETS1, mirtarbase
# hsa-miR-4278	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4425	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6769a-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6754-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-588	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6721-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3667-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-5699-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-7152-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-5591-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4288	INHIBITION	ETS1, mirtarbase
# hsa-miR-6799-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-543	INHIBITION	ETS1, mirtarbase
# hsa-miR-506-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-654-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-15b-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4690-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-8064	INHIBITION	ETS1, mirtarbase
# hsa-miR-19a-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-6780a-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-7974	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3689a-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-30c-2-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-30c-1-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6779-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4441	INHIBITION	HMGA1, mirtarbase
# hsa-miR-764	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3689b-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-7106-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6847-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-557	INHIBITION	ETS1, mirtarbase
# hsa-miR-557	INHIBITION	GDNF, mirtarbase
# hsa-miR-192-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-4667-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4709-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6726-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6846-5p	INHIBITION	HMGA1, mirtarbase
# HIF1A/ARNT	ACTIVATION	ETS1, pid
# LEF1/beta catenin	ACTIVATION	PITX2, pid
# hsa-miR-887-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-1273h-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-744-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-196a-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6872-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-142-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-920	INHIBITION	HMGA1, mirtarbase
# hsa-miR-135b-5p	INHIBITION	STAT6, mirtarbase
# hsa-miR-135b-3p	INHIBITION	STAT6, mirtarbase
# hsa-miR-19b-2-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-505-3p	INHIBITION	TP53BP1, mirtarbase
# hsa-miR-4779	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6081	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6165	INHIBITION	HMGA1, mirtarbase
# hsa-miR-19b-1-5p	INHIBITION	ETS1, mirtarbase
# hsa-miR-132-3p	INHIBITION	MEF2A, mirtarbase
# hsa-miR-486-5p	INHIBITION	HMGA1, mirtarbase
# JUN/FOS	ACTIVATION	ETS1, pid
# hsa-miR-758-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-765	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6788-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-5685	INHIBITION	HMGA1, mirtarbase
# hsa-miR-877-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-1202	INHIBITION	ETS1, mirtarbase
# hsa-miR-6865-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-193b-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-2276-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-4758-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4328	INHIBITION	ETS1, mirtarbase
# hsa-miR-5583-3p	INHIBITION	PITX2, mirtarbase
# hsa-miR-6873-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6859-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3125	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3173-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6848-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3189-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-494-3p	INHIBITION	PITX2, mirtarbase
# hsa-miR-6809-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6887-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-486-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6815-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-1301-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3650	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3680-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-3680-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-6783-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-7108-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-632	INHIBITION	ETS1, mirtarbase
# hsa-miR-4641	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4772-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-361-5p	INHIBITION	STAT6, mirtarbase
# hsa-miR-361-5p	INHIBITION	TP53BP1, mirtarbase
# hsa-miR-4517	INHIBITION	PITX2, mirtarbase
# hsa-miR-3934-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-125a-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-30b-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-3689c	INHIBITION	HMGA1, mirtarbase
# hsa-miR-144-3p	INHIBITION	ETS1, mirtarbase
# hsa-miR-6827-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6824-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-5581-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-6805-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-7112-5p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-215-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-7978	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4323	INHIBITION	HMGA1, mirtarbase
# hsa-miR-1236-3p	INHIBITION	HMGA1, mirtarbase
# hsa-miR-4297	INHIBITION	HMGA1, mirtarbase
# EGR4	UNKNOWN	PITX2, msigdb
# TFDP1	UNKNOWN	HMGA1, msigdb
# FOXD1	UNKNOWN	PITX2, msigdb
# MECOM	UNKNOWN	MEF2A, msigdb
# PBX1	UNKNOWN	PITX2, msigdb
# PAX3	UNKNOWN	PITX2, msigdb
# MAF	UNKNOWN	STAT6, msigdb
# MAF	UNKNOWN	HMGA1, msigdb
# STAT4	UNKNOWN	ETS1, msigdb
# STAT4	UNKNOWN	PITX2, msigdb
# GABPB2	UNKNOWN	HMGA1, msigdb
# CDC5L	UNKNOWN	HMGA1, msigdb
# AR	UNKNOWN	PITX2, msigdb
# AR	UNKNOWN	TP53BP1, msigdb
# FOXQ1	UNKNOWN	PITX2, msigdb
# FOXA1	UNKNOWN	PITX2, msigdb
# PPARG	UNKNOWN	TP53BP1, msigdb
# VSX1	UNKNOWN	TP53BP1, msigdb
# VSX1	UNKNOWN	PITX2, msigdb
# GATA6	UNKNOWN	PITX2, msigdb
# NR3C1	UNKNOWN	ETS1, msigdb
# NR3C1	UNKNOWN	GDNF, msigdb
# STAT2	UNKNOWN	STAT6, msigdb
# ZBTB14	UNKNOWN	PITX2, msigdb
# STAT1	UNKNOWN	STAT6, msigdb
# ELF2	UNKNOWN	HMGA1, msigdb
# ELF2	UNKNOWN	PITX2, msigdb
# BACH1	UNKNOWN	HMGA1, msigdb
# BACH1	UNKNOWN	GDNF, msigdb
# SOX9	UNKNOWN	ETS1, msigdb
# NR1H4	UNKNOWN	PITX2, msigdb
# GATA4	UNKNOWN	ETS1, msigdb
# LHX3	UNKNOWN	PITX2, msigdb
# CEBPA	UNKNOWN	PITX2, msigdb
# POU3F1	UNKNOWN	PITX2, msigdb
# CUX1	UNKNOWN	PITX2, msigdb
# PGR	UNKNOWN	ETS1, msigdb
# PGR	UNKNOWN	GDNF, msigdb
# TFAP2C	UNKNOWN	PITX2, msigdb
# TFAP2A	UNKNOWN	PITX2, msigdb
# ETV7	UNKNOWN	HMGA1, msigdb
# GABPA	UNKNOWN	HMGA1, msigdb
# RUNX2	UNKNOWN	PITX2, msigdb
# IRF8	UNKNOWN	STAT6, msigdb
# TFDP2	UNKNOWN	HMGA1, msigdb
# IRF7	UNKNOWN	PITX2, msigdb
# IRF7	UNKNOWN	GDNF, msigdb
# E2F4	UNKNOWN	HMGA1, msigdb
# PAX6	UNKNOWN	HMGA1, msigdb
# HOXA4	UNKNOWN	PITX2, msigdb
# CEBPB	UNKNOWN	PITX2, msigdb
# POU6F1	UNKNOWN	PITX2, msigdb
# MIF	UNKNOWN	TP53BP1, msigdb
# RB1	UNKNOWN	HMGA1, msigdb
# ATP12A	UNKNOWN	ETS1, msigdb
# PDX1	UNKNOWN	PITX2, msigdb
# PDX1	UNKNOWN	GDNF, msigdb
# GDNF	UNKNOWN	PNPLA3, msigdb
# GDNF	UNKNOWN	SPI1, msigdb
# GDNF	UNKNOWN	PITX2, msigdb
# GDNF	UNKNOWN	STAT6, msigdb
# GDNF	UNKNOWN	GDNF, msigdb
# GDNF	UNKNOWN	DAND5, msigdb
# hsa-miR-22-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-409-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-548f-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-4307	INHIBITION	GDNF, mirtarbase
# hsa-miR-4499	INHIBITION	GDNF, mirtarbase
# hsa-miR-4724-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-2116-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-1912	INHIBITION	GDNF, mirtarbase
# hsa-miR-302d-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-140-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-1295b-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-548x-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-548aj-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-153-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-4255	INHIBITION	GDNF, mirtarbase
# hsa-miR-33a-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-96-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-3129-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-3124-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-499b-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-548aw	INHIBITION	GDNF, mirtarbase
# hsa-miR-8066	INHIBITION	GDNF, mirtarbase
# hsa-miR-5583-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-548g-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-133a-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-302b-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-4282	INHIBITION	GDNF, mirtarbase
# hsa-miR-448	INHIBITION	GDNF, mirtarbase
# hsa-miR-1468-3p	INHIBITION	GDNF, mirtarbase
# hsa-miR-7-5p	INHIBITION	GDNF, mirtarbase
# hsa-miR-548an	INHIBITION	GDNF, mirtarbase
# hsa-miR-4304	INHIBITION	GDNF, mirtarbase
# POU3F2	UNKNOWN	GDNF, msigdb
# RXRA	UNKNOWN	GDNF, msigdb
# RXRB	UNKNOWN	GDNF, msigdb
# KAT2B	UNKNOWN	GDNF, msigdb
# SMAD1	UNKNOWN	GDNF, msigdb
# DAND5	UNKNOWN	DAND5, msigdb
# DAND5	UNKNOWN	SLC7A1, msigdb
# DAND5	UNKNOWN	PNPLA3, msigdb
# DAND5	UNKNOWN	CREB1, msigdb
# DAND5	UNKNOWN	RFX1, msigdb
# DAND5	UNKNOWN	TP53, msigdb
# DAND5	UNKNOWN	FOXO4, msigdb
# DAND5	UNKNOWN	HMGA1, msigdb
# DAND5	UNKNOWN	PITX2, msigdb
# DAND5	UNKNOWN	TP53BP1, msigdb
# DAND5	UNKNOWN	GDNF, msigdb
# hsa-miR-542-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-367-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6849-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-4701-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6736-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6776-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6720-5p	INHIBITION	DAND5, mirtarbase
# hsa-miR-6512-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-766-3p	INHIBITION	DAND5, mirtarbase
# hsa-miR-1262	INHIBITION	DAND5, mirtarbase
# MYC/Max	ACTIVATION	HMGA1, pid
# hsa-miR-4325	INHIBITION	DAND5, mirtarbase
# MIR27A	ACTIVATION	DAND5, ctd
# SLC39A8	INHIBITION	DAND5, ctd
# INS	INHIBITION	DAND5, ctd
# NOG	ACTIVATION	GDNF, ctd
