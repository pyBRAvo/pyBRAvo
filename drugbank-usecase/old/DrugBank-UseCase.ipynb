# %% [markdown]
# # pyBravo - Drugbank use case
#
# ---
# In this use case, our goal is to demonstrate how pyBravo can support *in silico* drug screening.
#
# We show here **how a list of potential drug targets can be completed based on a reconstructed gene regulation network**.
#
# We consider that evaluating the biological or clinical relevance of the retrieved potential drugs is out of the scope of this demonstration.

# %%
# Imports
import csv
from SPARQLWrapper import SPARQLWrapper, JSON
from IPython.display import display, Markdown, Latex

sparql_endpoint = SPARQLWrapper("https://bio2rdf.org/sparql")

def get_bio2rdf_drug_targets(gene_set):
    """
    From a list of genes (HGNC symbols) this function queries the Bio2RDF sparql endpoint 
    and checks if the symbols are known as a drug target (Drugbank). It returns the list of drug targets. 
    """
    drug_targets = set() 
    for g in gene_set:
        ask_query = 'ASK { ?drug <http://bio2rdf.org/drugbank_vocabulary:target> ?target . ?target <http://bio2rdf.org/drugbank_vocabulary:gene-name> "'+g+'"^^xsd:string}'

        sparql_endpoint.setQuery(ask_query)
        sparql_endpoint.setReturnFormat(JSON)
        results = sparql_endpoint.query().convert()
        if (results["boolean"] == True):
            print(f'found drug targeting {g} in Drugbank (live Bio2RDF endpoint)')
            drug_targets.add(g)
    
    return drug_targets

def get_bio2rdf_drugs(gene_set):
    """
    From a list of genes (HGNC symbols) known as drug targets, returns the URL of found drug in Drugbank. 
    """
    drugs = set() 
    drug_groups = ['Approved', 'Nutraceutical', 'Experimental']
    group = drug_groups[0]
    for g in gene_set:
        query = 'SELECT ?drug WHERE { \
            # ?drug <http://bio2rdf.org/drugbank_vocabulary:target> ?target .\
            # ?target <http://bio2rdf.org/drugbank_vocabulary:gene-name> "'+g+'"^^xsd:string .\
            # ?drug rdf:type <http://bio2rdf.org/drugbank_vocabulary:Drug> .\
            # ?drug <http://bio2rdf.org/drugbank_vocabulary:group> <http://bio2rdf.org/drugbank_vocabulary:'+group+'> .\
            }'

        sparql_endpoint.setQuery(query)
        sparql_endpoint.setReturnFormat(JSON)
        results = sparql_endpoint.query().convert()
        
        for r in results["results"]["bindings"]:
            d = r["drug"]["value"]
            d_url = d.replace("http://bio2rdf.org/drugbank:", "https://www.drugbank.ca/drugs/")
            print(f'{g} --> {d_url}')
            drugs.add(d_url)
    
    return drugs

# %% [markdown]
# ## 1. Loading input gene list to be considered as drug targets

# %%
# Read input genes list from a file
def read_input_genes(filename):
    res = set()
    with open(filename, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=' ', quotechar='|')
        for row in reader:
            #print(''.join(row))
            res.add(''.join(row))
    return res

# Genes input list
#gene_set = read_input_genes('data/target_genes.csv')
gene_set = read_input_genes('../regulation-demo/data/input-910.csv')
print('{} target genes'.format(len(gene_set)))
# Out:
# 910 target genes

# %% [markdown]
# ## 2. Retrieving potential drugs

# %%
# %%time
#drug_targets = get_bio2rdf_drug_targets(gene_set)
#potential_drugs = get_bio2rdf_drugs(drug_targets)

potential_drugs = get_bio2rdf_drugs(gene_set)
# Out:
# PROC --> https://www.drugbank.ca/drugs/DB00170
# PROC --> https://www.drugbank.ca/drugs/DB00464
# MMP7 --> https://www.drugbank.ca/drugs/DB00786
# PDE5A --> https://www.drugbank.ca/drugs/DB00203
# PDE5A --> https://www.drugbank.ca/drugs/DB00820
# PDE5A --> https://www.drugbank.ca/drugs/DB00862
# PDE5A --> https://www.drugbank.ca/drugs/DB06267
# NOV --> https://www.drugbank.ca/drugs/DB00030
# NOV --> https://www.drugbank.ca/drugs/DB00071
# ALOX5 --> https://www.drugbank.ca/drugs/DB00795
# ALOX5 --> https://www.drugbank.ca/drugs/DB00471
# ALOX5 --> https://www.drugbank.ca/drugs/DB00163
# ALOX5 --> https://www.drugbank.ca/drugs/DB00233
# ALOX5 --> https://www.drugbank.ca/drugs/DB00179
# ALOX5 --> https://www.drugbank.ca/drugs/DB00744
# ALOX5 --> https://www.drugbank.ca/drugs/DB01017
# ALOX5 --> https://www.drugbank.ca/drugs/DB01014
# ALOX5 --> https://www.drugbank.ca/drugs/DB00244
# ALOX5 --> https://www.drugbank.ca/drugs/DB00711
# ALOX5 --> https://www.drugbank.ca/drugs/DB00586
# ALOX5 --> https://www.drugbank.ca/drugs/DB00939
# PDE10A --> https://www.drugbank.ca/drugs/DB00975
# PDE10A --> https://www.drugbank.ca/drugs/DB01113
# PDE10A --> https://www.drugbank.ca/drugs/DB08811
# PDE10A --> https://www.drugbank.ca/drugs/DB08814
# OXTR --> https://www.drugbank.ca/drugs/DB00107
# OXTR --> https://www.drugbank.ca/drugs/DB01282
# FGFR1 --> https://www.drugbank.ca/drugs/DB00039
# FGFR1 --> https://www.drugbank.ca/drugs/DB00398
# FGFR1 --> https://www.drugbank.ca/drugs/DB08896
# FGFR1 --> https://www.drugbank.ca/drugs/DB08901
# CA4 --> https://www.drugbank.ca/drugs/DB00869
# CA4 --> https://www.drugbank.ca/drugs/DB00232
# CA4 --> https://www.drugbank.ca/drugs/DB00436
# CA4 --> https://www.drugbank.ca/drugs/DB00880
# CA4 --> https://www.drugbank.ca/drugs/DB00999
# CA4 --> https://www.drugbank.ca/drugs/DB00273
# CA4 --> https://www.drugbank.ca/drugs/DB00606
# CA4 --> https://www.drugbank.ca/drugs/DB00703
# CA4 --> https://www.drugbank.ca/drugs/DB00774
# CA4 --> https://www.drugbank.ca/drugs/DB00819
# CA4 --> https://www.drugbank.ca/drugs/DB00909
# CA4 --> https://www.drugbank.ca/drugs/DB01021
# CA4 --> https://www.drugbank.ca/drugs/DB01144
# CA4 --> https://www.drugbank.ca/drugs/DB01194
# CA4 --> https://www.drugbank.ca/drugs/DB00562
# STAB2 --> https://www.drugbank.ca/drugs/DB08818
# CPU times: user 14.5 s, sys: 940 ms, total: 15.4 s
# Wall time: 2min 7s

# %%
display(Markdown(f"**{len(potential_drugs)}** found **potential drugs** in bio2rdf"))
# Out:
# **322** found **potential drugs** in bio2rdf

# %% [markdown]
# ## 3. Reconstructing the gene regulation network with pyBravo (max depth = 1)

# %%
# !python ../src/pyBravo.py --regulation --input_file data/target_genes.csv -md 1 -excl mirtarbase msigdb -co -su -sy
# Out:
# Explored 1 regulators
# Explored 4 regulators
# Explored 6 regulators
# Explored 7 regulators
# Explored 8 regulators
# Explored 9 regulators
# Explored 11 regulators
# Explored 11 regulators
# Explored 11 regulators
# Explored 11 regulators
# Explored 12 regulators
# Explored 18 regulators
# Explored 18 regulators
# Explored 18 regulators
# Explored 18 regulators
# Explored 18 regulators
# Explored 23 regulators
# Explored 24 regulators
# Explored 27 regulators
# Explored 28 regulators
# Explored 28 regulators
# Explored 30 regulators
# Explored 34 regulators
# Explored 34 regulators
# Explored 36 regulators
# Explored 36 regulators
# Explored 38 regulators
# Explored 38 regulators
# Explored 38 regulators
# Explored 43 regulators
# Explored 44 regulators
# Explored 44 regulators
# Explored 44 regulators
# Explored 45 regulators
# Explored 45 regulators
# Explored 45 regulators
# Explored 46 regulators
# Explored 47 regulators
# Explored 47 regulators
# Explored 49 regulators
# Explored 49 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 50 regulators
# Explored 51 regulators
# Explored 51 regulators
# Explored 54 regulators
# Explored 54 regulators
# Explored 54 regulators
# Explored 54 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# Explored 57 regulators
# --- Upstream regulation network in 402.23 seconds ---
# Number of nodes = 231
# Number of edges = 330
# SIF network written to out.sif
# Basic regulation reaction provenance written to out-provenance.csv
#
# | Node | Degree Centrality |
# |------|------|
# | NOG | 0.313 |
# | INS | 0.187 |
# | TGFB1 | 0.152 |
# | pirinixic acid/PPARA | 0.113 |
# | NSC 689534/Copper | 0.057 |
# | CAT | 0.057 |
# | ciglitazone/PPARG | 0.052 |
# | fenofibric acid/PPARA | 0.052 |
# | ACSL1 | 0.043 |
# | CPT1A | 0.039 |
#
# --- Network simplification in 0.04 seconds ---
# SIF network written to out-unified.sif
# Basic regulation reaction provenance written to out-unified-provenance.csv
# Nodes after simplification = 216
# Edges after simplification = 327
#
# | Node | Degree Centrality |
# |------|------|
# | NOG | 0.335 |
# | INS | 0.195 |
# | TGFB1 | 0.163 |
# | pirinixic acid/PPARA | 0.121 |
# | NSC 689534/Copper | 0.06 |
# | CAT | 0.06 |
# | ciglitazone/PPARG | 0.056 |
# | fenofibric acid/PPARA | 0.056 |
# | ACSL1 | 0.047 |
# | CPT1A | 0.042 |

# %% [markdown]
# ## 4. Extracting the gene regulators to be considered as potential drug targets

# %%
def read_regulatory_genes(filename):
    res = set()
    with open(filename, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter='\t', quotechar='|')
        for row in reader:
            for item in row:
                res.add(item)
    return res

reg_gene_set = read_regulatory_genes('out-unified.sif')
#reg_gene_set = read_regulatory_genes('out.sif')

to_be_explored_genes = reg_gene_set - gene_set

print('{} new potential target genes'.format(len(to_be_explored_genes)))
# Out:
# 214 new potential target genes

# %% [markdown]
# ## 5. Retrieving new potential drug targets

# %%
# %%time
#drug_targets = get_bio2rdf_drug_targets(gene_set)
#potential_drugs = get_bio2rdf_drugs(drug_targets)

new_potential_drugs = get_bio2rdf_drugs(to_be_explored_genes)
# Out:
# FABP2 --> https://www.drugbank.ca/drugs/DB01050
# ACADSB --> https://www.drugbank.ca/drugs/DB00313
# SLC22A4 --> https://www.drugbank.ca/drugs/DB00583
# SLC16A6 --> https://www.drugbank.ca/drugs/DB00119
# ACADM --> https://www.drugbank.ca/drugs/DB03147
# FADS2 --> https://www.drugbank.ca/drugs/DB00132
# ACAD8 --> https://www.drugbank.ca/drugs/DB03147
# JUN --> https://www.drugbank.ca/drugs/DB00570
# JUN --> https://www.drugbank.ca/drugs/DB01029
# JUN --> https://www.drugbank.ca/drugs/DB01169
# ACSL4 --> https://www.drugbank.ca/drugs/DB00159
# ACSL4 --> https://www.drugbank.ca/drugs/DB00412
# ESR1 --> https://www.drugbank.ca/drugs/DB00655
# ESR1 --> https://www.drugbank.ca/drugs/DB01108
# ESR1 --> https://www.drugbank.ca/drugs/DB04573
# ESR1 --> https://www.drugbank.ca/drugs/DB04575
# ESR1 --> https://www.drugbank.ca/drugs/DB00294
# ESR1 --> https://www.drugbank.ca/drugs/DB00304
# ESR1 --> https://www.drugbank.ca/drugs/DB00367
# ESR1 --> https://www.drugbank.ca/drugs/DB00396
# ESR1 --> https://www.drugbank.ca/drugs/DB00603
# ESR1 --> https://www.drugbank.ca/drugs/DB00675
# ESR1 --> https://www.drugbank.ca/drugs/DB00823
# ESR1 --> https://www.drugbank.ca/drugs/DB00957
# ESR1 --> https://www.drugbank.ca/drugs/DB00977
# ESR1 --> https://www.drugbank.ca/drugs/DB01196
# ESR1 --> https://www.drugbank.ca/drugs/DB01357
# ESR1 --> https://www.drugbank.ca/drugs/DB01406
# ESR1 --> https://www.drugbank.ca/drugs/DB04574
# ESR1 --> https://www.drugbank.ca/drugs/DB04938
# ESR1 --> https://www.drugbank.ca/drugs/DB00286
# ESR1 --> https://www.drugbank.ca/drugs/DB01065
# ESR1 --> https://www.drugbank.ca/drugs/DB00783
# ESR1 --> https://www.drugbank.ca/drugs/DB01431
# ESR1 --> https://www.drugbank.ca/drugs/DB00255
# ESR1 --> https://www.drugbank.ca/drugs/DB00539
# ESR1 --> https://www.drugbank.ca/drugs/DB00882
# ESR1 --> https://www.drugbank.ca/drugs/DB00890
# ESR1 --> https://www.drugbank.ca/drugs/DB01183
# ESR1 --> https://www.drugbank.ca/drugs/DB01185
# ESR1 --> https://www.drugbank.ca/drugs/DB00481
# ESR1 --> https://www.drugbank.ca/drugs/DB00947
# NFKB1 --> https://www.drugbank.ca/drugs/DB01041
# NFKB1 --> https://www.drugbank.ca/drugs/DB01411
# NFKB1 --> https://www.drugbank.ca/drugs/DB08814
# ACSL1 --> https://www.drugbank.ca/drugs/DB00131
# ACSL1 --> https://www.drugbank.ca/drugs/DB00171
# ACOX1 --> https://www.drugbank.ca/drugs/DB03147
# PCYT1A --> https://www.drugbank.ca/drugs/DB00122
# CAT --> https://www.drugbank.ca/drugs/DB01213
# CPU times: user 3.17 s, sys: 244 ms, total: 3.42 s
# Wall time: 28.8 s

# %%
display(Markdown(f"**{len(new_potential_drugs)}** found **potential drugs** in bio2rdf"))
# Out:
# **117** found **potential drugs** in bio2rdf
