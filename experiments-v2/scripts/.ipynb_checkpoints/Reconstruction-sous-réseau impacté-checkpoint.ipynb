# %% [markdown]
# # Un scénario complet

# %% [markdown]
# Quelques informations et paramètres pour commencer

# %%
from Entete import *

# %% [markdown]
# Tous les includes

# %%
## DEBUG ONLY
begintotal = timer()
eprint("Testing",Param_SBMLfile,"for",Param_Drug)

## END DEBUG ONLY
# Out:
# Testing ../data/iLiverCancer1715.xml for Sorafenib (USAN/INN)

# %% [markdown]
# Chargement des listes de correspondances

# %%
#from AllTables import *
from AllTables import *

# %%
Param_Pourcentage = 1.1

# %% [markdown]
# Construction de la liste des cibles

# %%
# étape 1 : construction du fichier d'association Reactions <-> EC numbers

# obsolete : La liste RXN -> liste gènes est désormais récupérée directement depuis HMRDatabase

# dictionnaire HMR_to_Ensembl


eprint("Entering : Association RxN <-> Enzymes list construction")

SBMLfile = Param_SBMLfile

#SBMLfile = raw_input("Enter the SBML filename ? ")

def ConstructAssociationList(SBMLfile, RXN_EC_file="/tmp/RXN_EC.txt"):

    import os
    os.system("../scripts/Construct_List_RXN_Enzymes.sh "+SBMLfile+" "+RXN_EC_file)
    fd = open(RXN_EC_file,"r")
    lines = fd.readlines()

    genes = dict()
    for l in lines:
        t=l.split(" ")
        cum=''
        for i in range(1,len(t)-1):
            cum=cum+t[i]+" "
        genes[t[0]]=cum
    return genes

genes=ConstructAssociationList(SBMLfile,RXN_EC_file)
# Out:
# Entering : Association RxN <-> Enzymes list construction

# %%
# Etape 2 : Single Reaction Analysis

eprint("Entering : Single Reaction Analysis")

## DEBUG ONLY
begin = timer()
## END DEBUG ONLY


# perfoming a single_reaction_deletion analysis of the network

model = cobra.io.read_sbml_model(Param_SBMLfile)

# the objective coefficient must be properly set
model.reactions.CancerBiomass_OF.objective_coefficient=1

# reference biomass growth
fba=model.optimize().f

# single reaction deletion analysis


if (Param_DoReconstruction and Param_Pourcentage<1):
    rates, status = cobra.flux_analysis.single_reaction_deletion(model,solver=whichsolver)
else:
    rates=dict()
    for r in model.reactions:
        rates[r.id]=0
        
## DEBUG ONLY
end = timer()
eprint("Execution time (Single Reaction Analysis) = ",end-begin,"seconds")
## END DEBUG ONLY
# Out:
# Entering : Single Reaction Analysis
# Execution time (Single Reaction Analysis) =  6.15656549599953 seconds

# %%
# Etape 3 : Extraction des enzymes régulateurs (nécessite étape 1 et 2)

def getRegulators(rates, percentage=1.1):
    regulators = dict()

    cpt=0
    for r in rates:
        if (rates.get(r)<percentage*fba):
            if (HMR_to_Ensembl.get(r)!=''):
                # print(r,':',rates.get(r)," ",genes.get(r))
                cpt=cpt+1
                l=HMR_to_Ensembl.get(r)
                if (l):
                    for i in l:
                        if (i != ''):
                            regulators[i]=1
    return regulators


def getRegulators_obsolete(rates, percentage=1.1):
    regulators = dict()

    cpt=0
    for r in rates:
        if (rates.get(r)<percentage*fba):
            if (genes.get(r)!=''):
                # print(r,':',rates.get(r)," ",genes.get(r))
                cpt=cpt+1
                l=genes.get(r).split(' ')
                for i in l:
                    if (i != ''):
                        regulators[i]=1
    return regulators

if (Param_DoReconstruction):
    regulators = getRegulators(rates, Param_Pourcentage)

# %%
# Etape 4 : récupération de la liste de gènes régulateurs
def GeneListFromEC(ecnumber):
    if (ecnumber.find('-')>0):
        cum=list()
        for i in range(1,500):
            gl=ECTCDBToEnsembl.get(ecnumber.replace('-',str(i)))
            if (gl != None and len(gl)>0):
                cum+=gl
        return cum
    else:
        gl=ECTCDBToEnsembl.get(ecnumber)
        if (gl == None):
            gl=list()
        return gl

if (Param_DoReconstruction):
    TargetGenesEnsembl=list()
    for ec in regulators:
#        TargetGenesEnsembl+=GeneListFromEC(ec.lower())
        TargetGenesEnsembl+=[ec.replace("'","%27")]
    
    TargetGenes = [EnsemblToGeneNames.get(x) for x in TargetGenesEnsembl]
    TargetGenes=list()
    for x in TargetGenesEnsembl:
        if (genelist.get(x)):
            TargetGenes.append(genelist.get(x)[0])
        else:
            eprint('Missing ',x)
    
    TargetGenes=set(TargetGenes)
    TargetGenes=list(TargetGenes)
    
    TargetGenesEnsembl=set(TargetGenesEnsembl)
    TargetGenesEnsembl=list(TargetGenesEnsembl)
    
    eprint("Target gene list size =",len(TargetGenes))
    
    fd = open(Param_TargetFilename,"w")
    for g in TargetGenes:
        fd.write(g+"\n")
    fd.close()
    fd = open(Param_TargetFilename+"_EnsemblId","w")
    for g in TargetGenesEnsembl:
        fd.write(g+"\n")
    fd.close()
# Out:
# Missing  DLSTP1
# Missing  ENSG00000256049
# Missing  ENSG00000123009
# Missing  ENSG00000230359
# Missing  ENSG00000141141
# Missing  ENSG00000184674
# Missing  LOC642502
# Missing  ENSG00000123201
# Missing  ENSG00000179087
# Missing  ENSG00000230204
# Missing  ENSG00000253861
# Missing  LOC729020
# Missing  ENSG00000204466
# Missing  ENSG00000141720
# Missing  ENSG00000132142
# Missing  ENSG00000250630
# Missing  ENSG00000182851
# Missing  ENSG00000264216
# Missing  ENSG00000196326
# Missing  ENSG00000166157
# Missing  FRA1I
# Missing  ENSG00000215151
# Missing  ENSG00000256062
# Missing  LOC101060704
# Missing  ENSG00000107618
# Missing  ENSG00000176134
# Missing  ENSG00000182909
# Missing  ENSG00000231087
# Missing  ENSG00000105663
# Missing  ENSG00000182319
# Missing  ENSG00000205794
# Missing  ENSG00000167494
# Missing  GK6P
# Missing  ENSG00000213599
# Missing  ENSG00000205318
# Missing  ENSG00000226278
# Missing  ENSG00000099251
# Missing  ENSG00000183038
# Missing  ENSG00000178596
# Missing  ENSG00000174083
# Missing  ENSG00000197421
# Missing  ENSG00000072444
# Missing  ENSG00000049319
# Missing  ENSG00000178723
# Missing  ENSG00000184886
# Missing  ENSG00000165862
# Missing  ENSG00000099984
# Missing  CYP3A
# Missing  LOC100507855
# Missing  ENSG00000235957
# Missing  ENSG00000206269
# Missing  UGP1
# Missing  ENSG00000242836
# Missing  ENSG00000161326
# Missing  BP1
# Missing  CDC14C
# Missing  LOC100288842
# Missing  ENSG00000229604
# Missing  ENSG00000244681
# Missing  ENSG00000214617
# Missing  ENSG00000176115
# Missing  ENSG00000182021
# Missing  ENSG00000249948
# Missing  ENSG00000087916
# Missing  ENSG00000181260
# Missing  ENSG00000143466
# Target gene list size = 2852

# %% [markdown]
# Regulatory network reconstruction using PathwayCommons SPARQL endpoint

# %%
# Algorithms

Aliases = dict()
for g in GeneAltNameToName:
    if not Aliases.get(GeneAltNameToName.get(g)):
        Aliases[GeneAltNameToName.get(g)] = list()
    Aliases[GeneAltNameToName.get(g)].append(g)



def GetTFControllers(EnsemblId):
    commonPCPrefixes = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX taxon: <http://identifiers.org/taxonomy/>
PREFIX reactome: <http://identifiers.org/reactome/>
PREFIX release: <http://www.reactome.org/biopax/49/48887#>

PREFIX up: <http://purl.uniprot.org/core/> 
PREFIX uniprot: <http://purl.uniprot.org/uniprot/>
PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX chebi: <http://purl.obolibrary.org/obo/CHEBI_>
PREFIX obo2: <http://purl.obolibrary.org/obo#>
"""

    Request = """
SELECT ?tempReac ?type ?controlledName ?controllerName ?source WHERE{ 
    FILTER( (?controlledName = 'Transcription of %%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>)
        and (?controllerName != '%%GENETARGETNAME%%')
        and (?source != 'mirtarbase') ) .
    # ?tempReac a bp:TemplateReactionRegulation .
    # ?tempReac bp:displayName ?reacName ; 
        bp:controlled ?controlled ; 
        bp:controller ?controller ; 
        bp:controlType ?type ; 
        bp:dataSource ?source .
    # ?controlled bp:displayName ?controlledName .
    # ?controller bp:displayName ?controllerName . }
GROUP BY ?controlledName ?controllerName
"""
    RequestToBePerformed=commonPCPrefixes+Request.replace("%%GENETARGETNAME%%",EnsemblId)
    sparql = SPARQLWrapper(PC_Endpoint)
    sparql.setQuery(RequestToBePerformed)
    sparql.setReturnFormat(JSON)
    query = sparql.query().convert()
    results=list()
    listofgenes=list()
    ListBindings=query.get('results').get('bindings')
    for l in ListBindings:
        controllerName = (l.get('controllerName').get('value'))
        controlType= (l.get('type').get('value'))
        rule = controllerName+"_"+controlType+"_"+EnsemblId
        if (rule not in results):
            results.append(rule)
        if (controllerName not in listofgenes):
            listofgenes.append(controllerName)
    return results,listofgenes

def getParentGraph(l,limit=30):
    i=0
    allgenes=dict()
    for g in l:
        allgenes[g]=1
    listofrelations=list()
    unmapped=list()
    while (i<len(l) and i<limit):
        gene=l[i]
        L=Aliases.get(GeneAltNameToName.get(gene))
        relations=list()
        newgenes=list()
        for g in L:
            a,b=GetTFControllers(g)
            relations=relations+a
            newgenes=newgenes+b
        
        relations=list(set(relations))
        newgenes=list(set(newgenes))
#        relations,newgenes = GetTFControllers(GeneAltNameToName.get(gene))
        if (len(relations) == 0):
            unmapped.append(gene)
        listofrelations+=relations
        for g in newgenes:
            if (allgenes.get(g) != 1): # (g not in l):
                l.append(g)
                allgenes[g]=1
        i+=1
    return listofrelations,l,unmapped




# Improved version

def GetTFControllersList(EnsemblId):
    commonPCPrefixes = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX taxon: <http://identifiers.org/taxonomy/>
PREFIX reactome: <http://identifiers.org/reactome/>
PREFIX release: <http://www.reactome.org/biopax/49/48887#>

PREFIX up: <http://purl.uniprot.org/core/> 
PREFIX uniprot: <http://purl.uniprot.org/uniprot/>
PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX chebi: <http://purl.obolibrary.org/obo/CHEBI_>
PREFIX obo2: <http://purl.obolibrary.org/obo#>
"""
# SELECT ?tempReac ?type ?controlledName ?controllerName ?source FROM <http://PC> 

    Request = """
SELECT ?tempReac ?type ?controlledName ?controllerName ?source
WHERE{ 
    FILTER(
    ("""
    for i in range(0,len(EnsemblId)-1):
        EnsemblId[i]=EnsemblId[i].replace("'","%27")
        Request=Request+"""(?controlledName = 'Transcription of %%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>) or 
        """.replace("%%GENETARGETNAME%%",EnsemblId[i])
#        Request=Request+"""(?controllerName = '%%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>) or 
#        """.replace("%%GENETARGETNAME%%",EnsemblId[i])
#    Request=Request+"""(?controllerName = '%%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>) or 
#    """.replace("%%GENETARGETNAME%%",EnsemblId[len(EnsemblId)-1])
    Request=Request+"(?controlledName = 'Transcription of %%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>)".replace("%%GENETARGETNAME%%",EnsemblId[len(EnsemblId)-1])
    Request=Request+""")
        and (?source != 'mirtarbase') ) .
    # ?tempReac a bp:TemplateReactionRegulation .
    # ?tempReac bp:displayName ?reacName ; 
        bp:controlled ?controlled ; 
        bp:controller ?controller ; 
        bp:controlType ?type ; 
        bp:dataSource ?source .
    # ?controlled bp:displayName ?controlledName .
    # ?controller bp:displayName ?controllerName . }
    
GROUP BY ?controlledName ?controllerName
"""
#    print(Request)
#    RequestToBePerformed=commonPCPrefixes+Request.replace("%%GENETARGETNAME%%",EnsemblId)
    RequestToBePerformed=commonPCPrefixes+Request
    sparql = SPARQLWrapper(PC_Endpoint)
    sparql.setQuery(RequestToBePerformed)
    sparql.setReturnFormat(JSON)
    sparql.setMethod("POST")
    query = sparql.query().convert()
    results=list()
    listofgenes=list()
    ListBindings=query.get('results').get('bindings')
    for l in ListBindings:
        controllerName = (l.get('controllerName').get('value'))
        controlType= (l.get('type').get('value'))
        controlledGene=(l.get('controlledName').get('value')).replace("Transcription of ","")
        rule = controllerName+"_"+controlType +"_"+GeneAltNameToName.get(controlledGene)
        if (rule not in results):
            results.append(rule)
        if (controllerName not in listofgenes):
            listofgenes.append(controllerName)
    return results,listofgenes

def getParentGraphList(l,limit=30):
    pas=100
    i=0
    allgenes=dict()
    for g in l:
        allgenes[g]=1
    listofrelations=list()
    unmapped=list()
    while (i<len(l) and i<limit):
        eprint("Treated ",i," genes, still ",(len(l)-i)," limit = ",limit)
        L=list()
        for j in range(0,pas):
            if (i+j<len(l)):
                gene=l[i+j]
                L=L+Aliases.get(GeneAltNameToName.get(gene))
        relations,newgenes=GetTFControllersList(L)
        if (len(relations) == 0):
            unmapped.append(gene)
        listofrelations+=relations
        for g in newgenes:
            g=GeneAltNameToName.get(g)
            if (g not in l): #(allgenes.get(g) != 1): # 
                l.append(g)
                allgenes[g]=1
        i+=pas
    return listofrelations,l,unmapped

# %%
eprint("Entering : RRG reconstruction")


## DEBUG ONLY
begin = timer()
## END DEBUG ONLY

if (Param_DoReconstruction):
    TargetGenesName = TargetGenes #[EnsemblToGeneNames.get(x) for x in TargetGenes if (len(x) > 2)]
    
    a,b,u=getParentGraphList(TargetGenesName,50000)
    
    ## DEBUG ONLY
    end = timer()
    eprint("Execution time for RRG reconstruction = ",end-begin,"seconds")
    ## END DEBUG ONLY
    
    eprint('Reconstructed graph contains',len(b),'genes,',len(a),'interactions')
    
    
    # write the file for compatibility purpose
    
    fd = open(Param_RRGFilename,"w")
    for r in a:
        relation=r.split("_")
        if (relation[1] != "ACTIVATION"):
            eprint(relation)
        fd.write(relation[0]+";"+relation[2]+"\n")
    fd.close()
# Out:
# Entering : RRG reconstruction
# Treated  0  genes, still  2852  limit =  50000
# Treated  100  genes, still  2890  limit =  50000
# Treated  200  genes, still  2824  limit =  50000
# Treated  300  genes, still  2735  limit =  50000
# Treated  400  genes, still  2637  limit =  50000
# Treated  500  genes, still  2541  limit =  50000
# Treated  600  genes, still  2441  limit =  50000
# Treated  700  genes, still  2341  limit =  50000
# Treated  800  genes, still  2242  limit =  50000
# Treated  900  genes, still  2143  limit =  50000
# Treated  1000  genes, still  2043  limit =  50000
# Treated  1100  genes, still  1943  limit =  50000
# Treated  1200  genes, still  1843  limit =  50000
# Treated  1300  genes, still  1743  limit =  50000
# Treated  1400  genes, still  1643  limit =  50000
# Treated  1500  genes, still  1543  limit =  50000
# Treated  1600  genes, still  1443  limit =  50000
# Treated  1700  genes, still  1343  limit =  50000
# Treated  1800  genes, still  1243  limit =  50000
# Treated  1900  genes, still  1143  limit =  50000
# Treated  2000  genes, still  1043  limit =  50000
# Treated  2100  genes, still  943  limit =  50000
# Treated  2200  genes, still  843  limit =  50000
# Treated  2300  genes, still  744  limit =  50000
# Treated  2400  genes, still  644  limit =  50000
# Treated  2500  genes, still  544  limit =  50000
# Treated  2600  genes, still  444  limit =  50000
# Treated  2700  genes, still  345  limit =  50000
# Treated  2800  genes, still  245  limit =  50000
# Treated  2900  genes, still  145  limit =  50000
# Treated  3000  genes, still  45  limit =  50000
# Execution time for RRG reconstruction =  152.53126322999015 seconds
# Reconstructed graph contains 3045 genes, 17873 interactions

# %%
endtotal = timer()
eprint("Execution completed in",endtotal-begintotal,"seconds")
# Out:
# Execution completed in 163.83983606600668 seconds

# %%
tg = Allmeds.get(Param_Drug).get('TargetsGenes')

# %%
b
# Out:
# ['PTPMT1',
#  'ABCB4',
#  'B3GALNT2',
#  'CHST13',
#  'DNM1',
#  'VNN2',
#  'AMDHD1',
#  'PIK3CB',
#  'POLE3',
#  'UGT2B11',
#  'NEK1',
#  'FDPS',
#  'RBAK',
#  'HSD17B6',
#  'NDUFB2',
#  'DHCR24',
#  'PPT2',
#  'HSD11B2',
#  'PCK2',
#  'PADI3',
#  'LPCAT3',
#  'ACVR1',
#  'PTK2B',
#  'STK31',
#  'SPTLC3',
#  'EYA4',
#  'LIPT2',
#  'AKR7A2',
#  'SULT1E1',
#  'NDUFS7',
#  'SLC36A3',
#  'KATNAL2',
#  'RFC5',
#  'IP6K2',
#  'AMPD1',
#  'TK2',
#  'CYP1A1',
#  'PLD1',
#  'AZIN2',
#  'SLC29A2',
#  'GSTT2B',
#  'SLC9A4',
#  'SLC6A20',
#  'DPYS',
#  'EPHX2',
#  'ERN1',
#  'SLC13A1',
#  'ENO1',
#  'PNLIPRP3',
#  'PTPN22',
#  'DIO1',
#  'SLC39A8',
#  'AHCY',
#  'MAN2A1',
#  'POLR3F',
#  'ATP6V1D',
#  'PTPN7',
#  'GUCY1B3',
#  'ALG14',
#  'SLC27A2',
#  'MINPP1',
#  'GSTA3',
#  'PTGS2',
#  'LPO',
#  'CLYBL',
#  'GALNTL5',
#  'BUB1',
#  'TH',
#  'SUV39H2',
#  'NDUFB5',
#  'B3GALNT1',
#  'JMJD7-PLA2G4B',
#  'EPHB2',
#  'DOLPP1',
#  'PC',
#  'PTPN1',
#  'MECR',
#  'DNAJC6',
#  'COX6C',
#  'ATP4A',
#  'TREH',
#  'GAD2',
#  'GC',
#  'FABP1',
#  'CHEK2',
#  'PIGO',
#  'DLAT',
#  'SRR',
#  'IRAK3',
#  'INPP5J',
#  'DECR2',
#  'MAPKAPK3',
#  'PLCD3',
#  'LIPA',
#  'TSTA3',
#  'AMT',
#  'ADSL',
#  'MTMR2',
#  'PDHB',
#  'PFKL',
#  'DUPD1',
#  'MAPKAPK5',
#  'HK2',
#  'ALG11',
#  'POLR3K',
#  'LPIN3',
#  'FADS2',
#  'SLC14A2',
#  'EEF1A1',
#  'GGT5',
#  'BUB1B',
#  'NAGLU',
#  'COX10',
#  'EXT2',
#  'KHK',
#  'FXN',
#  'ACOX2',
#  'SMPD2',
#  'ACADM',
#  'UAP1L1',
#  'CYP1B1',
#  'STK10',
#  'NMNAT2',
#  'MAN1A1',
#  'PIK3C3',
#  'DDX21',
#  'SULT1C2',
#  'TPP1',
#  'SIK2',
#  'LCLAT1',
#  'PLA2G10',
#  'B4GALNT3',
#  'MANSC1',
#  'CA8',
#  'MET',
#  'MOGAT2',
#  'NDST1',
#  'GARS',
#  'ACP2',
#  'HIBCH',
#  'AGPAT2',
#  'HSD17B14',
#  'PDE6B',
#  'UGGT1',
#  'AOC2',
#  'EPHA5',
#  'PDP2',
#  'RIOK2',
#  'NT5C2',
#  'EPHA3',
#  'CBR1',
#  'PTP4A1',
#  'SLC2A6',
#  'CA4',
#  'TDO2',
#  'ATP2B4',
#  'PLPP7',
#  'MGAT5',
#  'CDC42BPA',
#  'PLD4',
#  'GATM',
#  'ATP6V1E1',
#  'EXTL2',
#  'VARS',
#  'CHMP4A',
#  'HAAO',
#  'GSTM5',
#  'PDK4',
#  'MTMR14',
#  'SIRT1',
#  'CYP4Z1',
#  'B3GALT1',
#  'MBOAT7',
#  'MRI1',
#  'PFKM',
#  'CTSC',
#  'SRPK1',
#  'LTC4S',
#  'SACM1L',
#  'MAP3K6',
#  'COX4I1',
#  'CES3',
#  'ABL2',
#  'GPD2',
#  'UBIAD1',
#  'SLCO1A2',
#  'STK36',
#  'TECR',
#  'DDOST',
#  'PLIN1',
#  'NDST2',
#  'PIK3C2A',
#  'SPTLC2',
#  'NUDT12',
#  'GLDC',
#  'SYNJ1',
#  'DAD1',
#  'ABCB11',
#  'SRC',
#  'POGLUT1',
#  'NMRK1',
#  'TEC',
#  'EPHB3',
#  'AP1G1',
#  'EPHB4',
#  'B3GALT5',
#  'TPTE2',
#  'CA3',
#  'PNPT1',
#  'STARD8',
#  'SH3BP1',
#  'ACSM4',
#  'UCP3',
#  'FAM20B',
#  'PIGZ',
#  'MT-ND1',
#  'ADSS',
#  'KDR',
#  'AKT2',
#  'PTS',
#  'PIM3',
#  'RDH10',
#  'SLC2A1',
#  'ENOPH1',
#  'PIK3C2G',
#  'LYPLA2',
#  'ALG5',
#  'PAFAH1B1',
#  'PDE10A',
#  'SLC6A19',
#  'CDC7',
#  'GALNT9',
#  'ACOX3',
#  'NT5C',
#  'ETNK1',
#  'EIF2AK4',
#  'CPT1B',
#  'MCM3',
#  'SDHC',
#  'SLC6A18',
#  'NME7',
#  'BMP2K',
#  'FTH1',
#  'CYP3A43',
#  'PDE1A',
#  'PRKD2',
#  'GCNT4',
#  'ABL1',
#  'ETFB',
#  'MAOB',
#  'CHST3',
#  'PPIP5K2',
#  'ALDOC',
#  'PPM1M',
#  'BRSK1',
#  'MOK',
#  'ST6GALNAC5',
#  'MOGAT1',
#  'ACVRL1',
#  'POLG2',
#  'FABP5',
#  'SLC25A10',
#  'SLC39A14',
#  'LEFTY1',
#  'LTA4H',
#  'CHSY3',
#  'POLA1',
#  'CA5B',
#  'SLC16A7',
#  'PDE4B',
#  'OGDH',
#  'CAMK1',
#  'MPC2',
#  'DUSP26',
#  'BCHE',
#  'PRKACB',
#  'HS6ST2',
#  'ALOX15B',
#  'NPEPPS',
#  'SLC17A2',
#  'SLC32A1',
#  'PIPOX',
#  'ACYP2',
#  'PAPOLG',
#  'ATP5J2',
#  'SLC6A7',
#  'HSD17B12',
#  'MAP4K2',
#  'RPS6KB2',
#  'ALPL',
#  'RAD54L2',
#  'ADCY2',
#  'ACHE',
#  'STT3A',
#  'FUT4',
#  'PRDX1',
#  'PLA2G4C',
#  'GAL3ST3',
#  'PDE8B',
#  'ACOT8',
#  'DBT',
#  'SGPP1',
#  'SLC6A6',
#  'DYRK4',
#  'CHI3L1',
#  'PMPCA',
#  'AMACR',
#  'WNK1',
#  'GSTM2',
#  'PIGS',
#  'SLC27A6',
#  'ALPI',
#  'SUOX',
#  'MPC1L',
#  'RIOK1',
#  'SLC39A5',
#  'PLOD1',
#  'CHST9',
#  'POLB',
#  'PDZD4',
#  'NOS1',
#  'FYN',
#  'AGPAT4',
#  'BMPR2',
#  'INSRR',
#  'GCNT2',
#  'SOAT1',
#  'PIK3CG',
#  'ACSS2',
#  'DYRK1A',
#  'SLC3A1',
#  'POR',
#  'ACOT6',
#  'ADH1C',
#  'ACP5',
#  'ULK2',
#  'UGDH',
#  'KMT2A',
#  'PXDNL',
#  'SLC2A2',
#  'SLC25A27',
#  'SDC1',
#  'ALDH1B1',
#  'SLC18A2',
#  'CHD7',
#  'SLC5A12',
#  'A4GNT',
#  'DHX37',
#  'B3GAT2',
#  'DHX57',
#  'ATP2C2',
#  'PDE6D',
#  'ASPG',
#  'RET',
#  'NDUFC2',
#  'KMT2D',
#  'SGMS1',
#  'BAAT',
#  'KMT2C',
#  'APOA5',
#  'ALG2',
#  'GK',
#  'UBLCP1',
#  'ERN2',
#  'PFKFB3',
#  'KDSR',
#  'CSNK2A2',
#  'ATP10A',
#  'ITPA',
#  'SLC7A1',
#  'ABO',
#  'PRKCA',
#  'ST3GAL3',
#  'GSTK1',
#  'GALT',
#  'PGAM5',
#  'NPC1',
#  'UGCG',
#  'DHX15',
#  'RDH12',
#  'SMARCAL1',
#  'NOS2',
#  'EZH2',
#  'NTRK2',
#  'ST6GAL2',
#  'ACSM3',
#  'RBP4',
#  'MERTK',
#  'TUT1',
#  'PLCB2',
#  'EHHADH',
#  'CHST15',
#  'COX6B2',
#  'NDUFA2',
#  'MCCC1',
#  'HARS2',
#  'MINK1',
#  'CTDSPL2',
#  'ATP1B1',
#  'IDUA',
#  'G6PD',
#  'CSGALNACT2',
#  'FBP1',
#  'RIPK2',
#  'PRKAR1B',
#  'ICMT',
#  'HSD17B10',
#  'ALG3',
#  'STK17B',
#  'GSTO1',
#  'FAXDC2',
#  'THTPA',
#  'MAP3K9',
#  'PFKP',
#  'DHFR2',
#  'HSD17B3',
#  'PRUNE1',
#  'PLPP2',
#  'NUP85',
#  'CHST2',
#  'ENTPD6',
#  'POLM',
#  'NDUFA11',
#  'MGAT2',
#  'MKNK1',
#  'BLK',
#  'SLC7A7',
#  'ADCY7',
#  'MCM5',
#  'PRKAR1A',
#  'DCTD',
#  'ME3',
#  'DIO2',
#  'PPP2R1B',
#  'SLC37A4',
#  'ACY3',
#  'TMEM55B',
#  'LPL',
#  'ALDH3A1',
#  'STK38',
#  'HUNK',
#  'CTSF',
#  'NDUFV2',
#  'PIGM',
#  'TESK2',
#  'PPP6C',
#  'SLC29A1',
#  'ERCC2',
#  'FAM65A',
#  'UGT2B7',
#  'NME5',
#  'HACD1',
#  'NPR2',
#  'COX7C',
#  'B3GNT4',
#  'RIPK4',
#  'CTH',
#  'DGKE',
#  'GBGT1',
#  'NDUFA4L2',
#  'MAN1B1',
#  'LDHD',
#  'GPX5',
#  'LRAT',
#  'ATPAF2',
#  'SLC22A5',
#  'PMM2',
#  'ILKAP',
#  'NEK6',
#  'TRPM7',
#  'SLC26A8',
#  'POLR2B',
#  'MOGAT3',
#  'ROCK2',
#  'ALLC',
#  'MT-ND4',
#  'LIPC',
#  'CYP24A1',
#  'GYG2',
#  'CHST4',
#  'SPHK2',
#  'SLC1A3',
#  'SLC2A12',
#  'SLC34A3',
#  'ELOVL3',
#  'ENTPD2',
#  'HACD4',
#  'CHPF2',
#  'CPOX',
#  'COPG1',
#  'DGAT2',
#  'ATP8B4',
#  'PRPF4',
#  'SLC25A13',
#  'DHX30',
#  'PLCD1',
#  'POLH',
#  'SLC25A28',
#  'FUT8',
#  'ATP5G1',
#  'GMPPB',
#  'SLC25A12',
#  'RP1-37E16.12',
#  'PLCB3',
#  'UCK1',
#  'GFPT1',
#  'POLR2L',
#  'MAP4K3',
#  'FLAD1',
#  'FGFR1',
#  'CYP4B1',
#  'EBP',
#  'SLC25A11',
#  'QPRT',
#  'ALDH2',
#  'NUAK2',
#  'TXN',
#  'FUT11',
#  'HSD17B7',
#  'HACL1',
#  'DBP',
#  'CYP46A1',
#  'HSD17B8',
#  'HPRT1',
#  'GUSB',
#  'PLCL1',
#  'TRMT12',
#  'PIP4K2A',
#  'STK32A',
#  'ATP6V0D2',
#  'ZCCHC6',
#  'GALK2',
#  'NME4',
#  'PASK',
#  'SLC16A6',
#  'CTSZ',
#  'IPMK',
#  'GPAT2',
#  'GPX2',
#  'BRAF',
#  'ZCCHC11',
#  'FABP2',
#  'GALE',
#  'HEXDC',
#  'STARD7',
#  'HAL',
#  'NDUFB11',
#  'ALDH7A1',
#  'HACD3',
#  'SMPD3',
#  'DEGS1',
#  'GSR',
#  'GMPR',
#  'NUP210L',
#  'MARK1',
#  'ALPP',
#  'ACLY',
#  'MARS2',
#  'ACYP1',
#  'CARS2',
#  'MAP4K5',
#  'FABP6',
#  'NDUFA9',
#  'ETFA',
#  'AK8',
#  'PDK1',
#  'SLC25A2',
#  'ACSS3',
#  'GLB1L',
#  'BHMT',
#  'B4GALT6',
#  'PIK3R1',
#  'ACSBG1',
#  'ACAA1',
#  'NUP62CL',
#  'PTPRK',
#  'PROSC',
#  'PRPS2',
#  'MGAM',
#  'PHYH',
#  'ST6GALNAC6',
#  'PIGY',
#  'CSNK2A1',
#  'STK19',
#  'CAMK2D',
#  'AFMID',
#  'STK25',
#  'SLC19A3',
#  'B3GALT6',
#  'ACADL',
#  'GALK1',
#  'SLC7A10',
#  'RECQL',
#  'CDS2',
#  'GALNT7',
#  'COX6A2',
#  'DDX50',
#  'NEU1',
#  'TRIB3',
#  'XYLT1',
#  'PYCRL',
#  'PAPOLA',
#  'SLC2A14',
#  'IDO1',
#  'CDK14',
#  'ULK4',
#  'HIBADH',
#  'PDE11A',
#  'HSD17B11',
#  'NMRK2',
#  'PIGU',
#  'MCM6',
#  'PPP3R1',
#  'PCYOX1',
#  'SNRK',
#  'IMPDH1',
#  'PPP1R3B',
#  'SCCPDH',
#  'CNDP1',
#  'CA2',
#  'FER',
#  'PTPRZ1',
#  'POLE',
#  'CDO1',
#  'ABHD5',
#  'SRD5A3',
#  'ALDH5A1',
#  'APOA1',
#  'AAK1',
#  'PCTP',
#  'ALAS2',
#  'UQCRB',
#  'DLX4',
#  'POLR3D',
#  'PDSS2',
#  'B4GALNT2',
#  'MGAT5B',
#  'CA14',
#  'LGMN',
#  'WNK2',
#  'ATP6V0A1',
#  'SLC1A6',
#  'MAP4K4',
#  'CYP4F3',
#  'ACAD11',
#  'ITPKB',
#  'MYLK',
#  'DDX6',
#  'SLC39A6',
#  'PTGS1',
#  'GLRX',
#  'CDKL1',
#  'AGPAT3',
#  'PDE6G',
#  'SOD2',
#  'HFM1',
#  'ADH1B',
#  'SDR9C7',
#  'PANK1',
#  'NEK5',
#  'PGM1',
#  'SLC5A6',
#  'UBAC2',
#  'PRKX',
#  'ATP6V1H',
#  'CYP2S1',
#  'CA5A',
#  'POLR1C',
#  'POLN',
#  'SLC35C1',
#  'GK5',
#  'PYGB',
#  'MTHFD1',
#  'NUP155',
#  'SLC26A9',
#  'GALNT14',
#  'PLA2G2C',
#  'SLC39A2',
#  'PRKD3',
#  'SLC3A2',
#  'CTDSPL',
#  'PDE3A',
#  'CTDSP2',
#  'EPRS',
#  'NDUFS6',
#  'DUSP15',
#  'SLC26A11',
#  'FTMT',
#  'XPO6',
#  'GNS',
#  'UGT1A1',
#  'FECH',
#  'ACOX1',
#  'TXNRD3',
#  'KYAT3',
#  'SLC26A7',
#  'UQCRH',
#  'ACSS1',
#  'BCKDHA',
#  'NUP160',
#  'CHD2',
#  'GPX6',
#  'DUSP28',
#  'PIK3CA',
#  'B3GNT2',
#  'FASTK',
#  'FADS1',
#  'TNFRSF21',
#  'PTGES',
#  'GANAB',
#  'ATP11B',
#  'HIPK2',
#  'CHEK1',
#  'ACSM5',
#  'SLC6A5',
#  'CMAS',
#  'NUP107',
#  'ADO',
#  'SULT2A1',
#  'PPP3CA',
#  'MAP3K8',
#  'BCAT1',
#  'MOS',
#  'KIF3B',
#  'DUSP21',
#  'MTTP',
#  'SLC7A3',
#  'CYP26B1',
#  'PPM1K',
#  'ACO2',
#  'PPM1D',
#  'COX15',
#  'GPCPD1',
#  'PTPRJ',
#  'ATP8A1',
#  'PSAT1',
#  'TREX1',
#  'PKLR',
#  'ATAD2',
#  'AUH',
#  'SLC51A',
#  'IMPDH2',
#  'ALG1L',
#  'CLK2',
#  'ATIC',
#  'LENEP',
#  'GPI',
#  'HPS3',
#  'NT5C3B',
#  'PLK3',
#  'ATP9A',
#  'SKIV2L2',
#  'AURKA',
#  'FN3K',
#  'DDX1',
#  'MPO',
#  'DYRK1B',
#  'PIK3R4',
#  'TKFC',
#  'KIAA0319',
#  'JAK1',
#  'GCDH',
#  'MT-CO2',
#  'LCK',
#  'TBCB',
#  'CPT1A',
#  'TPO',
#  'LYN',
#  'PLA2G1B',
#  'AHCYL1',
#  'CTSL',
#  'SLC13A5',
#  'ATP2A3',
#  'ESCO2',
#  'HK3',
#  'ACAA2',
#  'AKR1C3',
#  'HPSE',
#  'IDO2',
#  'PRPF4B',
#  'ALDH1A2',
#  'SLC7A2',
#  'TESK1',
#  'EHMT1',
#  'DDX5',
#  'FNTA',
#  'PPP2R2B',
#  'ACAT1',
#  'INPP5E',
#  'EPHB1',
#  'MTHFR',
#  'CHST12',
#  'PTPRH',
#  'EGFR',
#  'DHRS3',
#  'RECQL5',
#  'PPP2R2A',
#  'CSNK1A1L',
#  'PPP1R3C',
#  'PIGV',
#  'SLC22A4',
#  'ACSL3',
#  'UGT2A3',
#  'SMOX',
#  'STK33',
#  'UQCR10',
#  'PRDX3',
#  'ATP6V1G1',
#  'HNMT',
#  'NME6',
#  'GANC',
#  'CHD6',
#  'WRN',
#  'ATP6V1C1',
#  'NT5C1B',
#  'EXTL3',
#  'CDK20',
#  'PTGDS',
#  'INO80',
#  'NUP205',
#  'TPH1',
#  'DDX49',
#  'AKT1',
#  'ATP6V0A2',
#  'SLC25A1',
#  'ELOVL1',
#  'SDR42E1',
#  'CHST5',
#  'SCP2',
#  'CAMK4',
#  'DUSP7',
#  'XYLT2',
#  'IDH2',
#  'PNLIP',
#  'ODC1',
#  'CA7',
#  'EPHA10',
#  'SREBF1',
#  'LGSN',
#  'SLC16A5',
#  'DOLK',
#  'KARS',
#  'COX5B',
#  'MCAT',
#  'KMT5B',
#  'TTK',
#  'SLC38A5',
#  'POLR3H',
#  'PAK1',
#  'FIG4',
#  'SLC4A2',
#  'CEL',
#  'NEK9',
#  'GCNT1',
#  'IFIH1',
#  'PTPRC',
#  'INPP4A',
#  'SLC22A9',
#  'PLCL2',
#  'KMT5A',
#  'ROCK1',
#  'WDYHV1',
#  'AKR7A3',
#  'PCCB',
#  'CBR3',
#  'CYP2A13',
#  'NLK',
#  'PDXK',
#  'DDX18',
#  'PPEF1',
#  'COX6A1',
#  'PHPT1',
#  'PNCK',
#  'MLYCD',
#  'LDHB',
#  'DCTPP1',
#  'INPP5B',
#  'NUP35',
#  'CERK',
#  'ERBB4',
#  'PPM1A',
#  'PHKG2',
#  'CDC42BPB',
#  'DUSP6',
#  'IMPA1',
#  'PSPH',
#  'MAPK4',
#  'GLYCTK',
#  'DPM1',
#  'NNT',
#  'CYP17A1',
#  'CPT1C',
#  'HSD17B2',
#  'FLT4',
#  'CYP51A1',
#  'STYK1',
#  'PDGFRB',
#  'AMHR2',
#  'EXT1',
#  'FABP7',
#  'ACOT9',
#  'HYAL4',
#  'SETD1B',
#  'KIT',
#  'AMD1',
#  'HCST',
#  'PNPLA7',
#  'CAMKK1',
#  'DAGLB',
#  'PLPP4',
#  'SIRT5',
#  'MAP3K15',
#  'MAPK15',
#  'CYP3A4',
#  'PLPPR3',
#  'PPP1R3A',
#  'CTSG',
#  'ATP10D',
#  'PNLIPRP1',
#  'MTMR8',
#  'PTPRG',
#  'CYP2B6',
#  'PFAS',
#  'UGT2B4',
#  'PI4K2B',
#  'SSU72',
#  'DHRS4L2',
#  'PDE1B',
#  'SGPL1',
#  'SLC12A2',
#  'SLC25A26',
#  'PLPP6',
#  'PAICS',
#  'RECQL4',
#  'TALDO1',
#  'ATP2A2',
#  'CDIPT',
#  'POLE4',
#  'SLC38A4',
#  'HMGCR',
#  'PLA2G12A',
#  'CDK3',
#  'PLA2G4B',
#  'CHST7',
#  'SLC22A15',
#  'GGT1',
#  'PPM1B',
#  'POLD3',
#  'CYP7B1',
#  'ST6GAL1',
#  'MAPK9',
#  'CYP2E1',
#  'LPCAT1',
#  'SLC7A6',
#  'GSTA2',
#  'KMT2E',
#  'AKR1B1',
#  'LIPE',
#  'GYS1',
#  'ATP5I',
#  'DUSP12',
#  'PNPLA3',
#  'SPAM1',
#  'STARD4',
#  'PDK3',
#  'ABAT',
#  'PTPN6',
#  'MAPK11',
#  'ARID4B',
#  'HMGCL',
#  'GPX4',
#  'CHDH',
#  'SLC1A4',
#  'PGM3',
#  'COX6B1',
#  'MYO5B',
#  'COLGALT1',
#  'GALNT5',
#  'ST3GAL6',
#  'GMDS',
#  'ELOVL5',
#  'POLR1A',
#  'NDUFS3',
#  'CPNE7',
#  'AQP9',
#  'ARSD',
#  'POC1B-GALNT4',
#  'RRM2B',
#  'MAT2B',
#  'MAPK3',
#  'EYA1',
#  'NUP62',
#  'SIK3',
#  'MAP3K5',
#  'CSNK1D',
#  'PIGC',
#  'AKR1A1',
#  'RPS6KC1',
#  'AURKC',
#  'CYP2C19',
#  ...]

# %%
[GeneAltNameToName.get(x) for x in b if GeneAltNameToName.get(x) in tg]
# Out:
# ['BRAF',
#  'UGT1A1',
#  'PDGFRB',
#  'KIT',
#  'CYP3A4',
#  'CYP2B6',
#  'CYP2C9',
#  'UGT1A9',
#  'FLT3',
#  'CYP2C8']

# %%
possibleTargets=dict()
for m in Allmeds:
    tg = Allmeds.get(m).get('TargetsGenes')
    malist = [GeneAltNameToName.get(x) for x in b if GeneAltNameToName.get(x) in tg]
    for g in malist:
        if not possibleTargets.get(g):
            possibleTargets[g]=list()
        possibleTargets[g].append(m)
#    if (len(malist)>0):
#        print(m,malist)

# %%
possibleTargets
# Out:
# {'ABAT': ['Depakene (TN)',
#   'Selenica (TN)',
#   'Sabril (TN)',
#   'Convulsofin (TN)',
#   'Depakote (TN)'],
#  'ABCB4': ['Lanoxin (TN)', 'Velban (TN)', 'Taxol (TN)', 'Vinblastina (TN)'],
#  'ABCC2': ['Misostol (TN)',
#   'Diovan (TN)',
#   'Olmetec (TN)',
#   'Invokana (TN)',
#   'Olmesartan (USAN/INN)',
#   'Trexall (TN)',
#   'Otrexup (TN)',
#   'Novantron (TN)'],
#  'ABCC3': ['Telfast (TN)', 'Allegra (TN)', 'Trexall (TN)', 'Otrexup (TN)'],
#  'ABCC4': ['Lasix (TN)',
#   'Potactasol (TN)',
#   'Adefovir (USAN/INN)',
#   'Hepsera (TN)',
#   'Trexall (TN)',
#   'Hycamtin (TN)',
#   'Otrexup (TN)',
#   'Nuriban (TN)',
#   'Tenofovir hydrate'],
#  'ABL1': ['Bosulif (TN)',
#   'Saracatinib (USAN/INN)',
#   'Saracatinib difumarate (USAN)',
#   'Bosutinib (USAN)'],
#  'ACHE': ['Suronacrine maleate (USAN)',
#   'Ubretid (TN)',
#   'Mytelase (TN)',
#   'Antilirium (TN)',
#   'Aricept (TN)',
#   'Obidoxime chloride (USAN)',
#   'Nimvastid (TN)',
#   'Mentane (TN)',
#   'Itopride (INN)',
#   'Arundic acid (JAN/INN)',
#   'Acotiamide hydrochloride hydrate (JAN)',
#   'Ganaton (TN)',
#   'Latrepirdine (USAN/INN)',
#   'Eserine (TN)',
#   'Floropryl (TN)',
#   'Pralidoxime mesylate (USAN)',
#   'Zanapezil fumarate (JAN)',
#   'Caracemide (USAN)',
#   'Dimebon',
#   'Dimetacrine (INN)',
#   'Miochol (TN)',
#   'Phospholine iodide (TN)',
#   'Tensilon (TN)',
#   'Tacrinal (TN)',
#   'Ipidacrine hydrochloride hydrate (JAN)',
#   'Eserine sulfate (TN)',
#   'Prostigmin (TN)',
#   'Quilostigmine (USAN/INN)',
#   'Prometax (TN)',
#   'Donaz (TN)',
#   'Vagostigmin (TN)',
#   'Cognex (TN)',
#   'Protopam (TN)',
#   'Pam (TN)',
#   'Besipirdine hydrochloride (USAN)',
#   'Mestinon (TN)',
#   'Ladostigil tartrate (USAN)',
#   'Reminyl (TN)',
#   'Paraoxon',
#   'Icopezil maleate (USAN)',
#   'Humorsol (TN)'],
#  'ACLY': ['Bempedoic acid (USAN/INN)'],
#  'ACVR2A': ['Bimagrumab (JAN/USAN/INN)', 'Sotatercept (USAN/INN)'],
#  'ACVR2B': ['Bimagrumab (JAN/USAN/INN)'],
#  'ACVRL1': ['Dalantercept (USAN)'],
#  'AKR1B1': ['CT 112',
#   'Aldos (TN)',
#   'Ranirestat (JAN/INN)',
#   'Zenarestat (USAN/INN)',
#   'Ponalrestat (USAN/INN)',
#   'Minalrestat (USAN/INN)',
#   'Sorbinil (USAN/INN)',
#   'Lidorestat (USAN)',
#   'Alrestatin sodium (USAN)',
#   'Kinedak (TN)',
#   'Alredase (TN)',
#   'Alond (TN)'],
#  'ALK': ['Brigatinib (USAN)',
#   'Alecensa (TN)',
#   'Alectinib (USAN/INN)',
#   'Zykadia (TN)'],
#  'ALOX5': ['Setileuton (USAN/INN)',
#   'Enazadrem phosphate (USAN)',
#   'Atreleuton (USAN/INN)',
#   'Lonapalene (USAN)',
#   'Zyflo (TN)',
#   'Celtect (TN)',
#   'Oraflex (TN)',
#   'Lofrin [veterinary] (TN)',
#   'Docebenone (USAN/INN)',
#   'Darbufelone mesylate (USAN)'],
#  'ANPEP': ['Tosedostat (USAN/INN)'],
#  'AOC1': ['Aminoguanidine hydrochloride'],
#  'AOC3': ['Apresoline (TN)', 'Hidral (TN)', 'Hydralazine polistirex (USAN)'],
#  'ATP1A1': ['Vascor (TN)', 'Bepadin (TN)'],
#  'ATP1A2': ['Vascor (TN)', 'Bepadin (TN)'],
#  'ATP1A3': ['Vascor (TN)', 'Bepadin (TN)'],
#  'ATP1A4': ['Vascor (TN)', 'Bepadin (TN)'],
#  'ATP4A': ['Prevacid (TN)',
#   'Timoprazole (INN)',
#   'Inexium paranova (TN)',
#   'Takecab (TN)',
#   'Esomeprazole strontium tetrahydrate',
#   'Prilosec OTC (TN)',
#   'Nexium (TN)',
#   'Prilosec (TN)',
#   'Esomeprazole potassium (USAN)',
#   'Penaprazole sodium hydrate (JAN)',
#   'Eraloc (TN)',
#   'Pantoprazole (USAN/INN)',
#   'Leminoprazole (INN)',
#   'TU 199',
#   'Nexium IV (TN)',
#   'Picoprazole (INN)',
#   'Losec sodium (TN)',
#   'Pariet (TN)',
#   'Dexlansoprazole (INN/USAN)',
#   'Omepral (TN)',
#   'Protonix (TN)'],
#  'ATP4B': ['Prevacid (TN)',
#   'Timoprazole (INN)',
#   'Inexium paranova (TN)',
#   'Takecab (TN)',
#   'Esomeprazole strontium tetrahydrate',
#   'Prilosec OTC (TN)',
#   'Nexium (TN)',
#   'Prilosec (TN)',
#   'Esomeprazole potassium (USAN)',
#   'Penaprazole sodium hydrate (JAN)',
#   'Eraloc (TN)',
#   'Pantoprazole (USAN/INN)',
#   'Leminoprazole (INN)',
#   'TU 199',
#   'Nexium IV (TN)',
#   'Picoprazole (INN)',
#   'Losec sodium (TN)',
#   'Pariet (TN)',
#   'Dexlansoprazole (INN/USAN)',
#   'Omepral (TN)',
#   'Protonix (TN)'],
#  'AURKA': ['Alisertib (USAN)', 'Alisertib sodium hydrate'],
#  'AXL': ['Gilteritinib (USAN/INN)',
#   'Amuvatinib hydrochloride (USAN)',
#   'Amuvatinib (USAN/INN)',
#   'Gilteritinib fumarate (JAN/USAN)'],
#  'BCHE': ['Nimvastid (TN)',
#   'Itopride (INN)',
#   'Ganaton (TN)',
#   'Floropryl (TN)',
#   'Prometax (TN)',
#   'Eklira genuair (TN)'],
#  'BRAF': ['Dabrafenib (USAN)',
#   'Nexavar (TN)',
#   'Tafinlar (TN)',
#   'Sorafenib (USAN/INN)',
#   'Zelboraf (TN)'],
#  'BTK': ['Spebrutinib (USAN/INN)',
#   'Spebrutinib besylate (USAN)',
#   'Imbruvica (TN)'],
#  'CA9': ['Iodine (124I) girentuximab (USAN/INN)', 'Girentuximab (USAN/INN)'],
#  'CALM1': ['Prosynap (TN)'],
#  'CDK1': ['Dinaciclib (USAN/INN)'],
#  'CDK2': ['Dinaciclib (USAN/INN)'],
#  'CDK4': ['Palbociclib isethionate (USAN)',
#   'Ibrance (TN)',
#   'Abemaciclib (USAN)'],
#  'CDK5': ['Dinaciclib (USAN/INN)'],
#  'CDK6': ['Palbociclib isethionate (USAN)',
#   'Ibrance (TN)',
#   'Abemaciclib (USAN)'],
#  'CDK9': ['Dinaciclib (USAN/INN)'],
#  'CEL': ['Xenical (TN)'],
#  'CES1': ['Lixiana (TN)', 'Lixiana (TN)'],
#  'CFTR': ['Bayer 205 (TN)', 'Kalydeco (TN)', 'Lumacaftor (USAN)'],
#  'CHEK1': ['Rabusertib (USAN/INN)'],
#  'COMT': ['Ephtanon (TN)',
#   'Intropin (TN)',
#   'Epipen (TN)',
#   'Medopa (TN)',
#   'Dilospan S (TN)',
#   'Comtan (TN)',
#   'Nitecapone (INN)',
#   'Adrenalin chloride (TN)',
#   'Tasmar (TN)',
#   'Dealyd (TN)',
#   'Medihaler-epi (TN)'],
#  'CPS1': ['Carbaglu (TN)'],
#  'CTSK': ['Odanacatib (JAN/USAN)',
#   'Odanacatib (JAN/USAN)',
#   'Relacatib (USAN/INN)',
#   'Relacatib (USAN/INN)'],
#  'CYP19A1': ['Fadrozole (INN)',
#   'Liazal (TN)',
#   'Femara (TN)',
#   'Cytadren (TN)',
#   'Lentaron (TN)',
#   'Rivizor (TN)',
#   'Fadrozole hydrochloride (USAN)',
#   'Plomestane (USAN/INN)',
#   'Liarozole hydrochloride (USAN)',
#   'Aromasin (TN)',
#   'Arimidex (TN)',
#   'Afema (TN)',
#   'Teslac (TN)'],
#  'CYP1A1': ['Ramosetron (INN)',
#   'Acotiamide hydrochloride hydrate (JAN)',
#   'Nasea (TN)',
#   'Xagrid (TN)',
#   'Anagrelide (INN/BAN)',
#   'Oxsoralen (TN)',
#   'Deltyba (TN)',
#   'Nouriast (TN)',
#   'Agrylin (TN)',
#   'Adempas (TN)'],
#  'CYP1A2': ['Lidosite (TN)',
#   'Haldol (TN)',
#   'Tylenol (TN)',
#   'Arava (TN)',
#   'Chirocaine (TN)',
#   'Clozaril (TN)',
#   'Dantrolene (USAN/INN)',
#   'Esbriet (TN)',
#   'Verapamil (USAN/INN)',
#   'Asendin (TN)',
#   'Emend (TN)',
#   'Mexitil (TN)',
#   'Choice (TN)',
#   'Melatonina (TN)',
#   'Promacta (TN)',
#   'Propafenon hexal (TN)',
#   'Amiodarone (USAN/INN)',
#   'Aloxi (TN)',
#   'Coreg CR (TN)',
#   'Naramig (TN)',
#   'Proquin XR (TN)',
#   'Lamasil (TN)',
#   'Neupro (TN)',
#   'Jantoven (TN)',
#   'Ramosetron (INN)',
#   'Zomig (TN)',
#   'Phenazone (INN)',
#   'Ropitor (TN)',
#   'Novabupi (TN)',
#   'Mexiletine (INN)',
#   'Nasea (TN)',
#   'Xagrid (TN)',
#   'Yentreve (TN)',
#   'Noroxin (TN)',
#   'Fluvoxamine (INN)',
#   'Nolvadex (TN)',
#   'Ribomustin (TN)',
#   'Paraflex (TN)',
#   'Telzir (TN)',
#   'Athrombin-K (TN)',
#   'Naproxen etemesil (USAN)',
#   'Quinabic soluble powder (TN) [veterinary]',
#   'Lidocaine (TN)',
#   'Tamoplex (TN)',
#   'Respia (TN)',
#   'Cimetidine hydrochloride (TN)',
#   'Olanzapine pamoate monohydrate',
#   'Laroxyl (TN)',
#   'Enoxacin hydrate (JP17)',
#   'Flexeril (TN)',
#   'Stiripentol (JAN/USAN/INN)',
#   'Lamisil (TN)',
#   'Sarpogrelate (INN)',
#   'Relafen (TN)',
#   'Naropin (TN)',
#   'Dantrium (TN)',
#   'Theocolin (TN)',
#   'Aminophylline hydrate (JP17)',
#   'Clopidogrel (TN)',
#   'Luvox (TN)',
#   'Dexpropranolol hydrochloride (USAN)',
#   'Lotrpnex (TN)',
#   'Sirdalud (TN)',
#   'Alosetron (INN)',
#   'Tacrinal (TN)',
#   'Verelan (TN)',
#   'Cafcit (TN)',
#   'Cipro (TN)',
#   'Nuvigil (TN)',
#   'Tofranil (TN)',
#   'Erlotinib (INN)',
#   'Anaprox (TN)',
#   'Anagrelide (INN/BAN)',
#   'Anplag (TN)',
#   'Dexamethasone cipecilate (JAN/INN)',
#   'Oxsoralen (TN)',
#   'Tolvon (TN)',
#   'Anafranil (TN)',
#   'Uniphyl (TN)',
#   'Ciproxin (TN)',
#   'Propranolol (TN)',
#   'Anapeine (TN)',
#   'Plavix (TN)',
#   'Rozerem (TN)',
#   'Phenacetin (JAN/INN)',
#   'Theophylline sodium acetate (JAN)',
#   'Zofran ODT (TN)',
#   'Fosamprenavir sodium (USAN)',
#   'Rilutek (TN)',
#   'Caffeine (TN)',
#   'Elavil (TN)',
#   'Cordarone (TN)',
#   'Tetramide (TN)',
#   'Naprosyn (TN)',
#   'Zyflo (TN)',
#   'Lexiva (TN)',
#   'Vivelle (TN)',
#   'Zyprexa (TN)',
#   'Inlyta (TN)',
#   'Cognex (TN)',
#   'Tarceva (TN)',
#   'Tagamet (TN)',
#   'Coreg (TN)',
#   'Requip (TN)',
#   'Zanaflex (TN)',
#   'Accurbron (TN)',
#   'Halomonth (TN)',
#   'Rythmol (TN)',
#   'Intermezzo (TN)',
#   'Innopran XL (TN)',
#   'Asbron (TN)',
#   'Agrylin (TN)',
#   'Votrient (TN)',
#   'Xenazine (TN)',
#   'Cyclobenzaprine (INN)',
#   'Reflex (TN)',
#   'Sanval (TN)',
#   'Rizaben (TN)',
#   'Theophylline ethylenediamine (TN)',
#   'Xylocaine (TN)',
#   'Amerge (TN)',
#   'Velcade (TN)',
#   'Fosamprenavir (INN)',
#   'Orap (TN)',
#   'Provigil (TN)',
#   'Zofran (TN)'],
#  'CYP1B1': ['Vivelle (TN)'],
#  'CYP2A6': ['Tylenol (TN)',
#   'Metronidazole phosphate (USAN)',
#   'Habitrol (TN)',
#   'Femara (TN)',
#   'Ocusert pilo-20 (TN)',
#   'Noritate (TN)',
#   'Nicotine bitartrate dihydrate',
#   'Flagyl I.V. (TN)',
#   'Cytoxan (TN)',
#   'Atillon (TN)',
#   'Oxsoralen (TN)',
#   'Pilagan (TN)',
#   'Elyzol (TN)',
#   'pilolarpin ophtha (TN)',
#   'Neosar (TN)',
#   'Sanpilo (TN)',
#   'Nicorette (TN)'],
#  'CYP2B6': ['Viramune (TN)',
#   'Methadone (BAN)',
#   'Dabrafenib (USAN)',
#   'Effient (TN)',
#   'Testosterone phenylacetate (USAN)',
#   'Testanon 50 (TN)',
#   'Tegretol (TN)',
#   'Testosterone ketolaurate (USAN/INN)',
#   'Depo-testosterone (TN)',
#   'Takecab (TN)',
#   'Dilantin (TN)',
#   'Bupropion (INN)',
#   'Clopidogrel (TN)',
#   'Sertraline (INN)',
#   'Sustiva (TN)',
#   'Cytoxan (TN)',
#   'Nuvigil (TN)',
#   'Anplag (TN)',
#   'Ifex (TN)',
#   'Plavix (TN)',
#   'Testex (TN)',
#   'L-polamidon (TN)',
#   'Zyban (TN)',
#   'Dolophine hydrochloride (TN)',
#   'Delatestryl (TN)',
#   'Tafinlar (TN)',
#   'Aleviatin with phenobarbital (TN)',
#   'Andriol (TN)',
#   'Hydantol F (TN)',
#   'Zoloft (TN)',
#   'Bupropion hydrobromide (USAN)',
#   'Neosar (TN)',
#   'Testocaps (TN)',
#   'Levomethadone (INN)',
#   'Sorafenib (USAN/INN)',
#   'Provigil (TN)'],
#  'CYP2C18': ['Valium (TN)', 'Deberza (TN)', 'Rizaben (TN)'],
#  'CYP2C19': ['Prevacid (TN)',
#   'Arava (TN)',
#   'Dabrafenib (USAN)',
#   'Esbriet (TN)',
#   'Asendin (TN)',
#   'Emend (TN)',
#   'Aurorix (TN)',
#   'Volibris (TN)',
#   'Fostoin (TN)',
#   'Chloromycetin palmitate (TN)',
#   'Lamasil (TN)',
#   'Neupro (TN)',
#   'Mysoline (TN)',
#   'Staxyn (TN)',
#   'Luminal (TN)',
#   'Valium (TN)',
#   'Rescriptor (TN)',
#   'Indocin I.V. (TN)',
#   'Pantofenicol (TN)',
#   'Inexium paranova (TN)',
#   'Chloramphenicol ICN (TN)',
#   'Diflucan (TN)',
#   'Fluvoxamine (INN)',
#   'Belsomra (TN)',
#   'Takecab (TN)',
#   'Delavirdine (INN)',
#   'Calmday (TN)',
#   'Esomeprazole strontium tetrahydrate',
#   'Prilosec OTC (TN)',
#   'Tofranil-pm (TN)',
#   'Dilantin (TN)',
#   'Prometrium (TN)',
#   'Laroxyl (TN)',
#   'Stiripentol (JAN/USAN/INN)',
#   'Nexium (TN)',
#   'Tracleer (TN)',
#   'Lamisil (TN)',
#   'Sarpogrelate (INN)',
#   'Gratusminal (TN)',
#   'Fosphenytoin (INN)',
#   'Clopidogrel (TN)',
#   'Luvox (TN)',
#   'Tyverb (TN)',
#   'Dexpropranolol hydrochloride (USAN)',
#   'Bosentan (INN)',
#   'Vfend (TN)',
#   'Sertraline (INN)',
#   'Prilosec (TN)',
#   'Mebaral (TN)',
#   'Esomeprazole potassium (USAN)',
#   'Eraloc (TN)',
#   'Nuvigil (TN)',
#   'Tofranil (TN)',
#   'Vumon (TN)',
#   'Pantoprazole (USAN/INN)',
#   'Indocin (TN)',
#   'Anplag (TN)',
#   'Viracept (TN)',
#   'Econochlor (TN)',
#   'Esertia (TN)',
#   'Tolvon (TN)',
#   'Anafranil (TN)',
#   'Propranolol (TN)',
#   'Plavix (TN)',
#   'Chloromycetin succinate (TN)',
#   'Luminal sodium (TN)',
#   'Pletal (TN)',
#   'Prodif (TN)',
#   'Nexium IV (TN)',
#   'Elavil (TN)',
#   'Tetramide (TN)',
#   'Crestor (TN)',
#   'Xeljanz (TN)',
#   'Nilandron (TN)',
#   'Mesantoin (TN)',
#   'Inlyta (TN)',
#   'Quemicetina (TN)',
#   'Losec sodium (TN)',
#   'Dolophine hydrochloride (TN)',
#   'Pariet (TN)',
#   'Soma (TN)',
#   'Intelence (TN)',
#   'Tafinlar (TN)',
#   'Aleviatin with phenobarbital (TN)',
#   'Hydantol F (TN)',
#   'Innopran XL (TN)',
#   'Cerebyx (TN)',
#   'Dexlansoprazole (INN/USAN)',
#   'Zoloft (TN)',
#   'Atelec (TN)',
#   'Paludrine (TN)',
#   'Lexapro (TN)',
#   'Lansap (TN)',
#   'Omepral (TN)',
#   'Protonix (TN)',
#   'Hexobarbital (JAN/INN)',
#   'Velcade (TN)',
#   'Onfi (TN)',
#   'Provigil (TN)',
#   'Levitra (TN)',
#   'Proguanil (INN)'],
#  'CYP2C8': ['Dabrafenib (USAN)',
#   'Promacta (TN)',
#   'Torem (TN)',
#   'Lamasil (TN)',
#   'Staxyn (TN)',
#   'Tegretol (TN)',
#   'Orinase diagnostic (TN)',
#   'Tasigna (TN)',
#   'Acotiamide hydrochloride hydrate (JAN)',
#   'Imodium (TN)',
#   'Uptravi (TN)',
#   'Amodiaquine (USAN/INN)',
#   'Lamisil (TN)',
#   'Tyverb (TN)',
#   'Baycol (TN)',
#   'Sonias (TN)',
#   'Avandia (TN)',
#   'Cytoxan (TN)',
#   'Januvia (TN)',
#   'Camoquin hydrochloride (TN)',
#   'Mozavaptane hydrochloride (JAN)',
#   'Taxol (TN)',
#   'Lapatinib (INN)',
#   'Orinase (TN)',
#   'Retinol acetate (JP17)',
#   'Surepost (TN)',
#   'Zopiclone (TN)',
#   'Dolophine hydrochloride (TN)',
#   'Aquasol A (TN)',
#   'Tafinlar (TN)',
#   'Remodulin (TN)',
#   'Nilotinib (USAN/INN)',
#   'Votrient (TN)',
#   'Gaudil (TN)',
#   'Cerivastatin (INN)',
#   'Rizaben (TN)',
#   'Microvit a dlc [veterinary] (TN)',
#   'Neosar (TN)',
#   'Singulair (TN)',
#   'Xtandi (TN)',
#   'Sorafenib (USAN/INN)',
#   'Luprac (TN)',
#   'Levitra (TN)',
#   'Chocola A (TN)'],
#  'CYP2C9': ['Ponstel (TN)',
#   'Motrin (TN)',
#   'Ansaid (TN)',
#   'Ibuprofen sodium hydrate',
#   'Arava (TN)',
#   'Dabrafenib (USAN)',
#   'Esbriet (TN)',
#   'Aphrodil (TN)',
#   'Lescol (TN)',
#   'Choice (TN)',
#   'Avapro (TN)',
#   'Pitavastatin calcium hydrate (JP17)',
#   'Voltaren (TN)',
#   'Neoprofen (TN)',
#   'Diovan (TN)',
#   'Doral (TN)',
#   'Torem (TN)',
#   'Prozac (TN)',
#   'Fostoin (TN)',
#   'Zocor (TN)',
#   'Amiodarone (USAN/INN)',
#   'Coreg CR (TN)',
#   'Naramig (TN)',
#   'Flector (TN)',
#   'Lamasil (TN)',
#   'Staxyn (TN)',
#   'Jantoven (TN)',
#   'Piroxicam cinnamate (USAN)',
#   'Sedekopan (TN)',
#   'Orinase diagnostic (TN)',
#   'Candesartan (USAN/INN)',
#   'Rescriptor (TN)',
#   'Xeloda (TN)',
#   'Glufast (TN)',
#   'Glivec (TN)',
#   'Micronase (TN)',
#   'Diflucan (TN)',
#   'Nolvadex (TN)',
#   'Delavirdine (INN)',
#   'Depakene (TN)',
#   'Azilva (TN)',
#   'Selenica (TN)',
#   'Telzir (TN)',
#   'Amaryl (TN)',
#   'Athrombin-K (TN)',
#   'Naproxen etemesil (USAN)',
#   'Dilantin (TN)',
#   'Esprenit (TN)',
#   'Tamoplex (TN)',
#   'Cimetidine hydrochloride (TN)',
#   'Profenal (TN)',
#   'Tracleer (TN)',
#   'Lamisil (TN)',
#   'Sarpogrelate (INN)',
#   'Fosphenytoin (INN)',
#   'Tilcotil (TN)',
#   'Bosentan (INN)',
#   'Lorcam (TN)',
#   'Glamox (TN)',
#   'Vfend (TN)',
#   'Marinol (TN)',
#   'Losartic (TN)',
#   'Sertraline (INN)',
#   'Sonias (TN)',
#   'Zipsor (TN)',
#   'Ropion (TN)',
#   'Avandia (TN)',
#   'Cytoxan (TN)',
#   'Nuvigil (TN)',
#   'Feldene (TN)',
#   'Piroxicam olamine (USAN)',
#   'Jakavi (TN)',
#   'Anaprox (TN)',
#   'Anplag (TN)',
#   'Viracept (TN)',
#   'Livalo (TN)',
#   'Comtan (TN)',
#   'Voltaren Actingo Extra (TN)',
#   'Brondilat (TN)',
#   'Vascor (TN)',
#   'Flucam (TN)',
#   'Fosamprenavir sodium (USAN)',
#   'Starsis (TN)',
#   'Losarhyd (TN)',
#   'Prodif (TN)',
#   'Cordarone (TN)',
#   'Naprosyn (TN)',
#   'Crestor (TN)',
#   'Lexiva (TN)',
#   'Orinase (TN)',
#   'Tagamet (TN)',
#   'Coreg (TN)',
#   'Cozaar (TN)',
#   'Mofezolac (TN)',
#   'Intelence (TN)',
#   'Convulsofin (TN)',
#   'Fluoxetine (TN)',
#   'Piroxicam betadex (USAN)',
#   'Tafinlar (TN)',
#   'Intermezzo (TN)',
#   'Aleviatin with phenobarbital (TN)',
#   'Hydantol F (TN)',
#   'Cerebyx (TN)',
#   'Glucotrol (TN)',
#   'Zafen (TN)',
#   'Zoloft (TN)',
#   'Mobic (TN)',
#   'Remodulin (TN)',
#   'Uroleap (TN)',
#   'Gaudil (TN)',
#   'Atacand (TN)',
#   'Viagra (TN)',
#   'Depakote (TN)',
#   'Sanval (TN)',
#   'Rizaben (TN)',
#   'Ibuprofen aluminum (USAN)',
#   'Hexobarbital (JAN/INN)',
#   'Neosar (TN)',
#   'Singulair (TN)',
#   'Voltaren Emulgel (TN)',
#   'Bepadin (TN)',
#   'Tridione (TN)',
#   'Amerge (TN)',
#   'Loqoa (TN)',
#   'Fosamprenavir (INN)',
#   'Zorvolex (TN)',
#   'Sorafenib (USAN/INN)',
#   'Luprac (TN)',
#   'Provigil (TN)',
#   'Levitra (TN)',
#   'Ocufen (TN)',
#   'Fluvas (TN)',
#   'Onsenal (TN)'],
#  'CYP2D6': ['Pamelor (TN)',
#   'Vena (TN)',
#   'Declinax (TN)',
#   'Sparteine sulfate pentahydrate',
#   'Eldepryl (TN)',
#   'Viramune (TN)',
#   'Saligren (TN)',
#   'Haldol (TN)',
#   'Nortrilen (TN)',
#   'Arava (TN)',
#   'Esbriet (TN)',
#   'Asendin (TN)',
#   'Mexitil (TN)',
#   'Nozinan (TN)',
#   'Risperdal (TN)',
#   'Diphenhydramine salicylate (JAN)',
#   'Codeine sulfate trihydrate',
#   'Desyrel (TN)',
#   'Flecainide (INN)',
#   'Prozac (TN)',
#   'Propafenon hexal (TN)',
#   'Restamin (TN)',
#   'Aricept (TN)',
#   'Amiodarone (USAN/INN)',
#   'Betrilol (TN)',
#   'Oxycodone hydrochloride hydrate (JP17)',
#   'Aloxi (TN)',
#   'Coreg CR (TN)',
#   'Naramig (TN)',
#   'Visken (TN)',
#   'Redux (TN)',
#   'Prolixin (TN)',
#   'Encainide hydrochloride (USAN)',
#   'Norpramin (TN)',
#   'Flunarizine hydrochloride (JAN/USAN)',
#   'Clofeniramina (TN)',
#   'Ramosetron (INN)',
#   'Celenid (TN)',
#   'Carteolol (INN)',
#   'Ajimalin (TN)',
#   'Codeine (TN)',
#   'Rescriptor (TN)',
#   'Timoptic (TN)',
#   'Romergan (TN)',
#   'Phenformin (BAN)',
#   'Mexiletine (INN)',
#   'Nasea (TN)',
#   'Chlorpromazine tannate (JAN)',
#   'Ethanol (TN)',
#   'Alprenolol (INN)',
#   'Encainide (INN)',
#   'Dexfenfluramine (INN)',
#   'Yentreve (TN)',
#   'Desipramine (INN)',
#   'Glivec (TN)',
#   'Aspenon (TN)',
#   'Pexeva (TN)',
#   'Promethazine (JAN/INN)',
#   'Paroxetine (TN)',
#   'Invokana (TN)',
#   'Cisordinol-acutard (TN)',
#   'Codeine hydrate',
#   'Vegetamin (TN)',
#   'Fluvoxamine (INN)',
#   'PZC intramuscular injection (TN)',
#   'Nolvadex (TN)',
#   'Takecab (TN)',
#   'Delavirdine (INN)',
#   'Citadur (TN)',
#   'Ultram (TN)',
#   'Abilify (TN)',
#   'Trittico (TN)',
#   'Telzir (TN)',
#   'Tenormin (TN)',
#   'Tofranil-pm (TN)',
#   'Minaprine hydrochloride (USAN)',
#   'Alcohol diluted (NF)',
#   'Lidocaine (TN)',
#   'Tamoplex (TN)',
#   'Metoprolol (USAN/INN)',
#   'Cimetidine hydrochloride (TN)',
#   'Olanzapine pamoate monohydrate',
#   'Dextrostat (TN)',
#   'Teldrin (TN)',
#   'Laroxyl (TN)',
#   'Belviq (TN)',
#   'Sibelium (TN)',
#   'Diphenhydramine citrate (USP)',
#   'Effexor (TN)',
#   'Polaramine (TN)',
#   'Sarpogrelate (INN)',
#   'Moditen (TN)',
#   'Dothep (TN)',
#   'Strattera (TN)',
#   'Luvox (TN)',
#   'Dexpropranolol hydrochloride (USAN)',
#   'Dehydrated ethanol (TN)',
#   'Glamox (TN)',
#   'Clopixol (TN)',
#   'Trilafon dekanoat (TN)',
#   'Protecadin (TN)',
#   'Bisoltus (TN)',
#   'Toviaz (TN)',
#   'Oxycodone (USAN/INN)',
#   'Dapriton (TN)',
#   'Dihydro (TN)',
#   'Sandonorm (TN)',
#   'Foradil (TN)',
#   'Tolterodine (USAN/INN)',
#   'Tomoxetine',
#   'Reglan (TN)',
#   'Celexa (TN)',
#   'Benylin DM (TN)',
#   'Permax (TN)',
#   'Tofranil (TN)',
#   'Claritin (TN)',
#   'Prolixin decanoate (TN)',
#   'Detrusitol (TN)',
#   'Anplag (TN)',
#   'Viracept (TN)',
#   'Perhexiline maleate (USAN)',
#   'Debei (TN)',
#   'Lopressor (TN)',
#   'Olanedine (TN)',
#   'Terperan (TN)',
#   'Efectin (TN)',
#   'Donaz (TN)',
#   'Perhexiline (INN)',
#   'Esertia (TN)',
#   'Paxil (TN)',
#   'Avomine (TN)',
#   'Tolvon (TN)',
#   'Anafranil (TN)',
#   'Bystolic (TN)',
#   'Propranolol (TN)',
#   'Kitazemin (TN)',
#   'Aristada (TN)',
#   'Regletin (TN)',
#   'Tambocor (TN)',
#   'Dexamfetamine (INN)',
#   'Vascor (TN)',
#   'Cantor (TN)',
#   'Pletal (TN)',
#   'Phenacetin (JAN/INN)',
#   'Zofran ODT (TN)',
#   'Fosamprenavir sodium (USAN)',
#   'Deltyba (TN)',
#   'Contomin (TN)',
#   'Elavil (TN)',
#   'Cordarone (TN)',
#   'Emsam (TN)',
#   'Tetramide (TN)',
#   'Mellaril-S (TN)',
#   'Cinnarizine (JAN/USAN/INN)',
#   'Ethanol for disinfection (TN)',
#   'Oxycodone terephthalate (USP)',
#   'Hirnamin (TN)',
#   'Lexiva (TN)',
#   'Nebivolol (USAN/INN)',
#   'Zyprexa (TN)',
#   'Ludiomil (TN)',
#   'Seropram (TN)',
#   'Pyrethia (TN)',
#   'Trilafon (TN)',
#   'Tagamet (TN)',
#   'Cipralan (TN)',
#   'Coreg (TN)',
#   'Dolophine hydrochloride (TN)',
#   'Iressa (TN)',
#   'Cibenzoline (INN)',
#   'Sediel (TN)',
#   'Halomonth (TN)',
#   'Betimol (TN)',
#   'Rythmol (TN)',
#   'Fluoxetine (TN)',
#   'Benzedrine (TN)',
#   'Aprindine (USAN/INN)',
#   'Roxicodone (TN)',
#   'Restamin A (TN)',
#   'Zafatek (TN)',
#   'Dosulepin (TN)',
#   'Sonazine (TN)',
#   'Mellaril (TN)',
#   'Innopran XL (TN)',
#   'Cevimeline (INN)',
#   'Norvir (TN)',
#   'Levoprome (TN)',
#   'Remedacen (TN)',
#   'Flumezin (TN)',
#   'Ocupress (TN)',
#   'Promethegan (TN)',
#   'Pavinal (TN)',
#   'Clopixol depot (TN)',
#   'Xenazine (TN)',
#   'Benadryl (TN)',
#   'PZC (TN)',
#   'Reflex (TN)',
#   'Lexapro (TN)',
#   'Aripiprazole monohydrate',
#   'Ketek (TN)',
#   'Rizaben (TN)',
#   'Aripiprazole cavoxil (USAN)',
#   'Eliglustat tartrate (JAN/USAN)',
#   'Incruse ellipta (TN)',
#   'Surmontil (TN)',
#   'Sparteine (INN)',
#   'Bepadin (TN)',
#   'Amanda (TN)',
#   'Amerge (TN)',
#   'Dextromethorphan (USP)',
#   'Fosamprenavir (INN)',
#   'Toprol XL (TN)',
#   'Orap (TN)',
#   'Hiberna (TN)',
#   'Trimipramine (USAN/INN)',
#   'Maprotiline (USAN)',
#   'Tandospirone (INN)',
#   'Wintermin (TN)',
#   'Medicon (TN)',
#   'Thorazine (TN)',
#   'Zofran (TN)',
#   'Onsenal (TN)'],
#  'CYP2E1': ['Tylenol (TN)',
#   'Fluothane (TN)',
#   'Coreg CR (TN)',
#   'Naramig (TN)',
#   'Ethanol (TN)',
#   'Paraflex (TN)',
#   'Zarontin (TN)',
#   'Alcohol diluted (NF)',
#   'Ethrane (TN)',
#   'Respia (TN)',
#   'Dehydrated ethanol (TN)',
#   'Cafcit (TN)',
#   'Viracept (TN)',
#   'Olanedine (TN)',
#   'Penthrane (TN)',
#   'Uniphyl (TN)',
#   'Acetone (TN)',
#   'Deltyba (TN)',
#   'Caffeine (TN)',
#   'Ethanol for disinfection (TN)',
#   'Coreg (TN)',
#   'Accurbron (TN)',
#   'Aczone (TN)',
#   'Lunesta (TN)',
#   'Ultane (TN)',
#   'Diethyl ether',
#   'Forane (TN)',
#   'Amerge (TN)'],
#  'CYP2J2': ['Relafen (TN)', 'Xarelto (TN)', 'Kestine (TN)', 'Adempas (TN)'],
#  'CYP3A4': ['Dexamedium [veterinary] (TN)',
#   'Oralet (TN)',
#   'Staybla (TN)',
#   'Lidosite (TN)',
#   'Erythromycin propionate (USAN)',
#   'Propulsid (TN)',
#   'Eldepryl (TN)',
#   'Viramune (TN)',
#   'Urief (TN)',
#   'Orfadin (TN)',
#   'Saligren (TN)',
#   'Procardia (TN)',
#   'Turisteron (TN)',
#   'Haldol (TN)',
#   'Prevacid (TN)',
#   'Cortone acetate (TN)',
#   'Symbicort (TN)',
#   'Tylenol (TN)',
#   'Nymalize (TN)',
#   'Arava (TN)',
#   'Chirocaine (TN)',
#   'Methadone (BAN)',
#   'Clozaril (TN)',
#   'Dabrafenib (USAN)',
#   'Verapamil (USAN/INN)',
#   'Calblock (TN)',
#   'Subsys (TN)',
#   'Dexafort [veterinary] (TN)',
#   'Nasonex (TN)',
#   'Cisapride (USAN/INN)',
#   'Solu-cortef (TN)',
#   'Erythrocin W (TN)',
#   'Hismanal (TN)',
#   'Asendin (TN)',
#   'Aphrodil (TN)',
#   'Emend (TN)',
#   'Endometrion (TN)',
#   'Mexitil (TN)',
#   'Seroquel (TN)',
#   'Quinidex (TN)',
#   'Vesicare (TN)',
#   'Navelbine (TN)',
#   'Westcort (TN)',
#   'Risperdal (TN)',
#   'Lescol (TN)',
#   'Celestone (TN)',
#   'Trokendi xr (TN)',
#   'Ilotycin gluceptate (TN)',
#   'Codeine sulfate trihydrate',
#   'Volibris (TN)',
#   'Desyrel (TN)',
#   'Flecainide (INN)',
#   'Yondelis (TN)',
#   'Vincrex (TN)',
#   'Decadron-phosphate (TN)',
#   'Invirase (TN)',
#   'Casodex (TN)',
#   'Doral (TN)',
#   'Testosterone phenylacetate (USAN)',
#   'Erythrocin (TN)',
#   'Salmeterol (USAN/INN)',
#   'Propafenon hexal (TN)',
#   'Zocor (TN)',
#   'Testanon 50 (TN)',
#   'Parlodel (TN)',
#   'Depo-medrol (TN)',
#   'Faslodex (TN)',
#   'Aricept (TN)',
#   'Amiodarone (USAN/INN)',
#   'Fluothane (TN)',
#   'Sular (TN)',
#   'Levacetylmethadol (INN)',
#   'Oxycodone hydrochloride hydrate (JP17)',
#   'Benidipine (INN)',
#   'Aloxi (TN)',
#   'Coreg CR (TN)',
#   'Bosulif (TN)',
#   'Naramig (TN)',
#   'Methylprednisolone sodium phosphate (USAN)',
#   'Lamasil (TN)',
#   'Fareston (TN)',
#   'Estinyl (TN)',
#   'Zortress (TN)',
#   'Tegretol (TN)',
#   'Baypress (TN)',
#   'Testosterone ketolaurate (USAN/INN)',
#   'Campto (TN)',
#   'Piroxicam cinnamate (USAN)',
#   'Clofeniramina (TN)',
#   'Elocon (TN)',
#   'Emandaxin (TN)',
#   'Taxotere (TN)',
#   'Geodon (TN)',
#   'Penetrex (TN)',
#   'Efficort (TN)',
#   'Sedekopan (TN)',
#   'Indinavir hydrate',
#   'ProSom (TN)',
#   'Femara (TN)',
#   'Xolegel (TN)',
#   'Zipradon (TN)',
#   'Rinderon (TN)',
#   'Valium (TN)',
#   'Prezios (TN)',
#   'Nivadil (TN)',
#   'Prograf (TN)',
#   'Codeine (TN)',
#   'T-stat (TN)',
#   'Novabupi (TN)',
#   'Tasigna (TN)',
#   'Sapresta (TN)',
#   'Rescriptor (TN)',
#   'Coco-quinine (TN)',
#   'Crixivan (TN)',
#   'Mexiletine (INN)',
#   'Sonata (TN)',
#   'Acotiamide hydrochloride hydrate (JAN)',
#   'Aerivio Spiromax (TN)',
#   'Zalucs (TN)',
#   'Quinine hydrochloride (TN)',
#   'Gasmotin (TN)',
#   'Dexamethasone beloxil (USAN)',
#   'Buprenex (TN)',
#   'inhibin (TN)',
#   'Hydrocortone phosphate (TN)',
#   'Inexium paranova (TN)',
#   'Ilosone (TN)',
#   'Sandimmune (TN)',
#   'Glivec (TN)',
#   'Eliquis (TN)',
#   'Mimpara (TN)',
#   'Invokana (TN)',
#   'Imodium (TN)',
#   'Torisel (TN)',
#   'Ethylmorphine hydrochloride (TN)',
#   'Exparel (TN)',
#   'Ergotamine (INN)',
#   'Codeine hydrate',
#   'Diflucan (TN)',
#   'Exforge (TN)',
#   'Kinidin (TN)',
#   'Fluvoxamine (INN)',
#   'Ergometrine (INN)',
#   'Caprelsa (TN)',
#   'Mosart (TN)',
#   'Coniel (TN)',
#   'Nolvadex (TN)',
#   'Lusefi (TN)',
#   'Depo-testosterone (TN)',
#   'Takecab (TN)',
#   'Mylotarg (TN)',
#   'Delavirdine (INN)',
#   'Citadur (TN)',
#   'Avodart (TN)',
#   'Depakene (TN)',
#   'Ultram (TN)',
#   'Calmday (TN)',
#   'Prezista (TN)',
#   'Abilify (TN)',
#   'Trittico (TN)',
#   'Rythmodan P (TN)',
#   'Vistaril pamoate (TN)',
#   'Zarontin (TN)',
#   'Locoid (TN)',
#   'Natisedine (TN)',
#   'Selenica (TN)',
#   'Telzir (TN)',
#   'Esomeprazole strontium tetrahydrate',
#   'Prilosec OTC (TN)',
#   'Tofranil-pm (TN)',
#   'Ethylmorphine (BAN)',
#   'Decadronal (TN)',
#   'Quinaglute (TN)',
#   'Uptravi (TN)',
#   'Methylprednisolone succinate (JP17)',
#   'Dexamethasone acefurate (USAN/INN)',
#   'Proemend (TN)',
#   'Novastan (TN)',
#   'Azlaire (TN)',
#   'Lidocaine (TN)',
#   'Setous (TN)',
#   'Velban (TN)',
#   'Impromen (TN)',
#   'Tamoplex (TN)',
#   'Propiverine (INN)',
#   'Erysec (TN)',
#   'Respia (TN)',
#   'Prometrium (TN)',
#   'Motilium (TN)',
#   'Cimetidine hydrochloride (TN)',
#   'Teldrin (TN)',
#   'Laroxyl (TN)',
#   'Stiripentol (JAN/USAN/INN)',
#   'Nexium (TN)',
#   'Cardene (TN)',
#   'Hifmeta (TN)',
#   'Tracleer (TN)',
#   'Polaramine (TN)',
#   'Ozenoxacin (JAN/INN)',
#   'Lamisil (TN)',
#   'Sarpogrelate (INN)',
#   'Omnaris (TN)',
#   'Decaject-L.A. (TN)',
#   'Calslot (TN)',
#   'Clopidogrel (TN)',
#   'Hydrocortisone hemisuccinate (USP)',
#   'Relvar ellipita (TN)',
#   'Luvox (TN)',
#   'Tyverb (TN)',
#   'Dexpropranolol hydrochloride (USAN)',
#   'Twynsta (TN)',
#   'Bosentan (INN)',
#   'Erythromycin salnacedin dihydrate',
#   'Glamox (TN)',
#   'Tao (TN)',
#   'Protecadin (TN)',
#   'Adehl (TN)',
#   'Sutent (TN)',
#   'Bisoltus (TN)',
#   'Toviaz (TN)',
#   'Vfend (TN)',
#   'Oxycodone (USAN/INN)',
#   'Alecensa (TN)',
#   'Dostinex (TN)',
#   'Dapriton (TN)',
#   'Marinol (TN)',
#   'Losartic (TN)',
#   'Baycol (TN)',
#   'Sertraline (INN)',
#   'Prilosec (TN)',
#   'Darunavir (USAN/INN)',
#   'Marcaine (TN)',
#   'Climara pro (TN)',
#   'Verelan (TN)',
#   'Limethason (TN)',
#   'Cafcit (TN)',
#   'Tolterodine (USAN/INN)',
#   'Sustiva (TN)',
#   'Esomeprazole potassium (USAN)',
#   'Celexa (TN)',
#   'Cytoxan (TN)',
#   'Xarelto (TN)',
#   'Eraloc (TN)',
#   'Rifadine (TN)',
#   'Caduet (TN)',
#   'Lercanil (TN)',
#   'Benylin DM (TN)',
#   'Norsic (TN)',
#   'Tecnocris (TN)',
#   'Nuvigil (TN)',
#   'Sporanox (TN)',
#   'Tofranil (TN)',
#   'Feldene (TN)',
#   'Rezaltas (TN)',
#   'Claritin (TN)',
#   'Vumon (TN)',
#   'Piroxicam olamine (USAN)',
#   'Klacid (TN)',
#   'Jakavi (TN)',
#   'Reyataz (TN)',
#   'Erlotinib (INN)',
#   'Lendormin (TN)',
#   'Onon (TN)',
#   'Myrbetriq (TN)',
#   'Januvia (TN)',
#   'Detrusitol (TN)',
#   'Anplag (TN)',
#   'Viracept (TN)',
#   'Melex (TN)',
#   'Premarin (TN)',
#   'Ifex (TN)',
#   'Olanedine (TN)',
#   'Teneligliptin hydrobromide hydrate (JAN)',
#   'Cleamine A (TN)',
#   'Pravachol (TN)',
#   'Tekturna (TN)',
#   'Donaz (TN)',
#   'Brondilat (TN)',
#   'Dexamethasone cipecilate (JAN/INN)',
#   'Kestine (TN)',
#   'Penthrane (TN)',
#   'Esertia (TN)',
#   'Hydrocortisone cypionate',
#   'Tolvon (TN)',
#   'Anafranil (TN)',
#   'Propranolol (TN)',
#   'Anapeine (TN)',
#   'Plavix (TN)',
#   'Aristada (TN)',
#   'Tambocor (TN)',
#   'Meilax (TN)',
#   'Fortovase (TN)',
#   'Biltricide (TN)',
#   'Kinder Quinina (TN)',
#   'Rozerem (TN)',
#   'Tradjenta (TN)',
#   'Inorter (TN)',
#   'Vascor (TN)',
#   'Aromasin (TN)',
#   'Pletal (TN)',
#   'Zofran ODT (TN)',
#   'Flucam (TN)',
#   'Fosamprenavir sodium (USAN)',
#   'Mevacor (TN)',
#   'Vepesid (TN)',
#   'Biotecan (TN)',
#   'Agenerase (TN)',
#   'Deltyba (TN)',
#   'Starsis (TN)',
#   'Testex (TN)',
#   'Protopic (TN)',
#   'Prodif (TN)',
#   'Caffeine (TN)',
#   'Norpace (TN)',
#   'Serevent (TN)',
#   'Nexium IV (TN)',
#   'Colchicine (TN)',
#   'Elavil (TN)',
#   'Quinine biascorbate',
#   'Cordarone (TN)',
#   'Emsam (TN)',
#   'Flutiform (TN)',
#   'Emilace (TN)',
#   'Tetramide (TN)',
#   'Mozavaptane hydrochloride (JAN)',
#   'L-polamidon (TN)',
#   'Synercid (TN)',
#   'Xyzal (TN)',
#   'AD 5423',
#   'Oxycodone terephthalate (USP)',
#   'Xeljanz (TN)',
#   'Lexiva (TN)',
#   'Taxol (TN)',
#   'Lapatinib (INN)',
#   'Enjuvia (TN)',
#   'Vivelle (TN)',
#   'Hypoca (TN)',
#   'Erasis (TN)',
#   'Inlyta (TN)',
#   'Stromectol (TN)',
#   'Amvaz (TN)',
#   'Lullan (TN)',
#   'Seropram (TN)',
#   'Rimactane (TN)',
#   'Tarceva (TN)',
#   'Surepost (TN)',
#   'Cortisone (TN)',
#   'Ergotyl (TN)',
#   'Tagamet (TN)',
#   'Vasexten (TN)',
#   'Santeson (TN)',
#   'Cipralan (TN)',
#   'Zopiclone (TN)',
#   'Coreg (TN)',
#   'Losec sodium (TN)',
#   'Dolophine hydrochloride (TN)',
#   'Nalfurafine hydrochloride (JAN/USAN)',
#   'Cozaar (TN)',
#   'Testim (TN)',
#   'Uceris (TN)',
#   'Iressa (TN)',
#   'Cibenzoline (INN)',
#   'Sediel (TN)',
#   'Methylprednisolone suleptanate (USAN/INN)',
#   'Temgesic (TN)',
#   'Halomonth (TN)',
#   'Pariet (TN)',
#   'Solu-medrol (TN)',
#   'Solifenacin (INN)',
#   'Rythmol (TN)',
#   'Intelence (TN)',
#   'Convulsofin (TN)',
#   'Pravator (TN)',
#   'Voalla ointment (TN)',
#   'Piroxicam betadex (USAN)',
#   'Roxicodone (TN)',
#   'Tarivid (TN)',
#   'Norvasc (TN)',
#   'Vistaril (TN)',
#   'Nouriast (TN)',
#   'Delatestryl (TN)',
#   'Domperidone (TN)',
#   'Bromperidol decanoate (USAN)',
#   'Tiamate (TN)',
#   'Etopophos preservative free (TN)',
#   'Nexavar (TN)',
#   'Tafinlar (TN)',
#   'Colircusi Dexametasona (TN)',
#   'Quinine (TN)',
#   'Intermezzo (TN)',
#   'Andriol (TN)',
#   'Hydrocortisone caproate (JAN)',
#   'Innopran XL (TN)',
#   'Cevimeline (INN)',
#   'Lusutrombopag (JAN/USAN/INN)',
#   'Dexlansoprazole (INN/USAN)',
#   'Lixiana (TN)',
#   'Aimix (TN)',
#   'Zoloft (TN)',
#   'Zytiga (TN)',
#   'Cardiovasc (TN)',
#   'Voren [veterinary] (TN)',
#   'Bromocriptine (USAN/INN)',
#   'Mobic (TN)',
#   'Amnoid (TN)',
#   'Nilotinib (USAN/INN)',
#   'Votrient (TN)',
#   'Plendil (TN)',
#   'Biaxin (TN)',
#   'Pavinal (TN)',
#   'Restoril (TN)',
#   'Aczone (TN)',
#   'Atelec (TN)',
#   'Xalkori (TN)',
#   'Dilt-CD (TN)',
#   'Unisia (TN)',
#   'Xenazine (TN)',
#   'Seldane (TN)',
#   'Floxin (TN)',
#   'Plenadren (TN)',
#   'Marex (TN)',
#   'Viagra (TN)',
#   'Lipitor (TN)',
#   'Lunesta (TN)',
#   'Adcetris (TN)',
#   'Cortifoam (TN)',
#   'Serotone (TN)',
#   'Medrol (TN)',
#   'Reflex (TN)',
#   'Cerivastatin (INN)',
#   'Lexapro (TN)',
#   'Aripiprazole monohydrate',
#   'Depakote (TN)',
#   'Advantan (TN)',
#   'Ketek (TN)',
#   'Sanval (TN)',
#   'Ultane (TN)',
#   'Halaven (TN)',
#   'Mictonorm (TN)',
#   'Zalutia (TN)',
#   'Vindesine (USAN/INN)',
#   'Vinblastina (TN)',
#   'Lansap (TN)',
#   'Omepral (TN)',
#   'Rizaben (TN)',
#   'Aripiprazole cavoxil (USAN)',
#   'Eliglustat tartrate (JAN/USAN)',
#   'Ergomar (TN)',
#   'Gelnique (TN)',
#   'Mucosta (TN)',
#   'Mycobutin (TN)',
#   'Maxidex (TN)',
#   'Neosar (TN)',
#   'Cardioquin (TN)',
#   'Singulair (TN)',
#   'Kadcyla (TN)',
#   'Mometasone (INN)',
#   'Orlaam (TN)',
#   'Surazem (TN)',
#   'Xylocaine (TN)',
#   'Bepadin (TN)',
#   'Dopram (TN)',
#   'Incivo (TN)',
#   'Tridione (TN)',
#   'Amanda (TN)',
#   'Innovar (TN)',
#   'Ergometrine (TN)',
#   'Testocaps (TN)',
#   'Sortis (TN)',
#   'Proscar (TN)',
#   'Amerge (TN)',
#   'Velcade (TN)',
#   'Dextromethorphan (USP)',
#   'Fosamprenavir (INN)',
#   'Methergine (TN)',
#   'Onfi (TN)',
#   'Amnestrogen (TN)',
#   'Orap (TN)',
#   'Levomethadone (INN)',
#   'Sorafenib (USAN/INN)',
#   'Quinine ethylcarbonate (TN)',
#   'Provigil (TN)',
#   'Tandospirone (INN)',
#   'Cinacalcet (USAN)',
#   'Daklinza (TN)',
#   'Hydrocortisone succinate (JP17)',
#   'Medicon (TN)',
#   'Arcapta neohaler (TN)',
#   'Artedil (TN)',
#   'Pandel (TN)',
#   'Fluvas (TN)',
#   'Zofran (TN)'],
#  'CYP3A5': ['Dexamedium [veterinary] (TN)',
#   'Oralet (TN)',
#   'Propulsid (TN)',
#   'Procardia (TN)',
#   'Haldol (TN)',
#   'Cortone acetate (TN)',
#   'Verapamil (USAN/INN)',
#   'Subsys (TN)',
#   'Dexafort [veterinary] (TN)',
#   'Cisapride (USAN/INN)',
#   'Solu-cortef (TN)',
#   'Hismanal (TN)',
#   'Aphrodil (TN)',
#   'Emend (TN)',
#   'Seroquel (TN)',
#   'Westcort (TN)',
#   'Volibris (TN)',
#   'Desyrel (TN)',
#   'Decadron-phosphate (TN)',
#   'Invirase (TN)',
#   'Testosterone phenylacetate (USAN)',
#   'Salmeterol (USAN/INN)',
#   'Testanon 50 (TN)',
#   'Naramig (TN)',
#   'Baypress (TN)',
#   'Testosterone ketolaurate (USAN/INN)',
#   'Campto (TN)',
#   'Clofeniramina (TN)',
#   'Geodon (TN)',
#   'Efficort (TN)',
#   'Indinavir hydrate',
#   'Zipradon (TN)',
#   'Coco-quinine (TN)',
#   'Crixivan (TN)',
#   'Sonata (TN)',
#   'Zalucs (TN)',
#   'Quinine hydrochloride (TN)',
#   'Dexamethasone beloxil (USAN)',
#   'inhibin (TN)',
#   'Hydrocortone phosphate (TN)',
#   'Sandimmune (TN)',
#   'Glivec (TN)',
#   'Eliquis (TN)',
#   'Lusefi (TN)',
#   'Depo-testosterone (TN)',
#   'Avodart (TN)',
#   'Trittico (TN)',
#   'Vistaril pamoate (TN)',
#   'Locoid (TN)',
#   'Decadronal (TN)',
#   'Dexamethasone acefurate (USAN/INN)',
#   'Respia (TN)',
#   'Motilium (TN)',
#   'Teldrin (TN)',
#   'Hifmeta (TN)',
#   'Polaramine (TN)',
#   'Decaject-L.A. (TN)',
#   'Hydrocortisone hemisuccinate (USP)',
#   'Tyverb (TN)',
#   'Dexpropranolol hydrochloride (USAN)',
#   'Glamox (TN)',
#   'Dapriton (TN)',
#   'Verelan (TN)',
#   'Limethason (TN)',
#   'Cafcit (TN)',
#   'Xarelto (TN)',
#   'Lercanil (TN)',
#   'Norsic (TN)',
#   'Olanedine (TN)',
#   'Dexamethasone cipecilate (JAN/INN)',
#   'Hydrocortisone cypionate',
#   'Propranolol (TN)',
#   'Fortovase (TN)',
#   'Kinder Quinina (TN)',
#   'Mevacor (TN)',
#   'Biotecan (TN)',
#   'Starsis (TN)',
#   'Testex (TN)',
#   'Caffeine (TN)',
#   'Serevent (TN)',
#   'Quinine biascorbate',
#   'Lapatinib (INN)',
#   'Inlyta (TN)',
#   'Amvaz (TN)',
#   'Cortisone (TN)',
#   'Santeson (TN)',
#   'Testim (TN)',
#   'Halomonth (TN)',
#   'Voalla ointment (TN)',
#   'Norvasc (TN)',
#   'Vistaril (TN)',
#   'Nouriast (TN)',
#   'Delatestryl (TN)',
#   'Domperidone (TN)',
#   'Tiamate (TN)',
#   'Colircusi Dexametasona (TN)',
#   'Quinine (TN)',
#   'Andriol (TN)',
#   'Hydrocortisone caproate (JAN)',
#   'Innopran XL (TN)',
#   'Cardiovasc (TN)',
#   'Voren [veterinary] (TN)',
#   'Plendil (TN)',
#   'Xalkori (TN)',
#   'Dilt-CD (TN)',
#   'Seldane (TN)',
#   'Plenadren (TN)',
#   'Marex (TN)',
#   'Viagra (TN)',
#   'Cortifoam (TN)',
#   'Ketek (TN)',
#   'Gelnique (TN)',
#   'Maxidex (TN)',
#   'Kadcyla (TN)',
#   'Surazem (TN)',
#   'Dopram (TN)',
#   'Testocaps (TN)',
#   'Amerge (TN)',
#   'Orap (TN)',
#   'Quinine ethylcarbonate (TN)',
#   'Hydrocortisone succinate (JP17)',
#   'Pandel (TN)'],
#  'CYP3A7': ['Dexamedium [veterinary] (TN)',
#   'Oralet (TN)',
#   'Erythromycin propionate (USAN)',
#   'Propulsid (TN)',
#   'Haldol (TN)',
#   'Verapamil (USAN/INN)',
#   'Subsys (TN)',
#   'Dexafort [veterinary] (TN)',
#   'Cisapride (USAN/INN)',
#   'Solu-cortef (TN)',
#   'Erythrocin W (TN)',
#   'Hismanal (TN)',
#   'Aphrodil (TN)',
#   'Emend (TN)',
#   'Seroquel (TN)',
#   'Westcort (TN)',
#   'Ilotycin gluceptate (TN)',
#   'Desyrel (TN)',
#   'Decadron-phosphate (TN)',
#   'Invirase (TN)',
#   'Testosterone phenylacetate (USAN)',
#   'Erythrocin (TN)',
#   'Salmeterol (USAN/INN)',
#   'Testanon 50 (TN)',
#   'Baypress (TN)',
#   'Testosterone ketolaurate (USAN/INN)',
#   'Campto (TN)',
#   'Clofeniramina (TN)',
#   'Geodon (TN)',
#   'Efficort (TN)',
#   'Indinavir hydrate',
#   'Zipradon (TN)',
#   'T-stat (TN)',
#   'Coco-quinine (TN)',
#   'Crixivan (TN)',
#   'Sonata (TN)',
#   'Zalucs (TN)',
#   'Quinine hydrochloride (TN)',
#   'Dexamethasone beloxil (USAN)',
#   'inhibin (TN)',
#   'Hydrocortone phosphate (TN)',
#   'Ilosone (TN)',
#   'Sandimmune (TN)',
#   'Depo-testosterone (TN)',
#   'Trittico (TN)',
#   'Locoid (TN)',
#   'Decadronal (TN)',
#   'Dexamethasone acefurate (USAN/INN)',
#   'Erysec (TN)',
#   'Respia (TN)',
#   'Motilium (TN)',
#   'Teldrin (TN)',
#   'Hifmeta (TN)',
#   'Polaramine (TN)',
#   'Decaject-L.A. (TN)',
#   'Hydrocortisone hemisuccinate (USP)',
#   'Dexpropranolol hydrochloride (USAN)',
#   'Erythromycin salnacedin dihydrate',
#   'Dapriton (TN)',
#   'Verelan (TN)',
#   'Limethason (TN)',
#   'Cafcit (TN)',
#   'Lercanil (TN)',
#   'Norsic (TN)',
#   'Dexamethasone cipecilate (JAN/INN)',
#   'Hydrocortisone cypionate',
#   'Propranolol (TN)',
#   'Fortovase (TN)',
#   'Kinder Quinina (TN)',
#   'Mevacor (TN)',
#   'Biotecan (TN)',
#   'Starsis (TN)',
#   'Testex (TN)',
#   'Caffeine (TN)',
#   'Serevent (TN)',
#   'Quinine biascorbate',
#   'Erasis (TN)',
#   'Amvaz (TN)',
#   'Santeson (TN)',
#   'Testim (TN)',
#   'Halomonth (TN)',
#   'Voalla ointment (TN)',
#   'Norvasc (TN)',
#   'Delatestryl (TN)',
#   'Domperidone (TN)',
#   'Tiamate (TN)',
#   'Colircusi Dexametasona (TN)',
#   'Quinine (TN)',
#   'Andriol (TN)',
#   'Hydrocortisone caproate (JAN)',
#   'Innopran XL (TN)',
#   'Cardiovasc (TN)',
#   'Voren [veterinary] (TN)',
#   'Plendil (TN)',
#   'Dilt-CD (TN)',
#   'Seldane (TN)',
#   'Plenadren (TN)',
#   'Viagra (TN)',
#   'Cortifoam (TN)',
#   'Ketek (TN)',
#   'Maxidex (TN)',
#   'Surazem (TN)',
#   'Testocaps (TN)',
#   'Orap (TN)',
#   'Quinine ethylcarbonate (TN)',
#   'Hydrocortisone succinate (JP17)',
#   'Pandel (TN)'],
#  'CYP4A11': ['Lusefi (TN)', 'Deberza (TN)', 'Lusutrombopag (JAN/USAN/INN)'],
#  'CYP4B1': ['Versed (TN)', 'Midazolam maleate (USAN)', 'Buccolam (TN)'],
#  'CYP4F12': ['Olanedine (TN)'],
#  'CYP4F2': ['Lusefi (TN)'],
#  'DBH': ['Nepicastat hydrochloride monohydrate'],
#  'DDC': ['Benserazide hydrochloride (JP17)',
#   'Lodosyn (TN)',
#   'Aldomet (TN)',
#   'Benserazide (USAN/INN)'],
#  'DGAT1': ['Pradigastat sodium (USAN)', 'Pradigastat (USAN)'],
#  'DHFR': ['Edatrexate (USAN/INN)',
#   'Trimetrexate (USAN/INN)',
#   'Neutrexin (TN)',
#   'Folotyn (TN)',
#   'Trexall (TN)',
#   'Otrexup (TN)'],
#  'DHODH': ['Arava (TN)', 'Aubagio (TN)', 'Brequinar sodium (USAN)'],
#  'DIO1': ['Basdene (TN)', 'Thimecil (TN)', 'Propylthiouracil (TN)'],
#  'DIO2': ['Basdene (TN)', 'Thimecil (TN)', 'Propylthiouracil (TN)'],
#  'DPEP1': ['CS', 'Cilastatin (INN)'],
#  'DPYD': ['Fluoroplex (TN)',
#   'Eniluracil (USAN/INN)',
#   'Fluorouracil (TN)',
#   'Gimeracil (JAN/INN)'],
#  'EGFR': ['Portrazza (TN)',
#   'Varlitinib tosylate (USAN)',
#   'Vectibix (TN)',
#   'Zalutumumab (USAN/INN)',
#   'Dacomitinib hydrate (JAN)',
#   'Pelitinib (USAN/INN)',
#   'Neratinib (USAN/INN)',
#   'Caprelsa (TN)',
#   'Tyverb (TN)',
#   'Erlotinib (INN)',
#   'Imgatuzumab (USAN/INN)',
#   'Tagrisso (TN)',
#   'Lapatinib (INN)',
#   'Tarceva (TN)',
#   'Iressa (TN)',
#   'Varlitinib (USAN/INN)',
#   'Olmutinib (INN)',
#   'Giotrif (TN)',
#   'Erbitux (TN)',
#   'Afatinib (USAN/INN)',
#   'Dacomitinib (USAN/INN)',
#   'Rociletinib (USAN/INN)',
#   'Canertinib dihydrochloride (USAN)'],
#  'EPHA2': ['Dasatinib (INN)', 'Sprycel (TN)'],
#  'ERBB2': ['Varlitinib tosylate (USAN)',
#   'Mubritinib (USAN/INN)',
#   'Herceptin (TN)',
#   'Dacomitinib hydrate (JAN)',
#   'Neratinib (USAN/INN)',
#   'Perjeta (TN)',
#   'Neuvenge (TN)',
#   'Tyverb (TN)',
#   'Neuvax',
#   'Margetuximab (USAN)',
#   'Lapatinib (INN)',
#   'Varlitinib (USAN/INN)',
#   'Giotrif (TN)',
#   'Afatinib (USAN/INN)',
#   'Dacomitinib (USAN/INN)',
#   'Kadcyla (TN)',
#   'Canertinib dihydrochloride (USAN)'],
#  'ERBB3': ['Canertinib dihydrochloride (USAN)'],
#  'ERBB4': ['Varlitinib tosylate (USAN)',
#   'Dacomitinib hydrate (JAN)',
#   'Varlitinib (USAN/INN)',
#   'Dacomitinib (USAN/INN)',
#   'Canertinib dihydrochloride (USAN)'],
#  'FDPS': ['Alendronic acid (INN)',
#   'Ibandronic acid (INN)',
#   'Ridron (TN)',
#   'Ribodroat (TN)',
#   'Reclast (TN)',
#   'Fosamax (TN)',
#   'Actonel (TN)',
#   'Zoledronic acid hemipentahydrate (JAN)',
#   'Bisphonal (TN)',
#   'Incadronic acid (INN)',
#   'Recalbon (TN)',
#   'Zoledronate trisodium hydrate',
#   'Bonviva (TN)',
#   'Zometa (TN)',
#   'Zoledronate disodium hydrate',
#   'Aredia (TN)'],
#  'FGFR1': ['Ofev (TN)',
#   'Stivarga (TN)',
#   'Dovitinib lactate hydrate (JAN)',
#   'Brivanib alaninate (JAN/USAN/INN)',
#   'Brivanib (USAN)'],
#  'FGFR2': ['Ofev (TN)',
#   'Dovitinib lactate hydrate (JAN)',
#   'Brivanib alaninate (JAN/USAN/INN)',
#   'Brivanib (USAN)'],
#  'FGFR3': ['Dovitinib lactate hydrate (JAN)'],
#  'FLT3': ['Gilteritinib (USAN/INN)',
#   'Toceranib phosphate (USAN)',
#   'Quizartinib dihydrochloride (USAN)',
#   'Toceranib (USAN)',
#   'Ofev (TN)',
#   'Tozasertib (USAN)',
#   'Sutent (TN)',
#   'Gilteritinib fumarate (JAN/USAN)',
#   'MK-0457',
#   'Midostaurin (USAN/INN)',
#   'Semaxanib (USAN/INN)',
#   'Sunitinib (INN)',
#   'Nexavar (TN)',
#   'Tandutinib (USAN/INN)',
#   'Quizartinib (USAN/INN)',
#   'Lestaurtinib (USAN/INN)',
#   'Sorafenib (USAN/INN)'],
#  'GAA': ['Precose (TN)', 'Basen (TN)', 'Emiglitate (JAN/INN)', 'Glyset (TN)'],
#  'GANC': ['Precose (TN)', 'Basen (TN)', 'Emiglitate (JAN/INN)', 'Glyset (TN)'],
#  'GART': ['Pelitrexol (USAN/INN)',
#   'Alimta (TN)',
#   'Pemetrexed accord (TN)',
#   'Pemetrexed (TN)'],
#  'GCK': ['Piragliatin (USAN)'],
#  'GSTP1': ['Ezatiostat hydrochloride (USAN)'],
#  'GUCY2C': ['Linaclotide acetate (USAN)',
#   'Linaclotide acetate (USAN)',
#   'Constella (TN)',
#   'Constella (TN)',
#   'Plecanatide (USAN/INN)',
#   'Plecanatide (USAN/INN)'],
#  'HMGCR': ['Lescol (TN)',
#   'Pitavastatin calcium hydrate (JP17)',
#   'Zocor (TN)',
#   'Baycol (TN)',
#   'Livalo (TN)',
#   'Crilvastatin (USAN/INN)',
#   'Pravachol (TN)',
#   'Mevacor (TN)',
#   'Creston (TN)',
#   'Crestor (TN)',
#   'Pravator (TN)',
#   'Dalvastatin (USAN/INN)',
#   'Lipitor (TN)',
#   'Cerivastatin (INN)',
#   'Tenivastatin calcium (USAN)',
#   'Sortis (TN)',
#   'Fluvas (TN)'],
#  'HPD': ['Orfadin (TN)'],
#  'HSD11B1': ['Carbenoxolone (INN)',
#   'Carbenoxolone sodium (JAN/USAN)',
#   'Hidermart (TN)'],
#  'IGF1R': ['Linsitinib (USAN/INN)',
#   'Ganitumab (USAN/INN)',
#   'Dalotuzumab (USAN)',
#   'Teprotumumab (USAN/INN)',
#   'Cixutumumab (USAN)',
#   'Myotrophin (TN)',
#   'Robatumumab (USAN/INN)',
#   'Figitumumab (USAN)',
#   'Iplex (TN)'],
#  'INSR': ['Lente iletin (TN)',
#   'Insulin human zinc (USP)',
#   'Lantus (TN)',
#   'Proinsulin human (USAN)',
#   'Insulin Humacart (TN)',
#   'Imusay-125 (TN)',
#   'Neutral insulin injection (INN)',
#   'Ultralente iletin (TN)',
#   'Apidra (TN)',
#   'Semilente iletin (TN)',
#   'Insulin (JAN/USP)',
#   'Tresiba (TN)',
#   'Insulin human zinc, extended (USP)',
#   'Humalog PEN (TN)',
#   'Levemir (TN)',
#   'Novolog (TN)',
#   'Humulin (TN)',
#   'Insulin peglispro (USAN/INN)',
#   'Imusay-131 (TN)',
#   'Insulin, dalanated (USAN)',
#   'Insulin human, isophane (USP)',
#   'Humalog (TN)'],
#  'JAK1': ['Oclacitinib (USAN)',
#   'Ruxolitinib (USAN/INN)',
#   'Momelotinib (USAN/INN)',
#   'Filgotinib (USAN/INN)',
#   'Baricitinib (JAN/USAN/INN)',
#   'Filgotinib hydrochloride (USAN)',
#   'Jakavi (TN)',
#   'Peficitinib (USAN/INN)',
#   'Oclacitinib maleate (USAN)',
#   'Solcitinib (USAN/INN)',
#   'Peficitinib hydrobromide (USAN)',
#   'Momelotinib dihydrochloride (USAN)'],
#  'JAK2': ['Ruxolitinib (USAN/INN)',
#   'Momelotinib (USAN/INN)',
#   'Tozasertib (USAN)',
#   'Baricitinib (JAN/USAN/INN)',
#   'Fedratinib (USAN/INN)',
#   'Jakavi (TN)',
#   'Peficitinib (USAN/INN)',
#   'MK-0457',
#   'Gandotinib (USAN)',
#   'Peficitinib hydrobromide (USAN)',
#   'Momelotinib dihydrochloride (USAN)',
#   'Lestaurtinib (USAN/INN)'],
#  'JAK3': ['Baricitinib (JAN/USAN/INN)',
#   'Peficitinib (USAN/INN)',
#   'Adelatinib',
#   'Xeljanz (TN)',
#   'Tasocitinib',
#   'Peficitinib hydrobromide (USAN)'],
#  'KIT': ['Cediranib (USAN/INN)',
#   'Motesanib phosphate (JAN)',
#   'Toceranib phosphate (USAN)',
#   'Amuvatinib hydrochloride (USAN)',
#   'Tasigna (TN)',
#   'Cometriq (TN)',
#   'Glivec (TN)',
#   'Amuvatinib (USAN/INN)',
#   'Toceranib (USAN)',
#   'Dasatinib (INN)',
#   'AMG 706',
#   'Glamox (TN)',
#   'Sutent (TN)',
#   'Sprycel (TN)',
#   'Inlyta (TN)',
#   'Midostaurin (USAN/INN)',
#   'Semaxanib (USAN/INN)',
#   'Sunitinib (INN)',
#   'Cediranib maleate (JAN/USAN)',
#   'Nexavar (TN)',
#   'Nilotinib (USAN/INN)',
#   'Votrient (TN)',
#   'Tandutinib (USAN/INN)',
#   'Vatalanib (USAN/INN)',
#   'Masitinib (INN)',
#   'Sorafenib (USAN/INN)'],
#  'LCAT': ['Elaszym (TN)'],
#  'LPL': ['Elaszym (TN)',
#   'MDS-Kowa A (TN)',
#   'Ibrolipim (USAN/INN)',
#   'Omacor (TN)',
#   'MDS (TN)'],
#  'LSS': ['Lapaquistat acetate (JAN/USAN)'],
#  'LYN': ['Bafetinib (USAN)'],
#  'MAOA': ['Clorgyline',
#   'Aurorix (TN)',
#   'Zomig (TN)',
#   '(+/-)-Noradrenaline hydrochloride',
#   'Levophed (TN)',
#   'Arterenol (TN)',
#   'Zecutity (TN)',
#   'Humoryl (TN)',
#   'Cimoxatone (INN)',
#   'Minaprine hydrochloride (USAN)',
#   'Implementor (TN)',
#   'Maxalt (TN)',
#   'Consonar (TN)',
#   'Cantor (TN)',
#   'Rizatriptan sulfate (USAN)',
#   'Nor adrenalin (TN)',
#   'Imitrex (TN)',
#   'Pyrazidol (TN)',
#   'Befloxatone (INN)'],
#  'MAOB': ['Eldepryl (TN)',
#   'Intropin (TN)',
#   'Azilect (TN)',
#   'Mofegiline hydrochloride (USAN)',
#   'Milacemide hydrochloride (USAN)',
#   'Medopa (TN)',
#   'Rasagiline (TN)',
#   'Emsam (TN)',
#   'Safinamide (USAN/INN)',
#   'Lazabemide (USAN/INN)',
#   'Tempium (TN)',
#   'Xadago (TN)'],
#  'MET': ['Tivantinib (JAN/USAN/INN)',
#   'Foretinib (USAN/INN)',
#   'Golvatinib (USAN)',
#   'Altiratinib (USAN)',
#   'Onartuzumab (genetical recombination) (JAN)',
#   'Capmatinib (USAN/INN)',
#   'Golvatinib tartrate (USAN)'],
#  'MGAM': ['Precose (TN)', 'Basen (TN)', 'Emiglitate (JAN/INN)', 'Glyset (TN)'],
#  'MTTP': ['Lojuxta (TN)',
#   'Lomitapide (USAN/INN)',
#   'Slentrol [veterinary] (TN)'],
#  'NAE1': ['Pevonedistat hydrochloride (USAN)', 'Pevonedistat (USAN)'],
#  'NPC1L1': ['Zetia (TN)'],
#  'NPR1': ['Hanp (TN)', 'Nesiritide citrate (USAN)', 'Natrecor (TN)'],
#  'NQO1': ['Choice (TN)',
#   'Jantoven (TN)',
#   'Athrombin-K (TN)',
#   'Ethyl biscoumacetate (INN)',
#   'Mini-sintrom (TN)'],
#  'NR1H4': ['Chenix (TN)', 'Ocaliva (TN)', 'Turofexorate isopropyl (USAN/INN)'],
#  'NR3C1': ['Dexamedium [veterinary] (TN)',
#   'Clocortolone acetate (USAN)',
#   'Hydeltra-TBA (TN)',
#   'Delta-cortef (TN)',
#   'Cortone acetate (TN)',
#   'Dexafort [veterinary] (TN)',
#   'Nasonex (TN)',
#   'Solu-cortef (TN)',
#   'Fluticaps (TN)',
#   'Prednisone 21-acetate',
#   'Cortivazol (USAN)',
#   'Sintisone (TN)',
#   'Westcort (TN)',
#   'Clocortolone (INN)',
#   'Celestone (TN)',
#   'Dagrocorat (USAN/INN)',
#   'Decadron-phosphate (TN)',
#   'Rinderon-V (TN)',
#   'Haldrone (TN)',
#   'Locorten (TN)',
#   'Veramyst (TN)',
#   'Depo-medrol (TN)',
#   'Aristospan (TN)',
#   'Methylprednisolone sodium phosphate (USAN)',
#   'Diflucortolone pivalate (USAN)',
#   'Fluocortolone (USAN/INN)',
#   'Flumetasone (INN)',
#   'Dermatop (TN)',
#   'Fluprednidene (INN)',
#   'Elocon (TN)',
#   'Efficort (TN)',
#   'Tixocortol (INN)',
#   'Olux (TN)',
#   'Resocortol (INN)',
#   'Zalucs (TN)',
#   'Dexamethasone beloxil (USAN)',
#   'Hydrocortone phosphate (TN)',
#   'Fluocortin (INN)',
#   'Dillar (TN)',
#   'Prednylidene (INN)',
#   'Beclometason (TN)',
#   'Cyclocort (TN)',
#   'Vanceril (TN)',
#   'Flarex (TN)',
#   'Cloderm (TN)',
#   'Antebate (TN)',
#   'Flunisolide acetate (USAN)',
#   'Haloart (TN)',
#   'Locoid (TN)',
#   'Resocortol butyrate (USAN)',
#   'Cortodoxone (USAN)',
#   'Decadronal (TN)',
#   'Deflazacort (USAN/INN)',
#   'Methylprednisolone succinate (JP17)',
#   'Dexamethasone acefurate (USAN/INN)',
#   'Decoderm (TN)',
#   'Verdeso (TN)',
#   'Uticort (TN)',
#   'Fluprednisolone valerate (USAN)',
#   'Hifmeta (TN)',
#   'Omnaris (TN)',
#   'Decaject-L.A. (TN)',
#   'HMS (TN)',
#   'Vexol (TN)',
#   'Loteprednol (INN)',
#   'Hydrocortisone hemisuccinate (USP)',
#   'Cordran (TN)',
#   'Spirazon (TN)',
#   'Rinderon-DP (TN)',
#   'Limethason (TN)',
#   'Fluclorolone acetonide (INN)',
#   'Cloradryn (TN)',
#   'Nasacort (TN)',
#   'Afusona (TN)',
#   'Tixocortol pivalate (USAN)',
#   'Clobecort Amex (TN)',
#   'Ultravate (TN)',
#   'Astonin-H (TN)',
#   'Synalar (TN)',
#   'Ultradil (TN)',
#   'Dexamethasone cipecilate (JAN/INN)',
#   'Hydrocortisone cypionate',
#   'Halometasone (INN)',
#   'Kohakusanin (TN)',
#   'Kenacort (TN)',
#   'Prednisolone succinate (JP17)',
#   'Alphadrol (TN)',
#   'Mapracorat (USAN)',
#   'Pred forte (TN)',
#   'Topicort (TN)',
#   'Murode (TN)',
#   'Durezol (TN)',
#   'Kindavate (TN)',
#   'Predenema (TN)',
#   'Farnerate (TN)',
#   'Meprednisone (USP/INN)',
#   'Cortisone (TN)',
#   'Ultracortenol (TN)',
#   'Santeson (TN)',
#   'Triamcinolone acetonide sodium phosphate (USAN)',
#   'Uceris (TN)',
#   'Methylprednisolone suleptanate (USAN/INN)',
#   'Fenicort (TN)',
#   'Solu-medrol (TN)',
#   'Fluocortin butyl (USAN)',
#   'Nasalide (TN)',
#   'Betamethasone acetate (JAN/USP)',
#   'Voalla ointment (TN)',
#   'Lotemax (TN)',
#   'Psorcon (TN)',
#   'Colircusi Dexametasona (TN)',
#   'Vanos (TN)',
#   'Hydrocortisone caproate (JAN)',
#   'Fluocortolone caproate (USAN)',
#   'Voren [veterinary] (TN)',
#   'Deflamene (TN)',
#   'Delvosteron [veterinary] (TN)',
#   'Oxylone (TN)',
#   'Flovent (TN)',
#   'Plenadren (TN)',
#   'Cortifoam (TN)',
#   'Medrol (TN)',
#   'Aclovate (TN)',
#   'Advantan (TN)',
#   'Clobetasone (INN)',
#   'Halopredone (INN)',
#   'Florinef acetate (TN)',
#   'Maxidex (TN)',
#   'Mometasone (INN)',
#   'Fosdagrocorat (USAN/INN)',
#   'Aristocort (TN)',
#   'Diflucortolone (USAN)',
#   'Halobetasol',
#   'Hydrocortisone succinate (JP17)',
#   'Alclometasone (INN)',
#   'Rayos (TN)',
#   'Pandel (TN)',
#   'Pediapred (TN)'],
#  'NTRK1': ['Lestaurtinib (USAN/INN)'],
#  'PDGFRA': ['Cediranib (USAN/INN)',
#   'Motesanib phosphate (JAN)',
#   'Toceranib phosphate (USAN)',
#   'Tasigna (TN)',
#   'Cometriq (TN)',
#   'Crenolanib (USAN)',
#   'Toceranib (USAN)',
#   'Ofev (TN)',
#   'Tovetumab (USAN)',
#   'AMG 706',
#   'Glamox (TN)',
#   'Sutent (TN)',
#   'Crenolanib besylate (USAN)',
#   'Ilorasertib (USAN)',
#   'Lartruvo (TN)',
#   'Sunitinib (INN)',
#   'Cediranib maleate (JAN/USAN)',
#   'Linifanib (USAN/INN)',
#   'Nilotinib (USAN/INN)',
#   'Votrient (TN)'],
#  'PDGFRB': ['Cediranib (USAN/INN)',
#   'Motesanib phosphate (JAN)',
#   'Regranex (TN)',
#   'Toceranib phosphate (USAN)',
#   'Tasigna (TN)',
#   'Cometriq (TN)',
#   'Crenolanib (USAN)',
#   'Toceranib (USAN)',
#   'Dasatinib (INN)',
#   'Ofev (TN)',
#   'AMG 706',
#   'Glamox (TN)',
#   'Sutent (TN)',
#   'Sprycel (TN)',
#   'Crenolanib besylate (USAN)',
#   'Stivarga (TN)',
#   'Ilorasertib (USAN)',
#   'Dovitinib lactate hydrate (JAN)',
#   'Inlyta (TN)',
#   'Midostaurin (USAN/INN)',
#   'Sunitinib (INN)',
#   'Cediranib maleate (JAN/USAN)',
#   'Linifanib (USAN/INN)',
#   'Nexavar (TN)',
#   'Nilotinib (USAN/INN)',
#   'Votrient (TN)',
#   'Tandutinib (USAN/INN)',
#   'Vatalanib (USAN/INN)',
#   'Sorafenib (USAN/INN)'],
#  'PIK3C3': ['Copanlisib (USAN/INN)',
#   'Safingol hydrochloride (USAN)',
#   'Zydelig (TN)',
#   'Safingol (USAN/INN)',
#   'Copanlisib hydrochloride hydrate (JAN)',
#   'Copanlisib hydrochloride (USAN)',
#   'Buparlisib hydrochloride (JAN/USAN)',
#   'Buparlisib (USAN/INN)'],
#  'PIK3CA': ['Apitolisib (USAN/INN)'],
#  'PIK3CD': ['Duvelisib (USAN/INN)'],
#  'PIK3CG': ['Duvelisib (USAN/INN)'],
#  'PLA2G4A': ['Giripladib (USAN)', 'Efipladib (USAN)', 'Ecopladib (USAN/INN)'],
#  'PLA2G7': ['Darapladib (JAN/USAN)',
#   'Goxalapladib (USAN)',
#   'Rilapladib (USAN)'],
#  'PLK1': ['Rigosertib sodium (JAN/USAN)',
#   'Rigosertib (USAN)',
#   'Volasertib hydrochloride (JAN)',
#   'Volasertib (USAN)'],
#  'PNLIP': ['Xenical (TN)'],
#  'PNP': ['Ulodesine hemisuccinate monohydrate',
#   'Forodesine hydrochloride (JAN/USAN)',
#   'Fodosine (TN)',
#   'Ulodesine (USAN)'],
#  'PRKCA': ['Affinitak (TN)', 'Midostaurin (USAN/INN)'],
#  'PRKCB': ['Safingol hydrochloride (USAN)',
#   'Enzastaurin hydrochloride (JAN/USAN)',
#   'Safingol (USAN/INN)'],
#  'PRKCD': ['Delcasertib (USAN/INN)',
#   'Safingol hydrochloride (USAN)',
#   'Delcasertib acetate',
#   'Sotrastaurin acetate (USAN)',
#   'Safingol (USAN/INN)',
#   'Sotrastaurin (USAN/INN)'],
#  'PRKCE': ['Safingol hydrochloride (USAN)',
#   'Sotrastaurin acetate (USAN)',
#   'Safingol (USAN/INN)',
#   'Sotrastaurin (USAN/INN)'],
#  'PRKCH': ['Sotrastaurin acetate (USAN)', 'Sotrastaurin (USAN/INN)'],
#  'PRKCQ': ['Sotrastaurin acetate (USAN)', 'Sotrastaurin (USAN/INN)'],
#  'PTGES': ['Aceclofenac (TN)'],
#  'PTGS1': ['Ponstel (TN)',
#   'Peon (TN)',
#   'Motrin (TN)',
#   'Ansaid (TN)',
#   'Ibuprofen sodium hydrate',
#   'Combec (TN)',
#   'Rimadyl (TN)',
#   'Nalfon (TN)',
#   'Mobidin (TN)',
#   'Voltaren (TN)',
#   'Neoprofen (TN)',
#   'Calmatel (TN)',
#   'Esflurbiprofen (JAN)',
#   'Minalfen (TN)',
#   'Flector (TN)',
#   'Yellox (TN)',
#   'Lodine (TN)',
#   'Piroxicam cinnamate (USAN)',
#   'Bruxel (TN)',
#   'Triparsean (TN)',
#   'Dexketoprofen (INN)',
#   'Tandearil (TN)',
#   'Superpyrin (TN)',
#   'Peralgin (TN)',
#   'Indocin I.V. (TN)',
#   'Elicapric (TN)',
#   'Nevanac (TN)',
#   'Salsonin (TN)',
#   'Oxyphenbutazone (TN)',
#   'Toradol (TN)',
#   'Etofenamate (USAN/INN)',
#   'Phenbutazone sodium glycerate (USAN)',
#   'Tolmetin (USAN/INN)',
#   'Orudis (TN)',
#   'Surgam (TN)',
#   'Naproxen etemesil (USAN)',
#   'Esprenit (TN)',
#   'Relafen (TN)',
#   'Tolectin (TN)',
#   'Miridacin (TN)',
#   'Tilcotil (TN)',
#   'Lorcam (TN)',
#   'Loxonin (TN)',
#   'Arthropan (TN)',
#   'Zipsor (TN)',
#   'Ropion (TN)',
#   'Aspirin aluminum (JP17)',
#   'Feldene (TN)',
#   'Piroxicam olamine (USAN)',
#   'Indocin (TN)',
#   'Anaprox (TN)',
#   'Artrosilene (TN)',
#   'Azolid (TN)',
#   'Loxoprofen (INN)',
#   'Voltaren Actingo Extra (TN)',
#   'Salicylamide (TN)',
#   'Aspegic (TN)',
#   'Dolobid (TN)',
#   'Fulgium (TN)',
#   'Clotam (TN)',
#   'Clinoril (TN)',
#   'Amfenac (INN)',
#   'Flucam (TN)',
#   'Meclomen (TN)',
#   'Disalcid (TN)',
#   'Staderm (TN)',
#   'Naprosyn (TN)',
#   'Apo-Benzydamine (TN)',
#   'Daypro (TN)',
#   'Notras (TN)',
#   'Meclofenamic acid (USAN/INN)',
#   'Bromfenac (INN)',
#   'Mofezolac (TN)',
#   'Magan (TN)',
#   'Piroxicam betadex (USAN)',
#   'Fenoprofen (USAN/INN)',
#   'Doctrin (TN)',
#   'Felbinac (TN)',
#   'Catalgine (TN)',
#   'Pamicogrel (JAN/INN)',
#   'Zafen (TN)',
#   'Mobic (TN)',
#   'Ambene (TN)',
#   'Indobufen (INN)',
#   'Tantum (TN)',
#   'Ibuprofen aluminum (USAN)',
#   'Rantudil (TN)',
#   'LM 001',
#   'Dexibuprofen (USAN/INN)',
#   'Pravadoline maleate (USAN)',
#   'Voltaren Emulgel (TN)',
#   'Fenazox (TN)',
#   'Arlef (TN)',
#   'Opyrin (TN)',
#   'Zorvolex (TN)',
#   'Equioxx (TN) [veterinary]',
#   'Triflusal (INN)',
#   'Infree (TN)',
#   'Idarac (TN)',
#   'Easprin (TN)',
#   'Ocufen (TN)'],
#  'PTGS2': ['Nimesulide (JAN/INN)',
#   'Ponstel (TN)',
#   'Peon (TN)',
#   'Motrin (TN)',
#   'Ansaid (TN)',
#   'Ibuprofen sodium hydrate',
#   'Combec (TN)',
#   'Rimadyl (TN)',
#   'Nalfon (TN)',
#   'Mobidin (TN)',
#   'Voltaren (TN)',
#   'Neoprofen (TN)',
#   'Calmatel (TN)',
#   'Esflurbiprofen (JAN)',
#   'Minalfen (TN)',
#   'Vioxx (TN)',
#   'Flector (TN)',
#   'Parecoxib (USAN/INN)',
#   'Yellox (TN)',
#   'Mavacoxib (USAN)',
#   'Lodine (TN)',
#   'Piroxicam cinnamate (USAN)',
#   'Bruxel (TN)',
#   'Triparsean (TN)',
#   'Dexketoprofen (INN)',
#   'Deracoxib (USAN)',
#   'Tandearil (TN)',
#   'Superpyrin (TN)',
#   'Peralgin (TN)',
#   'Indocin I.V. (TN)',
#   'Elicapric (TN)',
#   'Nevanac (TN)',
#   'Salsonin (TN)',
#   'Oxyphenbutazone (TN)',
#   'Toradol (TN)',
#   'Etofenamate (USAN/INN)',
#   'Phenbutazone sodium glycerate (USAN)',
#   'Tolmetin (USAN/INN)',
#   'Orudis (TN)',
#   'Surgam (TN)',
#   'Naproxen etemesil (USAN)',
#   'Esprenit (TN)',
#   'Niflugel (TN)',
#   'Relafen (TN)',
#   'Tolectin (TN)',
#   'Miridacin (TN)',
#   'Tilmacoxib (JAN/USAN/INN)',
#   'Tilcotil (TN)',
#   'Lorcam (TN)',
#   'Loxonin (TN)',
#   'Arthropan (TN)',
#   'Zipsor (TN)',
#   'Ropion (TN)',
#   'Aspirin aluminum (JP17)',
#   'Telzenac (TN)',
#   'Feldene (TN)',
#   'Bextra (TN)',
#   'Piroxicam olamine (USAN)',
#   'Indocin (TN)',
#   'Anaprox (TN)',
#   'Artrosilene (TN)',
#   'Azolid (TN)',
#   'Loxoprofen (INN)',
#   'Voltaren Actingo Extra (TN)',
#   'Salicylamide (TN)',
#   'Aspegic (TN)',
#   'Dolobid (TN)',
#   'Fulgium (TN)',
#   'Clotam (TN)',
#   'Clinoril (TN)',
#   'Amfenac (INN)',
#   'Flucam (TN)',
#   'Meclomen (TN)',
#   'Disalcid (TN)',
#   'Staderm (TN)',
#   'Naprosyn (TN)',
#   'Apo-Benzydamine (TN)',
#   'Daypro (TN)',
#   'Aceclofenac (TN)',
#   'Notras (TN)',
#   'Meclofenamic acid (USAN/INN)',
#   'Bromfenac (INN)',
#   'Polmacoxib (USAN/INN)',
#   'Etoricoxib (USAN/INN)',
#   'Magan (TN)',
#   'Piroxicam betadex (USAN)',
#   'Fenoprofen (USAN/INN)',
#   'Doctrin (TN)',
#   'Felbinac (TN)',
#   'Catalgine (TN)',
#   'Pamicogrel (JAN/INN)',
#   'Zafen (TN)',
#   'Mobic (TN)',
#   'Ambene (TN)',
#   'Indobufen (INN)',
#   'Tantum (TN)',
#   'Lumiracoxib (USAN/INN)',
#   'Ibuprofen aluminum (USAN)',
#   'Rantudil (TN)',
#   'LM 001',
#   'Dexibuprofen (USAN/INN)',
#   'Pravadoline maleate (USAN)',
#   'Voltaren Emulgel (TN)',
#   'Fenazox (TN)',
#   'Arlef (TN)',
#   'Opyrin (TN)',
#   'Dynastat (TN)',
#   'Zorvolex (TN)',
#   'Equioxx (TN) [veterinary]',
#   'Infree (TN)',
#   'Idarac (TN)',
#   'Easprin (TN)',
#   'Ocufen (TN)',
#   'Onsenal (TN)',
#   'Apricoxib (USAN/INN)',
#   'Darbufelone mesylate (USAN)'],
#  'PTK2B': ['Defactinib hydrochloride (USAN)', 'Defactinib (USAN/INN)'],
#  'PTPN1': ['Ertiprotafib (USAN/INN)'],
#  'RET': ['Motesanib phosphate (JAN)',
#   'Cometriq (TN)',
#   'Lenvima (TN)',
#   'AMG 706',
#   'Sutent (TN)',
#   'Lenvatinib (USAN/INN)',
#   'Sunitinib (INN)'],
#  'RNPEP': ['Bestatin (TN)'],
#  'RRM1': ['Gemzar (TN)',
#   'Gemcitabine (USAN/INN)',
#   'Caracemide (USAN)',
#   'Gemcitabine elaidate (USAN/INN)'],
#  'RRM2': ['Hydrea (TN)'],
#  'SLC12A1': ['Diart (TN)',
#   'Torem (TN)',
#   'Arelix (TN)',
#   'Lasix (TN)',
#   'Ethacrynate sodium (USP)',
#   'Bumex (TN)',
#   'Normonal (TN)',
#   'M17055',
#   'Nuriban (TN)',
#   'Muzolimine (USAN/INN)',
#   'Etacrynic acid (JP17/INN)',
#   'Luprac (TN)',
#   'Selacryn (TN)'],
#  'SLC12A2': ['Diart (TN)',
#   'Torem (TN)',
#   'Arelix (TN)',
#   'Lasix (TN)',
#   'Ethacrynate sodium (USP)',
#   'Bumex (TN)',
#   'Normonal (TN)',
#   'M17055',
#   'Nuriban (TN)',
#   'Muzolimine (USAN/INN)',
#   'Etacrynic acid (JP17/INN)',
#   'Luprac (TN)',
#   'Selacryn (TN)'],
#  'SLC18A1': ['Valbenazine (USAN/INN)',
#   'Tedatioxetine (USAN)',
#   'Serpalan (TN)',
#   'Tedatioxetine hydrobromide (USAN)'],
#  'SLC18A2': ['Valbenazine (USAN/INN)',
#   'Tedatioxetine (USAN)',
#   'Serpalan (TN)',
#   'Xenazine (TN)',
#   'Deutetrabenazine (USAN/INN)',
#   'Tedatioxetine hydrobromide (USAN)'],
#  'SLC22A1': ['Glucophage (TN)', 'Eloxatin (TN)', 'Metformin (USAN/INN)'],
#  'SLC22A2': ['Coco-quinine (TN)',
#   'Quinine hydrochloride (TN)',
#   'Pramipexole (USAN/INN)',
#   'Zyrtec (TN)',
#   'Mirapex (TN)',
#   'Kinder Quinina (TN)',
#   'Quinine biascorbate',
#   'Quinine (TN)',
#   'Cetiderm (TN)',
#   'Quinine ethylcarbonate (TN)'],
#  'SLC22A3': ['Procainamide (INN)',
#   'Quinidex (TN)',
#   'Kinidin (TN)',
#   'Pronestyl (TN)',
#   'Natisedine (TN)',
#   'Quinaglute (TN)',
#   'Cardioquin (TN)'],
#  'SLC29A1': ['Purinethol (TN)',
#   'Irutep (TN)',
#   'Persantine (TN)',
#   'Dilazep (INN)'],
#  'SLC29A2': ['Purinethol (TN)'],
#  'SLC47A1': ['Glucophage (TN)', 'Metformin (USAN/INN)'],
#  'SLC5A2': ['Ertugliflozin (USAN/INN)',
#   'Remogliflozin etabonate (USAN/INN)',
#   'Jardiance (TN)',
#   'Farxiga (TN)',
#   'Ipragliflozin (INN)',
#   'Invokana (TN)',
#   'Lusefi (TN)',
#   'Forxiga (TN)',
#   'Deberza (TN)',
#   'Sotagliflozin (USAN/INN)',
#   'Suglat (TN)',
#   'Sergliflozin',
#   'Bexagliflozin (USAN)'],
#  'SLC6A1': ['Gabitril (TN)'],
#  'SLC6A2': ['Pamelor (TN)',
#   'Nortrilen (TN)',
#   'Asendin (TN)',
#   'Amfetamin (TN)',
#   'Nisoxetine (USAN/INN)',
#   'Dasotraline hydrochloride (USAN)',
#   'Merital (TN)',
#   'Imipraminoxide (INN)',
#   'Amitriptylinoxide (INN)',
#   'Meridia (TN)',
#   'Norpramin (TN)',
#   'Talopram hydrochloride (USAN)',
#   'Yentreve (TN)',
#   'Desipramine (INN)',
#   'Pyrovalerone hydrochloride (USAN)',
#   'Sanorex (TN)',
#   'Risumic (TN)',
#   'Lisdexamfetamine (INN)',
#   'Centanafadine hydrochloride (USAN)',
#   'Amitifadine hydrochloride (USAN)',
#   'Tofranil-pm (TN)',
#   'Desoxyn (TN)',
#   'Milnacipran (INN)',
#   'Esreboxetine succinate (USAN)',
#   'Dextrostat (TN)',
#   'Laroxyl (TN)',
#   'Effexor (TN)',
#   'Dothep (TN)',
#   'Strattera (TN)',
#   'Edivoxetine (USAN/INN)',
#   'Tomoxetine',
#   'Tofranil (TN)',
#   'Elvanse (TN)',
#   'Toledomin (TN)',
#   'Vestra (TN)',
#   'Dasotraline (USAN/INN)',
#   'Efectin (TN)',
#   'Methamphetamine',
#   'Anafranil (TN)',
#   'Amitifadine (USAN)',
#   'Sinequan (TN)',
#   'Levomilnacipran (USAN/INN)',
#   'Zonalon (TN)',
#   'Dexamfetamine (INN)',
#   'Pristiq (TN)',
#   'Butramin (TN)',
#   'Elavil (TN)',
#   'Viloxazine (INN)',
#   'Ludiomil (TN)',
#   'Lofepramine (INN)',
#   'Benzedrine (TN)',
#   'Dosulepin (TN)',
#   'Esreboxetine (USAN/INN)',
#   'Cocaine hydrochloride (TN)',
#   'Edronax (TN)',
#   'Amplit (TN)',
#   'Elepsin (TN)',
#   'Desvenlafaxine (INN)',
#   'Levomilnacipran hydrochloride (USAN)',
#   'Vivalan (TN)',
#   'Surmontil (TN)',
#   'Trimipramine (USAN/INN)',
#   'Maprotiline (USAN)',
#   'Centanafadine (USAN)',
#   'Edivoxetine hydrochloride (USAN)',
#   'Cocaine (TN)',
#   'Liafensine (USAN)'],
#  'SLC6A3': ['Amfetamin (TN)',
#   'Dasotraline hydrochloride (USAN)',
#   'Meridia (TN)',
#   'Pyrovalerone hydrochloride (USAN)',
#   'Sanorex (TN)',
#   'Acidum amfonelicum (INN)',
#   'Lisdexamfetamine (INN)',
#   'Centanafadine hydrochloride (USAN)',
#   'Amitifadine hydrochloride (USAN)',
#   'Desoxyn (TN)',
#   'Dextrostat (TN)',
#   'Bicifadine hydrochloride (USAN)',
#   'Elvanse (TN)',
#   'Dasotraline (USAN/INN)',
#   'Methamphetamine',
#   'Amitifadine (USAN)',
#   'Dexamfetamine (INN)',
#   'Butramin (TN)',
#   'Brasofensine maleate (USAN)',
#   'Datscan (TN)',
#   'Benzedrine (TN)',
#   'Cocaine hydrochloride (TN)',
#   'Centanafadine (USAN)',
#   'Cocaine (TN)'],
#  'SLC6A9': ['Paliflutine'],
#  'SLC9A1': ['Zoniporide mesylate (INN/USAN)', 'Cariporide mesylate (USAN)'],
#  'SLCO1A2': ['Telfast (TN)',
#   'Lanoxin (TN)',
#   'Sulfobromophthalein',
#   'Allegra (TN)',
#   'Sulfobromophthalein sodium (JP17)',
#   'Trexall (TN)',
#   'Otrexup (TN)'],
#  'SLCO1B1': ['Sovriad (TN)',
#   'Vanihep (TN)',
#   'Pravachol (TN)',
#   'Creston (TN)',
#   'Crestor (TN)',
#   'Pravator (TN)'],
#  'SLCO1B3': ['Pitavastatin calcium hydrate (JP17)',
#   'Diovan (TN)',
#   'Vanihep (TN)',
#   'Olmetec (TN)',
#   'Sulfobromophthalein',
#   'Sulfobromophthalein sodium (JP17)',
#   'Livalo (TN)',
#   'Creston (TN)',
#   'Olmesartan (USAN/INN)',
#   'Crestor (TN)',
#   'Lipitor (TN)',
#   'Sortis (TN)'],
#  'SLCO2B1': ['Telfast (TN)',
#   'Sulfobromophthalein',
#   'Allegra (TN)',
#   'Sulfobromophthalein sodium (JP17)',
#   'Sunvepra (TN)'],
#  'SQLE': ['Naftifine (INN)', 'Naftin (TN)'],
#  'SRC': ['Bosulif (TN)',
#   'Saracatinib (USAN/INN)',
#   'Dasatinib (INN)',
#   'Saracatinib difumarate (USAN)',
#   'Sprycel (TN)',
#   'Ponatinib (USAN/INN)',
#   'Ilorasertib (USAN)',
#   'Bosutinib (USAN)'],
#  'SRD5A1': ['Avodart (TN)',
#   'Idronoxil (USAN/INN)',
#   '17alpha-Estradiol',
#   'Bexlosteride (USAN/INN)',
#   'Izonsteride (USAN/INN)'],
#  'SRD5A3': ['Idronoxil (USAN/INN)', '17alpha-Estradiol'],
#  'STAT3': ['Napabucasin (JAN/USAN/INN)'],
#  'STS': ['Irosustat (USAN/INN)'],
#  'SULT2A1': ['Takecab (TN)'],
#  'SYK': ['Fostamatinib (USAN)', 'Fostamatinib disodium (USAN)'],
#  'TACR1': ['Emend (TN)',
#   'Vofopitant dihydrochloride (USAN)',
#   'Ezlopitant (USAN/INN)',
#   'Orvepitant (USAN/INN)',
#   'Casopitant mesylate (USAN)',
#   'Orvepitant maleate (USAN)',
#   'Proemend (TN)',
#   'Maropitant citrate (USAN)',
#   'Telmapitant (USAN)',
#   'Rolapitant hydrochloride (USAN)',
#   'Befetupitant (USAN/INN)',
#   'Varubi (TN)',
#   'Serlopitant (USAN)',
#   'Vestipitant mesylate (USAN)'],
#  'TEK': ['Rebastinib Tosylate (USAN)',
#   'Altiratinib (USAN)',
#   'Rebastinib (USAN)'],
#  'TGFBR1': ['Galunisertib (USAN)'],
#  'TH': ['Demser (TN)'],
#  'TP53': ['Cenersen sodium (USAN)'],
#  'TPO': ['Basdene (TN)',
#   'Tapazole (TN)',
#   'Thimecil (TN)',
#   'Propylthiouracil (TN)'],
#  'TYMS': ['Furtulon (TN)',
#   'Plevitrexed (INN)',
#   'Alimta (TN)',
#   'Fluoroplex (TN)',
#   'Tomudex (TN)',
#   'Xeloda (TN)',
#   'Pemetrexed accord (TN)',
#   'Pemetrexed (TN)',
#   'Mifurol (TN)',
#   'Fluorouracil (TN)',
#   'Atillon (TN)',
#   'Metesind glucuronate (USAN)',
#   'FUDR (TN)'],
#  'UGCG': ['Cerdelga (TN)', 'Zavesca (TN)', 'Eliglustat tartrate (JAN/USAN)'],
#  'UGT1A1': ['Exjade (TN)',
#   'Promacta (TN)',
#   'Lusefi (TN)',
#   'Tivicay (TN)',
#   'Zolinza (TN)',
#   'MK-0518',
#   'Inlyta (TN)',
#   'Tarceva (TN)',
#   'Isentress (TN)',
#   'Sorafenib (USAN/INN)'],
#  'UGT1A3': ['Exjade (TN)',
#   'Volibris (TN)',
#   'Promacta (TN)',
#   'Jardiance (TN)',
#   'Glufast (TN)',
#   'Uptravi (TN)',
#   'Zolinza (TN)'],
#  'UGT1A4': ['Staybla (TN)', 'Lamictal (TN)'],
#  'UGT1A6': ['Nucynta (TN)'],
#  'UGT1A7': ['Zolinza (TN)'],
#  'UGT1A8': ['Jardiance (TN)',
#   'Acotiamide hydrochloride hydrate (JAN)',
#   'Zolinza (TN)',
#   'Suglat (TN)'],
#  'UGT1A9': ['Volibris (TN)',
#   'Nucynta (TN)',
#   'Neupro (TN)',
#   'Jardiance (TN)',
#   'Farxiga (TN)',
#   'Acotiamide hydrochloride hydrate (JAN)',
#   'Glufast (TN)',
#   'Invokana (TN)',
#   'Zolinza (TN)',
#   'Uriadec (TN)',
#   'Suglat (TN)',
#   'Nexavar (TN)',
#   'Sorafenib (USAN/INN)'],
#  'UGT2B15': ['Neupro (TN)'],
#  'UGT2B17': ['Zolinza (TN)'],
#  'UGT2B4': ['Invokana (TN)', 'Invokana (TN)', 'Suglat (TN)', 'Suglat (TN)'],
#  'UGT2B7': ['Codeine sulfate trihydrate',
#   'Volibris (TN)',
#   'Nucynta (TN)',
#   'Jardiance (TN)',
#   'Codeine (TN)',
#   'Codeine hydrate',
#   'Uptravi (TN)',
#   'Zolinza (TN)',
#   'Bisoltus (TN)',
#   'Suglat (TN)',
#   'Retrovir (TN)'],
#  'XDH': ['Uriadec (TN)',
#   'Zyloprim (TN)',
#   'Feburic (TN)',
#   'Aloprim (TN)',
#   'Oxipurinol (INN)']}

# %%
import json
