# %% [markdown]
# # Un scénario complet

# %% [markdown]
# Quelques informations et paramètres pour commencer

# %%
from __future__ import print_function

def is_interactive():
    import __main__ as main
    return not hasattr(main, '__file__')

if is_interactive():
    Param_SBMLfile = "../data/iLiverCancer1715.xml"
    Param_Pourcentage = 1.1
    Param_RNASeqFilename = "../data/LiverCancerTCGA_male.csv"
    Param_MaxIndegreeInRRG = 18
    Param_Drug = "Sorafenib (USAN/INN)"
    Param_NumberOfSample = 100
    debugon = True
    Param_DoReconstruction = False
else:
    import sys,getopt

    optlist, args = getopt.getopt(sys.argv[1:], 'i:p:r:m:d:s:vR', ["input", "percentage","rna","maxdegree","drug","samples","verbose","with-reconstruction"])

    for o,v in optlist:
        if  o in ("-i","--input"):
            Param_SBMLfile = v
        else:
            Param_SBMLfile = "../data/iLiverCancer1715.xml"
    
        if o in ("-r","--rna"):
            Param_RNASeqFilename = v
        else:
            Param_RNASeqFilename = "../data/LiverCancerTCGA_male.csv"
    
        if o in ("-p","--percentage"):
            Param_Pourcentage = float(v)
        else:
            Param_Pourcentage = 1.1
    
        if o in ("-m","--maxdegree"):
            Param_MaxIndegreeInRRG = int(v)
        else:
            Param_MaxIndegreeInRRG = 18
    
        if o in ("-d","--drug"):
            Param_Drug = v
        else:
            Param_Drug = "Sorafenib (USAN/INN)"
    
        if o in ("-s","--samples"):
            Param_NumberOfSample = int(v)
        else:
            Param_NumberOfSample = 100
    
        if o in ("-v","--verbose"):
            debugon = True
        else:
            debugon = False
            
        if o in ("-R","--with-reconstruction"):
            Param_DoReconstruction = True
        else:
            Param_DoReconstruction = False

# internal variables
#import shutils
#shutils.copy(Param_SBMLfile,"../tmp")
import os

Param_SBMLfileBN = "../tmp/"+os.path.basename(Param_SBMLfile)

PC_Endpoint = "http://rdf.pathwaycommons.org/sparql"
RXN_EC_file = Param_SBMLfileBN.replace(".xml",".rxn")
BIF_file = Param_SBMLfileBN.replace(".xml",".bif")
Param_RRGFilename = Param_SBMLfileBN.replace(".xml",".rrg")
Param_ProbaReactionsFilename = Param_SBMLfileBN.replace(".xml",".prob")
#whichsolver = "gurobi"
whichsolver = "cglpk"


filenameCorrespondanceEnsemblGenenames = "../tables/Correspondance_Ensembl_genename.txt"
filenameCorrespondanceEnsemblEnzymes = "../tables/Correspondance_Enzymes_genenames.txt"
filenameCorrespondanceEnsemblTransporters = "../tables/Correspondance_Transporters_genenames.txt"
filenameKEGGDrugsGenes = "../tables/Public_KEGGDRUG_Targets.csv"
filenameCorrespondanceEnsemblMeanLength = "../tables/Correspondance_Ensembl_MeanTranscriptSize.txt"


# internal function can be edited
def Binarized(x,m,s,gene="null"):
    x=log(0.0001+x)
    InfBoundCoeff=-0.46 #0.46
    SupBoundCoeff=10000000 # 0.46
    if (x<m-InfBoundCoeff*s):
        return 0
    if (x>m+SupBoundCoeff*s):
        return 2
    return 1


def Binarized2(x,m,s,gene="null"):
    InfBoundCoeff=0.1
    m=AllGeneMeans.get(gene)
    if (m):
        if (m !=0):
            if (x/m<InfBoundCoeff):
                return 0
            else:
                return 1
    return 0

def Binarized3(x,m,s,gene="null"):
    InfBoundCoeff=1
#    m=AllGeneMeans.get(gene)
    m=1
    if (m):
        if (m !=0):
            if (x/m<InfBoundCoeff):
                return 0
            else:
                return 1
    return 0

# %% [markdown]
# Tous les includes

# %%
import optlang # NB : due to a bug in cobrapy, optlang must be imported before cobra
import cobra
from cobra.flux_analysis import flux_variability_analysis

from timeit import default_timer as timer
import csv
from SPARQLWrapper import SPARQLWrapper, JSON
import networkx as nx
from math import log
import numpy as np
import pandas as pd

from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator
from pgmpy.factors.discrete import State
from pgmpy.sampling import BayesianModelSampling
from pgmpy.readwrite import BIFReader, BIFWriter


#from optlang import Model,Variable,Constraint,Objective

import sys




# a few definition to print on stderr
def eprint(*args, **kwargs):
    if debugon:
        print(*args, file=sys.stderr, **kwargs)

# %%
## DEBUG ONLY
begintotal = timer()
eprint("Testing",Param_SBMLfile,"for",Param_Drug)

## END DEBUG ONLY
# Out:
# Testing ../data/iLiverCancer1715.xml for Sorafenib (USAN/INN)

# %% [markdown]
# Chargement des listes de correspondances

# %%
eprint("Importing all the correspondance tables")
# Tables 1 et 2: correspondance Ensembl <-> GeneNames (à refaire en SPARQL ?)

filename = filenameCorrespondanceEnsemblGenenames

EnsemblToGeneNames = dict()
GeneNamesToEnsembl = dict()

EnsemblToGeneNamesList = dict()
GeneNamesToEnsemblList = dict()


fd = open(filename,"r")

lines = fd.readlines()
for l in lines:
    t=l.split(";")
    t[2]=t[2].replace("\n","")
    EnsemblToGeneNames[t[0]]=t[2]
    GeneNamesToEnsembl[t[2]]=t[0]
    if (not EnsemblToGeneNamesList.get(t[0])):
        EnsemblToGeneNamesList[t[0]]=list()
    if (not GeneNamesToEnsemblList.get(t[2])):
        GeneNamesToEnsemblList[t[2]]=list()
    EnsemblToGeneNamesList[t[0]].append(t[2])
    GeneNamesToEnsemblList[t[2]].append(t[0])
    
fd.close()

# Missing genename associations
GeneNamesToEnsembl["TGIF"]=GeneNamesToEnsembl["TGIF1"]
GeneNamesToEnsembl["CART1"]=GeneNamesToEnsembl["ALX1"]
EnsemblToGeneNames["ENSG00000122718"]="OR2S2"
EnsemblToGeneNames["ENSG00000155640"] = "C10orf12"
GeneNamesToEnsembl["C10orf12"]="ENSG00000155640"
EnsemblToGeneNames["ENSG00000168260"] = "C14orf183"
GeneNamesToEnsembl["C14orf183"]="ENSG00000168260"
EnsemblToGeneNames["ENSG00000168787"] = "OR12D2"
EnsemblToGeneNames["ENSG00000170803"] = "OR2AG1"
EnsemblToGeneNames["ENSG00000171484"] = "OR1B1"
EnsemblToGeneNames["ENSG00000172381"] = "OR6Q1"




# Tables 3 et 4 : Correspondance (Enzymes,Transporters) <-> Ensembl

filename = filenameCorrespondanceEnsemblEnzymes

ECTCDBToEnsembl = dict()
fd = open(filename,"r")

lines = fd.readlines()
for l in lines:
    t=l.split(";")
    L=t[1].replace("\n","").split(",")
    ECTCDBToEnsembl[t[0]]=list()
    for g in L:
        if (GeneNamesToEnsembl.get(g)):
            ECTCDBToEnsembl[t[0]].append(GeneNamesToEnsembl.get(g))
fd.close()


filename = filenameCorrespondanceEnsemblTransporters

fd = open(filename,"r")

lines = fd.readlines()
for l in lines:
    t=l.split(";")
    L=t[1].replace("\n","").split(",")
    ECTCDBToEnsembl[t[0]]=list()
    for g in L:
        if (GeneNamesToEnsembl.get(g)):
            ECTCDBToEnsembl[t[0]].append(GeneNamesToEnsembl.get(g))
fd.close()

# Table 5 : Second filter, the genes present in the RRG must possess a RNASeq value. List of genes having a RNASeq value

#Request = """curl -o /dev/stdout "http://bgee.org/?page=gene&gene_id=%%GENEID%%" -q | grep "Name" | awk -F "<td>|</td>|<th>|</th>" '{for(i=1;i<NF;i++) {if ($i == "Ensembl ID") {printf("%s;;",$(i+2));}; if ($i == "Name") {printf("%s\\n",$(i+2));};          }    }'>>~/Downloads/missing.csv"""

#fout=open("/Users/jeremiebourdon/Downloads/requete.sh","w")

filename = Param_RNASeqFilename
fd = open(filename,"r")
l=fd.readline()
RNASeqlistofgenes=list()
#missing=""
for l in fd:
    l=l.replace('"','').replace('\n','')
    t=l.split(",")
    geneid=t[0].split(".")[0]
#    if not (EnsemblToGeneNames.get(geneid)):
#        print(geneid)
#        missing=(Request.replace("%%GENEID%%",geneid))
#        fout.write(missing+"\n")
    if (EnsemblToGeneNames.get(geneid)):
#        RNASeqlistofgenes.append(GeneNamesToEnsembl[EnsemblToGeneNames[geneid]]) # a conversion Ensembl->Gene->Ensembl to get a unique Ensemble Id for a given gene name
        RNASeqlistofgenes.append(geneid)
    else:
        eprint("Missing",geneid)
fd.close()

#fout.close()


# Table 6 : Drug targets
fd=open(filenameKEGGDrugsGenes ,"r")

lines = fd.readlines()

Allmeds=dict()

for l in lines:
    t=l.split(";")
    t[len(t)-1]=t[len(t)-1].replace("\n","")
    completeTargets=t[2].split('|')+t[3].replace("Enzyme:","").split(',')+t[4].split('|')
    completeTargets=[x.strip().split(" ")[0] for x in completeTargets if len(x)>2]
    completeTargetsEnsembl=[GeneNamesToEnsembl.get(x) for x in completeTargets if (GeneNamesToEnsembl.get(x) != None)]
    Allmeds[t[1].strip()]={'KeggId': t[0], 'TargetsGenes': completeTargets, 'TargetsGenesEnsembl': completeTargetsEnsembl }

fd.close()

# Table 6 : Mean Transcript length

fd = open(filenameCorrespondanceEnsemblMeanLength,"r")

lines=fd.readlines()

AllGeneMeans = dict()
for g in lines:
    t=g.split(";")
    t[1]=float(t[1].replace("\n",""))
    AllGeneMeans[t[0]]=t[1]
    
fd.close()
# Out:
# Importing all the correspondance tables
# Missing ENSG00000273504
# Missing ENSG00000273527
# Missing ENSG00000273530
# Missing ENSG00000273531
# Missing ENSG00000273534
# Missing ENSG00000273545
# Missing ENSG00000273556
# Missing ENSG00000273560
# Missing ENSG00000273561
# Missing ENSG00000273577
# Missing ENSG00000273581
# Missing ENSG00000273583
# Missing ENSG00000273615
# Missing ENSG00000273626
# Missing ENSG00000273630
# Missing ENSG00000273631
# Missing ENSG00000273632
# Missing ENSG00000273653
# Missing ENSG00000273662
# Missing ENSG00000273663
# Missing ENSG00000273665
# Missing ENSG00000273667
# Missing ENSG00000273672
# Missing ENSG00000273678
# Missing ENSG00000273684
# Missing ENSG00000273685
# Missing ENSG00000273689
# Missing ENSG00000273690
# Missing ENSG00000273695
# Missing ENSG00000273697
# Missing ENSG00000273699
# Missing ENSG00000273705
# Missing ENSG00000273718
# Missing ENSG00000273743
# Missing ENSG00000273751
# Missing ENSG00000273754
# Missing ENSG00000273774
# Missing ENSG00000273781
# Missing ENSG00000273787
# Missing ENSG00000273789
# Missing ENSG00000273790
# Missing ENSG00000273798
# Missing ENSG00000273801
# Missing ENSG00000273809
# Missing ENSG00000273810
# Missing ENSG00000273811
# Missing ENSG00000273817
# Missing ENSG00000273823
# Missing ENSG00000273826
# Missing ENSG00000273832
# Missing ENSG00000273834
# Missing ENSG00000273842
# Missing ENSG00000273848
# Missing ENSG00000273854
# Missing ENSG00000273857
# Missing ENSG00000273862
# Missing ENSG00000273868
# Missing ENSG00000273878
# Missing ENSG00000273879
# Missing ENSG00000273892
# Missing ENSG00000273895
# Missing ENSG00000273902
# Missing ENSG00000273910
# Missing ENSG00000273915
# Missing ENSG00000273917
# Missing ENSG00000273926
# Missing ENSG00000273930
# Missing ENSG00000273939
# Missing ENSG00000273941
# Missing ENSG00000273949
# Missing ENSG00000273952
# Missing ENSG00000273960
# Missing ENSG00000273985
# Missing ENSG00000273996
# Missing ENSG00000274013
# Missing ENSG00000274014
# Missing ENSG00000274027
# Missing ENSG00000274037
# Missing ENSG00000274043
# Missing ENSG00000274057
# Missing ENSG00000274061
# Missing ENSG00000274065
# Missing ENSG00000274074
# Missing ENSG00000274077
# Missing ENSG00000274083
# Missing ENSG00000274087
# Missing ENSG00000274088
# Missing ENSG00000274094
# Missing ENSG00000274095
# Missing ENSG00000274096
# Missing ENSG00000274103
# Missing ENSG00000274140
# Missing ENSG00000274141
# Missing ENSG00000274151
# Missing ENSG00000274153
# Missing ENSG00000274155
# Missing ENSG00000274160
# Missing ENSG00000274182
# Missing ENSG00000274188
# Missing ENSG00000274190
# Missing ENSG00000274200
# Missing ENSG00000274203
# Missing ENSG00000274207
# Missing ENSG00000274222
# Missing ENSG00000274223
# Missing ENSG00000274237
# Missing ENSG00000274241
# Missing ENSG00000274246
# Missing ENSG00000274250
# Missing ENSG00000274255
# Missing ENSG00000274268
# Missing ENSG00000274277
# Missing ENSG00000274278
# Missing ENSG00000274289
# Missing ENSG00000274298
# Missing ENSG00000274301
# Missing ENSG00000274302
# Missing ENSG00000274304
# Missing ENSG00000274325
# Missing ENSG00000274329
# Missing ENSG00000274335
# Missing ENSG00000274358
# Missing ENSG00000274366
# Missing ENSG00000274368
# Missing ENSG00000274377
# Missing ENSG00000274388
# Missing ENSG00000274389
# Missing ENSG00000274416
# Missing ENSG00000274426
# Missing ENSG00000274431
# Missing ENSG00000274433
# Missing ENSG00000274448
# Missing ENSG00000274453
# Missing ENSG00000274464
# Missing ENSG00000274470
# Missing ENSG00000274479
# Missing ENSG00000274483
# Missing ENSG00000274490
# Missing ENSG00000274496
# Missing ENSG00000274509
# Missing ENSG00000274519
# Missing ENSG00000274521
# Missing ENSG00000274524
# Missing ENSG00000274526
# Missing ENSG00000274537
# Missing ENSG00000274548
# Missing ENSG00000274550
# Missing ENSG00000274555
# Missing ENSG00000274557
# Missing ENSG00000274590
# Missing ENSG00000274592
# Missing ENSG00000274596
# Missing ENSG00000274604
# Missing ENSG00000274622
# Missing ENSG00000274633
# Missing ENSG00000274634
# Missing ENSG00000274635
# Missing ENSG00000274645
# Missing ENSG00000274648
# Missing ENSG00000274668
# Missing ENSG00000274673
# Missing ENSG00000274674
# Missing ENSG00000274683
# Missing ENSG00000274689
# Missing ENSG00000274694
# Missing ENSG00000274725
# Missing ENSG00000274728
# Missing ENSG00000274735
# Missing ENSG00000274743
# Missing ENSG00000274753
# Missing ENSG00000274761
# Missing ENSG00000274773
# Missing ENSG00000274778
# Missing ENSG00000274784
# Missing ENSG00000274787
# Missing ENSG00000274793
# Missing ENSG00000274794
# Missing ENSG00000274802
# Missing ENSG00000274815
# Missing ENSG00000274831
# Missing ENSG00000274856
# Missing ENSG00000274871
# Missing ENSG00000274872
# Missing ENSG00000274877
# Missing ENSG00000274880
# Missing ENSG00000274888
# Missing ENSG00000274890
# Missing ENSG00000274900
# Missing ENSG00000274910
# Missing ENSG00000274913
# Missing ENSG00000274924
# Missing ENSG00000274951
# Missing ENSG00000274961
# Missing ENSG00000274982
# Missing ENSG00000274983
# Missing ENSG00000274991
# Missing ENSG00000274992
# Missing ENSG00000275000
# Missing ENSG00000275010
# Missing ENSG00000275020
# Missing ENSG00000275027
# Missing ENSG00000275039
# Missing ENSG00000275042
# Missing ENSG00000275044
# Missing ENSG00000275053
# Missing ENSG00000275058
# Missing ENSG00000275065
# Missing ENSG00000275076
# Missing ENSG00000275077
# Missing ENSG00000275085
# Missing ENSG00000275089
# Missing ENSG00000275096
# Missing ENSG00000275098
# Missing ENSG00000275100
# Missing ENSG00000275105
# Missing ENSG00000275114
# Missing ENSG00000275124
# Missing ENSG00000275135
# Missing ENSG00000275147
# Missing ENSG00000275149
# Missing ENSG00000275159
# Missing ENSG00000275182
# Missing ENSG00000275184
# Missing ENSG00000275200
# Missing ENSG00000275209
# Missing ENSG00000275218
# Missing ENSG00000275220
# Missing ENSG00000275224
# Missing ENSG00000275233
# Missing ENSG00000275235
# Missing ENSG00000275241
# Missing ENSG00000275251
# Missing ENSG00000275252
# Missing ENSG00000275258
# Missing ENSG00000275261
# Missing ENSG00000275264
# Missing ENSG00000275267
# Missing ENSG00000275270
# Missing ENSG00000275271
# Missing ENSG00000275277
# Missing ENSG00000275279
# Missing ENSG00000275292
# Missing ENSG00000275301
# Missing ENSG00000275303
# Missing ENSG00000275309
# Missing ENSG00000275364
# Missing ENSG00000275370
# Missing ENSG00000275378
# Missing ENSG00000275382
# Missing ENSG00000275398
# Missing ENSG00000275402
# Missing ENSG00000275403
# Missing ENSG00000275425
# Missing ENSG00000275439
# Missing ENSG00000275446
# Missing ENSG00000275447
# Missing ENSG00000275459
# Missing ENSG00000275466
# Missing ENSG00000275505
# Missing ENSG00000275507
# Missing ENSG00000275509
# Missing ENSG00000275510
# Missing ENSG00000275530
# Missing ENSG00000275533
# Missing ENSG00000275534
# Missing ENSG00000275535
# Missing ENSG00000275537
# Missing ENSG00000275541
# Missing ENSG00000275554
# Missing ENSG00000275595
# Missing ENSG00000275603
# Missing ENSG00000275604
# Missing ENSG00000275622
# Missing ENSG00000275653
# Missing ENSG00000275657
# Missing ENSG00000275668
# Missing ENSG00000275677
# Missing ENSG00000275682
# Missing ENSG00000275685
# Missing ENSG00000275686
# Missing ENSG00000275687
# Missing ENSG00000275690
# Missing ENSG00000275694
# Missing ENSG00000275701
# Missing ENSG00000275702
# Missing ENSG00000275704
# Missing ENSG00000275707
# Missing ENSG00000275727
# Missing ENSG00000275729
# Missing ENSG00000275739
# Missing ENSG00000275742
# Missing ENSG00000275761
# Missing ENSG00000275783
# Missing ENSG00000275790
# Missing ENSG00000275802
# Missing ENSG00000275813
# Missing ENSG00000275820
# Missing ENSG00000275829
# Missing ENSG00000275831
# Missing ENSG00000275845
# Missing ENSG00000275847
# Missing ENSG00000275849
# Missing ENSG00000275858
# Missing ENSG00000275864
# Missing ENSG00000275870
# Missing ENSG00000275876
# Missing ENSG00000275883
# Missing ENSG00000275884
# Missing ENSG00000275891
# Missing ENSG00000275892
# Missing ENSG00000275899
# Missing ENSG00000275912
# Missing ENSG00000275916
# Missing ENSG00000275922
# Missing ENSG00000275925
# Missing ENSG00000275926
# Missing ENSG00000275934
# Missing ENSG00000275943
# Missing ENSG00000275952
# Missing ENSG00000275955
# Missing ENSG00000275957
# Missing ENSG00000275977
# Missing ENSG00000275986
# Missing ENSG00000275998
# Missing ENSG00000276018
# Missing ENSG00000276024
# Missing ENSG00000276037
# Missing ENSG00000276038
# Missing ENSG00000276056
# Missing ENSG00000276059
# Missing ENSG00000276078
# Missing ENSG00000276079
# Missing ENSG00000276090
# Missing ENSG00000276104
# Missing ENSG00000276108
# Missing ENSG00000276117
# Missing ENSG00000276151
# Missing ENSG00000276157
# Missing ENSG00000276165
# Missing ENSG00000276171
# Missing ENSG00000276198
# Missing ENSG00000276201
# Missing ENSG00000276215
# Missing ENSG00000276235
# Missing ENSG00000276236
# Missing ENSG00000276237
# Missing ENSG00000276242
# Missing ENSG00000276244
# Missing ENSG00000276246
# Missing ENSG00000276252
# Missing ENSG00000276271
# Missing ENSG00000276273
# Missing ENSG00000276280
# Missing ENSG00000276283
# Missing ENSG00000276288
# Missing ENSG00000276301
# Missing ENSG00000276305
# Missing ENSG00000276315
# Missing ENSG00000276322
# Missing ENSG00000276325
# Missing ENSG00000276331
# Missing ENSG00000276335
# Missing ENSG00000276338
# Missing ENSG00000276347
# Missing ENSG00000276354
# Missing ENSG00000276369
# Missing ENSG00000276372
# Missing ENSG00000276373
# Missing ENSG00000276381
# Missing ENSG00000276389
# Missing ENSG00000276401
# Missing ENSG00000276419
# Missing ENSG00000276444
# Missing ENSG00000276456
# Missing ENSG00000276472
# Missing ENSG00000276477
# Missing ENSG00000276499
# Missing ENSG00000276506
# Missing ENSG00000276510
# Missing ENSG00000276511
# Missing ENSG00000276513
# Missing ENSG00000276515
# Missing ENSG00000276543
# Missing ENSG00000276554
# Missing ENSG00000276555
# Missing ENSG00000276558
# Missing ENSG00000276574
# Missing ENSG00000276587
# Missing ENSG00000276602
# Missing ENSG00000276607
# Missing ENSG00000276614
# Missing ENSG00000276617
# Missing ENSG00000276619
# Missing ENSG00000276621
# Missing ENSG00000276624
# Missing ENSG00000276629
# Missing ENSG00000276635
# Missing ENSG00000276648
# Missing ENSG00000276652
# Missing ENSG00000276659
# Missing ENSG00000276660
# Missing ENSG00000276661
# Missing ENSG00000276677
# Missing ENSG00000276682
# Missing ENSG00000276683
# Missing ENSG00000276694
# Missing ENSG00000276695
# Missing ENSG00000276737
# Missing ENSG00000276741
# Missing ENSG00000276743
# Missing ENSG00000276745
# Missing ENSG00000276748
# Missing ENSG00000276750
# Missing ENSG00000276751
# Missing ENSG00000276752
# Missing ENSG00000276762
# Missing ENSG00000276773
# Missing ENSG00000276783
# Missing ENSG00000276792
# Missing ENSG00000276793
# Missing ENSG00000276796
# Missing ENSG00000276797
# Missing ENSG00000276801
# Missing ENSG00000276811
# Missing ENSG00000276812
# Missing ENSG00000276813
# Missing ENSG00000276815
# Missing ENSG00000276817
# Missing ENSG00000276818
# Missing ENSG00000276827
# Missing ENSG00000276852
# Missing ENSG00000276862
# Missing ENSG00000276877
# Missing ENSG00000276883
# Missing ENSG00000276889
# Missing ENSG00000276893
# Missing ENSG00000276899
# Missing ENSG00000276921
# Missing ENSG00000276922
# Missing ENSG00000276924
# Missing ENSG00000276927
# Missing ENSG00000276933
# Missing ENSG00000276939
# Missing ENSG00000276942
# Missing ENSG00000276943
# Missing ENSG00000276962
# Missing ENSG00000276967
# Missing ENSG00000276978
# Missing ENSG00000276987
# Missing ENSG00000276989
# Missing ENSG00000276990
# Missing ENSG00000276995
# Missing ENSG00000277002
# Missing ENSG00000277021
# Missing ENSG00000277023
# Missing ENSG00000277026
# Missing ENSG00000277045
# Missing ENSG00000277054
# Missing ENSG00000277061
# Missing ENSG00000277064
# Missing ENSG00000277074
# Missing ENSG00000277082
# Missing ENSG00000277097
# Missing ENSG00000277100
# Missing ENSG00000277102
# Missing ENSG00000277105
# Missing ENSG00000277115
# Missing ENSG00000277116
# Missing ENSG00000277121
# Missing ENSG00000277122
# Missing ENSG00000277123
# Missing ENSG00000277137
# Missing ENSG00000277155
# Missing ENSG00000277158
# Missing ENSG00000277160
# Missing ENSG00000277169
# Missing ENSG00000277180
# Missing ENSG00000277189
# Missing ENSG00000277197
# Missing ENSG00000277201
# Missing ENSG00000277204
# Missing ENSG00000277207
# Missing ENSG00000277212
# Missing ENSG00000277216
# Missing ENSG00000277225
# Missing ENSG00000277231
# Missing ENSG00000277239
# Missing ENSG00000277244
# Missing ENSG00000277257
# Missing ENSG00000277259
# Missing ENSG00000277275
# Missing ENSG00000277284
# Missing ENSG00000277285
# Missing ENSG00000277294
# Missing ENSG00000277296
# Missing ENSG00000277300
# Missing ENSG00000277302
# Missing ENSG00000277305
# Missing ENSG00000277312
# Missing ENSG00000277321
# Missing ENSG00000277323
# Missing ENSG00000277325
# Missing ENSG00000277326
# Missing ENSG00000277328
# Missing ENSG00000277329
# Missing ENSG00000277330
# Missing ENSG00000277331
# Missing ENSG00000277333
# Missing ENSG00000277338
# Missing ENSG00000277346
# Missing ENSG00000277347
# Missing ENSG00000277348
# Missing ENSG00000277353
# Missing ENSG00000277360
# Missing ENSG00000277372
# Missing ENSG00000277393
# Missing ENSG00000277394
# Missing ENSG00000277433
# Missing ENSG00000277441
# Missing ENSG00000277451
# Missing ENSG00000277472
# Missing ENSG00000277487
# Missing ENSG00000277489
# Missing ENSG00000277497
# Missing ENSG00000277503
# Missing ENSG00000277520
# Missing ENSG00000277528
# Missing ENSG00000277537
# Missing ENSG00000277547
# Missing ENSG00000277555
# Missing ENSG00000277573
# Missing ENSG00000277593
# Missing ENSG00000277601
# Missing ENSG00000277609
# Missing ENSG00000277612
# Missing ENSG00000277622
# Missing ENSG00000277627
# Missing ENSG00000277644
# Missing ENSG00000277645
# Missing ENSG00000277648
# Missing ENSG00000277652
# Missing ENSG00000277663
# Missing ENSG00000277664
# Missing ENSG00000277665
# Missing ENSG00000277682
# Missing ENSG00000277683
# Missing ENSG00000277685
# Missing ENSG00000277699
# Missing ENSG00000277700
# Missing ENSG00000277703
# Missing ENSG00000277712
# Missing ENSG00000277714
# Missing ENSG00000277716
# Missing ENSG00000277719
# Missing ENSG00000277724
# Missing ENSG00000277727
# Missing ENSG00000277731
# Missing ENSG00000277735
# Missing ENSG00000277736
# Missing ENSG00000277756
# Missing ENSG00000277760
# Missing ENSG00000277772
# Missing ENSG00000277779
# Missing ENSG00000277780
# Missing ENSG00000277787
# Missing ENSG00000277792
# Missing ENSG00000277793
# Missing ENSG00000277798
# Missing ENSG00000277805
# Missing ENSG00000277810
# Missing ENSG00000277812
# Missing ENSG00000277813
# Missing ENSG00000277814
# Missing ENSG00000277815
# Missing ENSG00000277819
# Missing ENSG00000277821
# Missing ENSG00000277822
# Missing ENSG00000277827
# Missing ENSG00000277832
# Missing ENSG00000277838
# Missing ENSG00000277839
# Missing ENSG00000277843
# Missing ENSG00000277847
# Missing ENSG00000277854
# Missing ENSG00000277861
# Missing ENSG00000277875
# Missing ENSG00000277877
# Missing ENSG00000277884
# Missing ENSG00000277886
# Missing ENSG00000277896
# Missing ENSG00000277910
# Missing ENSG00000277929
# Missing ENSG00000277933
# Missing ENSG00000277934
# Missing ENSG00000277937
# Missing ENSG00000277939
# Missing ENSG00000277951
# Missing ENSG00000277960
# Missing ENSG00000277962
# Missing ENSG00000277990
# Missing ENSG00000277992
# Missing ENSG00000278005
# Missing ENSG00000278014
# Missing ENSG00000278027
# Missing ENSG00000278047
# Missing ENSG00000278056
# Missing ENSG00000278059
# Missing ENSG00000278065
# Missing ENSG00000278067
# Missing ENSG00000278076
# Missing ENSG00000278093
# Missing ENSG00000278105
# Missing ENSG00000278125
# Missing ENSG00000278136
# Missing ENSG00000278142
# Missing ENSG00000278148
# Missing ENSG00000278150
# Missing ENSG00000278166
# Missing ENSG00000278176
# Missing ENSG00000278179
# Missing ENSG00000278185
# Missing ENSG00000278187
# Missing ENSG00000278203
# Missing ENSG00000278219
# Missing ENSG00000278227
# Missing ENSG00000278228
# Missing ENSG00000278244
# Missing ENSG00000278251
# Missing ENSG00000278258
# Missing ENSG00000278260
# Missing ENSG00000278282
# Missing ENSG00000278285
# Missing ENSG00000278290
# Missing ENSG00000278297
# Missing ENSG00000278309
# Missing ENSG00000278321
# Missing ENSG00000278335
# Missing ENSG00000278350
# Missing ENSG00000278352
# Missing ENSG00000278353
# Missing ENSG00000278366
# Missing ENSG00000278371
# Missing ENSG00000278375
# Missing ENSG00000278392
# Missing ENSG00000278393
# Missing ENSG00000278398
# Missing ENSG00000278405
# Missing ENSG00000278423
# Missing ENSG00000278435
# Missing ENSG00000278439
# Missing ENSG00000278452
# Missing ENSG00000278453
# Missing ENSG00000278460
# Missing ENSG00000278471
# Missing ENSG00000278479
# Missing ENSG00000278491
# Missing ENSG00000278504
# Missing ENSG00000278506
# Missing ENSG00000278507
# Missing ENSG00000278509
# Missing ENSG00000278512
# Missing ENSG00000278521
# Missing ENSG00000278534
# Missing ENSG00000278536
# Missing ENSG00000278544
# Missing ENSG00000278547
# Missing ENSG00000278556
# Missing ENSG00000278557
# Missing ENSG00000278560
# Missing ENSG00000278564
# Missing ENSG00000278568
# Missing ENSG00000278575
# Missing ENSG00000278578
# Missing ENSG00000278579
# Missing ENSG00000278584
# Missing ENSG00000278597
# Missing ENSG00000278609
# Missing ENSG00000278612
# Missing ENSG00000278628
# Missing ENSG00000278629
# Missing ENSG00000278639
# Missing ENSG00000278645
# Missing ENSG00000278648
# Missing ENSG00000278651
# Missing ENSG00000278652
# Missing ENSG00000278660
# Missing ENSG00000278663
# Missing ENSG00000278669
# Missing ENSG00000278671
# Missing ENSG00000278675
# Missing ENSG00000278679
# Missing ENSG00000278686
# Missing ENSG00000278717
# Missing ENSG00000278748
# Missing ENSG00000278750
# Missing ENSG00000278751
# Missing ENSG00000278753
# Missing ENSG00000278772
# Missing ENSG00000278792
# Missing ENSG00000278804
# Missing ENSG00000278810
# Missing ENSG00000278814
# Missing ENSG00000278820
# Missing ENSG00000278832
# Missing ENSG00000278841
# Missing ENSG00000278844
# Missing ENSG00000278882
# Missing ENSG00000278947
# Missing ENSG00000279003
# Missing ENSG00000279027
# Missing ENSG00000279037
# Missing ENSG00000279038
# Missing ENSG00000279185
# Missing ENSG00000279188
# Missing ENSG00000279210
# Missing ENSG00000279216
# Missing ENSG00000279242
# Missing ENSG00000279252
# Missing ENSG00000279260
# Missing ENSG00000279272
# Missing ENSG00000279291
# Missing ENSG00000279338
# Missing ENSG00000279424
# Missing ENSG00000279468
# Missing ENSG00000279496
# Missing ENSG00000279556
# Missing ENSG00000279582
# Missing ENSG00000279618
# Missing ENSG00000279624
# Missing ENSG00000279723
# Missing ENSG00000279802
# Missing ENSG00000279831
# Missing ENSG00000279843
# Missing ENSG00000279866
# Missing ENSG00000279868
# Missing ENSG00000279888
# Missing ENSG00000279893
# Missing ENSG00000279911
# Missing ENSG00000279922
# Missing ENSG00000279941
# Missing ENSG00000279975
# Missing ENSG00000279978
# Missing ENSG00000280008
# Missing ENSG00000280065
# Missing ENSG00000280074
# Missing ENSG00000280102
# Missing ENSG00000280111
# Missing ENSG00000280112
# Missing ENSG00000280133
# Missing ENSG00000280246
# Missing ENSG00000280253
# Missing ENSG00000280258
# Missing ENSG00000280315
# Missing ENSG00000280324
# Missing ENSG00000280328
# Missing ENSG00000280361
# Missing ENSG00000280370
# Missing ENSG00000280391
# Missing ENSG00000280413
# Missing ENSG00000280448
# Missing ENSG00000280456
# Missing ENSG00000280458
# Missing ENSG00000280459
# Missing ENSG00000280462
# Missing ENSG00000280464
# Missing ENSG00000280465
# Missing ENSG00000280468
# Missing ENSG00000280469
# Missing ENSG00000280472
# Missing ENSG00000280478
# Missing ENSG00000280480
# Missing ENSG00000280481
# Missing ENSG00000280483
# Missing ENSG00000280487
# Missing ENSG00000280488
# Missing ENSG00000280489
# Missing ENSG00000280492
# Missing ENSG00000280493
# Missing ENSG00000280499
# Missing ENSG00000280503
# Missing ENSG00000280507
# Missing ENSG00000280508
# Missing ENSG00000280509
# Missing ENSG00000280510
# Missing ENSG00000280517
# Missing ENSG00000280519
# Missing ENSG00000280522
# Missing ENSG00000280523
# Missing ENSG00000280524
# Missing ENSG00000280526
# Missing ENSG00000280527
# Missing ENSG00000280528
# Missing ENSG00000280533
# Missing ENSG00000280536
# Missing ENSG00000280539
# Missing ENSG00000280546
# Missing ENSG00000280547
# Missing ENSG00000280553
# Missing ENSG00000280558
# Missing ENSG00000280564
# Missing ENSG00000280565
# Missing ENSG00000280566
# Missing ENSG00000280567
# Missing ENSG00000280570
# Missing ENSG00000280573
# Missing ENSG00000280574
# Missing ENSG00000280576
# Missing ENSG00000280581
# Missing ENSG00000280583
# Missing ENSG00000280586
# Missing ENSG00000280588
# Missing ENSG00000280589
# Missing ENSG00000280595
# Missing ENSG00000280598
# Missing ENSG00000280599
# Missing ENSG00000280600
# Missing ENSG00000280602
# Missing ENSG00000280605
# Missing ENSG00000280608
# Missing ENSG00000280615
# Missing ENSG00000280622
# Missing ENSG00000280624
# Missing ENSG00000280625
# Missing ENSG00000280628
# Missing ENSG00000280630
# Missing ENSG00000280637
# Missing ENSG00000280642
# Missing ENSG00000280643
# Missing ENSG00000280644
# Missing ENSG00000280648
# Missing ENSG00000280653
# Missing ENSG00000280654
# Missing ENSG00000280656
# Missing ENSG00000280657
# Missing ENSG00000280659
# Missing ENSG00000280662
# Missing ENSG00000280667
# Missing ENSG00000280672
# Missing ENSG00000280673
# Missing ENSG00000280676
# Missing ENSG00000280678
# Missing ENSG00000280685
# Missing ENSG00000280687
# Missing ENSG00000280692
# Missing ENSG00000280694
# Missing ENSG00000280696
# Missing ENSG00000280697
# Missing ENSG00000280698
# Missing ENSG00000280699
# Missing ENSG00000280702
# Missing ENSG00000280713
# Missing ENSG00000280715
# Missing ENSG00000280718
# Missing ENSG00000280723
# Missing ENSG00000280727
# Missing ENSG00000280728
# Missing ENSG00000280729
# Missing ENSG00000280730
# Missing ENSG00000280731
# Missing ENSG00000280736
# Missing ENSG00000280738
# Missing ENSG00000280742
# Missing ENSG00000280743
# Missing ENSG00000280746
# Missing ENSG00000280747
# Missing ENSG00000280753
# Missing ENSG00000280756
# Missing ENSG00000280760
# Missing ENSG00000280761
# Missing ENSG00000280762
# Missing ENSG00000280763
# Missing ENSG00000280764
# Missing ENSG00000280766
# Missing ENSG00000280771
# Missing ENSG00000280772
# Missing ENSG00000280777
# Missing ENSG00000280779
# Missing ENSG00000280783
# Missing ENSG00000280785
# Missing ENSG00000280788
# Missing ENSG00000280790
# Missing ENSG00000280791
# Missing ENSG00000280793
# Missing ENSG00000280796
# Missing ENSG00000280801
# Missing ENSG00000280803
# Missing ENSG00000280804
# Missing ENSG00000280816
# Missing ENSG00000280818
# Missing ENSG00000280822
# Missing ENSG00000280823
# Missing ENSG00000280824
# Missing ENSG00000280826
# Missing ENSG00000280827
# Missing ENSG00000280829
# Missing ENSG00000280833
# Missing ENSG00000280834
# Missing ENSG00000280835
# Missing ENSG00000280842
# Missing ENSG00000280843
# Missing ENSG00000280845
# Missing ENSG00000280846
# Missing ENSG00000280847
# Missing ENSG00000280848
# Missing ENSG00000280849
# Missing ENSG00000280851
# Missing ENSG00000280854
# Missing ENSG00000280855
# Missing ENSG00000280856
# Missing ENSG00000280857
# Missing ENSG00000280859
# Missing ENSG00000280860
# Missing ENSG00000280861
# Missing ENSG00000280862
# Missing ENSG00000280863
# Missing ENSG00000280867
# Missing ENSG00000280869
# Missing ENSG00000280871
# Missing ENSG00000280874
# Missing ENSG00000280875
# Missing ENSG00000280884
# Missing ENSG00000280886
# Missing ENSG00000280887
# Missing ENSG00000280888
# Missing ENSG00000280896
# Missing ENSG00000280897
# Missing ENSG00000280900
# Missing ENSG00000280901
# Missing ENSG00000280902
# Missing ENSG00000280903
# Missing ENSG00000280910
# Missing ENSG00000280911
# Missing ENSG00000280914
# Missing ENSG00000280915
# Missing ENSG00000280918
# Missing ENSG00000280919
# Missing ENSG00000280921
# Missing ENSG00000280922
# Missing ENSG00000280925
# Missing ENSG00000280933
# Missing ENSG00000280934
# Missing ENSG00000280942
# Missing ENSG00000280945
# Missing ENSG00000280947
# Missing ENSG00000280950
# Missing ENSG00000280954
# Missing ENSG00000280955
# Missing ENSG00000280956
# Missing ENSG00000280957
# Missing ENSG00000280964
# Missing ENSG00000280965
# Missing ENSG00000280966
# Missing ENSG00000280970
# Missing ENSG00000280974
# Missing ENSG00000280976
# Missing ENSG00000280977
# Missing ENSG00000280979
# Missing ENSG00000280981
# Missing ENSG00000280985
# Missing ENSG00000280988
# Missing ENSG00000280992
# Missing ENSG00000280995
# Missing ENSG00000280998
# Missing ENSG00000280999
# Missing ENSG00000281001
# Missing ENSG00000281002
# Missing ENSG00000281003
# Missing ENSG00000281006
# Missing ENSG00000281007
# Missing ENSG00000281014
# Missing ENSG00000281017
# Missing ENSG00000281018
# Missing ENSG00000281023
# Missing ENSG00000281025
# Missing ENSG00000281027
# Missing ENSG00000281030
# Missing ENSG00000281033
# Missing ENSG00000281034
# Missing ENSG00000281035
# Missing ENSG00000281037
# Missing ENSG00000281041
# Missing ENSG00000281044
# Missing ENSG00000281045
# Missing ENSG00000281046
# Missing ENSG00000281047
# Missing ENSG00000281052
# Missing ENSG00000281057
# Missing ENSG00000281059
# Missing ENSG00000281061
# Missing ENSG00000281064
# Missing ENSG00000281066
# Missing ENSG00000281068
# Missing ENSG00000281069
# Missing ENSG00000281070
# Missing ENSG00000281075
# Missing ENSG00000281080
# Missing ENSG00000281085
# Missing ENSG00000281088
# Missing ENSG00000281090
# Missing ENSG00000281096
# Missing ENSG00000281098
# Missing ENSG00000281105
# Missing ENSG00000281108
# Missing ENSG00000281109
# Missing ENSG00000281110
# Missing ENSG00000281114
# Missing ENSG00000281115
# Missing ENSG00000281116
# Missing ENSG00000281117
# Missing ENSG00000281119
# Missing ENSG00000281124
# Missing ENSG00000281125
# Missing ENSG00000281129
# Missing ENSG00000281130
# Missing ENSG00000281134
# Missing ENSG00000281135
# Missing ENSG00000281136
# Missing ENSG00000281138
# Missing ENSG00000281140
# Missing ENSG00000281142
# Missing ENSG00000281143
# Missing ENSG00000281146
# Missing ENSG00000281147
# Missing ENSG00000281148
# Missing ENSG00000281152
# Missing ENSG00000281155
# Missing ENSG00000281158
# Missing ENSG00000281164
# Missing ENSG00000281169
# Missing ENSG00000281170
# Missing ENSG00000281171
# Missing ENSG00000281172
# Missing ENSG00000281177
# Missing ENSG00000281187
# Missing ENSG00000281190
# Missing ENSG00000281193
# Missing ENSG00000281194
# Missing ENSG00000281199
# Missing ENSG00000281200
# Missing ENSG00000281201
# Missing ENSG00000281203
# Missing ENSG00000281204
# Missing ENSG00000281206
# Missing ENSG00000281209
# Missing ENSG00000281212
# Missing ENSG00000281214
# Missing ENSG00000281215
# Missing ENSG00000281217
# Missing ENSG00000281218
# Missing ENSG00000281220
# Missing ENSG00000281222
# Missing ENSG00000281231
# Missing ENSG00000281235
# Missing ENSG00000281238
# Missing ENSG00000281239
# Missing ENSG00000281241
# Missing ENSG00000281242
# Missing ENSG00000281247
# Missing ENSG00000281253
# Missing ENSG00000281255
# Missing ENSG00000281257
# Missing ENSG00000281258
# Missing ENSG00000281259
# Missing ENSG00000281262
# Missing ENSG00000281271
# Missing ENSG00000281272
# Missing ENSG00000281275
# Missing ENSG00000281278
# Missing ENSG00000281280
# Missing ENSG00000281281
# Missing ENSG00000281285
# Missing ENSG00000281286
# Missing ENSG00000281288
# Missing ENSG00000281290
# Missing ENSG00000281291
# Missing ENSG00000281293
# Missing ENSG00000281294
# Missing ENSG00000281297
# Missing ENSG00000281298
# Missing ENSG00000281301
# Missing ENSG00000281302
# Missing ENSG00000281303
# Missing ENSG00000281304
# Missing ENSG00000281312
# Missing ENSG00000281314
# Missing ENSG00000281315
# Missing ENSG00000281318
# Missing ENSG00000281319
# Missing ENSG00000281322
# Missing ENSG00000281328
# Missing ENSG00000281329
# Missing ENSG00000281330
# Missing ENSG00000281337
# Missing ENSG00000281338
# Missing ENSG00000281339
# Missing ENSG00000281341
# Missing ENSG00000281342
# Missing ENSG00000281346
# Missing ENSG00000281350
# Missing ENSG00000281352
# Missing ENSG00000281353
# Missing ENSG00000281355
# Missing ENSG00000281366
# Missing ENSG00000281368
# Missing ENSG00000281372
# Missing ENSG00000281373
# Missing ENSG00000281375
# Missing ENSG00000281378
# Missing ENSG00000281381
# Missing ENSG00000281389
# Missing ENSG00000281390
# Missing ENSG00000281397
# Missing ENSG00000281405
# Missing ENSG00000281408
# Missing ENSG00000281411
# Missing ENSG00000281413
# Missing ENSG00000281414
# Missing ENSG00000281415
# Missing ENSG00000281419
# Missing ENSG00000281423
# Missing ENSG00000281428
# Missing ENSG00000281431
# Missing ENSG00000281433
# Missing ENSG00000281435
# Missing ENSG00000281437
# Missing ENSG00000281438
# Missing ENSG00000281439
# Missing ENSG00000281440
# Missing ENSG00000281441
# Missing ENSG00000281443
# Missing ENSG00000281444
# Missing ENSG00000281445
# Missing ENSG00000281447
# Missing ENSG00000281451
# Missing ENSG00000281452
# Missing ENSG00000281454
# Missing ENSG00000281457
# Missing ENSG00000281458
# Missing ENSG00000281461
# Missing ENSG00000281462
# Missing ENSG00000281463
# Missing ENSG00000281466
# Missing ENSG00000281467
# Missing ENSG00000281474
# Missing ENSG00000281475
# Missing ENSG00000281476
# Missing ENSG00000281479
# Missing ENSG00000281480
# Missing ENSG00000281483
# Missing ENSG00000281485
# Missing ENSG00000281488
# Missing ENSG00000281492
# Missing ENSG00000281497
# Missing ENSG00000281506
# Missing ENSG00000281512
# Missing ENSG00000281514
# Missing ENSG00000281515
# Missing ENSG00000281517
# Missing ENSG00000281522
# Missing ENSG00000281528
# Missing ENSG00000281531
# Missing ENSG00000281532
# Missing ENSG00000281534
# Missing ENSG00000281535
# Missing ENSG00000281539
# Missing ENSG00000281544
# Missing ENSG00000281545
# Missing ENSG00000281546
# Missing ENSG00000281549
# Missing ENSG00000281551
# Missing ENSG00000281554
# Missing ENSG00000281555
# Missing ENSG00000281558
# Missing ENSG00000281568
# Missing ENSG00000281570
# Missing ENSG00000281572
# Missing ENSG00000281574
# Missing ENSG00000281575
# Missing ENSG00000281576
# Missing ENSG00000281579
# Missing ENSG00000281581
# Missing ENSG00000281585
# Missing ENSG00000281587
# Missing ENSG00000281588
# Missing ENSG00000281589
# Missing ENSG00000281592
# Missing ENSG00000281594
# Missing ENSG00000281595
# Missing ENSG00000281596
# Missing ENSG00000281598
# Missing ENSG00000281599
# Missing ENSG00000281600
# Missing ENSG00000281605
# Missing ENSG00000281606
# Missing ENSG00000281611
# Missing ENSG00000281615
# Missing ENSG00000281619
# Missing ENSG00000281621
# Missing ENSG00000281628
# Missing ENSG00000281629
# Missing ENSG00000281631
# Missing ENSG00000281632
# Missing ENSG00000281634
# Missing ENSG00000281636
# Missing ENSG00000281637
# Missing ENSG00000281638
# Missing ENSG00000281639
# Missing ENSG00000281640
# Missing ENSG00000281643
# Missing ENSG00000281646
# Missing ENSG00000281647
# Missing ENSG00000281653
# Missing ENSG00000281662
# Missing ENSG00000281663
# Missing ENSG00000281666
# Missing ENSG00000281669
# Missing ENSG00000281672
# Missing ENSG00000281673
# Missing ENSG00000281675
# Missing ENSG00000281678
# Missing ENSG00000281681
# Missing ENSG00000281682
# Missing ENSG00000281684
# Missing ENSG00000281685
# Missing ENSG00000281686
# Missing ENSG00000281689
# Missing ENSG00000281694
# Missing ENSG00000281695
# Missing ENSG00000281698
# Missing ENSG00000281700
# Missing ENSG00000281701
# Missing ENSG00000281712
# Missing ENSG00000281713
# Missing ENSG00000281714
# Missing ENSG00000281715
# Missing ENSG00000281717
# Missing ENSG00000281719
# Missing ENSG00000281724
# Missing ENSG00000281726
# Missing ENSG00000281727
# Missing ENSG00000281729
# Missing ENSG00000281730
# Missing ENSG00000281735
# Missing ENSG00000281739
# Missing ENSG00000281744
# Missing ENSG00000281745
# Missing ENSG00000281746
# Missing ENSG00000281747
# Missing ENSG00000281749
# Missing ENSG00000281751
# Missing ENSG00000281752
# Missing ENSG00000281755
# Missing ENSG00000281765
# Missing ENSG00000281768
# Missing ENSG00000281774
# Missing ENSG00000281776
# Missing ENSG00000281779
# Missing ENSG00000281784
# Missing ENSG00000281786
# Missing ENSG00000281789
# Missing ENSG00000281790
# Missing ENSG00000281791
# Missing ENSG00000281795
# Missing ENSG00000281796
# Missing ENSG00000281802
# Missing ENSG00000281807
# Missing ENSG00000281812
# Missing ENSG00000281814
# Missing ENSG00000281816
# Missing ENSG00000281817
# Missing ENSG00000281823
# Missing ENSG00000281824
# Missing ENSG00000281826
# Missing ENSG00000281827
# Missing ENSG00000281834
# Missing ENSG00000281838
# Missing ENSG00000281843
# Missing ENSG00000281844
# Missing ENSG00000281845
# Missing ENSG00000281850
# Missing ENSG00000281851
# Missing ENSG00000281854
# Missing ENSG00000281864
# Missing ENSG00000281866
# Missing ENSG00000281867
# Missing ENSG00000281868
# Missing ENSG00000281869
# Missing ENSG00000281871
# Missing ENSG00000281872
# Missing ENSG00000281875
# Missing ENSG00000281882
# Missing ENSG00000281884
# Missing ENSG00000281888
# Missing ENSG00000281891
# Missing ENSG00000281892
# Missing ENSG00000281893
# Missing ENSG00000281895
# Missing ENSG00000281902
# Missing ENSG00000281905
# Missing ENSG00000281906
# Missing ENSG00000281918
# Missing ENSG00000281921
# Missing ENSGR0000002586
# Missing ENSGR0000124333
# Missing ENSGR0000124334
# Missing ENSGR0000167393
# Missing ENSGR0000168939
# Missing ENSGR0000169084
# Missing ENSGR0000169093
# Missing ENSGR0000169100
# Missing ENSGR0000178605
# Missing ENSGR0000182162
# Missing ENSGR0000182378
# Missing ENSGR0000182484
# Missing ENSGR0000185203
# Missing ENSGR0000185291
# Missing ENSGR0000185960
# Missing ENSGR0000196433
# Missing ENSGR0000197976
# Missing ENSGR0000198223
# Missing ENSGR0000205755
# Missing ENSGR0000214717
# Missing ENSGR0000223274
# Missing ENSGR0000223484
# Missing ENSGR0000223511
# Missing ENSGR0000223571
# Missing ENSGR0000223773
# Missing ENSGR0000225661
# Missing ENSGR0000226179
# Missing ENSGR0000227159
# Missing ENSGR0000228410
# Missing ENSGR0000228572
# Missing ENSGR0000229232
# Missing ENSGR0000230542
# Missing ENSGR0000234622
# Missing ENSGR0000234958
# Missing ENSGR0000236017
# Missing ENSGR0000236871
# Missing ENSGR0000237040
# Missing ENSGR0000237531
# Missing ENSGR0000237801
# Missing ENSGR0000263835
# Missing ENSGR0000263980
# Missing ENSGR0000264510
# Missing ENSGR0000264819
# Missing ENSGR0000265658
# Missing ENSGR0000270726
# Missing ENSGR0000275287
# Missing ENSGR0000276543
# Missing ENSGR0000277120
# Missing ENSGR0000280767
# Missing ENSGR0000281849

# %%
for g in EnsemblToGeneNamesList:
    EnsemblToGeneNamesList[g]=list(set(EnsemblToGeneNamesList.get(g)))
    EnsemblToGeneNamesList.get(g).sort()
    if (len(EnsemblToGeneNamesList.get(g))>1):
        print(g,EnsemblToGeneNamesList.get(g).sort())

# %% [markdown]
# Construction de la liste des cibles

# %%
# étape 1 : construction du fichier d'association Reactions <-> EC numbers

eprint("Entering : Association RxN <-> Enzymes list construction")

SBMLfile = Param_SBMLfile

#SBMLfile = raw_input("Enter the SBML filename ? ")

def ConstructAssociationList(SBMLfile, RXN_EC_file="/tmp/RXN_EC.txt"):

    import os
    os.system("../scripts/Construct_List_RXN_Enzymes.sh "+SBMLfile+" "+RXN_EC_file)
    fd = open(RXN_EC_file,"r")
    lines = fd.readlines()

    genes = dict()
    for l in lines:
        t=l.split(" ")
        cum=''
        for i in range(1,len(t)-1):
            cum=cum+t[i]+" "
        genes[t[0]]=cum
    return genes

genes=ConstructAssociationList(SBMLfile,RXN_EC_file)
# Out:
# Entering : Association RxN <-> Enzymes list construction

# %%
# Etape 2 : Single Reaction Analysis

eprint("Entering : Single Reaction Analysis")

# perfoming a single_reaction_deletion analysis of the network

model = cobra.io.read_sbml_model(SBMLfile)

# the objective coefficient must be properly set
model.reactions.CancerBiomass_OF.objective_coefficient=1

# reference biomass growth
fba=model.optimize().f

# single reaction deletion analysis

## DEBUG ONLY
begin = timer()
## END DEBUG ONLY
if (Param_DoReconstruction):
    rates, status = cobra.flux_analysis.single_reaction_deletion(model,solver=whichsolver)

## DEBUG ONLY
end = timer()
eprint("Execution time (Single Reaction Analysis) = ",end-begin,"seconds")
## END DEBUG ONLY
# Out:
# Entering : Single Reaction Analysis
# Execution time (Single Reaction Analysis) =  0.00010793498950079083 seconds

# %%
# Etape 3 : Extraction des enzymes régulateurs (nécessite étape 1 et 2)

def getRegulators(rates, percentage=1.1):
    regulators = dict()

    cpt=0
    for r in rates:
        if (rates.get(r)<percentage*fba):
            if (genes.get(r)!=''):
                # print(r,':',rates.get(r)," ",genes.get(r))
                cpt=cpt+1
                l=genes.get(r).split(' ')
                for i in l:
                    if (i != ''):
                        regulators[i]=1
    return regulators

if (Param_DoReconstruction):
    regulators = getRegulators(rates, Param_Pourcentage)

# %%
# Etape 4 : récupération de la liste de gènes régulateurs
def GeneListFromEC(ecnumber):
    if (ecnumber.find('-')>0):
        cum=list()
        for i in range(1,500):
            gl=ECTCDBToEnsembl.get(ecnumber.replace('-',str(i)))
            if (gl != None and len(gl)>0):
                cum+=gl
        return cum
    else:
        gl=ECTCDBToEnsembl.get(ecnumber)
        if (gl == None):
            gl=list()
        return gl

if (Param_DoReconstruction):
    TargetGenesEnsembl=list()
    for ec in regulators:
        TargetGenesEnsembl+=GeneListFromEC(ec.lower())
    
    TargetGenes = [EnsemblToGeneNames.get(x) for x in TargetGenesEnsembl]
    
    
    TargetGenes=set(TargetGenes)
    TargetGenes=list(TargetGenes)
    
    TargetGenesEnsembl=set(TargetGenesEnsembl)
    TargetGenesEnsembl=list(TargetGenesEnsembl)
    
    eprint("Target gene list size =",len(TargetGenes))

# %% [markdown]
# Regulatory network reconstruction using PathwayCommons SPARQL endpoint

# %%
# Algorithms

def GetTFControllers(EnsemblId):
    commonPCPrefixes = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX taxon: <http://identifiers.org/taxonomy/>
PREFIX reactome: <http://identifiers.org/reactome/>
PREFIX release: <http://www.reactome.org/biopax/49/48887#>

PREFIX up: <http://purl.uniprot.org/core/> 
PREFIX uniprot: <http://purl.uniprot.org/uniprot/>
PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX chebi: <http://purl.obolibrary.org/obo/CHEBI_>
PREFIX obo2: <http://purl.obolibrary.org/obo#>
"""

    Request = """
SELECT ?tempReac ?type ?controlledName ?controllerName ?source WHERE{ 
    FILTER( (?controlledName = 'Transcription of %%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>)
        and (?controllerName != '%%GENETARGETNAME%%')
        and (?source != 'mirtarbase') ) .
    # ?tempReac a bp:TemplateReactionRegulation .
    # ?tempReac bp:displayName ?reacName ; 
        bp:controlled ?controlled ; 
        bp:controller ?controller ; 
        bp:controlType ?type ; 
        bp:dataSource ?source .
    # ?controlled bp:displayName ?controlledName .
    # ?controller bp:displayName ?controllerName . }
GROUP BY ?controlledName ?controllerName
"""
    RequestToBePerformed=commonPCPrefixes+Request.replace("%%GENETARGETNAME%%",EnsemblId)
    sparql = SPARQLWrapper(PC_Endpoint)
    sparql.setQuery(RequestToBePerformed)
    sparql.setReturnFormat(JSON)
    query = sparql.query().convert()
    results=list()
    listofgenes=list()
    ListBindings=query.get('results').get('bindings')
    for l in ListBindings:
        controllerName = (l.get('controllerName').get('value'))
        controlType= (l.get('type').get('value'))
        rule = controllerName+"_"+controlType+"_"+EnsemblId
        if (rule not in results):
            results.append(rule)
        if (controllerName not in listofgenes):
            listofgenes.append(controllerName)
    return results,listofgenes

def getParentGraph(l,limit=30):
    i=0
    allgenes=dict()
    for g in l:
        allgenes[g]=1
    listofrelations=list()
    unmapped=list()
    while (i<len(l) and i<limit):
        gene=l[i]
        relations,newgenes = GetTFControllers(gene)
        if (len(relations) == 0):
            unmapped.append(gene)
        listofrelations+=relations
        for g in newgenes:
            if (allgenes.get(g) != 1): # (g not in l):
                l.append(g)
                allgenes[g]=1
        i+=1
    return listofrelations,l,unmapped

# %%
eprint("Entering : RRG reconstruction")


## DEBUG ONLY
begin = timer()
## END DEBUG ONLY

if (Param_DoReconstruction):
    TargetGenesName = TargetGenes #[EnsemblToGeneNames.get(x) for x in TargetGenes if (len(x) > 2)]
    
    a,b,u=getParentGraph(TargetGenesName,50000)
    
    ## DEBUG ONLY
    end = timer()
    eprint("Execution time for RRG reconstruction = ",end-begin,"seconds")
    ## END DEBUG ONLY
    
    eprint('Reconstructed graph contains',len(b),'genes,',len(a),'interactions,','with',len(u),'unmapped genes.')
    
    
    # write the file for compatibility purpose
    
    fd = open(Param_RRGFilename,"w")
    for r in a:
        relation=r.split("_")
        if (relation[1] != "ACTIVATION"):
            eprint(relation)
        fd.write(relation[0]+";"+relation[2]+"\n")
    fd.close()
# Out:
# Entering : RRG reconstruction

# %%
# Construction and filter
eprint("Entering : Graph Filtering")

RNASeqList=dict()
for g in RNASeqlistofgenes:
    RNASeqList[EnsemblToGeneNames[g]]=1


GenesToBeRemoved=list()

filename = Param_RRGFilename

genesingraph = dict()
listofgenes = list()
listofinteractions = list()
listofinteractionsNamed = list()

fd = open(filename,"r")

lines = fd.readlines()
geneid=0
for l in lines:
    t=l.split(";")
    t[1]=t[1].replace("\n","")
#    if (GeneNamesToEnsembl[t[0]] in RNASeqlistofgenes and GeneNamesToEnsembl[t[1]] in RNASeqlistofgenes):
    if (RNASeqList.get(t[0]) and RNASeqList.get(t[1])):
        if (not (GeneNamesToEnsembl[t[0]] in GenesToBeRemoved or GeneNamesToEnsembl[t[1]] in GenesToBeRemoved)):
            if (listofgenes.count(GeneNamesToEnsembl[t[0]]) == 0):
                listofgenes.append(GeneNamesToEnsembl[t[0]])
                genesingraph[GeneNamesToEnsembl[t[0]]]=len(listofgenes)-1
            if (listofgenes.count(GeneNamesToEnsembl[t[1]]) == 0):
                listofgenes.append(GeneNamesToEnsembl[t[1]])
                genesingraph[GeneNamesToEnsembl[t[1]]]=len(listofgenes)-1
            listofinteractions.append((genesingraph[GeneNamesToEnsembl[t[0]]],genesingraph[GeneNamesToEnsembl[t[1]]]))
            listofinteractionsNamed.append((GeneNamesToEnsembl[t[0]],GeneNamesToEnsembl[t[1]]))
    else:
        eprint("Warning : ",GeneNamesToEnsembl[t[0]],"or",GeneNamesToEnsembl[t[1]],"isn't in RNASeq",)

fd.close()



# It is required to remove cycles and loops in the graph.
# Here is a greedy method

listofinteractionsNamedClean = list()

RRG = nx.DiGraph()
for t in listofinteractionsNamed:
#    if True:
    if not((RRG.has_node(t[0]) and RRG.has_node(t[1]) and (RRG.has_edge(t[1],t[0]) or nx.has_path(RRG,t[1],t[0])))):
        RRG.add_edge(t[0],t[1])
        listofinteractionsNamedClean.append((t[0],t[1]))

globalmax=100
nbRemovedGenes=0

while (globalmax>Param_MaxIndegreeInRRG):
    T=RRG.in_degree()
    Tout=RRG.out_degree()
    vmax=-1
    globalmax=-1
    keymax = ""
    for g in T:
        v=T.get(g)
        if (v>vmax and Tout.get(g)>0):
            vmax=v
            keymax = g
        if (v>globalmax):
            globalmax=v
    #print("Remove gene ",keymax, "having an in degree equal to",vmax)
    GenesToBeRemoved.append(keymax)
    nbRemovedGenes+=1
    RRG.remove_node(keymax)
eprint("Remove ",nbRemovedGenes,"genes")

filename = Param_RRGFilename

genesingraph = dict()
listofgenes = list()
listofinteractions = list()
listofinteractionsNamed = list()

fd = open(filename,"r")

lines = fd.readlines()
geneid=0
for l in lines:
    t=l.split(";")
    t[1]=t[1].replace("\n","")
#    if (GeneNamesToEnsembl[t[0]] in RNASeqlistofgenes and GeneNamesToEnsembl[t[1]] in RNASeqlistofgenes):
#    if (RNASeqList.get(GeneNamesToEnsembl[t[0]]) and RNASeqList.get(GeneNamesToEnsembl[t[1]])):
    if (RNASeqList.get(t[0]) and RNASeqList.get(t[1])):
        if (not (GeneNamesToEnsembl[t[0]] in GenesToBeRemoved or GeneNamesToEnsembl[t[1]] in GenesToBeRemoved)):
            if (listofgenes.count(GeneNamesToEnsembl[t[0]]) == 0):
                listofgenes.append(GeneNamesToEnsembl[t[0]])
                genesingraph[GeneNamesToEnsembl[t[0]]]=len(listofgenes)-1
            if (listofgenes.count(GeneNamesToEnsembl[t[1]]) == 0):
                listofgenes.append(GeneNamesToEnsembl[t[1]])
                genesingraph[GeneNamesToEnsembl[t[1]]]=len(listofgenes)-1
            listofinteractions.append((genesingraph[GeneNamesToEnsembl[t[0]]],genesingraph[GeneNamesToEnsembl[t[1]]]))
            listofinteractionsNamed.append((GeneNamesToEnsembl[t[0]],GeneNamesToEnsembl[t[1]]))

fd.close()

# It is required to remove to cycles and loops in the graph.
# Here is a greedy method

listofinteractionsNamedClean = list()

RRG = nx.DiGraph()
for t in listofinteractionsNamed:
    if not((RRG.has_node(t[0]) and RRG.has_node(t[1]) and (RRG.has_edge(t[1],t[0]) or nx.has_path(RRG,t[1],t[0])))):
        RRG.add_edge(t[0],t[1])
        listofinteractionsNamedClean.append((t[0],t[1]))
#    else:
#        print("Boucle si ajout de %s -> %s" % (t[0],t[1]))
# Out:
# Entering : Graph Filtering
# Warning :  ENSG00000180318 or ENSG00000115919 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000104313 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000104313 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000089250 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000064655 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000008086 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000161896 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000077264 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000133216 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000116539 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000155897 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000081237 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000146872 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000175175 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000115170 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000275176 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000115687 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000087095 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000233276 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000135333 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000143322 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000154358 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000109107 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000110422 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000044524 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000104375 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000010810 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000095596 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000095596 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000173153 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000106546 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000100644 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000156925 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000163064 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000163064 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000143190 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000113580 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000118689 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000185630 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000179456 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000125952 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000168267 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000134532 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000106004 isn't in RNASeq
# Warning :  ENSG00000177426 or ENSG00000168269 isn't in RNASeq
# Warning :  ENSG00000180318 or ENSG00000105997 isn't in RNASeq
# Remove  116 genes

# %%
# Building the Bayesian model (from listofinteractionsNamedClean)

eprint("Entering : Bayesian model Skeleton Construction")

## DEBUG ONLY
begin = timer()
## END DEBUG ONLY



model = BayesianModel(listofinteractionsNamedClean)



## DEBUG ONLY
end = timer()
eprint("Execution time (Bayesian model Skeleton Construction) = ",end-begin,"seconds")
## END DEBUG ONLY
# Out:
# Entering : Bayesian model Skeleton Construction
# Execution time (Bayesian model Skeleton Construction) =  0.06754369499685708 seconds

# %%
# basic optimization (use of a hash table to know if a gene is in the RRG)
GeneDict=dict()

for g in listofgenes:
    GeneDict[g]=1

# %% [markdown]
# RNASeq Data integration

# %%
# Reading the datafile (RNA-seq normalized with DESeq2)

eprint("Entering : RNASeq data discretization")


## DEBUG ONLY
begin = timer()
## END DEBUG ONLY




filename = Param_RNASeqFilename

data = dict()

TumoralConditions=list()
NormalConditions=list()

fd = open(filename,"r")

l=fd.readline()
l=l.replace('"','').replace('\n','')
t=l.split(",")

for i in range(1,len(t)):
    if (t[i][0:2] == "CT"):
        TumoralConditions.append(i)
    if (t[i][0:2] == "CN"):
        NormalConditions.append(i)

# à résoudre: il y a des gènes dans le graphe qui ne sont pas dans les données... Arrrgh

raw_data=np.random.randint(low=0, high=1, size=(len(TumoralConditions),len(listofgenes)))

sortedlistofgenes=list()
# allgenes=list()

for l in fd:
    l=l.replace('"','').replace('\n','')
    t=l.split(",")
    NormalValues = [log(0.0001+float(t[x])) for x in NormalConditions]
#    NormalValues=np.array(len(NormalConditions))
#    for j in range(len(NormalConditions)):
#        NormalValues[j]=t[NormalConditions[j]]
    NormalMean=np.mean(NormalValues)
    NormalStd=np.std(NormalValues)
    geneid=t[0].split(".")[0]
    BinarizedValues=[Binarized(float(t[x]),NormalMean,NormalStd,geneid) for x in TumoralConditions]
    #if (GeneDict.get(geneid) == 1):
    #        print(geneid,sum(BinarizedValues))
    #if (geneid in listofgenes):
    if (GeneDict.get(geneid) == 1):
        raw_data[:,len(sortedlistofgenes)]=BinarizedValues
        sortedlistofgenes.append(geneid)
    #print(t[0].split(".")[0],BinarizedValues)

fd.close()

data = pd.DataFrame(raw_data, columns=sortedlistofgenes)




## DEBUG ONLY
end = timer()
eprint("Execution time (RNASeq data discretization) = ",end-begin,"seconds")
## END DEBUG ONLY
# Out:
# Entering : RNASeq data discretization
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jeremiebourdon/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    3983                 blocks = [make_block(values=blocks[0],
# -> 3984                                      placement=slice(0, len(axes[0])))]
#    3985
#
# /Users/jeremiebourdon/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2517
# -> 2518     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2519
#
# /Users/jeremiebourdon/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim, fastpath)
#      89                              'implies %d' % (len(self.values),
# ---> 90                                              len(self.mgr_locs)))
#      91
#
# ValueError: Wrong number of items passed 589, placement implies 584
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-dc2de07731ec> in <module>()
#      58 fd.close()
#      59
# ---> 60 data = pd.DataFrame(raw_data, columns=sortedlistofgenes)
#      61
#      62
#
# /Users/jeremiebourdon/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     253             else:
#     254                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 255                                          copy=copy)
#     256         elif isinstance(data, (list, types.GeneratorType)):
#     257             if isinstance(data, types.GeneratorType):
#
# /Users/jeremiebourdon/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     430             values = _possibly_infer_to_datetimelike(values)
#     431
# --> 432         return create_block_manager_from_blocks([values], [columns, index])
#     433
#     434     @property
#
# /Users/jeremiebourdon/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    3991         blocks = [getattr(b, 'values', b) for b in blocks]
#    3992         tot_items = sum(b.shape[0] for b in blocks)
# -> 3993         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    3994
#    3995
#
# /Users/jeremiebourdon/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    3968         raise ValueError("Empty data passed with indices specified.")
#    3969     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 3970         passed, implied))
#    3971
#    3972
#
# ValueError: Shape of passed values is (589, 250), indices imply (584, 250)

# %%
# Fitting the BN with data

eprint("Entering : Bayesian Network fitting with RNASeq data")

## DEBUG ONLY
begin = timer()
## END DEBUG ONLY

model.fit(data, estimator=BayesianEstimator, prior_type='K2')

## DEBUG ONLY
end = timer()
eprint("Execution time (Bayesian Network fitting with RNASeq data) = ",end-begin,"seconds")
## END DEBUG ONLY

# saving the Bayesian Network for further use
writer = BIFWriter(model)
writer.write_bif(filename=BIF_file)

# %% [markdown]
# Querying the Bayesian Network

# %%
def getEvidence(medname):
    listgenes = Allmeds.get(medname).get("TargetsGenesEnsembl")
    evidences = [State(x, 0) for x in listgenes if x in RRG.nodes()]
    return evidences

# %%
# An alternative way is to perform a Bayesian Sampling of the BN

eprint("Entering : Querying the Bayesian Network")


## DEBUG ONLY
begin = timer()
## END DEBUG ONLY

inference = BayesianModelSampling(model)
## DEBUG ONLY
end = timer()
eprint("Execution time, first part of Querying the Bayesian Network = ",end-begin,"seconds")
## END DEBUG ONLY


Number_of_samples = Param_NumberOfSample

# NB evidences should be read somewhere
evidences = getEvidence(Param_Drug)


## DEBUG ONLY
begin = timer()
## END DEBUG ONLY

samples=inference.likelihood_weighted_sample(evidences, Number_of_samples)
#samples=inference.rejection_sample(evidences, Number_of_samples)


## DEBUG ONLY
end = timer()
eprint("Execution time, second part (Querying the Bayesian Network) = ",end-begin,"seconds")
## END DEBUG ONLY

# %%
# get all the marginal probabilities for that evidence
allMarginalProb=dict()
for g in sortedlistofgenes:
    #print(g," p0=",samples[g].eq(0).sum()/Number_of_samples," p1=",samples[g].eq(1).sum()/Number_of_samples," p2=",samples[g].eq(2).sum()/Number_of_samples)
    allMarginalProb[g]=[samples[g].eq(0).sum()/Number_of_samples,samples[g].eq(1).sum()/Number_of_samples,samples[g].eq(2).sum()/Number_of_samples]

# %%
# Correspondance Reaction <-> Enzymes
filename = RXN_EC_file

ReactionsToEnsembl = dict()

fd = open(filename,"r")

lines = fd.readlines()
for l in lines:
    t=l.split(" ")
    RXN = t[0]
    t[len(t)-1]=t[len(t)-1].replace("\n","")
    ReactionsToEnsembl[RXN]=list()
    for i in range(1,len(t)):
        val = ECTCDBToEnsembl.get(t[i].lower())
        if (val != None):
            ReactionsToEnsembl[RXN]+=val
fd.close()

# %%
def ProbaReaction(L):
    global allMarginalProb
    maximum=0
    minimum=1000    
    for l in L:
        if allMarginalProb.get(l):
            minimum=min([minimum,1-allMarginalProb.get(l)[0]])
            maximum=max([maximum,1-allMarginalProb.get(l)[0]])
    if minimum==1000:
        return "1;1"
    else:
        return str(minimum)+";"+str(maximum)



# Output the reactions probabilities

output=open(Param_ProbaReactionsFilename,"w")

for r in ReactionsToEnsembl:
    if (len(ReactionsToEnsembl.get(r))>0):
        output.write(str(r)+";"+str(ProbaReaction(ReactionsToEnsembl.get(r)))+"\n")
output.close()

# %% [markdown]
# Dernière partie, calcul de la nouvelle biomasse

# %%
# To be very efficient, the long formal expressions must be reconstructed in a clever way

def ExpressionFromList_rec(L,a,b):
    #print(L,a,b)
    if (b == a):
        #print("Adding",0)
        return 0
    else:
        if (b-a == 1):
            #print("Adding L["+str(a)+"]",L[a])
            return L[a]
        else:
            milieu = int((a+b)/2)
            return ExpressionFromList_rec(L,a,milieu)+ExpressionFromList_rec(L,milieu,b)

def ExpressionFromList(L):
    return ExpressionFromList_rec(L,0,len(L))


def CobraModelToPROMOptLangModel(model,Prob,lambd=-1.0,usedsolver="cglpk"):
    epsilon = 1e-10
    myoptmodel = optlang.Model(name = "test")
    # first of all, performs a FVA analysis
    eprint("Performing a FVA analysis")
    currenttime=timer()
    fva0=flux_variability_analysis(model,fraction_of_optimum=0.001,solver=usedsolver)
    fva=flux_variability_analysis(model,fraction_of_optimum=0.99,solver=usedsolver)
    eprint("Finishing the FVA analysis in",timer()-currenttime,"seconds")


    obj=0
    ListObjective=list()

    Allvariables = list()
    Alphavariables = list()
    Betavariables = list()

    AdditionalConstraints = list()
    i=0
    currenttime=timer()
    
    
    for r in model.reactions:
        if (i % 100 == 0):
            eprint("Creating",i,"variables in",timer()-currenttime,"seconds")
            currenttime=timer()
        i+=1

        #v=optlang.Variable(r.id,lb=r.lower_bound,ub=r.upper_bound)
        v=optlang.Variable(r.id,lb=fva0.get(r.id).get('minimum')-epsilon,ub=fva0.get(r.id).get('maximum')+epsilon)     
        # v=optlang.Variable(r.id,lb=-2000,ub=2000)
        Allvariables.append(v)

        # alpha_i and beta_i
        pi = Prob.get(r.id) # now a vector of [min,max] probabilities
        if not pi:
            pi = [1,1]
        if (pi[0]<0.99):        
            alpha=optlang.Variable('alpha_'+r.id,lb=0,ub=100000)
            beta=optlang.Variable('beta_'+r.id,lb=0,ub=100000)
            Alphavariables.append(alpha)
            Betavariables.append(beta)
            # contributions of alpha and beta to the objective = lambda * (alpha+beta) with lambda = -1
            #obj = obj + lambd * alpha + lambd * beta
            ListObjective.append(lambd * alpha)
            ListObjective.append(lambd * beta)
            
            AdditionalConstraints.append(optlang.Constraint(v+alpha,lb=pi[1]*fva.get(r.id).get('minimum'),ub=2000))
            AdditionalConstraints.append(optlang.Constraint(v-beta,lb=-2000,ub=pi[0]*fva.get(r.id).get('maximum')))

        if r.objective_coefficient != 0:
            # obj = obj + r.objective_coefficient * v
            ListObjective.append(r.objective_coefficient * v)

    
    currenttime=timer()
    eprint("Reconstructing Objective")
#    for o in ListObjective:
#        obj=obj+o
    obj = ExpressionFromList(ListObjective)
    eprint("Reconstructing Objective in",timer()-currenttime,"seconds")
    
    AllConstraints = list()
    i=0
    currenttime=timer()
    for m in model.metabolites:
        if (i % 100 == 0):
            eprint("Creating",i,"constraints in",timer()-currenttime,"seconds")
            currenttime=timer()
        i+=1
        C=list()
        for r in m.reactions:
            C.append(r.get_coefficient(m)*Allvariables[model.reactions.index(r)])
        AllConstraints.append(optlang.Constraint(ExpressionFromList(C),lb=0,ub=0))

    eprint("Adding Allvariables")
    myoptmodel.add(Allvariables)
    eprint("Adding Alphavariables")
    myoptmodel.add(Alphavariables)
    eprint("Adding Betavariables")
    myoptmodel.add(Betavariables)
    eprint("Adding AllConstraints")
    myoptmodel.add(AllConstraints)
    eprint("Adding AdditionalConstraints")
    myoptmodel.add(AdditionalConstraints)
    myoptmodel.objective = optlang.Objective(obj, direction="max")
    return myoptmodel

# %%
# on recharge les probabilités des réactions pour des problèmes de compatibilités

filename = Param_ProbaReactionsFilename
fd=open(filename,"r")

ProbaReaction=dict()

lines = fd.readlines()

for l in lines:
    t=l.split(";")
    t[1]=t[1].replace("\n","")
    ProbaReaction[t[0]]=[float(t[1]),float(t[2])]

fd.close()

# %%
# on recharge le modèle cobra
mcancer = cobra.io.read_sbml_model(Param_SBMLfile)
mcancer.reactions.CancerBiomass_OF.objective_coefficient = 1

# %%
# Creation du modèle PROM sous optlang
begin = timer()
mProm=CobraModelToPROMOptLangModel(mcancer,ProbaReaction,usedsolver=whichsolver)
end = timer()

eprint("Execution time (PROM Model creation) =",end-begin,"seconds")
# Out:
# Performing a FVA analysis
# Finishing the FVA analysis in 76.13515910299611 seconds
# Creating 0 variables in 6.417001713998616e-06 seconds
# Creating 100 variables in 0.030046086001675576 seconds
# Creating 200 variables in 0.0203411279944703 seconds
# Creating 300 variables in 0.010559315996943042 seconds
# Creating 400 variables in 0.012518830000772141 seconds
# Creating 500 variables in 0.024819788988679647 seconds
# Creating 600 variables in 0.01967674499610439 seconds
# Creating 700 variables in 0.015266921996953897 seconds
# Creating 800 variables in 0.014040042995475233 seconds
# Creating 900 variables in 0.011274874996161088 seconds
# Creating 1000 variables in 0.08095710199268069 seconds
# Creating 1100 variables in 0.1867264239990618 seconds
# Creating 1200 variables in 0.005916485999478027 seconds
# Creating 1300 variables in 0.01320988500083331 seconds
# Creating 1400 variables in 0.019400478995521553 seconds
# Creating 1500 variables in 0.04817806000937708 seconds
# Creating 1600 variables in 0.0031690759933553636 seconds
# Creating 1700 variables in 0.01826351099589374 seconds
# Creating 1800 variables in 0.028528194990940392 seconds
# Creating 1900 variables in 0.011076031005359255 seconds
# Creating 2000 variables in 0.009096594003494829 seconds
# Creating 2100 variables in 0.006940927007235587 seconds
# Creating 2200 variables in 0.046684043991263025 seconds
# Creating 2300 variables in 0.09375382200232707 seconds
# Creating 2400 variables in 0.015189646001090296 seconds
# Creating 2500 variables in 0.019523658993421122 seconds
# Creating 2600 variables in 0.01469865300168749 seconds
# Creating 2700 variables in 0.013686356993275695 seconds
# Creating 2800 variables in 0.003939035988878459 seconds
# Creating 2900 variables in 0.007446809991961345 seconds
# Creating 3000 variables in 0.009837412988417782 seconds
# Creating 3100 variables in 0.015926922991639003 seconds
# Creating 3200 variables in 0.02326843500486575 seconds
# Creating 3300 variables in 0.025805875993683003 seconds
# Creating 3400 variables in 0.015393075009342283 seconds
# Creating 3500 variables in 0.01176388499152381 seconds
# Creating 3600 variables in 0.037220494996290654 seconds
# Creating 3700 variables in 0.02658603100280743 seconds
# Creating 3800 variables in 0.004345388995716348 seconds
# Creating 3900 variables in 0.019068911002250388 seconds
# Creating 4000 variables in 0.005567524000070989 seconds
# Creating 4100 variables in 0.006077224999899045 seconds
# Creating 4200 variables in 0.0054606829944532365 seconds
# Creating 4300 variables in 0.003749022987904027 seconds
# Reconstructing Objective
# Reconstructing Objective in 3.3227467329998035 seconds
# Creating 0 constraints in 2.6439956855028868e-06 seconds
# Creating 100 constraints in 0.10732738900696859 seconds
# Creating 200 constraints in 0.0949693699949421 seconds
# Creating 300 constraints in 0.12793338700430468 seconds
# Creating 400 constraints in 0.09718989100656472 seconds
# Creating 500 constraints in 0.09863689199846704 seconds
# Creating 600 constraints in 0.08612152400019113 seconds
# Creating 700 constraints in 0.07760658500774298 seconds
# Creating 800 constraints in 0.06442352299927734 seconds
# Creating 900 constraints in 0.06379382099839859 seconds
# Creating 1000 constraints in 0.05630172100791242 seconds
# Creating 1100 constraints in 0.06606741400901228 seconds
# Creating 1200 constraints in 0.0722536449902691 seconds
# Creating 1300 constraints in 0.11045158799970523 seconds
# Creating 1400 constraints in 0.4210732690116856 seconds
# Creating 1500 constraints in 0.6858793729916215 seconds
# Creating 1600 constraints in 0.22451510399696417 seconds
# Creating 1700 constraints in 0.06666701199719682 seconds
# Creating 1800 constraints in 0.1220121329970425 seconds
# Creating 1900 constraints in 1.1117296960001113 seconds
# Creating 2000 constraints in 0.0965191940049408 seconds
# Creating 2100 constraints in 0.13515087599807885 seconds
# Creating 2200 constraints in 0.2087875110009918 seconds
# Creating 2300 constraints in 0.2040262890077429 seconds
# Creating 2400 constraints in 2.585072854999453 seconds
# Creating 2500 constraints in 0.08199741899443325 seconds
# Creating 2600 constraints in 0.09777572000166401 seconds
# Creating 2700 constraints in 0.07595156699244399 seconds
# Creating 2800 constraints in 0.37060559599194676 seconds
# Creating 2900 constraints in 0.15597878900007345 seconds
# Creating 3000 constraints in 1.5615662539930781 seconds
# Creating 3100 constraints in 0.49823358899448067 seconds
# Creating 3200 constraints in 0.23690037199412473 seconds
# Creating 3300 constraints in 0.5729069119988708 seconds
# Creating 3400 constraints in 0.1870405809895601 seconds
# Creating 3500 constraints in 0.19951709899760317 seconds
# Creating 3600 constraints in 0.08836949399847072 seconds
# Creating 3700 constraints in 0.3215925690019503 seconds
# Creating 3800 constraints in 0.016125961992656812 seconds
# Creating 3900 constraints in 0.004587500006891787 seconds
# Creating 4000 constraints in 0.004864007991272956 seconds
# Creating 4100 constraints in 0.004492406995268539 seconds
# Creating 4200 constraints in 0.004547219010419212 seconds
# Creating 4300 constraints in 0.004970887006493285 seconds
# Creating 4400 constraints in 0.005295830997056328 seconds
# Creating 4500 constraints in 0.005173491997993551 seconds
# Creating 4600 constraints in 0.004780839997692965 seconds
# Creating 4700 constraints in 0.0055556860024807975 seconds
# Creating 4800 constraints in 0.004543547998764552 seconds
# Creating 4900 constraints in 0.005146640003658831 seconds
# Creating 5000 constraints in 0.00675992199103348 seconds
# Creating 5100 constraints in 0.006119033991126344 seconds
# Creating 5200 constraints in 0.005560357996728271 seconds
# Creating 5300 constraints in 0.004985684005077928 seconds
# Creating 5400 constraints in 0.004643287000362761 seconds
# Adding Allvariables
# Adding Alphavariables
# Adding Betavariables
# Adding AllConstraints
# Adding AdditionalConstraints
# Execution time (PROM Model creation) = 96.81688027000928 seconds

# %%
# Compares glpk and gurobi
if debugon:
    import gurobipy

    lp = mProm.to_lp()
    lpfilename = Param_SBMLfileBN.replace(".xml",".lp")
    fd=open(lpfilename,"w")
    fd.write(lp)
    fd.close()

    mPromGurobi = gurobipy.read(lpfilename)
    
    begin = timer()
    res=mPromGurobi.optimize()
    eprint("Gurobi",timer()-begin,"seconds, biomass=",mPromGurobi.getVarByName("CancerBiomass_OF").X)


    begin = timer()
    res=mProm.optimize()
    eprint("glpk",timer()-begin,"seconds, biommass=",mProm.variables.CancerBiomass_OF.primal)
# Out:
# Optimize a model with 7134 rows, 7736 columns and 24296 nonzeros
# Coefficient statistics:
#   Matrix range     [1e-04, 8e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [2e-12, 1e+05]
#   RHS range        [7e-15, 2e+03]
# Presolve removed 6249 rows and 5733 columns
# Presolve time: 0.02s
# Presolved: 885 rows, 2003 columns, 8390 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.0591486e+03   3.797524e+05   0.000000e+00      0s
# Extra 281 simplex iterations after uncrush
#     1110   -2.0133030e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 1110 iterations and 0.09 seconds
# Optimal objective -2.013303011e+01
# Gurobi 0.0891809849999845 seconds, biomass= 0.9792230891827144
# glpk 1.0316394029941875 seconds, biommass= 0.9792231215846577

# %%
# Optimisation
begin = timer()
mProm.optimize()
end = timer()

eprint("Execution time (PROM Optimization) =",end-begin,"seconds")
# Out:
# Execution time (PROM Optimization) = 0.0036909530026605353 seconds

# %%
# Results
eprint("Objective value = ",mProm.objective.value)
print("Biomass = ",mProm.variables.CancerBiomass_OF.primal)
# Out:
# Biomass =  0.9792231215846577
# Objective value =  -20.133030226594947

# %%
endtotal = timer()
eprint("Execution completed in",endtotal-begintotal,"seconds")
# Out:
# Execution completed in 16114.383364281995 seconds

# %%
print(GeneNamesToEnsembl[EnsemblToGeneNames['ENSG00000204231']])
