# %% [markdown]
# # Un scénario complet

# %% [markdown]
# Quelques informations et paramètres pour commencer

# %%
from Entete import *

# %% [markdown]
# Tous les includes

# %%
#Param_SBMLfile = "/Users/jeremiebourdon/Downloads/Hep-G2.xml"

# %%
## DEBUG ONLY
begintotal = timer()
eprint("Testing",Param_SBMLfile,"for",Param_Drug)

## END DEBUG ONLY
# Out:
# Testing ../data/iLiverCancer1715.xml for Sorafenib (USAN/INN)

# %% [markdown]
# Chargement des listes de correspondances

# %%
#from AllTables import *
from AllTables import *

# %%
Param_Pourcentage = 0.95

# %% [markdown]
# Construction de la liste des cibles

# %%
# étape 1 : construction du fichier d'association Reactions <-> EC numbers

# obsolete : La liste RXN -> liste gènes est désormais récupérée directement depuis HMRDatabase

# dictionnaire HMR_to_Ensembl


eprint("Entering : Association RxN <-> Enzymes list construction")

SBMLfile = Param_SBMLfile

#SBMLfile = raw_input("Enter the SBML filename ? ")

def ConstructAssociationList(SBMLfile, RXN_EC_file="/tmp/RXN_EC.txt"):

    import os
    os.system("../scripts/Construct_List_RXN_Enzymes.sh "+SBMLfile+" "+RXN_EC_file)
    fd = open(RXN_EC_file,"r")
    lines = fd.readlines()

    genes = dict()
    for l in lines:
        t=l.split(" ")
        cum=''
        for i in range(1,len(t)-1):
            cum=cum+t[i]+" "
        genes[t[0]]=cum
    return genes

genes=ConstructAssociationList(SBMLfile,RXN_EC_file)
# Out:
# Entering : Association RxN <-> Enzymes list construction

# %%
# Etape 2 : Single Reaction Analysis

eprint("Entering : Single Reaction Analysis")

## DEBUG ONLY
begin = timer()
## END DEBUG ONLY


# perfoming a single_reaction_deletion analysis of the network

model = cobra.io.read_sbml_model(Param_SBMLfile)

# the objective coefficient must be properly set
model.reactions.CancerBiomass_OF.objective_coefficient=1

# reference biomass growth
fba=model.optimize().f

# single reaction deletion analysis


if (Param_DoReconstruction and Param_Pourcentage<1):
    rates, status = cobra.flux_analysis.single_reaction_deletion(model,solver=whichsolver)
else:
    rates=dict()
    for r in model.reactions:
        rates[r.id]=0
        
## DEBUG ONLY
end = timer()
eprint("Execution time (Single Reaction Analysis) = ",end-begin,"seconds")
## END DEBUG ONLY
# Out:
# Entering : Single Reaction Analysis
# Execution time (Single Reaction Analysis) =  60.53408400499029 seconds

# %%
model = cobra.io.read_sbml_model('/Users/jeremiebourdon/Downloads/MCF-7.xml')

# %%
for m in model.metabolites:
    if (m.name.count("ADP")):
        print(m.id, m.name, m.compartment)
#for r in model.reactions:
#    print(r)
# Out:
# m00215c [protein]-omega-N-(ADP-D-ribosyl)-L-arginine c
# m01285c ADP c
# m01285l ADP l
# m01285m ADP m
# m01285n ADP n
# m01285r ADP r
# m01285s ADP s
# m01286c ADP-glucose c
# m01286s ADP-glucose s
# m01287c ADP-mannose c
# m01287s ADP-mannose s
# m01288c ADP-ribose c
# m01288s ADP-ribose s
# m01637c dADP c
# m01637m dADP m
# m01637n dADP n
# m02496c N(omega)-(ADP-D-ribosyl)-L-arginine c
# m02554c NADP+ c
# m02554m NADP+ m
# m02554n NADP+ n
# m02554p NADP+ p
# m02554r NADP+ r
# m02555c NADPH c
# m02555m NADPH m
# m02555n NADPH n
# m02555p NADPH p
# m02555r NADPH r

# %%
model.reactions.biomass_components.objective_coefficient = 1
model.optimize()
# Out:
# <Solution -0.00 at 0x13d72fac8>

# %%
MetFlux["NEFA"]=9.435
MetFlux["glucose"]=61.967
MetFlux["linoleate"]=-1.4771
MetFlux["histidine"]=-0.42186
MetFlux["isoleucine"]=-4.5346
MetFlux["leucine"]=-4.8616
MetFlux["lysine"]=-3.7669
MetFlux["methionine"]=-1.512
MetFlux["phenylalanine"]=-0.42186
MetFlux["threonine"]=-2.1126
MetFlux["tryptophan"]=-0.42186
MetFlux["valine"]=-2.5502
MetFlux["H2O"]=0.012347
MetFlux["O2"]=-47.1389
MetFlux["CO2"]=-32.3697
MetFlux["alanine"]=-2.0184
MetFlux["asparagine"]=1.24
MetFlux["glutamine"]=18.1648
MetFlux["tyrosine"]=1.7553
MetFlux["cysteine"]=-0.66829
MetFlux["arginine"]=2.7083
MetFlux["glycine"]=1.4082
MetFlux["proline"]=0.20996
MetFlux["serine"]=5.5838
MetFlux["aspartate"]=1.8467
MetFlux["glutamate"]=1.411
MetFlux["Pi"]=-0.012347
MetFlux["NH3"]=-2.8121
MetFlux["HCO3-"]=-0.80866
MetFlux["choline"]=0.42717
MetFlux["ethanolamine"]=-4.8705
MetFlux["acetate"]=-47.4465
MetFlux["ornithine"]=-30.0037
MetFlux["5-formyl-THF"]=0.24872
MetFlux["acetoacetate"]=-0.42157
MetFlux["L-lactate"]=-41.7375
MetFlux["fructose"]=-38.4359
MetFlux["ADP-ribose"]=0.012519
MetFlux["folate"]=0.0022124
MetFlux["homoserine"]=0.6349
MetFlux["citrulline"]=0.082847
MetFlux["2-hydroxybutyrate"]=-3.4158
MetFlux["5-methyl-THF"]=-0.66829
MetFlux["adenine"]=-0.00093523
MetFlux["adenosine"]=-0.00040792
MetFlux["ADP"]=0.0012202
MetFlux["AKG"]=-0.0015523
MetFlux["AMP"]=-0.0012202
MetFlux["CMP"]=-0.0015891
MetFlux["cytidine"]=0.0021187
MetFlux["deoxycytidine"]=0.0018937
MetFlux["deoxyuridine"]=0.0020755
MetFlux["GDP"]=0.0020071
MetFlux["GMP"]=-0.00063611
MetFlux["hypoxanthine"]=0.021934
MetFlux["inosine"]=-0.00024905
MetFlux["THF"]=0.41736
MetFlux["thymine"]=-0.000079265
MetFlux["thymidine"]=0.0015529
MetFlux["UDP"]=0.0045704
MetFlux["UMP"]=-0.0045704
MetFlux["uracil"]=-0.0084013
MetFlux["urea"]=-2.3693
MetFlux["uridine"]=0.0068026
MetFlux["UTP"]=0.61997
MetFlux["XTP"]=0.28912
MetFlux["ADP-glucose"]=0.31787
MetFlux["D-glucitol"]=-0.014345

# %%
model = cobra.io.read_sbml_model('/Users/jeremiebourdon/Downloads/Hep-G2.xml')


MetFlux=dict()
MetFlux["propanoate"]=0.000078515
MetFlux["NEFA"]=9.435
MetFlux["glucose"]=61.967
MetFlux["linoleate"]=-1.4771
MetFlux["histidine"]=-0.42186
MetFlux["isoleucine"]=-4.5346
MetFlux["leucine"]=-4.8616
MetFlux["lysine"]=-3.7669
MetFlux["methionine"]=-1.512
MetFlux["phenylalanine"]=-0.42186
MetFlux["threonine"]=-2.1126
MetFlux["tryptophan"]=-0.42186
MetFlux["valine"]=-2.5502
MetFlux["H2O"]=0.012347
MetFlux["O2"]=-47.1389
MetFlux["CO2"]=-32.3697
MetFlux["alanine"]=-2.0184
MetFlux["asparagine"]=1.24
MetFlux["glutamine"]=18.1648
#MetFlux["tyrosine"]=1.7553
MetFlux["cysteine"]=-0.66829
MetFlux["arginine"]=2.7083
MetFlux["glycine"]=1.4082
MetFlux["proline"]=0.20996
MetFlux["serine"]=5.5838
#MetFlux["aspartate"]=1.8467
MetFlux["glutamate"]=1.411
MetFlux["Pi"]=-0.012347
MetFlux["NH3"]=-2.8121
#MetFlux["HCO3-"]=-0.80866
MetFlux["choline"]=0.42717
MetFlux["ethanolamine"]=-4.8705
MetFlux["acetate"]=-47.4465
MetFlux["ornithine"]=-30.0037
#MetFlux["5-formyl-THF"]=0.24872
MetFlux["acetoacetate"]=-0.42157
MetFlux["L-lactate"]=-41.7375
MetFlux["fructose"]=-38.4359
#MetFlux["ADP-ribose"]=0.012519
MetFlux["folate"]=0.0022124
#MetFlux["homoserine"]=0.6349
#MetFlux["citrulline"]=0.082847
MetFlux["2-hydroxybutyrate"]=-3.4158
MetFlux["5-methyl-THF"]=-0.66829
MetFlux["adenine"]=-0.00093523
MetFlux["adenosine"]=-0.00040792
MetFlux["ADP"]=0.0012202
MetFlux["AKG"]=-0.0015523
MetFlux["AMP"]=-0.0012202
MetFlux["CMP"]=-0.0015891
MetFlux["cytidine"]=0.0021187
MetFlux["deoxycytidine"]=0.0018937
MetFlux["deoxyuridine"]=0.0020755
MetFlux["GDP"]=0.0020071
MetFlux["GMP"]=-0.00063611
MetFlux["hypoxanthine"]=0.021934
MetFlux["inosine"]=-0.00024905
MetFlux["THF"]=0.41736
MetFlux["thymine"]=-0.000079265
MetFlux["thymidine"]=0.0015529
MetFlux["UDP"]=0.0045704
MetFlux["UMP"]=-0.0045704
MetFlux["uracil"]=-0.0084013
#MetFlux["urea"]=-2.3693
MetFlux["uridine"]=0.0068026
MetFlux["UTP"]=0.61997
#MetFlux["XTP"]=0.28912
#MetFlux["ADP-glucose"]=0.31787
MetFlux["D-glucitol"]=-0.014345

modelC=model.copy()
for met in MetFlux:
    find=0
    for m in modelC.metabolites:
        if (m.name == met and m.compartment == "s"):
            for r in m.reactions:
                if (len(r.reactants) == 0):        
                    #print(m.id+":"+m.name, r.id, r.build_reaction_string(), r.lower_bound, r.upper_bound, -MetFlux[met])
                    diff=0.1*abs(MetFlux[met])
                    r.lower_bound=MetFlux[met]-diff
                    r.upper_bound=MetFlux[met]+diff
                    find+=1
    if find == 0:
        print("no match for ",met)
modelC.reactions.biomass_components.objective_coefficient = -1
fmin=modelC.optimize()
modelC.reactions.biomass_components.objective_coefficient = 1
fmax=modelC.optimize()    
print(met,":",fmin.f,fmax.f)
# print(model.compartments)
# Out:
# no match for  adenine
# no match for  hypoxanthine
# no match for  CO2
# no match for  thymine
# no match for  uracil
# no match for  NEFA
# CMP : None None

# %%
model.reactions.biomass_components.objective_coefficient=-1
print(model.reactions.biomass_components.build_reaction_string())
print(model.reactions.biomass_components.upper_bound)
# Out:
# m01307c + m01365c + m01369c + m01370c + m01450c + m01451r + m01589c + m01602c + m01628c + m01721n + m01722n + m01974c + m01975c + m01986c + m02125c + m02184c + m02360c + m02392c + m02426c + m02471c + m02724c + m02733c + m02750c + m02770c + m02847c + m02896c + m02908c + m02993c + m03089c + m03101c + m03135c + m03161c -->
# 1000

# %%
model = cobra.io.read_sbml_model('/Users/jeremiebourdon/Downloads/liver_-_hepatocytes_2 4.xml')
model.optimize()
# Out:
# <Solution 0.00 at 0x12b04e358>

# %%
cobra.flux_analysis.flux_variability_analysis(model)
# Out:
# {'HMR_2433': {'maximum': 259.63531814505706,
#   'minimum': -2.9113443586344774e-29},
#  'HMR_3446': {'maximum': 1000.0000000000001,
#   'minimum': 1.5695121276565709e-27},
#  'HMR_4806': {'maximum': 641.0256410256414, 'minimum': -6.627231917863478e-14},
#  'HMR_2336': {'maximum': 100.1733832508143, 'minimum': -7.89654488578498e-31},
#  'HMR_1289': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3275': {'maximum': 472.768455640305, 'minimum': 0.0},
#  'HMR_1894': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2904': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6975': {'maximum': 689.704649513123, 'minimum': 0.0},
#  'HMR_6303': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0579': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5351': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_5784': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5318': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3931': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1494': {'maximum': 73.91304347826089,
#   'minimum': -5.0268793649962536e-14},
#  'HMR_3191': {'maximum': 200.4867882690664,
#   'minimum': -1.4717261136626878e-13},
#  'HMR_3307': {'maximum': 166.66666666666666, 'minimum': 0.0},
#  'HMR_9118': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0516': {'maximum': 0.4142294240892268, 'minimum': 0.0},
#  'HMR_9366': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8396': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5963': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7218': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5644': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7341': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9303': {'maximum': 0.0, 'minimum': -750.0},
#  'HMR_1186': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1496': {'maximum': 73.91304347826124, 'minimum': 0.0},
#  'HMR_5612': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4271': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0786': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7725': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5634': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1739': {'maximum': -1.591511881433391e-13, 'minimum': 0.0},
#  'HMR_5977': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3995': {'maximum': 1000.0000000000043,
#   'minimum': 1.1368683772161603e-12},
#  'HMR_4342': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8146': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5074': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7334': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9815': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6784': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7639': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6467': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5447': {'maximum': 1000.0000000000034, 'minimum': 0.0},
#  'HMR_7908': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2579': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9151': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8691': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7546': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8184': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2311': {'maximum': 999.9999999999992, 'minimum': 6.678667666438039e-31},
#  'HMR_0979': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4193': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2572': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6435': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9159': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6738': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7081': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2598': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7375': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5224': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5520': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0560': {'maximum': 130.83627253498247, 'minimum': 0.0},
#  'HMR_8497': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2945': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6642': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8026': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0160': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2365': {'maximum': 310.30321825671297, 'minimum': 0.0},
#  'HMR_0173': {'maximum': 999.9999999999995, 'minimum': -800.3524969568687},
#  'HMR_3678': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0640': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3677': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0204': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7401': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9516': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3396': {'maximum': 144.04767345858048, 'minimum': 0.0},
#  'HMR_4604': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6939': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7266': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6601': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4061': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4345': {'maximum': 0.0, 'minimum': -999.9999999999995},
#  'HMR_7713': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1105': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7267': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7997': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8208': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2998': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5907': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3802': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1277': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8434': {'maximum': 1000.0000000000047, 'minimum': 0.0},
#  'HMR_4285': {'maximum': 1000.000000000006, 'minimum': 0.0},
#  'HMR_9295': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7624': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8933': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2947': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5305': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6526': {'maximum': 500.00000000000074, 'minimum': 0.0},
#  'HMR_4786': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2342': {'maximum': 999.9999999999998, 'minimum': 0.0},
#  'HMR_9029': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3343': {'maximum': 100.00000000000036,
#   'minimum': -2.4394857548816796e-12},
#  'HMR_4176': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3675': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4065': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7002': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0909': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0368': {'maximum': 0.08758968621051294, 'minimum': 0.0},
#  'HMR_6083': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6051': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3333': {'maximum': 100.00000000000036,
#   'minimum': -2.4394857548816796e-12},
#  'HMR_6017': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7466': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6128': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3236': {'maximum': 580.0073922552128, 'minimum': -8.073969497514748e-14},
#  'HMR_4077': {'maximum': 499.9999999999958, 'minimum': 0.0},
#  'HMR_6980': {'maximum': 689.704649513123, 'minimum': 0.0},
#  'HMR_2967': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8501': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2634': {'maximum': 51.06415559576385, 'minimum': -300.72251570250125},
#  'HMR_2983': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9412': {'maximum': 0.0, 'minimum': -1000.0000000000011},
#  'HMR_0272': {'maximum': 190.14443404584154, 'minimum': 0.0},
#  'HMR_0319': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_4708': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2260': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2733': {'maximum': 349.74817425180913, 'minimum': 0.0},
#  'HMR_7169': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7955': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7799': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5430': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3701': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0196': {'maximum': 1.1368683772161603e-13, 'minimum': -1000.0},
#  'HMR_3831': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8615': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0015': {'maximum': 875.8968621051398, 'minimum': 0.0},
#  'HMR_0953': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8513': {'maximum': 0.0, 'minimum': -999.9999999999995},
#  'HMR_0610': {'maximum': 44.27031798780235, 'minimum': 8.596397481514687e-14},
#  'HMR_9297': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4949': {'maximum': 1000.0, 'minimum': -1000.0000000000061},
#  'HMR_2240': {'maximum': 199.9999999999846, 'minimum': -3.66114492269233e-15},
#  'HMR_0287': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7449': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6761': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3158': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2163': {'maximum': 200.00000000000028, 'minimum': 0.0},
#  'HMR_0438': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6157': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6508': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1239': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4526': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8784': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8800': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2736': {'maximum': 289.80856266038154, 'minimum': 0.0},
#  'HMR_5054': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8424': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4799': {'maximum': 641.0256410256466, 'minimum': 0.0},
#  'HMR_6286': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0456': {'maximum': 999.9999999999991, 'minimum': -5.435651928564766e-13},
#  'HMR_4171': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1027': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2193': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0370': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4458': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2070': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4370': {'maximum': 999.9999999999975, 'minimum': 0.0},
#  'HMR_0553': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8608': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1034': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8805': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2076': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2957': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0193': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9683': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_5717': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4519': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1535': {'maximum': 73.91304347826119, 'minimum': 0.0},
#  'HMR_8778': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6564': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7254': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6076': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0533': {'maximum': 0.4142294240892306, 'minimum': 0.0},
#  'HMR_0461': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7440': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3528': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9340': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7226': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1074': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4398': {'maximum': 1000.0, 'minimum': -999.9999999999995},
#  'HMR_8171': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7633': {'maximum': 333.3333333333505, 'minimum': 0.0},
#  'HMR_8055': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4494': {'maximum': 2.7755575615628914e-17, 'minimum': 0.0},
#  'HMR_3644': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6106': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3461': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7229': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4004': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7443': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7233': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1000': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8754': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2172': {'maximum': 200.0, 'minimum': 0.0},
#  'HMR_1279': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1260': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3105': {'maximum': 250.0, 'minimum': 0.0},
#  'HMR_0885': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2287': {'maximum': 303.48816182862663, 'minimum': 0.0},
#  'HMR_1976': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7565': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4160': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2269': {'maximum': 0.24177330687309745, 'minimum': 0.0},
#  'HMR_3096': {'maximum': 250.0, 'minimum': 0.0},
#  'HMR_6547': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9292': {'maximum': 1.2104464985895902e-08,
#   'minimum': -689.7046495131208},
#  'HMR_1451': {'maximum': 443.4782608695665, 'minimum': 3.162848653769844e-13},
#  'HMR_4979': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7800': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2032': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0963': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1067': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2025': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_5753': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7921': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7562': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7055': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9190': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1043': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2576': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6625': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1960': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0528': {'maximum': 0.4142294240892266, 'minimum': 0.0},
#  'HMR_4906': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2213': {'maximum': 111.03365690635903, 'minimum': 0.0},
#  'HMR_0225': {'maximum': 60.086524740411896, 'minimum': 0.0},
#  'HMR_7050': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6657': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0210': {'maximum': 999.9999999999998, 'minimum': 0.0},
#  'HMR_4796': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6001': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0912': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6996': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3650': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2548': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5458': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8587': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2671': {'maximum': 0.0, 'minimum': -196.09145870809812},
#  'HMR_8439': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2343': {'maximum': 999.9999999999998, 'minimum': 0.0},
#  'HMR_2526': {'maximum': 62.712718420515664,
#   'minimum': 1.4203684006852464e-17},
#  'HMR_4810': {'maximum': 641.0256410256507, 'minimum': 0.0},
#  'HMR_7080': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5754': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9254': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_9614': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2152': {'maximum': 200.00000000000028, 'minimum': 0.0},
#  'HMR_0217': {'maximum': -3.979039320256561e-12, 'minimum': -1000.0},
#  'HMR_2099': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0903': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9150': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4740': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6005': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6228': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2469': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6172': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0482': {'maximum': 583.2215299232396, 'minimum': 0.0},
#  'HMR_1094': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6477': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7273': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4907': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9115': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9360': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_9145': {'maximum': -1.1368683772161603e-12,
#   'minimum': -2.2737367544323206e-13},
#  'HMR_2921': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0297': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3017': {'maximum': 142.75754555560408,
#   'minimum': -8.193445921733655e-14},
#  'HMR_1879': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0925': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1178': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4817': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6227': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_9600': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6087': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1893': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_5946': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3727': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2362': {'maximum': 310.34193249440847, 'minimum': 0.0},
#  'HMR_0397': {'maximum': 1.1368683772161603e-13, 'minimum': -1000.0},
#  'HMR_0686': {'maximum': 1000.0, 'minimum': 1.161308137947497e-15},
#  'HMR_2505': {'maximum': 0.29704811332330844, 'minimum': 0.0},
#  'HMR_8109': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3375': {'maximum': 0.0, 'minimum': -142.75754555560502},
#  'HMR_4163': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0406': {'maximum': 1000.0000000000002, 'minimum': 0.0},
#  'HMR_8742': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4976': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3625': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8627': {'maximum': 1000.0000000000056, 'minimum': 0.0},
#  'HMR_2560': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5084': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2942': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5975': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1269': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4187': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9165': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2989': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9081': {'maximum': 0.0, 'minimum': 1.1368683772161603e-13},
#  'HMR_8385': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0524': {'maximum': 11.263077166194284,
#   'minimum': 2.5715365922179423e-30},
#  'HMR_7028': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2138': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7271': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5311': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1382': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2553': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0937': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2951': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2095': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0665': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9279': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1068': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7377': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2610': {'maximum': 171.21263712085442, 'minimum': -303.4881618288131},
#  'HMR_0188': {'maximum': 4.547473508864641e-12, 'minimum': -1000.0},
#  'HMR_2614': {'maximum': 335.1491848393109, 'minimum': -0.2970481133232852},
#  'HMR_6401': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4484': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7328': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8341': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3172': {'maximum': 1000.000000000002, 'minimum': 0.0},
#  'HMR_5790': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1742': {'maximum': -8.397398203633525e-14, 'minimum': 0.0},
#  'HMR_8761': {'maximum': 1000.0000000000018, 'minimum': 0.0},
#  'HMR_4207': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6603': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5470': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6369': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1061': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5064': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0959': {'maximum': 600.8759522893986, 'minimum': 0.0},
#  'HMR_9076': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8752': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4251': {'maximum': 4.623309984960959e-13,
#   'minimum': 1.8029207787851663e-13},
#  'HMR_7668': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2074': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2243': {'maximum': 199.9999999999846, 'minimum': -3.66114492269233e-15},
#  'HMR_7353': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8639': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1684': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1026': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1166': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5063': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4040': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3088': {'maximum': 249.56465344321077, 'minimum': 0.0},
#  'HMR_6019': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_9414': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4911': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6056': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6424': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7636': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9808': {'maximum': 866.6666666666583, 'minimum': -1000.0},
#  'HMR_7882': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4833': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4882': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_9048': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6855': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0328': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1533': {'maximum': 73.91304347826124, 'minimum': 0.0},
#  'HMR_0271': {'maximum': 2.2737367544323206e-13,
#   'minimum': -190.20027226166144},
#  'HMR_7747': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2720': {'maximum': 399.99999999999955, 'minimum': 0.0},
#  'HMR_0890': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8429': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2927': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2209': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2000': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0402': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6571': {'maximum': 42.77531015929249, 'minimum': 0.0},
#  'HMR_2157': {'maximum': 200.00000000000028, 'minimum': 0.0},
#  'HMR_4113': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3526': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3684': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0434': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5450': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4169': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2084': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2484': {'maximum': 399.9999999999997, 'minimum': 0.0},
#  'HMR_1011': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3171': {'maximum': 1000.000000000002, 'minimum': 0.0},
#  'HMR_2985': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9416': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0511': {'maximum': 0.4142294240892268, 'minimum': 0.0},
#  'HMR_5027': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2638': {'maximum': 0.0, 'minimum': -356.52781265460226},
#  'HMR_7514': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5940': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3971': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3003': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7789': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0730': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0386': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1887': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4752': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4611': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1786': {'maximum': 499.99999999999994,
#   'minimum': 1.2866400711215999e-13},
#  'HMR_4430': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3317': {'maximum': 166.66666666666666, 'minimum': 0.0},
#  'HMR_9158': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4986': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1203': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1908': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1925': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9136': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4861': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4075': {'maximum': 789.3845285149749, 'minimum': 0.0},
#  'HMR_3858': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4016': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8786': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4265': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4574': {'maximum': 1000.0, 'minimum': -1000.0000000000007},
#  'HMR_0240': {'maximum': 4.204304938104623, 'minimum': 0.0},
#  'HMR_6045': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0356': {'maximum': 0.08758968621051294, 'minimum': 0.0},
#  'HMR_8433': {'maximum': 1000.0000000000047, 'minimum': 0.0},
#  'HMR_6462': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9062': {'maximum': 19.587817843769017,
#   'minimum': -2.2737367544323206e-13},
#  'HMR_0296': {'maximum': 0.08758968621051391, 'minimum': 0.0},
#  'HMR_5624': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7417': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3240': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4068': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2755': {'maximum': -2.2737367544323206e-13,
#   'minimum': -1000.0000000000032},
#  'HMR_1437': {'maximum': 443.4782608695665, 'minimum': 3.162848653769844e-13},
#  'HMR_4510': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6570': {'maximum': 42.77531015929249, 'minimum': 0.0},
#  'HMR_8659': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7329': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0414': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6465': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6071': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0831': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4935': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0203': {'maximum': 0.08758968621051298, 'minimum': 0.0},
#  'HMR_4396': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2611': {'maximum': 236.7655238085822, 'minimum': 0.0},
#  'HMR_9214': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2264': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0648': {'maximum': 1000.0, 'minimum': 2.4293758403894088e-11},
#  'HMR_6197': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8940': {'maximum': 327.6374182647251, 'minimum': 0.0},
#  'HMR_6525': {'maximum': 999.999999999995, 'minimum': 0.0},
#  'HMR_9172': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_7286': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0446': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6492': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0838': {'maximum': 916.6666666666579, 'minimum': 0.0},
#  'HMR_9163': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4816': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0508': {'maximum': 0.4142294240892268, 'minimum': 0.0},
#  'HMR_2266': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7467': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4290': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8325': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4642': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8409': {'maximum': 500.0, 'minimum': 0.0},
#  'HMR_0660': {'maximum': 749.9999999999918, 'minimum': 0.0},
#  'HMR_5457': {'maximum': 999.9999999999955, 'minimum': 0.0},
#  'HMR_3537': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2179': {'maximum': 142.8571428571429, 'minimum': 0.0},
#  'HMR_7898': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_3342': {'maximum': 100.00000000000036,
#   'minimum': -2.4394857548816796e-12},
#  'HMR_9058': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9069': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2038': {'maximum': 999.9999999999939, 'minimum': 0.0},
#  'HMR_1549': {'maximum': 73.91304347826119, 'minimum': 0.0},
#  'HMR_8178': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2456': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3335': {'maximum': 100.00000000000036,
#   'minimum': -2.4394857548816796e-12},
#  'HMR_1177': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6999': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1901': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4474': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8803': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2132': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9040': {'maximum': 73.74237305889437, 'minimum': 0.0},
#  'HMR_2653': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6682': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0969': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7358': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5934': {'maximum': 999.9999999999943, 'minimum': 0.0},
#  'HMR_2567': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9578': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1952': {'maximum': 1000.0000000000001, 'minimum': 0.0},
#  'HMR_5131': {'maximum': 72.59014847984926, 'minimum': 0.0},
#  'HMR_8485': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6220': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0550': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6162': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3723': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1329': {'maximum': 1000.0, 'minimum': -1000.0000000000025},
#  'HMR_6217': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4338': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3708': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3465': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1568': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7357': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8066': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8206': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6122': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4060': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4485': {'maximum': 1000.0, 'minimum': -999.999999999999},
#  'HMR_6180': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0945': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9437': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0030': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4812': {'maximum': -3.410605131648481e-13,
#   'minimum': -641.0256410256372},
#  'HMR_6257': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8657': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2059': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1870': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4528': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6649': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7992': {'maximum': 789.3845285149632,
#   'minimum': -1.0880185641326534e-14},
#  'HMR_7796': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6658': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0448': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8039': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8498': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0346': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2915': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8027': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7534': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6671': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2389': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0189': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2415': {'maximum': 289.8104925469812,
#   'minimum': -2.9113443586344774e-29},
#  'HMR_4073': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0289': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2535': {'maximum': 349.7445412621249, 'minimum': 3.342296412445994e-30},
#  'HMR_3182': {'maximum': 167.28295309710464,
#   'minimum': -1.2358459901840217e-13},
#  'HMR_6901': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7489': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3312': {'maximum': 166.66666666666666, 'minimum': 0.0},
#  'HMR_7166': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9582': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8226': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7942': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8499': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6375': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8733': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0433': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5438': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6101': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3160': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5287': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7758': {'maximum': 0.0, 'minimum': -500.0000000000025},
#  'HMR_8102': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6287': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7325': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9148': {'maximum': 0.0, 'minimum': -1000.0000000000018},
#  'HMR_2236': {'maximum': 199.9999999999846, 'minimum': -3.66114492269233e-15},
#  'HMR_5929': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8149': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7884': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7044': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7488': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6748': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2905': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0187': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4456': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0607': {'maximum': 0.0, 'minimum': -44.2703179878024},
#  'HMR_8658': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5330': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1467': {'maximum': 73.91304347826066, 'minimum': 5.27141442294974e-14},
#  'HMR_4050': {'maximum': 1.1368683772161603e-12, 'minimum': -916.666666666667},
#  'HMR_2761': {'maximum': 0.0, 'minimum': -1.070421166119445},
#  'HMR_7026': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7263': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3302': {'maximum': 166.66666666666666, 'minimum': 0.0},
#  'HMR_6126': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4022': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0348': {'maximum': 487.17948717948724, 'minimum': 0.0},
#  'HMR_3001': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1927': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7394': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4802': {'maximum': 641.0256410256466, 'minimum': 0.0},
#  'HMR_6025': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_9494': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1598': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2570': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6316': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4147': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7645': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6436': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4739': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7670': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7209': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3717': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5429': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5299': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7146': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3014': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4995': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5003': {'maximum': 916.6666666666656, 'minimum': -1000.0000000000005},
#  'HMR_0008': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2876': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5349': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7574': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2194': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6185': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4282': {'maximum': 999.9999999999956, 'minimum': 0.0},
#  'HMR_7516': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8509': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3153': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0602': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8476': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7396': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6986': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0504': {'maximum': 0.4142294240892268, 'minimum': 0.0},
#  'HMR_2684': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0459': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6006': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6414': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4296': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1200': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5998': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4312': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4687': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0255': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2503': {'maximum': 0.5940962266466169, 'minimum': 0.0},
#  'HMR_2097': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9438': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_1293': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3706': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0010': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4778': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8654': {'maximum': 999.9999999999999, 'minimum': 0.0},
#  'HMR_3910': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2231': {'maximum': 199.9999999999846, 'minimum': -3.66114492269233e-15},
#  'HMR_4705': {'maximum': 1000.0000000000056, 'minimum': 0.0},
#  'HMR_4179': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8662': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_9064': {'maximum': 1000.0, 'minimum': -1000.0000000000001},
#  'HMR_6751': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6221': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3358': {'maximum': 142.75754555560496, 'minimum': 0.0},
#  'HMR_5013': {'maximum': 499.9999999999959, 'minimum': 0.0},
#  'HMR_4617': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9180': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4848': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3850': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6021': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0177': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2990': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1902': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4332': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6790': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7374': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4412': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_8031': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3763': {'maximum': 1000.0000000000039, 'minimum': 0.0},
#  'HMR_1809': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4189': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7535': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0184': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7344': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0425': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9220': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_2334': {'maximum': 100.1733832508143, 'minimum': -7.89654488578498e-31},
#  'HMR_4588': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1259': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6587': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2380': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4940': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0532': {'maximum': 0.4142294240892306, 'minimum': 0.0},
#  'HMR_4694': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7268': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6080': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6439': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4059': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4862': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0312': {'maximum': 0.6131278034735974, 'minimum': 0.0},
#  'HMR_7404': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0208': {'maximum': 0.08758968621051298, 'minimum': 0.0},
#  'HMR_2347': {'maximum': 174.0305656825311, 'minimum': 0.0},
#  'HMR_3311': {'maximum': 166.66666666666666, 'minimum': 0.0},
#  'HMR_8600': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8725': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2600': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0514': {'maximum': 0.4142294240892268, 'minimum': 0.0},
#  'HMR_4735': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3819': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7123': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6186': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0536': {'maximum': 14.426862887035355, 'minimum': 2.65727708790484e-47},
#  'HMR_4450': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6952': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6786': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9280': {'maximum': 0.0, 'minimum': -500.0},
#  'HMR_2516': {'maximum': 323.3695652173815, 'minimum': 0.0},
#  'HMR_2319': {'maximum': 1000.0, 'minimum': 1.901229031658962e-31},
#  'HMR_8529': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3015': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8596': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4926': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1271': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2509': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0373': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2551': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6205': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4145': {'maximum': 999.9999999999852, 'minimum': -1000.0},
#  'HMR_4635': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3332': {'maximum': 100.00000000000036, 'minimum': 0.0},
#  'HMR_7613': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3241': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6614': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1749': {'maximum': 8.397398203633525e-14, 'minimum': 0.0},
#  'HMR_0248': {'maximum': 90.30496648303888, 'minimum': 0.0},
#  'HMR_8411': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2350': {'maximum': 174.0305656825311, 'minimum': 0.0},
#  'HMR_3907': {'maximum': 1000.0000000000005, 'minimum': 0.0},
#  'HMR_6561': {'maximum': 43.76050444904752, 'minimum': 0.0},
#  'HMR_2982': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1862': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7116': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3510': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4716': {'maximum': 5.684341886080804e-13, 'minimum': 0.0},
#  'HMR_6507': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5961': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8384': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8051': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0851': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4846': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4422': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2417': {'maximum': 289.8104925469812,
#   'minimum': -2.9113443586344774e-29},
#  'HMR_6211': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_9364': {'maximum': 1000.0000000000412, 'minimum': -712.0573699439137},
#  'HMR_3699': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6679': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4420': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4121': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0304': {'maximum': 0.4379484310525696, 'minimum': 0.0},
#  'HMR_7385': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9047': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0416': {'maximum': 0.08758968621051393, 'minimum': 0.0},
#  'HMR_6100': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3707': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8616': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6904': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3447': {'maximum': 1000.0000000000001, 'minimum': 1.442732074593502e-26},
#  'HMR_8530': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3709': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2655': {'maximum': 1000.0, 'minimum': -1000.0000000000002},
#  'HMR_8239': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6188': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2233': {'maximum': 199.9999999999846, 'minimum': -3.66114492269233e-15},
#  'HMR_9075': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_5317': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4166': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7575': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6935': {'maximum': 875.0000000000001, 'minimum': 0.0},
#  'HMR_2930': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0770': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0531': {'maximum': 0.4142294240892306, 'minimum': 0.0},
#  'HMR_3807': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2719': {'maximum': 0.0, 'minimum': -400.0000000000123},
#  'HMR_6146': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2557': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6762': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3237': {'maximum': 580.0073922552128, 'minimum': -8.073969497514748e-14},
#  'HMR_3501': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1237': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4980': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3189': {'maximum': 200.4867882690664,
#   'minimum': -1.4717261136626878e-13},
#  'HMR_5140': {'maximum': 10.370021211407039, 'minimum': 0.0},
#  'HMR_6107': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1545': {'maximum': 73.91304347826119, 'minimum': 0.0},
#  'HMR_1250': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0400': {'maximum': 4.204304938104685, 'minimum': 0.0},
#  'HMR_6486': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3202': {'maximum': 200.4867882690664,
#   'minimum': -1.4717261136626878e-13},
#  'HMR_6069': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7277': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0944': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4539': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6014': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6277': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1718': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4693': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_2972': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8401': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9037': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1948': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7281': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7922': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7424': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5042': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0515': {'maximum': 0.4142294240892268, 'minimum': 0.0},
#  'HMR_6618': {'maximum': 3.410605131648481e-13, 'minimum': -1000.0},
#  'HMR_4956': {'maximum': 499.9999999999993, 'minimum': 0.0},
#  'HMR_1754': {'maximum': -8.397398203633525e-14, 'minimum': 0.0},
#  'HMR_1049': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9065': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_0309': {'maximum': 0.0, 'minimum': -1000.0},
#  'HMR_6674': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1570': {'maximum': 73.91304347826056, 'minimum': 0.0},
#  'HMR_0498': {'maximum': 0.4142294240892102,
#   'minimum': -6.360062206461803e-32},
#  'HMR_2992': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4425': {'maximum': 1000.0000000000007, 'minimum': 0.0},
#  'HMR_1035': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3233': {'maximum': 560.3709501096854, 'minimum': -3.569933464488565e-14},
#  'HMR_3628': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7885': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9422': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_5339': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6196': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6012': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6144': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8660': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4442': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8726': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5976': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4789': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1991': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1165': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2618': {'maximum': 0.29704811332339887, 'minimum': -335.1491848393183},
#  'HMR_7397': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8227': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0246': {'maximum': 999.9999999999998, 'minimum': 0.0},
#  'HMR_9206': {'maximum': 750.0, 'minimum': -1000.0},
#  'HMR_6040': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3427': {'maximum': 400.00000000000017, 'minimum': 0.0},
#  'HMR_6743': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8934': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6169': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7951': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6060': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7558': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4381': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6943': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4170': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4204': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0525': {'maximum': 6.933128709307535, 'minimum': 1.0581581854421627e-30},
#  'HMR_9152': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7129': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8785': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6959': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4239': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4657': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8770': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0738': {'maximum': 0.0, 'minimum': -6.148252082082132e-14},
#  'HMR_4783': {'maximum': 874.9999999999502, 'minimum': 0.0},
#  'HMR_3672': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7388': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9267': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4194': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0547': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7109': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0590': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_1599': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3729': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7000': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1585': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2112': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7240': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4546': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2457': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1244': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2466': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6065': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3735': {'maximum': 7.105427357601002e-15,
#   'minimum': 7.105427357601002e-15},
#  'HMR_6167': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8636': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2974': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2758': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6136': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8551': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_5922': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6054': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1221': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0877': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2203': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3315': {'maximum': 166.66666666666666, 'minimum': 0.0},
#  'HMR_4044': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_6383': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3132': {'maximum': 299.78592953412635, 'minimum': 0.0},
#  'HMR_0238': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6290': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4103': {'maximum': 999.9999999999841, 'minimum': 0.0},
#  'HMR_7673': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3957': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7717': {'maximum': 733.3333333333935, 'minimum': 0.0},
#  'HMR_3252': {'maximum': 356.5278126545981, 'minimum': 0.0},
#  'HMR_4599': {'maximum': 999.9999999999972, 'minimum': 0.0},
#  'HMR_2980': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8605': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6620': {'maximum': 1000.0000000000002,
#   'minimum': -1.1368683772161603e-12},
#  'HMR_3112': {'maximum': 1000.0, 'minimum': 1.1368683772161603e-13},
#  'HMR_7762': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4419': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_8277': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6302': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4487': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0342': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_0167': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2143': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9067': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_2475': {'maximum': 413.4275618374562, 'minimum': 7.284378861411511e-13},
#  'HMR_4692': {'maximum': 999.9999999999977, 'minimum': 0.0},
#  'HMR_0942': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2540': {'maximum': 289.8086439893559, 'minimum': -8.629337626089382e-31},
#  'HMR_2164': {'maximum': 200.00000000000028, 'minimum': 0.0},
#  'HMR_2142': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1833': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0540': {'maximum': 0.4142294240892319, 'minimum': 0.0},
#  'HMR_3869': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6097': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1726': {'maximum': -3.183231456205249e-12, 'minimum': -1000.0},
#  'HMR_1503': {'maximum': 73.91304347826089,
#   'minimum': -5.0268793649962536e-14},
#  'HMR_1251': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9679': {'maximum': 999.9999999999977, 'minimum': 0.0},
#  'HMR_7213': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6396': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3351': {'maximum': 100.00000000000036,
#   'minimum': -2.4394857548816796e-12},
#  'HMR_8414': {'maximum': 333.3333333325361, 'minimum': 0.0},
#  'HMR_6431': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3627': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1182': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7495': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0638': {'maximum': 698.4126984126987, 'minimum': -4.369854566074532e-12},
#  'HMR_7904': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4244': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1394': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9240': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6108': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_8076': {'maximum': 1000.0000000000002, 'minimum': 0.0},
#  'HMR_7545': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3114': {'maximum': 1000.0, 'minimum': 1.1368683772161603e-13},
#  'HMR_3364': {'maximum': 142.75754555560493, 'minimum': 0.0},
#  'HMR_7938': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3264': {'maximum': 380.3840929681561,
#   'minimum': -2.2014495485402255e-15},
#  'HMR_2575': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3626': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5397': {'maximum': 181.8181818181558,
#   'minimum': -4.2860212083959977e-13},
#  'HMR_6627': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_7478': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9432': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1290': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_4690': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4765': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0545': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6007': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1272': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1863': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6933': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3737': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0825': {'maximum': 916.6666666587751, 'minimum': 0.0},
#  'HMR_6075': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_3725': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6719': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1553': {'maximum': 73.91304347826109, 'minimum': 0.0},
#  'HMR_1543': {'maximum': 73.91304347826119, 'minimum': 0.0},
#  'HMR_7566': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5455': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_7112': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2036': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_5944': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_6089': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1274': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6059': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_3450': {'maximum': 1000.0, 'minimum': -2.7993105516909597e-27},
#  'HMR_8219': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3011': {'maximum': 249.21637619774222, 'minimum': 0.0},
#  'HMR_7300': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0996': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_2118': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_7307': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_0735': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_9809': {'maximum': 1000.0, 'minimum': -1000.0000000011466},
#  'HMR_2464': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6677': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_8687': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_9038': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_4730': {'maximum': 6.821210263296962e-13, 'minimum': 0.0},
#  'HMR_1637': {'maximum': 499.9999999999977, 'minimum': 0.0},
#  'HMR_3322': {'maximum': 166.66666666666666, 'minimum': 0.0},
#  'HMR_5987': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_6140': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_1547': {'maximum': 73.91304347826119, 'minimum': 0.0},
#  'HMR_6030': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_9317': {'maximum': 0.0, 'minimum': 0.0},
#  'HMR_1907': {'maximum': 1000.0, 'minimum': -1000.0},
#  'HMR_4185': {'maximum': 1000.0, 'minimum': 0.0},
#  'HMR_3407': {'maximum': 196.0914587080969, 'minimum': 0.0},
#  'HMR_0548': {'maximum': 1000.0, 'minimum': 2.5112446920383115e-13},
#  ...}

# %%
# Etape 3 : Extraction des enzymes régulateurs (nécessite étape 1 et 2)

def getRegulators(rates, percentage=1.1):
    regulators = dict()

    cpt=0
    for r in rates:
        if (rates.get(r)<percentage*fba):
            if (HMR_to_Ensembl.get(r)!=''):
                # print(r,':',rates.get(r)," ",genes.get(r))
                cpt=cpt+1
                l=HMR_to_Ensembl.get(r)
                if (l):
                    for i in l:
                        if (i != ''):
                            regulators[i]=1
    return regulators


def getRegulators_obsolete(rates, percentage=1.1):
    regulators = dict()

    cpt=0
    for r in rates:
        if (rates.get(r)<percentage*fba):
            if (genes.get(r)!=''):
                # print(r,':',rates.get(r)," ",genes.get(r))
                cpt=cpt+1
                l=genes.get(r).split(' ')
                for i in l:
                    if (i != ''):
                        regulators[i]=1
    return regulators

if (Param_DoReconstruction):
    regulators = getRegulators(rates, Param_Pourcentage)

# %%
# Etape 4 : récupération de la liste de gènes régulateurs
def GeneListFromEC(ecnumber):
    if (ecnumber.find('-')>0):
        cum=list()
        for i in range(1,500):
            gl=ECTCDBToEnsembl.get(ecnumber.replace('-',str(i)))
            if (gl != None and len(gl)>0):
                cum+=gl
        return cum
    else:
        gl=ECTCDBToEnsembl.get(ecnumber)
        if (gl == None):
            gl=list()
        return gl

if (Param_DoReconstruction):
    TargetGenesEnsembl=list()
    for ec in regulators:
#        TargetGenesEnsembl+=GeneListFromEC(ec.lower())
        TargetGenesEnsembl+=[ec.replace("'","%27")]
    
    TargetGenes = [EnsemblToGeneNames.get(x) for x in TargetGenesEnsembl]
    TargetGenes=list()
    for x in TargetGenesEnsembl:
        if (genelist.get(x)):
            TargetGenes.append(genelist.get(x)[0])
        else:
            eprint('Missing ',x)
    
    TargetGenes=set(TargetGenes)
    TargetGenes=list(TargetGenes)
    
    TargetGenesEnsembl=set(TargetGenesEnsembl)
    TargetGenesEnsembl=list(TargetGenesEnsembl)
    
    eprint("Target gene list size =",len(TargetGenes))
    
    fd = open(Param_TargetFilename,"w")
    for g in TargetGenes:
        fd.write(g+"\n")
    fd.close()
    fd = open(Param_TargetFilename+"_EnsemblId","w")
    for g in TargetGenesEnsembl:
        fd.write(g+"\n")
    fd.close()
# Out:
# Missing  ENSG00000123009
# Missing  ENSG00000165862
# Target gene list size = 187

# %% [markdown]
# Regulatory network reconstruction using PathwayCommons SPARQL endpoint

# %%
# Algorithms

Aliases = dict()
for g in GeneAltNameToName:
    if not Aliases.get(GeneAltNameToName.get(g)):
        Aliases[GeneAltNameToName.get(g)] = list()
    Aliases[GeneAltNameToName.get(g)].append(g)



def GetTFControllers(EnsemblId):
    commonPCPrefixes = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX taxon: <http://identifiers.org/taxonomy/>
PREFIX reactome: <http://identifiers.org/reactome/>
PREFIX release: <http://www.reactome.org/biopax/49/48887#>

PREFIX up: <http://purl.uniprot.org/core/> 
PREFIX uniprot: <http://purl.uniprot.org/uniprot/>
PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX chebi: <http://purl.obolibrary.org/obo/CHEBI_>
PREFIX obo2: <http://purl.obolibrary.org/obo#>
"""

    Request = """
SELECT ?tempReac ?type ?controlledName ?controllerName ?source WHERE{ 
    FILTER( (?controlledName = 'Transcription of %%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>)
        and (?controllerName != '%%GENETARGETNAME%%')
        and (?source != 'mirtarbase') ) .
    # ?tempReac a bp:TemplateReactionRegulation .
    # ?tempReac bp:displayName ?reacName ; 
        bp:controlled ?controlled ; 
        bp:controller ?controller ; 
        bp:controlType ?type ; 
        bp:dataSource ?source .
    # ?controlled bp:displayName ?controlledName .
    # ?controller bp:displayName ?controllerName . }
GROUP BY ?controlledName ?controllerName
"""
    RequestToBePerformed=commonPCPrefixes+Request.replace("%%GENETARGETNAME%%",EnsemblId)
    sparql = SPARQLWrapper(PC_Endpoint)
    sparql.setQuery(RequestToBePerformed)
    sparql.setReturnFormat(JSON)
    query = sparql.query().convert()
    results=list()
    listofgenes=list()
    ListBindings=query.get('results').get('bindings')
    for l in ListBindings:
        controllerName = (l.get('controllerName').get('value'))
        controlType= (l.get('type').get('value'))
        rule = controllerName+"_"+controlType+"_"+EnsemblId
        if (rule not in results):
            results.append(rule)
        if (controllerName not in listofgenes):
            listofgenes.append(controllerName)
    return results,listofgenes

def getParentGraph(l,limit=30):
    i=0
    allgenes=dict()
    for g in l:
        allgenes[g]=1
    listofrelations=list()
    unmapped=list()
    while (i<len(l) and i<limit):
        gene=l[i]
        L=Aliases.get(GeneAltNameToName.get(gene))
        relations=list()
        newgenes=list()
        for g in L:
            a,b=GetTFControllers(g)
            relations=relations+a
            newgenes=newgenes+b
        
        relations=list(set(relations))
        newgenes=list(set(newgenes))
#        relations,newgenes = GetTFControllers(GeneAltNameToName.get(gene))
        if (len(relations) == 0):
            unmapped.append(gene)
        listofrelations+=relations
        for g in newgenes:
            if (allgenes.get(g) != 1): # (g not in l):
                l.append(g)
                allgenes[g]=1
        i+=1
    return listofrelations,l,unmapped




# Improved version

def GetTFControllersList(EnsemblId):
    commonPCPrefixes = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX taxon: <http://identifiers.org/taxonomy/>
PREFIX reactome: <http://identifiers.org/reactome/>
PREFIX release: <http://www.reactome.org/biopax/49/48887#>

PREFIX up: <http://purl.uniprot.org/core/> 
PREFIX uniprot: <http://purl.uniprot.org/uniprot/>
PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX chebi: <http://purl.obolibrary.org/obo/CHEBI_>
PREFIX obo2: <http://purl.obolibrary.org/obo#>
"""
# SELECT ?tempReac ?type ?controlledName ?controllerName ?source FROM <http://PC> 

    Request = """
SELECT ?tempReac ?type ?controlledName ?controllerName ?source
WHERE{ 
    FILTER(
    ("""
    for i in range(0,len(EnsemblId)-1):
        EnsemblId[i]=EnsemblId[i].replace("'","%27")
        Request=Request+"""(?controlledName = 'Transcription of %%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>) or 
        """.replace("%%GENETARGETNAME%%",EnsemblId[i])
#        Request=Request+"""(?controllerName = '%%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>) or 
#        """.replace("%%GENETARGETNAME%%",EnsemblId[i])
#    Request=Request+"""(?controllerName = '%%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>) or 
#    """.replace("%%GENETARGETNAME%%",EnsemblId[len(EnsemblId)-1])
    Request=Request+"(?controlledName = 'Transcription of %%GENETARGETNAME%%'^^<http://www.w3.org/2001/XMLSchema#string>)".replace("%%GENETARGETNAME%%",EnsemblId[len(EnsemblId)-1])
    Request=Request+""")
        and (?source != 'mirtarbase') ) .
    # ?tempReac a bp:TemplateReactionRegulation .
    # ?tempReac bp:displayName ?reacName ; 
        bp:controlled ?controlled ; 
        bp:controller ?controller ; 
        bp:controlType ?type ; 
        bp:dataSource ?source .
    # ?controlled bp:displayName ?controlledName .
    # ?controller bp:displayName ?controllerName . }
    
GROUP BY ?controlledName ?controllerName
"""
#    print(Request)
#    RequestToBePerformed=commonPCPrefixes+Request.replace("%%GENETARGETNAME%%",EnsemblId)
    RequestToBePerformed=commonPCPrefixes+Request
    sparql = SPARQLWrapper(PC_Endpoint)
    sparql.setQuery(RequestToBePerformed)
    sparql.setReturnFormat(JSON)
    sparql.setMethod("POST")
    query = sparql.query().convert()
    results=list()
    listofgenes=list()
    ListBindings=query.get('results').get('bindings')
    for l in ListBindings:
        controllerName = (l.get('controllerName').get('value'))
        controlType= (l.get('type').get('value'))
        controlledGene=(l.get('controlledName').get('value')).replace("Transcription of ","")
        rule = controllerName+"_"+controlType +"_"+GeneAltNameToName.get(controlledGene)
        if (rule not in results):
            results.append(rule)
        if (controllerName not in listofgenes):
            listofgenes.append(controllerName)
    return results,listofgenes

# New Improved version

def GetTFControllersList(EnsemblId):
    commonPCPrefixes = """
PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
"""

    Request = """
SELECT ?tempReac ?type ?controlledName ?controllerName ?source ?controllerType ?controlledType
WHERE{ 
    FILTER (
    ("""
    for i in range(0,len(EnsemblId)-1):
        EnsemblId[i]=EnsemblId[i].replace("'","%27")
#        Request=Request+"""((?controlledName = '%%GENETARGETNAME%%'^^xsd:string) and (?controllerName != '%%GENETARGETNAME%%'^^xsd:string) ) or 
        Request=Request+"""((?controlledName = '%%GENETARGETNAME%%'^^xsd:string) ) or 
        """.replace("%%GENETARGETNAME%%",EnsemblId[i])

#    Request=Request+"((?controlledName = '%%GENETARGETNAME%%'^^xsd:string) and (?controllerName != '%%GENETARGETNAME%%'^^xsd:string) )".replace("%%GENETARGETNAME%%",EnsemblId[len(EnsemblId)-1])
    Request=Request+"((?controlledName = '%%GENETARGETNAME%%'^^xsd:string) )".replace("%%GENETARGETNAME%%",EnsemblId[len(EnsemblId)-1])
    Request=Request+""")
        and (str(?source) != \"http://pathwaycommons.org/pc2/mirtarbase\") 
        and ((str(?controlledType) = "http://www.biopax.org/release/biopax-level3.owl#Protein") or (str(?controlledType) = "http://www.biopax.org/release/biopax-level3.owl#Rna"))
        and ((str(?controllerType) = "http://www.biopax.org/release/biopax-level3.owl#Protein") or (str(?controllerType) = "http://www.biopax.org/release/biopax-level3.owl#Rna"))
) .
# ?tempReac a bp:TemplateReactionRegulation .
# ?tempReac rdf:type ?ctype ; bp:controlled ?controlled ; bp:controller ?controller ; bp:controlType ?type ; bp:dataSource ?source .
# ?controlled bp:participant ?participant ; bp:dataSource ?controlledsource .
# ?participant bp:displayName ?controlledName; rdf:type ?controlledType .
# ?controller bp:displayName ?controllerName ; rdf:type ?controllerType ; bp:dataSource ?controllersource .
}    
GROUP BY ?controlledName ?controllerName
"""
#    print(Request)
#    RequestToBePerformed=commonPCPrefixes+Request.replace("%%GENETARGETNAME%%",EnsemblId)
    RequestToBePerformed=commonPCPrefixes+Request
    sparql = SPARQLWrapper(PC_Endpoint)
    sparql.setQuery(RequestToBePerformed)
    sparql.setReturnFormat(JSON)
    sparql.setMethod("POST")
    query = sparql.query().convert()
    results=list()
    listofgenes=list()
    ListBindings=query.get('results').get('bindings')
    for l in ListBindings:
        controllerName = (l.get('controllerName').get('value')).replace(" protein","").replace(" alternative form","")
        controlType= (l.get('type').get('value'))
        controlledGene=(l.get('controlledName').get('value')).replace("Transcription of ","")
        rule = controllerName+"_"+controlType +"_"+GeneAltNameToName.get(controlledGene)
        if (rule not in results):
            results.append(rule)
        if (controllerName not in listofgenes):
            listofgenes.append(controllerName)
    return results,listofgenes


"""
PREFIX bp: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#\n"
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
CONSTRUCT {
 # ?tempReac rdf:type ?type ; bp:controlled ?controlled ; bp:controller ?controller ; bp:dataSource ?source ; bp:controlType ?controlType .
  # ?controlled a ?controlledType ; bp:displayName ?controlledName ; bp:dataSource ?controlledsource .
  # ?controller a ?controllerType ; bp:displayName ?controllerName ; bp:dataSource ?controllersource .
} WHERE{ 
  FILTER( (?controlledName = \""+TF+"\"^^xsd:string)
  && (?controllerName != \""+TF+"\"^^xsd:string)
  && (str(?source) != \"http://pathwaycommons.org/pc2/mirtarbase\") ) .
# ?tempReac a bp:TemplateReactionRegulation .
# ?tempReac rdf:type ?type ; bp:controlled ?controlled ; bp:controller ?controller ; bp:controlType ?controlType ; bp:dataSource ?source .
# ?controlled bp:participant ?participant ; bp:dataSource ?controlledsource .
# ?participant bp:displayName ?controlledName; rdf:type ?controlledType .
# ?controller bp:displayName ?controllerName ; rdf:type ?controllerType ; bp:dataSource ?controllersource .
}
"""





def getParentGraphList(l,limit=30):
    pas=50
    i=0
    allgenes=dict()
    for g in l:
        allgenes[g]=1
    listofrelations=list()
    unmapped=list()
    while (i<len(l) and i<limit):
        eprint("Treated ",i," genes, still ",(len(l)-i)," limit = ",limit)
        L=list()
        for j in range(0,pas):
            if (i+j<len(l)):
                gene=l[i+j]
                if (Aliases.get(GeneAltNameToName.get(gene)) != None):
                    L=L+Aliases.get(GeneAltNameToName.get(gene))
        relations,newgenes=GetTFControllersList(L)
        if (len(relations) == 0):
            unmapped.append(gene)
        listofrelations+=relations
        for g in newgenes:
            g=GeneAltNameToName.get(g)
            if (g not in l): #(allgenes.get(g) != 1): # 
                l.append(g)
                allgenes[g]=1
        i+=pas
    return listofrelations,l,unmapped

# %%
eprint("Entering : RRG reconstruction")


## DEBUG ONLY
begin = timer()
## END DEBUG ONLY

if (Param_DoReconstruction):
    TargetGenesName = TargetGenes #[EnsemblToGeneNames.get(x) for x in TargetGenes if (len(x) > 2)]
    
    a,b,u=getParentGraphList(TargetGenesName,50000)
    
    ## DEBUG ONLY
    end = timer()
    eprint("Execution time for RRG reconstruction = ",end-begin,"seconds")
    ## END DEBUG ONLY
    
    eprint('Reconstructed graph contains',len(b),'genes,',len(a),'interactions')
    
    
    # write the file for compatibility purpose
    
    fd = open(Param_RRGFilename,"w")
    for r in a:
        relation=r.split("_")
#        if (relation[1] != "ACTIVATION"):
#        eprint(relation)
        fd.write(relation[0]+";"+relation[2]+"\n")
    fd.close()
# Out:
# Entering : RRG reconstruction
# Treated  0  genes, still  187  limit =  50000
# Treated  50  genes, still  251  limit =  50000
# Treated  100  genes, still  223  limit =  50000
# Treated  150  genes, still  194  limit =  50000
# Treated  200  genes, still  180  limit =  50000
# Treated  250  genes, still  148  limit =  50000
# Treated  300  genes, still  103  limit =  50000
# Treated  350  genes, still  54  limit =  50000
# Treated  400  genes, still  7  limit =  50000
# Execution time for RRG reconstruction =  48.604320397018455 seconds
# Reconstructed graph contains 408 genes, 4200 interactions

# %%
endtotal = timer()
eprint("Execution completed in",endtotal-begintotal,"seconds")
# Out:
# Execution completed in 143.61783465501503 seconds

# %%
tg = Allmeds.get(Param_Drug).get('TargetsGenes')

# %%
possibleTargets=dict()
for m in Allmeds:
    tg = Allmeds.get(m).get('TargetsGenes')
    malist = [GeneAltNameToName.get(x) for x in b if GeneAltNameToName.get(x) in tg]
    for g in malist:
        if not possibleTargets.get(g):
            possibleTargets[g]=list()
        possibleTargets[g].append(m)
#    if (len(malist)>0):
#        print(m,malist)

# %%
possibleTargets
# Out:
# {'CEL': ['Xenical (TN)'],
#  'DGAT1': ['Pradigastat sodium (USAN)', 'Pradigastat (USAN)'],
#  'IFNG': ['Fontolizumab (USAN/INN)'],
#  'IL1B': ['Ilaris (TN)', 'Gevokizumab (USAN/INN)'],
#  'NPC1L1': ['Zetia (TN)'],
#  'NR1H4': ['Turofexorate isopropyl (USAN/INN)', 'Ocaliva (TN)', 'Chenix (TN)'],
#  'NR3C1': ['Nasacort (TN)',
#   'Efficort (TN)',
#   'Dermatop (TN)',
#   'Cloderm (TN)',
#   'Fluprednisolone valerate (USAN)',
#   'Cyclocort (TN)',
#   'Decoderm (TN)',
#   'Advantan (TN)',
#   'Zalucs (TN)',
#   'Fluocortolone caproate (USAN)',
#   'Flunisolide acetate (USAN)',
#   'Santeson (TN)',
#   'Decadron-phosphate (TN)',
#   'Voren [veterinary] (TN)',
#   'Fluocortin (INN)',
#   'Meprednisone (USP/INN)',
#   'Cordran (TN)',
#   'Hydrocortone phosphate (TN)',
#   'Kohakusanin (TN)',
#   'Rinderon-DP (TN)',
#   'Dexamedium [veterinary] (TN)',
#   'Vexol (TN)',
#   'Flumetasone (INN)',
#   'Pandel (TN)',
#   'Diflucortolone (USAN)',
#   'Prednylidene (INN)',
#   'Fosdagrocorat (USAN/INN)',
#   'Afusona (TN)',
#   'Locorten (TN)',
#   'Haldrone (TN)',
#   'Durezol (TN)',
#   'Cortodoxone (USAN)',
#   'Clobecort Amex (TN)',
#   'Cortifoam (TN)',
#   'Sintisone (TN)',
#   'Triamcinolone acetonide sodium phosphate (USAN)',
#   'Halometasone (INN)',
#   'Clocortolone acetate (USAN)',
#   'Elocon (TN)',
#   'Prednisolone succinate (JP17)',
#   'Pediapred (TN)',
#   'Mapracorat (USAN)',
#   'Florinef acetate (TN)',
#   'Limethason (TN)',
#   'Pred forte (TN)',
#   'Maxidex (TN)',
#   'Murode (TN)',
#   'HMS (TN)',
#   'Decaject-L.A. (TN)',
#   'Farnerate (TN)',
#   'Dexamethasone acefurate (USAN/INN)',
#   'Voalla ointment (TN)',
#   'Cortivazol (USAN)',
#   'Halobetasol',
#   'Dexamethasone cipecilate (JAN/INN)',
#   'Dagrocorat (USAN/INN)',
#   'Topicort (TN)',
#   'Aclovate (TN)',
#   'Alclometasone (INN)',
#   'Loteprednol (INN)',
#   'Celestone (TN)',
#   'Vanceril (TN)',
#   'Synalar (TN)',
#   'Vanos (TN)',
#   'Hifmeta (TN)',
#   'Flarex (TN)',
#   'Alphadrol (TN)',
#   'Plenadren (TN)',
#   'Hydrocortisone hemisuccinate (USP)',
#   'Delta-cortef (TN)',
#   'Rayos (TN)',
#   'Diflucortolone pivalate (USAN)',
#   'Nasalide (TN)',
#   'Fluocortin butyl (USAN)',
#   'Lotemax (TN)',
#   'Halopredone (INN)',
#   'Resocortol (INN)',
#   'Cloradryn (TN)',
#   'Methylprednisolone sodium phosphate (USAN)',
#   'Resocortol butyrate (USAN)',
#   'Solu-medrol (TN)',
#   'Ultracortenol (TN)',
#   'Beclometason (TN)',
#   'Dillar (TN)',
#   'Fluprednidene (INN)',
#   'Omnaris (TN)',
#   'Medrol (TN)',
#   'Psorcon (TN)',
#   'Ultradil (TN)',
#   'Aristospan (TN)',
#   'Clobetasone (INN)',
#   'Methylprednisolone succinate (JP17)',
#   'Deflazacort (USAN/INN)',
#   'Flovent (TN)',
#   'Dexamethasone beloxil (USAN)',
#   'Uticort (TN)',
#   'Tixocortol pivalate (USAN)',
#   'Cortisone (TN)',
#   'Spirazon (TN)',
#   'Cortone acetate (TN)',
#   'Aristocort (TN)',
#   'Oxylone (TN)',
#   'Hydrocortisone cypionate',
#   'Westcort (TN)',
#   'Kindavate (TN)',
#   'Mometasone (INN)',
#   'Veramyst (TN)',
#   'Delvosteron [veterinary] (TN)',
#   'Betamethasone acetate (JAN/USP)',
#   'Hydrocortisone succinate (JP17)',
#   'Fluocortolone (USAN/INN)',
#   'Astonin-H (TN)',
#   'Antebate (TN)',
#   'Rinderon-V (TN)',
#   'Decadronal (TN)',
#   'Nasonex (TN)',
#   'Depo-medrol (TN)',
#   'Colircusi Dexametasona (TN)',
#   'Uceris (TN)',
#   'Fluticaps (TN)',
#   'Kenacort (TN)',
#   'Hydeltra-TBA (TN)',
#   'Ultravate (TN)',
#   'Solu-cortef (TN)',
#   'Verdeso (TN)',
#   'Prednisone 21-acetate',
#   'Olux (TN)',
#   'Fluclorolone acetonide (INN)',
#   'Clocortolone (INN)',
#   'Haloart (TN)',
#   'Deflamene (TN)',
#   'Predenema (TN)',
#   'Locoid (TN)',
#   'Hydrocortisone caproate (JAN)',
#   'Tixocortol (INN)',
#   'Methylprednisolone suleptanate (USAN/INN)',
#   'Dexafort [veterinary] (TN)',
#   'Fenicort (TN)'],
#  'PARP1': ['Rucaparib phosphate (USAN)',
#   'Talazoparib (USAN/INN)',
#   'Niraparib (USAN)',
#   'Veliparib (USAN/INN)',
#   'Rubraca (TN)',
#   'Lynparza (TN)',
#   'Iniparib (USAN/INN)',
#   'Talazoparib tosylate (USAN)'],
#  'PNLIP': ['Xenical (TN)'],
#  'SLC22A1': ['Eloxatin (TN)', 'Metformin (USAN/INN)', 'Glucophage (TN)'],
#  'SP1': ['Terameprocol (INN/USAN)'],
#  'STAT3': ['Napabucasin (JAN/USAN/INN)'],
#  'TNF': ['Ozoralizumab (USAN)',
#   'Enbrel (TN)',
#   'Lenercept (USAN/INN)',
#   'Placulumab (USAN/INN)',
#   'Humira (TN)',
#   'Onercept (USAN/INN)',
#   'Nerelimomab (USAN/INN)',
#   'Afelimomab (INN)',
#   'Simponi (TN)',
#   'Pegsunercept (USAN)',
#   'Revlimid (TN)',
#   'Cimzia (TN)',
#   'Remicade (TN)'],
#  'TP53': ['Cenersen sodium (USAN)']}

# %%
import json
with open("../tmp/PossibleTargets.json", 'w') as outfile:
    json.dump(possibleTargets, outfile)

# %%
ListReg=list()
for g in regulators:
    if (EnsemblToGeneNamesList.get(g) != None):
        ListReg=ListReg+EnsemblToGeneNamesList.get(g)

# %%
len(ListReg)
# Out:
# 194

# %%
possibleTargetsAvant=dict()
for m in Allmeds:
    tg = Allmeds.get(m).get('TargetsGenes')
    malist = [GeneAltNameToName.get(x) for x in ListReg if GeneAltNameToName.get(x) in tg]
    for g in malist:
        if not possibleTargetsAvant.get(g):
            possibleTargetsAvant[g]=list()
        possibleTargetsAvant[g].append(m)

# %%
possibleTargetsAvant
# Out:
# {'CEL': ['Xenical (TN)'],
#  'DGAT1': ['Pradigastat sodium (USAN)', 'Pradigastat (USAN)'],
#  'NPC1L1': ['Zetia (TN)'],
#  'PNLIP': ['Xenical (TN)'],
#  'SLC22A1': ['Eloxatin (TN)', 'Metformin (USAN/INN)', 'Glucophage (TN)']}

# %%
len(b)
# Out:
# 408

# %%
len(a)
# Out:
# 4200

# %%
len(possibleTargets)
# Out:
# 14

# %%
len(possibleTargetsAvant)
# Out:
# 5

# %%
len(possibleTargets)
# Out:
# 193

# %%
Drugs=list()
for t in possibleTargets:
    lg=possibleTargets.get(t)
    for g in lg:
        Drugs.append(g)
        
Drugs=list(set(Drugs))

# %%
len(Drugs)
# Out:
# 175

# %%
import networkx as nx

G=nx.DiGraph()

# %%
for i in a:
    source,typ,target=i.split("_")
    G.add_edge(source,target)

# %%
len(G.nodes())
# Out:
# 375

# %%
len(G.edges())
# Out:
# 4200

# %%
GT=nx.algorithms.tree.greedy_branching(G)

# %%
len(GT.edges())
# Out:
# 320

# %%
L=list()
for g in possibleTargets:
    L.append(g)
#L=['STAT3']
L=L+nx.algorithms.node_boundary(G,L)

# %%
G2=G.copy()

# %%
G2.remove_nodes_from(n for n in G.nodes() if n not in L)

# %%
len(G2.edges())
# Out:
# 2082

# %%
len(G2.nodes())
# Out:
# 186

# %%
len(list(set(G2.nodes())))
# Out:
# 186

# %%
GenesCibles=list()
for e in regulators:
    LR=EnsemblToGeneNamesList.get(e)
    if (LR != None):
        GenesCibles=GenesCibles+LR

len(GenesCibles)
# Out:
# 193

# %%
len(list(set(GenesCibles+G2.nodes())))
# Out:
# 319

# %%
G2.in_degree()
# Out:
# {'ABCD1': 7,
#  'ACADSB': 6,
#  'ACSL5': 9,
#  'AGPAT1': 13,
#  'AGPAT2': 2,
#  'AGPAT3': 1,
#  'AHR': 5,
#  'AR': 5,
#  'ATF2': 6,
#  'ATF3': 14,
#  'ATF4': 10,
#  'BACH2': 9,
#  'BRIP1': 14,
#  'CAT': 1,
#  'CBFA2T3': 10,
#  'CD36': 11,
#  'CDIPT': 3,
#  'CEBPA': 4,
#  'CEBPB': 12,
#  'CEL': 2,
#  'CPT1A': 4,
#  'CPT1B': 3,
#  'CPT2': 3,
#  'CRAT': 6,
#  'CREB1': 9,
#  'CUX1': 5,
#  'DAGLA': 6,
#  'DBP': 9,
#  'DDIT3': 19,
#  'E2F1': 14,
#  'E4F1': 5,
#  'EBF2': 24,
#  'ECH1': 3,
#  'EGR1': 18,
#  'EGR2': 27,
#  'EGR3': 25,
#  'ELK1': 3,
#  'ELOVL1': 6,
#  'ELOVL4': 5,
#  'ELOVL6': 14,
#  'EN1': 28,
#  'EP300': 17,
#  'ESR1': 15,
#  'ESRRA': 22,
#  'ETS1': 11,
#  'ETV4': 22,
#  'FABP3': 3,
#  'FABP4': 11,
#  'FABP6': 1,
#  'FGF10': 17,
#  'FOXA1': 23,
#  'FOXA2': 11,
#  'FOXC1': 1,
#  'FOXD3': 28,
#  'FOXF2': 10,
#  'FOXJ2': 4,
#  'FOXM1': 11,
#  'FOXO3': 15,
#  'FOXO4': 11,
#  'GATA3': 13,
#  'GATA4': 12,
#  'GATA6': 11,
#  'GOT2': 2,
#  'GPAT4': 3,
#  'GYS1': 4,
#  'HADH': 3,
#  'HIF1A': 13,
#  'HMGA1': 16,
#  'HNF4A': 7,
#  'HOXA3': 50,
#  'HOXA4': 17,
#  'HOXA5': 19,
#  'HOXA9': 19,
#  'HSF2': 6,
#  'IFNG': 2,
#  'IL10': 36,
#  'IL1B': 1,
#  'IRF1': 5,
#  'JDP2': 5,
#  'JUN': 8,
#  'KLF12': 30,
#  'LEF1': 11,
#  'LHX3': 5,
#  'MAF': 21,
#  'MAFA': 3,
#  'MAX': 8,
#  'MAZ': 8,
#  'MECOM': 17,
#  'MEIS1': 20,
#  'MOGAT3': 2,
#  'MSX1': 16,
#  'MYB': 15,
#  'MYC': 12,
#  'MYCBP': 5,
#  'MYOG': 5,
#  'NCOA3': 7,
#  'NFE2L1': 14,
#  'NFIL3': 15,
#  'NHLH1': 5,
#  'NKX2-1': 31,
#  'NME5': 2,
#  'NME7': 5,
#  'NOG': 21,
#  'NR1H4': 2,
#  'NR2F2': 26,
#  'NR3C1': 9,
#  'NR6A1': 20,
#  'ONECUT1': 8,
#  'PARP1': 1,
#  'PAX2': 21,
#  'PAX3': 17,
#  'PAX6': 33,
#  'PAX8': 8,
#  'PBX1': 13,
#  'PGR': 2,
#  'PITX2': 41,
#  'PKMYT1': 19,
#  'PLPP3': 6,
#  'PNLIP': 1,
#  'PNPLA2': 8,
#  'PNPLA3': 5,
#  'POU2F1': 20,
#  'POU3F1': 4,
#  'POU3F2': 10,
#  'PPARA': 4,
#  'PPP1R3B': 3,
#  'PPP1R3C': 7,
#  'PRUNE1': 8,
#  'REL': 6,
#  'RELA': 14,
#  'REPIN1': 5,
#  'RFX1': 9,
#  'RORA': 20,
#  'RREB1': 22,
#  'RXRB': 13,
#  'SCD': 7,
#  'SFI1': 3,
#  'SGMS1': 3,
#  'SGMS2': 4,
#  'SIRT1': 6,
#  'SLC16A1': 3,
#  'SLC25A20': 2,
#  'SLC25A29': 1,
#  'SLC27A1': 2,
#  'SLC27A2': 1,
#  'SLC27A3': 2,
#  'SLC36A1': 3,
#  'SLC43A1': 5,
#  'SLC43A2': 5,
#  'SLC7A1': 7,
#  'SLC7A2': 1,
#  'SLC7A3': 6,
#  'SLC7A7': 4,
#  'SLC7A8': 9,
#  'SMAD1': 15,
#  'SMAD3': 5,
#  'SNAI1': 5,
#  'SOX5': 38,
#  'SOX9': 6,
#  'SP1': 0,
#  'SP3': 13,
#  'SPTLC2': 7,
#  'SRF': 9,
#  'STAT1': 4,
#  'STAT3': 21,
#  'STAT5B': 13,
#  'TCF12': 21,
#  'TCF7L2': 40,
#  'TEAD1': 12,
#  'TEF': 13,
#  'TFAP2A': 6,
#  'TFAP2C': 11,
#  'TFAP4': 26,
#  'TFCP2': 5,
#  'TFDP2': 26,
#  'TLX2': 6,
#  'TNF': 9,
#  'TP53': 16,
#  'TRAF4': 26,
#  'UBP1': 2,
#  'YY1': 4,
#  'ZBTB18': 34,
#  'ZEB1': 11,
#  'ZHX2': 32,
#  'ZIC1': 28,
#  'ZIC2': 16}
